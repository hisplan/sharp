# %%
import os
import glob
import yaml
import pandas as pd

# %% [markdown]
# # Glob

# %%
dirs = glob.glob('./data/*/*')
dirs = list(filter(lambda f: os.path.isdir(f), dirs))

# %%
dirs
# Out:
# ['./data/1472_PBMC_v2_Meth_Hash_2_ADT/f86f455a-6167-4536-8cf7-d10f70db8ebe',
#  './data/1472_PBMC_v2_Meth_Hash_2_ADT/92837dfc-b84d-44ae-a225-feb125b9dff3',
#  './data/1800_MCMV_NK_CD8_TimeCourse_HTO_2/6276bd06-3ab4-420c-96d1-8a9053195726',
#  './data/1800_MCMV_NK_CD8_TimeCourse_HTO_2/19b6ca40-8f8e-497e-9cbb-6a96779910f9',
#  './data/1799_GH1529_HTO/7b4600c0-8651-460f-b773-14829ecf14fc',
#  './data/1973_HD1915_7xNK_FB_HTO/2dcd802e-a443-4b13-be71-f0468ddff8df',
#  './data/1973_HD1915_7xNK_FB_HTO/73cab1fb-c253-4c1a-ac27-e1044a9c7202',
#  './data/1973_HD1915_7xNK_FB_HTO/ab03bbd7-3930-49ee-8679-aad709d632bb',
#  './data/1573_KP1097_HTO/2ac79996-86ca-4306-a78a-33d39c8e7589',
#  './data/1625_A_mScarletOVA_HTO/e176f0d1-0abf-4dd0-b6cf-8eb0fc3f7518',
#  './data/1625_A_mScarletOVA_HTO/9c45f76f-2003-4d08-bbda-7feea71bb36f',
#  './data/1740_Preclinical_SP_batch1_HTO/6dfbeaa3-5487-467a-bddd-8d6865e3a157',
#  './data/1496_A_Y_SPCCRE_LUAD_HTO/bea04bc2-1604-44e3-9a5c-e4602378e8e8',
#  './data/1712_Y_mScarlet_HTO/f5ce1691-f1b4-4e92-bee0-744e29c10caf',
#  './data/1712_Y_mScarlet_HTO/12fdc08f-7572-4c14-87a0-179474c935a2',
#  './data/1937_AireRORc_HTO/a08a3170-fd36-4cfd-bda9-079c999cce7b',
#  './data/1054_Ay_ova_HTO/68687f04-d983-44db-9489-afc21a65b989',
#  './data/1741_Preclinical_DP_batch1_HTO/173ebedd-3b99-4a6b-9e10-e6ccf6e32f7a',
#  './data/1939_071320_A_Y_LUAD_HTO/f2fb0945-c899-4674-9e5b-ea0d8e4f8e0c',
#  './data/1713_A_mScarlet_HTO/eea46ef6-e458-4184-ad2c-e7b35ff7161e',
#  './data/1713_A_mScarlet_HTO/a15732a0-86e7-481d-82e9-58521e3a6604',
#  './data/1823_PDX_3_1_HTO/67c7c4db-b739-44d9-94f1-7d4c7ccb0b2b',
#  './data/1823_PDX_3_1_HTO/5964c0db-c689-421b-b972-40c93058712b',
#  './data/1469_TGFb_LCC-TRL_1_HTO/d5cfd38b-aeb2-489b-b01f-12fb8677b531',
#  './data/IL10pos/47080814-0fe7-458d-9edb-5e3cb86bf870',
#  './data/923_GH1344_GH1676_transplant_HTO/10303615-8412-47f7-acb4-9b2540149356',
#  './data/972_YY1017_YY1021_HTO/6807fd2b-28e9-41c8-9428-169f96bff0d5',
#  './data/1455/umis',
#  './data/1455/dask-worker-space',
#  './data/1972_NYBC265_7xNK_FB_HTO/d119f5d8-1470-4e53-905d-f81eab06b646',
#  './data/1972_NYBC265_7xNK_FB_HTO/75acc16c-f755-4a17-83dd-4091f93b0b4c',
#  './data/1972_NYBC265_7xNK_FB_HTO/73f175e9-afab-4a1e-8463-581edd1b2098',
#  './data/1454_080119_CAFPDPN-HTO/bb0ab5b9-cb21-457e-83a7-a031082f91be',
#  './data/1455_TGFb_LCC-TRL_3_HTO/2d809f63-713c-4edc-9093-2b0e9a5ff946',
#  './data/1626_BmTreg_HTO/36f39f48-0503-4ab7-b8db-f2fd35a7f4fd',
#  './data/1978_Adeno_fixed_InDrop2_HTO/eba48452-a3f7-4b4a-b4fa-7315b53be1f0',
#  './data/1978_Adeno_fixed_InDrop2_HTO/33743e28-4ef9-4356-b2ff-5a4a31ce57aa',
#  './data/1978_Adeno_fixed_InDrop2_HTO/27a9e78e-1d2d-4975-9f46-c8a36b05b09a',
#  './data/1978_Adeno_fixed_InDrop2_HTO/f8feeeda-e988-4f13-aba3-f75606e294b1',
#  './data/1780_PDX_2_1_HTO/8375a3e0-b4f6-4f81-8413-7867102aff86',
#  './data/971_YY1010_YY1024_HTO/d63f9b44-84cb-4dbd-9e72-9777625a3625',
#  './data/1905_shK_060120_HTO/b7fa5760-a2f1-4b3a-bbcd-eb2064165cd5',
#  './data/1687_LX33_1_4_1_HTO/b4a27cc5-9b8f-49f8-830e-1a65a477c8c1',
#  './data/1624_Y_mScarletOVA_HTO/dbdfdd6c-2091-42ea-9e08-b9fda5bd7280',
#  './data/1624_Y_mScarletOVA_HTO/bf69eda8-1437-4cc2-aae7-1550f63a8fcd',
#  './data/1470_TGFb_LCC-TRL_2_HTO/c8efcfc7-4592-4ed0-ab97-1293b79b2f7b',
#  './data/1940_071020_A_YLUAD_HTO/f03fd2c9-b5ae-490f-967c-1b274ebd7bde',
#  './data/1906_shK_052720_HTO/40f73699-d303-40c3-99da-5ecab92d5f42',
#  './data/1471_062719TregPDPN_HTO/831880af-6503-49e0-b42f-e318a37e3a8a',
#  './data/1237_Veh_HTO_2_rerun/7ed21cdd-dd86-4e64-a004-c7eb7f761651',
#  './data/1904_C7_cond_1_HTO/08778704-c763-4145-a951-b8af53cc45cc',
#  './data/1238_Lgk_HTO_2_rerun/54cdfdbb-6190-4f74-aa83-0ad02da44a25',
#  './data/1798_SM8822_HTO/7417f0eb-4d29-4d75-abfa-32e04cdd8665']

# %% [markdown]
# # Load Reports

# %%
def load_report(path_data):
    with open(os.path.join(path_data, "report/run_report.yaml"), "rt") as fin:
        # report file contains tabs
#         report = yaml.load(fin, Loader=yaml.FullLoader)        
        report = fin.read().replace("\t", "  ")
        report = yaml.load(report, Loader=yaml.FullLoader)
        return report

# %%
reports = {}

for path_data in dirs:
    try:
        report = load_report(path_data)
        title = "/".join(path_data.replace("./data/", "").split("/")[0:2])
        reports[title] = report
    except Exception as ex:
        print(ex)
# Out:
# [Errno 2] No such file or directory: './data/1455/umis/report/run_report.yaml'
# [Errno 2] No such file or directory: './data/1455/dask-worker-space/report/run_report.yaml'

# %%
yaml.__version__
# Out:
# '5.3.1'

# %%
reports.keys()
# Out:
4a-b4fa-7315b53be1f0', '1978_Adeno_fixed_InDrop2_HTO/33743e28-4ef9-4356-b2ff-5a4a31ce57aa', '1978_Adeno_fixed_InDrop2_HTO/27a9e78e-1d2d-4975-9f46-c8a36b05b09a', '1978_Adeno_fixed_InDrop2_HTO/f8feeeda-e988-4f13-aba3-f75606e294b1', '1780_PDX_2_1_HTO/8375a3e0-b4f6-4f81-8413-7867102aff86', '971_YY1010_YY1024_HTO/d63f9b44-84cb-4dbd-9e72-9777625a3625', '1905_shK_060120_HTO/b7fa5760-a2f1-4b3a-bbcd-eb2064165cd5', '1687_LX33_1_4_1_HTO/b4a27cc5-9b8f-49f8-830e-1a65a477c8c1', '1624_Y_mScarletOVA_HTO/dbdfdd6c-2091-42ea-9e08-b9fda5bd7280', '1624_Y_mScarletOVA_HTO/bf69eda8-1437-4cc2-aae7-1550f63a8fcd', '1470_TGFb_LCC-TRL_2_HTO/c8efcfc7-4592-4ed0-ab97-1293b79b2f7b', '1940_071020_A_YLUAD_HTO/f03fd2c9-b5ae-490f-967c-1b274ebd7bde', '1906_shK_052720_HTO/40f73699-d303-40c3-99da-5ecab92d5f42', '1471_062719TregPDPN_HTO/831880af-6503-49e0-b42f-e318a37e3a8a', '1237_Veh_HTO_2_rerun/7ed21cdd-dd86-4e64-a004-c7eb7f761651', '1904_C7_cond_1_HTO/08778704-c763-4145-a951-b8af53cc45cc', '1238_Lgk_HTO_2_rerun/54cdfdbb-6190-4f74-aa83-0ad02da44a25', '1798_SM8822_HTO/7417f0eb-4d29-4d75-abfa-32e04cdd8665'])

# %%
reports["1472_PBMC_v2_Meth_Hash_2_ADT/f86f455a-6167-4536-8cf7-d10f70db8ebe"]
# Out:
# {'Date': datetime.date(2020, 7, 17),
#  'Running time': '1.0 hour, 16.0 minutes, 47.85 seconds',
#  'CITE-seq-Count Version': '1.4.3',
#  'Reads processed': 75775940,
#  'Percentage mapped': 98,
#  'Percentage unmapped': 2,
#  'Uncorrected cells': 355,
#  'Correction': {'Cell barcodes collapsing threshold': 1,
#   'Cell barcodes corrected': 125444,
#   'UMI collapsing threshold': 1,
#   'UMIs corrected': 4825424},
#  'Run parameters': {'Read1_filename': '/cromwell_root/dp-lab-batch/cromwell-execution/Sharp/f86f455a-6167-4536-8cf7-d10f70db8ebe/call-TrimR1/R1.fastq.gz',
#   'Read2_filename': '/cromwell_root/dp-lab-batch/cromwell-execution/Sharp/f86f455a-6167-4536-8cf7-d10f70db8ebe/call-TrimR2/R2.fastq.gz',
#   'Cell barcode': {'First position': 1, 'Last position': 16},
#   'UMI barcode': {'First position': 17, 'Last position': 26},
#   'Expected cells': 0,
#   'Tags max errors': 2,
#   'Start trim': 1}}

# %%
rows = []
for name, report in reports.items():
    title, guid = name.split("/")
    rows.append(
        (
            title,
            guid,
            report["Percentage mapped"],
            report["Correction"]["Cell barcodes corrected"],
            report["Correction"]["UMIs corrected"],
            report["Run parameters"]["Tags max errors"],
            report["Reads processed"]
        )
    )

# %%
df = pd.DataFrame(
    rows,
    columns=["title", "guid", "mapping_rate", "umi_corrected", "cb_corrected", "tag_max_error", "reads"],
)
# df.set_index("title", inplace=True)
df.sort_values(["cb_corrected", "umi_corrected"], ascending=False, inplace=True)
df
# Out:
#                                 title                                  guid  \
# 33       1978_Adeno_fixed_InDrop2_HTO  eba48452-a3f7-4b4a-b4fa-7315b53be1f0
# 34       1978_Adeno_fixed_InDrop2_HTO  33743e28-4ef9-4356-b2ff-5a4a31ce57aa
# 36       1978_Adeno_fixed_InDrop2_HTO  f8feeeda-e988-4f13-aba3-f75606e294b1
# 21                   1823_PDX_3_1_HTO  67c7c4db-b739-44d9-94f1-7d4c7ccb0b2b
# 40                1687_LX33_1_4_1_HTO  b4a27cc5-9b8f-49f8-830e-1a65a477c8c1
# 1        1472_PBMC_v2_Meth_Hash_2_ADT  92837dfc-b84d-44ae-a225-feb125b9dff3
# 0        1472_PBMC_v2_Meth_Hash_2_ADT  f86f455a-6167-4536-8cf7-d10f70db8ebe
# 4                     1799_GH1529_HTO  7b4600c0-8651-460f-b773-14829ecf14fc
# 50                    1798_SM8822_HTO  7417f0eb-4d29-4d75-abfa-32e04cdd8665
# 16                    1054_Ay_ova_HTO  68687f04-d983-44db-9489-afc21a65b989
# 25   923_GH1344_GH1676_transplant_HTO  10303615-8412-47f7-acb4-9b2540149356
# 18           1939_071320_A_Y_LUAD_HTO  f2fb0945-c899-4674-9e5b-ea0d8e4f8e0c
# 48                 1904_C7_cond_1_HTO  08778704-c763-4145-a951-b8af53cc45cc
# 44            1940_071020_A_YLUAD_HTO  f03fd2c9-b5ae-490f-967c-1b274ebd7bde
# 10             1625_A_mScarletOVA_HTO  9c45f76f-2003-4d08-bbda-7feea71bb36f
# 2   1800_MCMV_NK_CD8_TimeCourse_HTO_2  6276bd06-3ab4-420c-96d1-8a9053195726
# 39                1905_shK_060120_HTO  b7fa5760-a2f1-4b3a-bbcd-eb2064165cd5
# 41             1624_Y_mScarletOVA_HTO  dbdfdd6c-2091-42ea-9e08-b9fda5bd7280
# 45                1906_shK_052720_HTO  40f73699-d303-40c3-99da-5ecab92d5f42
# 49               1238_Lgk_HTO_2_rerun  54cdfdbb-6190-4f74-aa83-0ad02da44a25
# 20                1713_A_mScarlet_HTO  a15732a0-86e7-481d-82e9-58521e3a6604
# 23            1469_TGFb_LCC-TRL_1_HTO  d5cfd38b-aeb2-489b-b01f-12fb8677b531
# 43            1470_TGFb_LCC-TRL_2_HTO  c8efcfc7-4592-4ed0-ab97-1293b79b2f7b
# 46            1471_062719TregPDPN_HTO  831880af-6503-49e0-b42f-e318a37e3a8a
# 38              971_YY1010_YY1024_HTO  d63f9b44-84cb-4dbd-9e72-9777625a3625
# 24                            IL10pos  47080814-0fe7-458d-9edb-5e3cb86bf870
# 32                    1626_BmTreg_HTO  36f39f48-0503-4ab7-b8db-f2fd35a7f4fd
# 12           1496_A_Y_SPCCRE_LUAD_HTO  bea04bc2-1604-44e3-9a5c-e4602378e8e8
# 13                1712_Y_mScarlet_HTO  f5ce1691-f1b4-4e92-bee0-744e29c10caf
# 47               1237_Veh_HTO_2_rerun  7ed21cdd-dd86-4e64-a004-c7eb7f761651
# 8                     1573_KP1097_HTO  2ac79996-86ca-4306-a78a-33d39c8e7589
# 30            1454_080119_CAFPDPN-HTO  bb0ab5b9-cb21-457e-83a7-a031082f91be
# 31            1455_TGFb_LCC-TRL_3_HTO  2d809f63-713c-4edc-9093-2b0e9a5ff946
# 26              972_YY1017_YY1021_HTO  6807fd2b-28e9-41c8-9428-169f96bff0d5
# 17     1741_Preclinical_DP_batch1_HTO  173ebedd-3b99-4a6b-9e10-e6ccf6e32f7a
# 11     1740_Preclinical_SP_batch1_HTO  6dfbeaa3-5487-467a-bddd-8d6865e3a157
# 27           1972_NYBC265_7xNK_FB_HTO  d119f5d8-1470-4e53-905d-f81eab06b646
# 22                   1823_PDX_3_1_HTO  5964c0db-c689-421b-b972-40c93058712b
# 5             1973_HD1915_7xNK_FB_HTO  2dcd802e-a443-4b13-be71-f0468ddff8df
# 15                  1937_AireRORc_HTO  a08a3170-fd36-4cfd-bda9-079c999cce7b
# 37                   1780_PDX_2_1_HTO  8375a3e0-b4f6-4f81-8413-7867102aff86
# 9              1625_A_mScarletOVA_HTO  e176f0d1-0abf-4dd0-b6cf-8eb0fc3f7518
# 3   1800_MCMV_NK_CD8_TimeCourse_HTO_2  19b6ca40-8f8e-497e-9cbb-6a96779910f9
# 42             1624_Y_mScarletOVA_HTO  bf69eda8-1437-4cc2-aae7-1550f63a8fcd
# 19                1713_A_mScarlet_HTO  eea46ef6-e458-4184-ad2c-e7b35ff7161e
# 14                1712_Y_mScarlet_HTO  12fdc08f-7572-4c14-87a0-179474c935a2
# 7             1973_HD1915_7xNK_FB_HTO  ab03bbd7-3930-49ee-8679-aad709d632bb
# 6             1973_HD1915_7xNK_FB_HTO  73cab1fb-c253-4c1a-ac27-e1044a9c7202
# 28           1972_NYBC265_7xNK_FB_HTO  75acc16c-f755-4a17-83dd-4091f93b0b4c
# 29           1972_NYBC265_7xNK_FB_HTO  73f175e9-afab-4a1e-8463-581edd1b2098
# 35       1978_Adeno_fixed_InDrop2_HTO  27a9e78e-1d2d-4975-9f46-c8a36b05b09a
#
#     mapping_rate  umi_corrected  cb_corrected  tag_max_error      reads
# 33            98         333255      15532769              2  100880482
# 34            98         333255      15515230              1  100880482
# 36            97         333255      15407199              0  100880482
# 21            98         370030      13232865              2  109247097
# 40            93         147091       8209366              2   82640138
# 1              1         125444       5188424              2   75775940
# 0             98         125444       4825424              2   75775940
# 4             91         176374       3608438              2   90982164
# 50            91         151075       2251412              2   88353575
# 16            96          85132       1729703              2   63893938
# 25            67          66754       1071600              2   74641242
# 18            95         173107        482538              2   87353499
# 48            94          95210        477024              2   56902257
# 44            95         184728        460745              2   82593082
# 10            95         182441        459997              2   76149607
# 2             96         202768        398880              2   61797139
# 39            95         240433        370485              2   70132617
# 41            95         153802        369357              2   80321892
# 45            94         161249        323090              2   62841716
# 49            90          74190        298736              2   36956115
# 20            94         152380        285088              2   61925209
# 23            97         142609        232313              2   44434089
# 43            98         146191        213813              2   39562215
# 46            98          94773        196713              2   85768873
# 38            97          55027        187744              2   56880615
# 24            95         189479        161063              2   30957311
# 32            96         113533        147958              2   58448423
# 12            97         130703        146036              2   41337375
# 13            96         100076        121214              2   62257041
# 47            88          27017        118752              2   37870260
# 8             48          79627        113876              2   51202697
# 30            98          46071        101652              2   81649865
# 31            98          36739         85271              2   66864091
# 26            97          24575         67373              2   48303755
# 17            16          52669         44563              2   68007726
# 11             4          41017         34649              2   71972268
# 27            95          61936         28333              2   12668814
# 22            98          16505         23480              2    1317866
# 5             95          57585         20999              2   10711133
# 15            98           6451          7477              2   59801649
# 37            91           7874          5669              2    1705308
# 9             95           7471          1656              2   76149607
# 3             96           7290          1122              2   61797139
# 42            95           6595           812              2   80321892
# 19            94           4862           592              2   61925209
# 14            94           4134           310              2   62257041
# 7              0           1650           125              2   10711133
# 6             95           1650            84              2   10711133
# 28             0           1601            42              2   12668814
# 29            95           1601            37              2   12668814
# 35            97              0             0              0  100880482

# %% [markdown]
# # Filter

# %%
# exclude this one
# because we turned off cb/umi/tag error correction
df = df[ df.guid != "27a9e78e-1d2d-4975-9f46-c8a36b05b09a" ]

# %% [markdown]
# # Calculate Fraction

# %%
df = df.assign(cb_corrected_frac=df.cb_corrected / df.reads)

# %%
df = df.assign(umi_corrected_frac=df.umi_corrected / df.reads)

# %%
df
# Out:
#                                 title                                  guid  \
# 33       1978_Adeno_fixed_InDrop2_HTO  eba48452-a3f7-4b4a-b4fa-7315b53be1f0
# 34       1978_Adeno_fixed_InDrop2_HTO  33743e28-4ef9-4356-b2ff-5a4a31ce57aa
# 36       1978_Adeno_fixed_InDrop2_HTO  f8feeeda-e988-4f13-aba3-f75606e294b1
# 21                   1823_PDX_3_1_HTO  67c7c4db-b739-44d9-94f1-7d4c7ccb0b2b
# 40                1687_LX33_1_4_1_HTO  b4a27cc5-9b8f-49f8-830e-1a65a477c8c1
# 1        1472_PBMC_v2_Meth_Hash_2_ADT  92837dfc-b84d-44ae-a225-feb125b9dff3
# 0        1472_PBMC_v2_Meth_Hash_2_ADT  f86f455a-6167-4536-8cf7-d10f70db8ebe
# 4                     1799_GH1529_HTO  7b4600c0-8651-460f-b773-14829ecf14fc
# 50                    1798_SM8822_HTO  7417f0eb-4d29-4d75-abfa-32e04cdd8665
# 16                    1054_Ay_ova_HTO  68687f04-d983-44db-9489-afc21a65b989
# 25   923_GH1344_GH1676_transplant_HTO  10303615-8412-47f7-acb4-9b2540149356
# 18           1939_071320_A_Y_LUAD_HTO  f2fb0945-c899-4674-9e5b-ea0d8e4f8e0c
# 48                 1904_C7_cond_1_HTO  08778704-c763-4145-a951-b8af53cc45cc
# 44            1940_071020_A_YLUAD_HTO  f03fd2c9-b5ae-490f-967c-1b274ebd7bde
# 10             1625_A_mScarletOVA_HTO  9c45f76f-2003-4d08-bbda-7feea71bb36f
# 2   1800_MCMV_NK_CD8_TimeCourse_HTO_2  6276bd06-3ab4-420c-96d1-8a9053195726
# 39                1905_shK_060120_HTO  b7fa5760-a2f1-4b3a-bbcd-eb2064165cd5
# 41             1624_Y_mScarletOVA_HTO  dbdfdd6c-2091-42ea-9e08-b9fda5bd7280
#     mapping_rate  umi_corrected  cb_corrected  tag_max_error      reads  \
# 33            98         333255      15532769              2  100880482
# 34            98         333255      15515230              1  100880482
# 36            97         333255      15407199              0  100880482
# 21            98         370030      13232865              2  109247097
# 40            93         147091       8209366              2   82640138
# 1              1         125444       5188424              2   75775940
# 0             98         125444       4825424              2   75775940
# 4             91         176374       3608438              2   90982164
# 50            91         151075       2251412              2   88353575
# 16            96          85132       1729703              2   63893938
# 25            67          66754       1071600              2   74641242
# 18            95         173107        482538              2   87353499
# 48            94          95210        477024              2   56902257
# 44            95         184728        460745              2   82593082
# 10            95         182441        459997              2   76149607
# 2             96         202768        398880              2   61797139
# 39            95         240433        370485              2   70132617
# 41            95         153802        369357              2   80321892
# 45            94         161249        323090              2   62841716
# 49            90          74190        298736              2   36956115
# 20            94         152380        285088              2   61925209
# 23            97         142609        232313              2   44434089
# 43            98         146191        213813              2   39562215
# 46            98          94773        196713              2   85768873
# 38            97          55027        187744              2   56880615
# 24            95         189479        161063              2   30957311
# 32            96         113533        147958              2   58448423
# 12            97         130703        146036              2   41337375
# 13            96         100076        121214              2   62257041
# 47            88          27017        118752              2   37870260
# 8             48          79627        113876              2   51202697
# 30            98          46071        101652              2   81649865
# 31            98          36739         85271              2   66864091
# 26            97          24575         67373              2   48303755
# 17            16          52669         44563              2   68007726
# 11             4          41017         34649              2   71972268
# 27            95          61936         28333              2   12668814
# 22            98          16505         23480              2    1317866
# 5             95          57585         20999              2   10711133
# 15            98           6451          7477              2   59801649
# 37            91           7874          5669              2    1705308
# 9             95           7471          1656              2   76149607
# 3             96           7290          1122              2   61797139
# 42            95           6595           812              2   80321892
# 19            94           4862           592              2   61925209
# 14            94           4134           310              2   62257041
# 7              0           1650           125              2   10711133
# 6             95           1650            84              2   10711133
# 28             0           1601            42              2   12668814
# 29            95           1601            37              2   12668814
#
#     cb_corrected_frac  umi_corrected_frac
# 33           0.153972            0.003303
# 34           0.153798            0.003303
# 36           0.152727            0.003303
# 21           0.121128            0.003387
# 40           0.099339            0.001780
# 1            0.068471            0.001655
# 0            0.063680            0.001655
# 4            0.039661            0.001939
# 50           0.025482            0.001710
# 16           0.027071            0.001332
# 25           0.014357            0.000894
# 18           0.005524            0.001982
# 48           0.008383            0.001673
# 44           0.005578            0.002237
# 10           0.006041            0.002396
# 2            0.006455            0.003281
# 39           0.005283            0.003428
# 41           0.004598            0.001915
# 45           0.005141            0.002566
# 49           0.008084            0.002008
# 20           0.004604            0.002461
# 23           0.005228            0.003209
# 43           0.005404            0.003695
# 46           0.002294            0.001105
# 38           0.003301            0.000967
# 24           0.005203            0.006121
# 32           0.002531            0.001942
# 12           0.003533            0.003162
# 13           0.001947            0.001607
# 47           0.003136            0.000713
# 8            0.002224            0.001555
# 30           0.001245            0.000564
# 31           0.001275            0.000549
# 26           0.001395            0.000509
# 17           0.000655            0.000774
# 11           0.000481            0.000570
# 27           0.002236            0.004889
# 22           0.017817            0.012524
# 5            0.001960            0.005376
# 15           0.000125            0.000108
# 37           0.003324            0.004617
# 9            0.000022            0.000098
# 3            0.000018            0.000118
# 42           0.000010            0.000082
# 19           0.000010            0.000079
# 14           0.000005            0.000066
# 7            0.000012            0.000154
# 6            0.000008            0.000154
# 28           0.000003            0.000126
# 29           0.000003            0.000126

# %% [markdown]
# # Plot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

# %%
from matplotlib.lines import Line2D
from matplotlib.patches import Patch

# %% [markdown]
# ## Test

# %%
fig, ax = plt.subplots(figsize=(12, 6), facecolor="white")

df_sorted = df.sort_values("umi_corrected", ascending=False)
df_sorted.reset_index(drop=True, inplace=True)

ax.bar(df_sorted.title, df_sorted.umi_corrected, color="lightgray")
ax.tick_params(axis="x", rotation=90)

for i, title in enumerate(df_sorted.title):
    for i, title in enumerate(df_sorted.title):
        if "1978_" in title:
            ax.get_children()[i].set_color("cornflowerblue")
#             ax.get_children()[i].set_hatch("//")
            ax.get_children()[i].set_edgecolor("black")
            ax.get_children()[i].set_label("New")
        if "1472_" in title or "1823_" in title or "1687_" in title:
            ax.get_children()[i].set_color("coral")
#             ax.get_children()[i].set_hatch("//")
            ax.get_children()[i].set_edgecolor("black")
            ax.get_children()[i].set_label("Old")
        if "1904_C7_cond_1_HTO" in title:
            ax.get_children()[i].set_color("yellow")
#             ax.get_children()[i].set_hatch("///")
            ax.get_children()[i].set_edgecolor("black")
            ax.get_children()[i].set_label("Good")


legend_elements = [
    Patch(facecolor="cornflowerblue", edgecolor="black", label="Most Recent"),
    Patch(facecolor="coral", edgecolor="black", label="Old"),
    Patch(facecolor="yellow", edgecolor="black", label="Good")
]

ax.legend(handles=legend_elements)

plt.show()

# %%
def plot_bar(df: pd.DataFrame, column_name: str, y_label: str = None):
    fig, ax = plt.subplots(figsize=(12, 6), facecolor="white")

    df_sorted = df.sort_values(column_name, ascending=False)
    df_sorted.reset_index(drop=True, inplace=True)

    ax.bar(df_sorted.title, df_sorted[column_name], color="lightgray")
    ax.tick_params(axis="x", rotation=90)
    ax.set_title(column_name, fontweight="bold")

    for i, title in enumerate(df_sorted.title):
        if "1978_" in title:
            ax.get_children()[i].set_color("cornflowerblue")
            ax.get_children()[i].set_edgecolor("black")
            ax.get_children()[i].set_label("New")
        if "1472_" in title or "1823_" in title or "1687_" in title or "1780_" in title:
            ax.get_children()[i].set_color("coral")
            ax.get_children()[i].set_edgecolor("black")
            ax.get_children()[i].set_label("Old")
        if "1904_C7_cond_1_HTO" in title:
            ax.get_children()[i].set_color("yellow")
            ax.get_children()[i].set_edgecolor("black")
            ax.get_children()[i].set_label("Good")

    if y_label:
        ax.set_ylabel(y_label)

    legend_elements = [
        Patch(facecolor="cornflowerblue", edgecolor="black", label="Most Recent"),
        Patch(facecolor="coral", edgecolor="black", label="Old"),
        Patch(facecolor="yellow", edgecolor="black", label="Good")
    ]
    ax.legend(handles=legend_elements)

    plt.show()

# %% [markdown]
# ## CB Corrected

# %%
plot_bar(df, "cb_corrected", y_label="number of correction")

# %% [markdown]
# ## CB Corrected Fraction (%)

# %%
plot_bar(df, "cb_corrected_frac", y_label="fraction of correction (%)")

# %% [markdown]
# ## UMI Corrected

# %%
plot_bar(df, "umi_corrected", y_label="number of correction")

# %% [markdown]
# ## UMI Corrected Fraction (%)

# %%
plot_bar(df, "umi_corrected_frac", y_label="fraction of correction (%)")

# %% [markdown]
# ## Reads

# %%
plot_bar(df, "reads", y_label="number of reads")

# %%
df.reads.describe()
# Out:
# count    5.000000e+01
# mean     5.923714e+07
# std      2.803101e+07
# min      1.317866e+06
# 25%      4.211155e+07
# 50%      6.225704e+07
# 75%      7.927882e+07
# max      1.092471e+08
# Name: reads, dtype: float64
