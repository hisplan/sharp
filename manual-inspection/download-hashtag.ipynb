# %%
import os
import json

import requests
from requests.exceptions import HTTPError
from requests.auth import HTTPBasicAuth

# %% [markdown]
# ## Parameters

# %%
# this cell is tagged `parameters` and will be overridden by papermill

workflow_id = "af1fa66d-943c-4343-84c7-8d3f476f34c1"
# workflow_id = "36faf89a-e615-4baa-84a3-3de42994ff9f"

path_secrets_file = "/Users/chunj/keys/secrets-aws.json"
path_base_data = "./hashtag"
skip_download = True

# %% [markdown]
# ## APIs to Cromwell

# %%
def get_secrets(path_secrets_file):

    with open(path_secrets_file, "rt") as fin:
        data = json.loads(fin.read())

    return data

def prep_api_call(secrets):

    api_version = "v1"
    url = secrets["url"]
    url = f"{url}/api/workflows/{api_version}"

    auth = HTTPBasicAuth(secrets["username"], secrets["password"])

    return url, auth

def get_metadata(secrets, workflow_id):

    base_url, auth = prep_api_call(secrets)

    try:
        response = requests.patch(
            url=f"{base_url}/{workflow_id}/metadata?expandSubWorkflows=true",
            headers={
                "Content-Type": "application/json",
                "Accept": "application/json"
            },
            auth=auth
        )

        # if response.status_code == 200:
        data = response.json()

        return data

    except HTTPError as err:
        print(err)

# %% [markdown]
# ## Get Metadata

# %%
metadata = get_metadata(
    get_secrets(path_secrets_file),
    workflow_id
)

# %%
print(json.dumps(metadata, indent=2))
# Out:
# {
#   "workflowName": "Sharp",
#   "workflowProcessingEvents": [
#     {
#       "cromwellId": "cromid-7c5523d",
#       "description": "Finished",
#       "timestamp": "2020-01-11T04:04:17.363Z",
#       "cromwellVersion": "45.1"
#     },
#     {
#       "cromwellId": "cromid-7c5523d",
#       "description": "PickedUp",
#       "timestamp": "2020-01-11T02:20:04.917Z",
#       "cromwellVersion": "45.1"
#     }
#   ],
#   "metadataSource": "Unarchived",
#   "actualWorkflowLanguageVersion": "1.0",
#   "submittedFiles": {
#     "workflow": "version 1.0\n\nimport \"modules/MergeFastq.wdl\" as MergeFastq\nimport \"modules/FastQC.wdl\" as FastQC\nimport \"modules/Cutadapt.wdl\" as Cutadapt\nimport \"modules/CutInDropSpacer.wdl\" as CutInDropSpacer\nimport \"modules/PrepCBWhitelist.wdl\" as PrepCBWhitelist\nimport \"modules/Count.wdl\" as Count\nimport \"modules/HtoDemuxSeurat.wdl\" as HtoDemuxSeurat\nimport \"modules/HtoDemuxKMeans.wdl\" as HtoDemuxKMeans\nimport \"modules/Combine.wdl\" as Combine\n\nworkflow Sharp {\n\n    input {\n        Array[File] uriFastqR1\n        Array[File] uriFastqR2\n\n        Int lengthR1\n        Int lengthR2\n\n        String sampleName\n\n        File cellBarcodeWhitelistUri\n        String cellBarcodeWhiteListMethod\n\n        String scRnaSeqPlatform = \"10x_v3\"\n\n        File hashTagList\n\n        # cellular barcode start/end positions\n        Int cbStartPos\n        Int cbEndPos\n\n        # UMI start/end positions\n        Int umiStartPos\n        Int umiEndPos\n\n        # how many bases should we trim before starting to look for hashtag sequence\n        Int trimPos = 0\n\n        # activate sliding window alignement\n        Boolean slidingWindowSearch = false\n\n        # correction\n        Int cbCollapsingDistance\n        Int umiCollapsingDistance\n\n        Int numExpectedCells\n\n        Int numCoresForCount\n\n        File denseCountMatrix\n    }\n\n    # merge FASTQ R1\n    call MergeFastq.MergeFastq as MergeFastqR1 {\n        input:\n            uriFastq = uriFastqR1,\n            sampleName = sampleName,\n            readName = \"R1\"\n    }\n\n    # merge FASTQ R2\n    call MergeFastq.MergeFastq as MergeFastqR2 {\n        input:\n            uriFastq = uriFastqR2,\n            sampleName = sampleName,\n            readName = \"R2\"\n    }\n\n    # run FastQC R1\n    call FastQC.FastQC as FastQCR1 {\n        input:\n            fastqFile = MergeFastqR1.out\n    }\n\n    # run FastQC R2\n    call FastQC.FastQC as FastQCR2 {\n        input:\n            fastqFile = MergeFastqR2.out\n    }\n\n    # if InDrops v4\n    if (scRnaSeqPlatform == \"in_drop_v4\") {\n        # trim R1 (remove the middler spacer as well)\n        call CutInDropSpacer.CutInDropSpacer {\n            input:\n                fastq = MergeFastqR1.out,\n                outFileName = \"R1.fastq.gz\"\n        }\n    }\n\n    # if not InDrops v4\n    if (scRnaSeqPlatform != \"in_drop_v4\") {\n        # trim R1\n        call Cutadapt.Trim as TrimR1 {\n            input:\n                fastq = MergeFastqR1.out,\n                length = lengthR1,\n                outFileName = \"R1.fastq.gz\"\n        }\n    }\n\n    File trimR1 = select_first([CutInDropSpacer.outFile, TrimR1.outFile])\n\n    # trim R2\n    call Cutadapt.Trim as TrimR2 {\n        input:\n            fastq = MergeFastqR2.out,\n            length = lengthR2,\n            outFileName = \"R2.fastq.gz\"\n    }\n\n    # prepare cell barcode whitelist\n    if (cellBarcodeWhiteListMethod == \"SeqcSparseCountsBarcodesCsv\") {\n        # *_sparse_counts_barcodes.csv\n        call PrepCBWhitelist.WhitelistFromSeqcSparseBarcodes {\n            input:\n                csvFile = cellBarcodeWhitelistUri\n        }\n    }\n\n    if (cellBarcodeWhiteListMethod == \"SeqcDenseCountsMatrixCsv\") {\n        # *_dense.csv\n        call PrepCBWhitelist.WhitelistFromSeqcDenseMatrix {\n            input:\n                csvFile = cellBarcodeWhitelistUri\n        }\n    }\n\n    if (cellBarcodeWhiteListMethod == \"BarcodeWhitelistCsv\") {\n        # one barcode per line\n        call PrepCBWhitelist.NotImplemented\n    }\n\n    File cbWhitelist = select_first([WhitelistFromSeqcSparseBarcodes.out, WhitelistFromSeqcDenseMatrix.out])\n\n    # run CITE-seq-Count\n    call Count.CiteSeqCount {\n        input:\n            fastqR1 = trimR1,\n            fastqR2 = TrimR2.outFile,\n            cbWhiteList = cbWhitelist,\n            hashTagList = hashTagList,\n            cbStartPos = cbStartPos,\n  ...
#     "root": "",
#     "options": "{\n  \"monitoring_script\": \"s3://dp-lab-batch/monitoring.sh\",\n  \"read_from_cache\": true,\n  \"workflow_failure_mode\": \"ContinueWhilePossible\",\n  \"write_to_cache\": true\n}",
#     "inputs": "{\"Sharp.cbCollapsingDistance\":1,\"Sharp.cbEndPos\":16,\"Sharp.cbStartPos\":1,\"Sharp.cellBarcodeWhiteListMethod\":\"SeqcDenseCountsMatrixCsv\",\"Sharp.cellBarcodeWhitelistUri\":\"s3://dp-lab-data/collaborators/tammela/C57BL6/A_mScarlet/seqc-results/1713_A_mScarlet_IGO_10298_B_40_dense.csv\",\"Sharp.denseCountMatrix\":\"s3://dp-lab-data/collaborators/tammela/C57BL6/A_mScarlet/seqc-results/1713_A_mScarlet_IGO_10298_B_40_dense.csv\",\"Sharp.hashTagList\":\"s3://dp-lab-data/sc-seq/Project_10477/A_mScarlet_HTO/Hashtag_results/tag-list.csv\",\"Sharp.lengthR1\":28,\"Sharp.lengthR2\":25,\"Sharp.numCoresForCount\":8,\"Sharp.numExpectedCells\":0,\"Sharp.sampleName\":\"1713_A_mScarlet_HTO\",\"Sharp.scRnaSeqPlatform\":\"10x_v3\",\"Sharp.slidingWindowSearch\":false,\"Sharp.trimPos\":1E+1,\"Sharp.umiCollapsingDistance\":1,\"Sharp.umiEndPos\":28,\"Sharp.umiStartPos\":17,\"Sharp.uriFastqR1\":[\"s3://dp-lab-data/sc-seq/Project_10477/A_mScarlet_HTO/FASTQ/1713_A_mScarlet_HTO_IGO_10477_12_S12_L001_R1_001.fastq.gz\",\"s3://dp-lab-data/sc-seq/Project_10477/A_mScarlet_HTO/FASTQ/1713_A_mScarlet_HTO_IGO_10477_12_S12_L002_R1_001.fastq.gz\"],\"Sharp.uriFastqR2\":[\"s3://dp-lab-data/sc-seq/Project_10477/A_mScarlet_HTO/FASTQ/1713_A_mScarlet_HTO_IGO_10477_12_S12_L001_R2_001.fastq.gz\",\"s3://dp-lab-data/sc-seq/Project_10477/A_mScarlet_HTO/FASTQ/1713_A_mScarlet_HTO_IGO_10477_12_S12_L002_R2_001.fastq.gz\"]}",
#     "workflowUrl": "",
#     "labels": "{\n    \"pipelineType\": \"Sharp\",\n    \"project\": \"Project 192\",\n    \"sample\": \"1713_A_mScarlet_HTO\",\n    \"owner\": \"masilioi\",\n    \"destination\": \"s3://dp-lab-data/sc-seq/Project_10477/A_mScarlet_HTO/Hashtag_results/\",\n    \"transfer\": \"-\",\n    \"comment\": \"1713_A_mScarlet_HTO\"\n}"
#   },
#   "calls": {
#     "Sharp.HtoDemuxKMeans": [
#       {
#         "executionStatus": "Done",
#         "stdout": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-HtoDemuxKMeans/HtoDemuxKMeans-stdout.log",
#         "backendStatus": "Succeeded",
#         "compressedDockerSize": 350719904,
#         "commandLine": "set -euo pipefail\n\nmkdir inputs\n\ncp /cromwell_root/dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz /cromwell_root/dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz /cromwell_root/dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz ./inputs/\n\n# --hto-umi-count-dir:  output directory from CITE-seq-Count\n#                       e.g. .../umi-count\n\npython3 /opt/demux_kmeans.py \\\n    --hto-umi-count-dir ./inputs",
#         "shardIndex": -1,
#         "outputs": {
#           "outClass": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-HtoDemuxKMeans/final-classification.tsv.gz",
#           "outStats": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-HtoDemuxKMeans/stats.yml",
#           "outLog": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-HtoDemuxKMeans/demux_kmeans.log"
#         },
#         "runtimeAttributes": {
#           "failOnStderr": "false",
#           "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/default-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#           "disks": "local-disk /cromwell_root",
#           "continueOnReturnCode": "0",
#           "docker": "hisplan/cromwell-hto-demux-kmeans:0.3",
#           "maxRetries": "0",
#           "cpu": "1",
#           "cpuMin": "1",
#           "noAddress": "false",
#           "zones": "us-east-1a",
#           "memoryMin": "2 GB",
#           "memory": "32 GB"
#         },
#         "callCaching": {
#           "allowResultReuse": false,
#           "effectiveCallCachingMode": "CallCachingOff"
#         },
#         "inputs": {
#           "dockerImage": "hisplan/cromwell-hto-demux-kmeans:0.3",
#           "numCores": 1,
#           "umiCountFiles": [
#             "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#             "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#             "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#           ]
#         },
#         "returnCode": 0,
#         "jobId": "3b735fdb-107d-4e92-ba43-05fbe556f65a",
#         "backend": "AWSBATCH",
#         "end": "2020-01-11T03:55:05.598Z",
#         "dockerImageUsed": "hisplan/cromwell-hto-demux-kmeans@sha256:d74707ef2f80d20ac571d016461acc21df710345895b44fab202b72c7249d332",
#         "stderr": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-HtoDemuxKMeans/HtoDemuxKMeans-stderr.log",
#         "callRoot": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-HtoDemuxKMeans",
#         "attempt": 1,
#         "executionEvents": [
#           {
#             "startTime": "2020-01-11T03:01:37.821Z",
#             "description": "Pending",
#             "endTime": "2020-01-11T03:01:37.821Z"
#           },
#           {
#             "startTime": "2020-01-11T03:01:39.712Z",
#             "description": "PreparingJob",
#             "endTime": "2020-01-11T03:01:39.928Z"
#           },
#           {
#             "startTime": "2020-01-11T03:01:39.712Z",
#             "description": "WaitingForValueStore",
#             "endTime": "2020-01-11T03:01:39.712Z"
#           },
#           {
#             "startTime": "2020-01-11T03:01:39.928Z",
#             "description": "RunningJob",
#             "endTime": "2020-01-11T03:55:05.040Z"
#           },
#           {
#             "startTime": "2020-01-11T03:55:05.040Z",
#             "description": "UpdatingJobStore",
#             "endTime": "2020-01-11T03:55:05.598Z"
#           },
#           {
#             "startTime": "2020-01-11T03:01:37.821Z",
#             "description": "RequestingExecutionToken",
#             "endTime": "2020-01-11T03:01:39.712Z"
#           }
#         ],
#         "start": "2020-01-11T03:01:37.821Z"
#       }
#     ],
#     "Sharp.FastQCR1": [
#       {
#         "executionStatus": "Done",
#         "stdout": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-FastQCR1/FastQCR1-stdout.log",
#         "backendStatus": "Succeeded",
#         "compressedDockerSize": 138864024,
#         "commandLine": "set -euo pipefail\n\nfastqc -o . /cromwell_root/dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-MergeFastqR1/1713_A_mScarlet_HTO_R1.fastq.gz",
#         "shardIndex": -1,
#         "outputs": {
#           "outHtml": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-FastQCR1/1713_A_mScarlet_HTO_R1_fastqc.html",
#           "outZip": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-FastQCR1/1713_A_mScarlet_HTO_R1_fastqc.zip"
#         },
#         "runtimeAttributes": {
#           "failOnStderr": "false",
#           "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/default-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#           "disks": "local-disk /cromwell_root",
#           "continueOnReturnCode": "0",
#           "docker": "hisplan/cromwell-fastqc:0.11.8",
#           "maxRetries": "0",
#           "cpu": "4",
#           "cpuMin": "1",
#           "noAddress": "false",
#           "zones": "us-east-1a",
#           "memoryMin": "2 GB",
#           "memory": "16 GB"
#         },
#         "callCaching": {
#           "allowResultReuse": false,
#           "effectiveCallCachingMode": "CallCachingOff"
#         },
#         "inputs": {
#           "numCores": 4,
#           "dockerImage": "hisplan/cromwell-fastqc:0.11.8",
#           "fastqFile": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-MergeFastqR1/1713_A_mScarlet_HTO_R1.fastq.gz",
#           "inputSize": 1.0896186288446188
#         },
#         "returnCode": 0,
#         "jobId": "fb5b18d6-1acb-495b-9fe6-9b5877c9b42a",
#         "backend": "AWSBATCH",
#         "end": "2020-01-11T02:36:49.603Z",
#         "dockerImageUsed": "hisplan/cromwell-fastqc@sha256:1b92481e73c96240701f1ecb7b02e8fde9dfbe4ba344a2756d37a1aa696cabb6",
#         "stderr": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-FastQCR1/FastQCR1-stderr.log",
#         "callRoot": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-FastQCR1",
#         "attempt": 1,
#         "executionEvents": [
#           {
#             "startTime": "2020-01-11T02:32:39.954Z",
#             "description": "RunningJob",
#             "endTime": "2020-01-11T02:36:48.681Z"
#           },
#           {
#             "startTime": "2020-01-11T02:32:39.712Z",
#             "description": "PreparingJob",
#             "endTime": "2020-01-11T02:32:39.954Z"
#           },
#           {
#             "startTime": "2020-01-11T02:32:38.772Z",
#             "description": "Pending",
#             "endTime": "2020-01-11T02:32:38.772Z"
#           },
#           {
#             "startTime": "2020-01-11T02:32:39.712Z",
#             "description": "WaitingForValueStore",
#             "endTime": "2020-01-11T02:32:39.712Z"
#           },
#           {
#             "startTime": "2020-01-11T02:32:38.772Z",
#             "description": "RequestingExecutionToken",
#             "endTime": "2020-01-11T02:32:39.712Z"
#           },
#           {
#             "startTime": "2020-01-11T02:36:48.681Z",
#             "description": "UpdatingJobStore",
#             "endTime": "2020-01-11T02:36:49.603Z"
#           }
#         ],
#         "start": "2020-01-11T02:32:38.772Z"
#       }
#     ],
#     "Sharp.TrimR2": [
#       {
#         "executionStatus": "Done",
#         "stdout": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-TrimR2/TrimR2-stdout.log",
#         "backendStatus": "Succeeded",
#         "compressedDockerSize": 210532600,
#         "commandLine": "set -euo pipefail\n\ncutadapt \\\n    --minimum-length 25 \\\n    --length 25 \\\n    --too-short-output too-short.R2.fastq.gz \\\n    --too-long-output too-long.R2.fastq.gz \\\n    -o R2.fastq.gz \\\n    /cromwell_root/dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-MergeFastqR2/1713_A_mScarlet_HTO_R2.fastq.gz",
#         "shardIndex": -1,
#         "outputs": {
#           "outTooShortTooLongFiles": [
#             "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-TrimR2/glob-0ee15da47465f38e299b3bd7f7bbe3be/too-short.R2.fastq.gz"
#           ],
#           "outFile": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-TrimR2/R2.fastq.gz"
#         },
#         "runtimeAttributes": {
#           "failOnStderr": "false",
#           "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/default-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#           "disks": "local-disk /cromwell_root",
#           "continueOnReturnCode": "0",
#           "docker": "hisplan/cromwell-cutadapt:2.5",
#           "maxRetries": "0",
#           "cpu": "4",
#           "cpuMin": "1",
#           "noAddress": "false",
#           "zones": "us-east-1a",
#           "memoryMin": "2 GB",
#           "memory": "16 GB"
#         },
#         "callCaching": {
#           "allowResultReuse": false,
#           "effectiveCallCachingMode": "CallCachingOff"
#         },
#         "inputs": {
#           "outFileName": "R2.fastq.gz",
#           "dockerImage": "hisplan/cromwell-cutadapt:2.5",
#           "length": 25,
#           "fastq": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-MergeFastqR2/1713_A_mScarlet_HTO_R2.fastq.gz",
#           "numCores": 4
#         },
#         "returnCode": 0,
#         "jobId": "e5ecee1f-39e3-4260-a2c2-dc08971c8317",
#         "backend": "AWSBATCH",
#         "end": "2020-01-11T02:46:20.599Z",
#         "dockerImageUsed": "hisplan/cromwell-cutadapt@sha256:483a1e6f3d77c8e6ac363cd103d26b8dd3d99f57554adc90463f08969b454b38",
#         "stderr": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-TrimR2/TrimR2-stderr.log",
#         "callRoot": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-TrimR2",
#         "attempt": 1,
#         "executionEvents": [
#           {
#             "startTime": "2020-01-11T02:39:29.711Z",
#             "description": "PreparingJob",
#             "endTime": "2020-01-11T02:39:29.714Z"
#           },
#           {
#             "startTime": "2020-01-11T02:39:27.772Z",
#             "description": "Pending",
#             "endTime": "2020-01-11T02:39:27.772Z"
#           },
#           {
#             "startTime": "2020-01-11T02:39:29.714Z",
#             "description": "RunningJob",
#             "endTime": "2020-01-11T02:46:20.388Z"
#           },
#           {
#             "startTime": "2020-01-11T02:39:29.711Z",
#             "description": "WaitingForValueStore",
#             "endTime": "2020-01-11T02:39:29.711Z"
#           },
#           {
#             "startTime": "2020-01-11T02:39:27.772Z",
#             "description": "RequestingExecutionToken",
#             "endTime": "2020-01-11T02:39:29.711Z"
#           },
#           {
#             "startTime": "2020-01-11T02:46:20.388Z",
#             "description": "UpdatingJobStore",
#             "endTime": "2020-01-11T02:46:20.599Z"
#           }
#         ],
#         "start": "2020-01-11T02:39:27.772Z"
#       }
#     ],
#     "Sharp.CiteSeqCount": [
#       {
#         "executionStatus": "Done",
#         "stdout": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/CiteSeqCount-stdout.log",
#         "backendStatus": "Succeeded",
#         "compressedDockerSize": 392564039,
#         "commandLine": "set -euo pipefail\n\nCITE-seq-Count \\\n    -R1 /cromwell_root/dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-TrimR1/R1.fastq.gz \\\n    -R2 /cromwell_root/dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-TrimR2/R2.fastq.gz \\\n    --tags /cromwell_root/dp-lab-data/sc-seq/Project_10477/A_mScarlet_HTO/Hashtag_results/tag-list.csv \\\n    -cbf 1 -cbl 16 \\\n    -umif 17 -umil 28 \\\n    --bc_collapsing_dist 1 \\\n    --umi_collapsing_dist 1 \\\n    --start-trim 10  \\\n    --expected_cells 0 \\\n    --whitelist /cromwell_root/dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-WhitelistFromSeqcDenseMatrix/cb-whitelist.txt \\\n    --output results \\\n    --dense \\\n    --unmapped-tags unmapped.csv \\\n    --threads 8",
#         "shardIndex": -1,
#         "outputs": {
#           "outUncorrected": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/results/uncorrected_cells/dense_umis.tsv",
#           "outReadCount": [
#             "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz",
#             "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz",
#             "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz"
#           ],
#           "outUmiDenseCount": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/results/dense_umis.tsv",
#           "outUnmapped": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/results/unmapped.csv",
#           "outUmiCount": [
#             "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#             "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#             "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#           ],
#           "outReport": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/results/run_report.yaml"
#         },
#         "runtimeAttributes": {
#           "failOnStderr": "false",
#           "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/default-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#           "disks": "local-disk /cromwell_root",
#           "continueOnReturnCode": "0",
#           "docker": "hisplan/cromwell-cite-seq-count:1.4.2-develop",
#           "maxRetries": "0",
#           "cpu": "8",
#           "cpuMin": "1",
#           "noAddress": "false",
#           "zones": "us-east-1a",
#           "memoryMin": "2 GB",
#           "memory": "32 GB"
#         },
#         "callCaching": {
#           "allowResultReuse": false,
#           "effectiveCallCachingMode": "CallCachingOff"
#         },
#         "inputs": {
#           "numExpectedCells": 0,
#           "slidingWindowSearch": false,
#           "hashTagList": "s3://dp-lab-data/sc-seq/Project_10477/A_mScarlet_HTO/Hashtag_results/tag-list.csv",
#           "umiEndPos": 28,
#           "cbCollapsingDistance": 1,
#           "umiStartPos": 17,
#           "fastqR2": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-TrimR2/R2.fastq.gz",
#           "dockerImage": "hisplan/cromwell-cite-seq-count:1.4.2-develop",
#           "fastqR1": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-TrimR1/R1.fastq.gz",
#           "umiCollapsingDistance": 1,
#           "cbEndPos": 16,
#           "cbWhiteList": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-WhitelistFromSeqcDenseMatrix/cb-whitelist.txt",
#           "inputSize": 1.778852440416813,
#           "cbStartPos": 1,
#           "trimPos": 10,
#           "numCores": 8
#         },
#         "returnCode": 0,
#         "jobId": "d4a1e3f1-1ed3-4b2b-ba98-bb97c490421b",
#         "backend": "AWSBATCH",
#         "end": "2020-01-11T03:01:36.600Z",
#         "dockerImageUsed": "hisplan/cromwell-cite-seq-count@sha256:b7e040ec487bf76ef704bbc93ddfc2e2054af873934a25f2d9afb31a18dde07d",
#         "stderr": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/CiteSeqCount-stderr.log",
#         "callRoot": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount",
#         "attempt": 1,
#         "executionEvents": [
#           {
#             "startTime": "2020-01-11T02:46:23.711Z",
#             "description": "PreparingJob",
#             "endTime": "2020-01-11T02:46:23.963Z"
#           },
#           {
#             "startTime": "2020-01-11T02:46:23.711Z",
#             "description": "WaitingForValueStore",
#             "endTime": "2020-01-11T02:46:23.711Z"
#           },
#           {
#             "startTime": "2020-01-11T03:01:35.817Z",
#             "description": "UpdatingJobStore",
#             "endTime": "2020-01-11T03:01:36.599Z"
#           },
#           {
#             "startTime": "2020-01-11T02:46:21.892Z",
#             "description": "RequestingExecutionToken",
#             "endTime": "2020-01-11T02:46:23.711Z"
#           },
#           {
#             "startTime": "2020-01-11T02:46:21.891Z",
#             "description": "Pending",
#             "endTime": "2020-01-11T02:46:21.892Z"
#           },
#           {
#             "startTime": "2020-01-11T02:46:23.963Z",
#             "description": "RunningJob",
#             "endTime": "2020-01-11T03:01:35.817Z"
#           }
#         ],
#         "start": "2020-01-11T02:46:21.891Z"
#       }
#     ],
#     "Sharp.TrimR1": [
#       {
#         "executionStatus": "Done",
#         "stdout": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-TrimR1/TrimR1-stdout.log",
#         "backendStatus": "Succeeded",
#         "compressedDockerSize": 210532600,
#         "commandLine": "set -euo pipefail\n\ncutadapt \\\n    --minimum-length 28 \\\n    --length 28 \\\n    --too-short-output too-short.R1.fastq.gz \\\n    --too-long-output too-long.R1.fastq.gz \\\n    -o R1.fastq.gz \\\n    /cromwell_root/dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-MergeFastqR1/1713_A_mScarlet_HTO_R1.fastq.gz",
#         "shardIndex": -1,
#         "outputs": {
#           "outTooShortTooLongFiles": [
#             "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-TrimR1/glob-c763acd1bbc2c02eb59e93c44eda4fa9/too-short.R1.fastq.gz"
#           ],
#           "outFile": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-TrimR1/R1.fastq.gz"
#         },
#         "runtimeAttributes": {
#           "failOnStderr": "false",
#           "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/default-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#           "disks": "local-disk /cromwell_root",
#           "continueOnReturnCode": "0",
#           "docker": "hisplan/cromwell-cutadapt:2.5",
#           "maxRetries": "0",
#           "cpu": "4",
#           "cpuMin": "1",
#           "noAddress": "false",
#           "zones": "us-east-1a",
#           "memoryMin": "2 GB",
#           "memory": "16 GB"
#         },
#         "callCaching": {
#           "allowResultReuse": false,
#           "effectiveCallCachingMode": "CallCachingOff"
#         },
#         "inputs": {
#           "outFileName": "R1.fastq.gz",
#           "dockerImage": "hisplan/cromwell-cutadapt:2.5",
#           "length": 28,
#           "fastq": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-MergeFastqR1/1713_A_mScarlet_HTO_R1.fastq.gz",
#           "numCores": 4
#         },
#         "returnCode": 0,
#         "jobId": "ef005cc0-82ce-4ea2-a9d1-46e5fe6375be",
#         "backend": "AWSBATCH",
#         "end": "2020-01-11T02:46:13.599Z",
#         "dockerImageUsed": "hisplan/cromwell-cutadapt@sha256:483a1e6f3d77c8e6ac363cd103d26b8dd3d99f57554adc90463f08969b454b38",
#         "stderr": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-TrimR1/TrimR1-stderr.log",
#         "callRoot": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-TrimR1",
#         "attempt": 1,
#         "executionEvents": [
#           {
#             "startTime": "2020-01-11T02:32:41.711Z",
#             "description": "WaitingForValueStore",
#             "endTime": "2020-01-11T02:32:41.712Z"
#           },
#           {
#             "startTime": "2020-01-11T02:32:38.772Z",
#             "description": "Pending",
#             "endTime": "2020-01-11T02:32:38.772Z"
#           },
#           {
#             "startTime": "2020-01-11T02:32:41.847Z",
#             "description": "RunningJob",
#             "endTime": "2020-01-11T02:46:13.507Z"
#           },
#           {
#             "startTime": "2020-01-11T02:32:38.772Z",
#             "description": "RequestingExecutionToken",
#             "endTime": "2020-01-11T02:32:41.711Z"
#           },
#           {
#             "startTime": "2020-01-11T02:46:13.507Z",
#             "description": "UpdatingJobStore",
#             "endTime": "2020-01-11T02:46:13.599Z"
#           },
#           {
#             "startTime": "2020-01-11T02:32:41.712Z",
#             "description": "PreparingJob",
#             "endTime": "2020-01-11T02:32:41.847Z"
#           }
#         ],
#         "start": "2020-01-11T02:32:38.772Z"
#       }
#     ],
#     "Sharp.HashedCountMatrix": [
#       {
#         "executionStatus": "Done",
#         "stdout": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-HashedCountMatrix/HashedCountMatrix-stdout.log",
#         "backendStatus": "Succeeded",
#         "compressedDockerSize": 350718928,
#         "commandLine": "set -euo pipefail\n\n# --dense-count-matrix: output from SEQC\n#                       e.g. 1187_IL10neg_P163_IGO_09902_8_dense.csv\n\n# --hto-classification: hto classification from either HtoDemuxSeurat or HtoDemuxKMeans\n#                       e.g. final-classification.tsv.gz\n\npython3 /opt/combine.py \\\n    --dense-count-matrix /cromwell_root/dp-lab-data/collaborators/tammela/C57BL6/A_mScarlet/seqc-results/1713_A_mScarlet_IGO_10298_B_40_dense.csv \\\n    --hto-classification /cromwell_root/dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-HtoDemuxKMeans/final-classification.tsv.gz",
#         "shardIndex": -1,
#         "outputs": {
#           "outStats": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-HashedCountMatrix/stats.yml",
#           "outLog": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-HashedCountMatrix/combine.log",
#           "outClass": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-HashedCountMatrix/final-classification.tsv.gz",
#           "outCountMatrix": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-HashedCountMatrix/final-matrix.tsv.gz"
#         },
#         "runtimeAttributes": {
#           "failOnStderr": "false",
#           "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/default-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#           "disks": "local-disk /cromwell_root",
#           "continueOnReturnCode": "0",
#           "docker": "hisplan/cromwell-hashed-count-matrix:0.1",
#           "maxRetries": "0",
#           "cpu": "1",
#           "cpuMin": "1",
#           "noAddress": "false",
#           "zones": "us-east-1a",
#           "memoryMin": "2 GB",
#           "memory": "32 GB"
#         },
#         "callCaching": {
#           "allowResultReuse": false,
#           "effectiveCallCachingMode": "CallCachingOff"
#         },
#         "inputs": {
#           "denseCountMatrix": "s3://dp-lab-data/collaborators/tammela/C57BL6/A_mScarlet/seqc-results/1713_A_mScarlet_IGO_10298_B_40_dense.csv",
#           "dockerImage": "hisplan/cromwell-hashed-count-matrix:0.1",
#           "htoClassification": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-HtoDemuxKMeans/final-classification.tsv.gz",
#           "inputSize": 0.2594005763530731,
#           "numCores": 1
#         },
#         "returnCode": 0,
#         "jobId": "8a80ebd6-578d-466c-9400-2aaebd251d9b",
#         "backend": "AWSBATCH",
#         "end": "2020-01-11T04:04:15.600Z",
#         "dockerImageUsed": "hisplan/cromwell-hashed-count-matrix@sha256:01c9ac0ef534a0653fd05724de5fbab1c442533c5ebb1d45c779ffc4d82732ec",
#         "stderr": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-HashedCountMatrix/HashedCountMatrix-stderr.log",
#         "callRoot": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-HashedCountMatrix",
#         "attempt": 1,
#         "executionEvents": [
#           {
#             "startTime": "2020-01-11T04:04:14.910Z",
#             "description": "UpdatingJobStore",
#             "endTime": "2020-01-11T04:04:15.600Z"
#           },
#           {
#             "startTime": "2020-01-11T03:55:07.602Z",
#             "description": "Pending",
#             "endTime": "2020-01-11T03:55:07.602Z"
#           },
#           {
#             "startTime": "2020-01-11T03:55:08.092Z",
#             "description": "RunningJob",
#             "endTime": "2020-01-11T04:04:14.910Z"
#           },
#           {
#             "startTime": "2020-01-11T03:55:07.602Z",
#             "description": "RequestingExecutionToken",
#             "endTime": "2020-01-11T03:55:07.711Z"
#           },
#           {
#             "startTime": "2020-01-11T03:55:07.711Z",
#             "description": "WaitingForValueStore",
#             "endTime": "2020-01-11T03:55:07.711Z"
#           },
#           {
#             "startTime": "2020-01-11T03:55:07.711Z",
#             "description": "PreparingJob",
#             "endTime": "2020-01-11T03:55:08.092Z"
#           }
#         ],
#         "start": "2020-01-11T03:55:07.602Z"
#       }
#     ],
#     "Sharp.WhitelistFromSeqcDenseMatrix": [
#       {
#         "executionStatus": "Done",
#         "stdout": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-WhitelistFromSeqcDenseMatrix/WhitelistFromSeqcDenseMatrix-stdout.log",
#         "backendStatus": "Succeeded",
#         "compressedDockerSize": 821071417,
#         "commandLine": "set -euo pipefail\n\npython - << EOF\nimport pandas as pd\nfrom seqc.sequence.encodings import DNA3Bit\n\ndf = pd.read_csv(\n    \"/cromwell_root/dp-lab-data/collaborators/tammela/C57BL6/A_mScarlet/seqc-results/1713_A_mScarlet_IGO_10298_B_40_dense.csv\",\n    index_col=0\n)\n\ndna3bit = DNA3Bit()\n\n# generate CB whitelist based on SEQC results\ncb_whitelist = df.index.map(lambda x: dna3bit.decode(x).decode()).sort_values().to_frame()\n\ncb_whitelist.to_csv(\n    \"cb-whitelist.txt\",\n    header=False, index=False\n)\nEOF",
#         "shardIndex": -1,
#         "outputs": {
#           "out": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-WhitelistFromSeqcDenseMatrix/cb-whitelist.txt"
#         },
#         "runtimeAttributes": {
#           "failOnStderr": "false",
#           "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/default-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#           "disks": "local-disk /cromwell_root",
#           "continueOnReturnCode": "0",
#           "docker": "hisplan/cromwell-seqc:0.2.4",
#           "maxRetries": "0",
#           "cpu": "1",
#           "cpuMin": "1",
#           "noAddress": "false",
#           "zones": "us-east-1a",
#           "memoryMin": "2 GB",
#           "memory": "16 GB"
#         },
#         "callCaching": {
#           "allowResultReuse": false,
#           "effectiveCallCachingMode": "CallCachingOff"
#         },
#         "inputs": {
#           "numCores": 1,
#           "csvFile": "s3://dp-lab-data/collaborators/tammela/C57BL6/A_mScarlet/seqc-results/1713_A_mScarlet_IGO_10298_B_40_dense.csv",
#           "dockerImage": "hisplan/cromwell-seqc:0.2.4",
#           "inputSize": 0.2593469573184848
#         },
#         "returnCode": 0,
#         "jobId": "ffba385d-b6e2-48e9-977b-31d060ff71ec",
#         "backend": "AWSBATCH",
#         "end": "2020-01-11T02:25:25.598Z",
#         "dockerImageUsed": "hisplan/cromwell-seqc@sha256:806621b83f3754a10a93ec568901bc47d990c416de9515a9a2380334a4db6007",
#         "stderr": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-WhitelistFromSeqcDenseMatrix/WhitelistFromSeqcDenseMatrix-stderr.log",
#         "callRoot": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-WhitelistFromSeqcDenseMatrix",
#         "attempt": 1,
#         "executionEvents": [
#           {
#             "startTime": "2020-01-11T02:20:12.013Z",
#             "description": "RunningJob",
#             "endTime": "2020-01-11T02:25:24.865Z"
#           },
#           {
#             "startTime": "2020-01-11T02:25:24.865Z",
#             "description": "UpdatingJobStore",
#             "endTime": "2020-01-11T02:25:25.598Z"
#           },
#           {
#             "startTime": "2020-01-11T02:20:11.712Z",
#             "description": "WaitingForValueStore",
#             "endTime": "2020-01-11T02:20:11.712Z"
#           },
#           {
#             "startTime": "2020-01-11T02:20:09.082Z",
#             "description": "Pending",
#             "endTime": "2020-01-11T02:20:09.082Z"
#           },
#           {
#             "startTime": "2020-01-11T02:20:11.712Z",
#             "description": "PreparingJob",
#             "endTime": "2020-01-11T02:20:12.013Z"
#           },
#           {
#             "startTime": "2020-01-11T02:20:09.082Z",
#             "description": "RequestingExecutionToken",
#             "endTime": "2020-01-11T02:20:11.712Z"
#           }
#         ],
#         "start": "2020-01-11T02:20:09.081Z"
#       }
#     ],
#     "Sharp.FastQCR2": [
#       {
#         "executionStatus": "Done",
#         "stdout": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-FastQCR2/FastQCR2-stdout.log",
#         "backendStatus": "Succeeded",
#         "compressedDockerSize": 138864024,
#         "commandLine": "set -euo pipefail\n\nfastqc -o . /cromwell_root/dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-MergeFastqR2/1713_A_mScarlet_HTO_R2.fastq.gz",
#         "shardIndex": -1,
#         "outputs": {
#           "outHtml": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-FastQCR2/1713_A_mScarlet_HTO_R2_fastqc.html",
#           "outZip": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-FastQCR2/1713_A_mScarlet_HTO_R2_fastqc.zip"
#         },
#         "runtimeAttributes": {
#           "failOnStderr": "false",
#           "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/default-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#           "disks": "local-disk /cromwell_root",
#           "continueOnReturnCode": "0",
#           "docker": "hisplan/cromwell-fastqc:0.11.8",
#           "maxRetries": "0",
#           "cpu": "4",
#           "cpuMin": "1",
#           "noAddress": "false",
#           "zones": "us-east-1a",
#           "memoryMin": "2 GB",
#           "memory": "16 GB"
#         },
#         "callCaching": {
#           "allowResultReuse": false,
#           "effectiveCallCachingMode": "CallCachingOff"
#         },
#         "inputs": {
#           "numCores": 4,
#           "dockerImage": "hisplan/cromwell-fastqc:0.11.8",
#           "fastqFile": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-MergeFastqR2/1713_A_mScarlet_HTO_R2.fastq.gz",
#           "inputSize": 1.95732731372118
#         },
#         "returnCode": 0,
#         "jobId": "e064bb51-0640-41c3-9ff6-3abd3c491296",
#         "backend": "AWSBATCH",
#         "end": "2020-01-11T02:52:12.597Z",
#         "dockerImageUsed": "hisplan/cromwell-fastqc@sha256:1b92481e73c96240701f1ecb7b02e8fde9dfbe4ba344a2756d37a1aa696cabb6",
#         "stderr": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-FastQCR2/FastQCR2-stderr.log",
#         "callRoot": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-FastQCR2",
#         "attempt": 1,
#         "executionEvents": [
#           {
#             "startTime": "2020-01-11T02:39:31.740Z",
#             "description": "RunningJob",
#             "endTime": "2020-01-11T02:52:11.720Z"
#           },
#           {
#             "startTime": "2020-01-11T02:39:27.772Z",
#             "description": "RequestingExecutionToken",
#             "endTime": "2020-01-11T02:39:31.711Z"
#           },
#           {
#             "startTime": "2020-01-11T02:52:11.720Z",
#             "description": "UpdatingJobStore",
#             "endTime": "2020-01-11T02:52:12.597Z"
#           },
#           {
#             "startTime": "2020-01-11T02:39:31.711Z",
#             "description": "PreparingJob",
#             "endTime": "2020-01-11T02:39:31.740Z"
#           },
#           {
#             "startTime": "2020-01-11T02:39:31.711Z",
#             "description": "WaitingForValueStore",
#             "endTime": "2020-01-11T02:39:31.711Z"
#           },
#           {
#             "startTime": "2020-01-11T02:39:27.772Z",
#             "description": "Pending",
#             "endTime": "2020-01-11T02:39:27.772Z"
#           }
#         ],
#         "start": "2020-01-11T02:39:27.772Z"
#       }
#     ],
#     "Sharp.HtoDemuxSeurat": [
#       {
#         "retryableFailure": false,
#         "executionStatus": "Failed",
#         "stdout": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-HtoDemuxSeurat/HtoDemuxSeurat-stdout.log",
#         "backendStatus": "Failed",
#         "compressedDockerSize": 677286273,
#         "commandLine": "set -euo pipefail\n\nmkdir inputs\n\ncp /cromwell_root/dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz /cromwell_root/dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz /cromwell_root/dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz ./inputs/\n\nmkdir outputs\n\nRscript --vanilla \\\n    /opt/hto-demux.R \\\n    ./inputs \\\n    ./outputs \\\n    0.99",
#         "shardIndex": -1,
#         "runtimeAttributes": {
#           "failOnStderr": "false",
#           "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/default-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#           "disks": "local-disk /cromwell_root",
#           "continueOnReturnCode": "0",
#           "docker": "hisplan/cromwell-hto-demux-seurat:0.5",
#           "maxRetries": "0",
#           "cpu": "2",
#           "cpuMin": "1",
#           "noAddress": "false",
#           "zones": "us-east-1a",
#           "memoryMin": "2 GB",
#           "memory": "16 GB"
#         },
#         "callCaching": {
#           "allowResultReuse": false,
#           "effectiveCallCachingMode": "CallCachingOff"
#         },
#         "inputs": {
#           "dockerImage": "hisplan/cromwell-hto-demux-seurat:0.5",
#           "umiCountFiles": [
#             "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#             "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#             "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#           ],
#           "numCores": 2,
#           "quantile": 0.99
#         },
#         "returnCode": 1,
#         "failures": [
#           {
#             "message": "Job Sharp.HtoDemuxSeurat:NA:1 exited with return code 1 which has not been declared as a valid return code. See 'continueOnReturnCode' runtime attribute for more details.",
#             "causedBy": []
#           }
#         ],
#         "jobId": "b61faff9-0176-49fc-95a9-838d33488bdf",
#         "backend": "AWSBATCH",
#         "end": "2020-01-11T03:02:48.596Z",
#         "stderr": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-HtoDemuxSeurat/HtoDemuxSeurat-stderr.log",
#         "callRoot": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-HtoDemuxSeurat",
#         "attempt": 1,
#         "executionEvents": [
#           {
#             "startTime": "2020-01-11T03:02:47.798Z",
#             "description": "UpdatingJobStore",
#             "endTime": "2020-01-11T03:02:48.596Z"
#           },
#           {
#             "startTime": "2020-01-11T03:01:41.826Z",
#             "description": "RunningJob",
#             "endTime": "2020-01-11T03:02:47.798Z"
#           },
#           {
#             "startTime": "2020-01-11T03:01:41.711Z",
#             "description": "PreparingJob",
#             "endTime": "2020-01-11T03:01:41.826Z"
#           },
#           {
#             "startTime": "2020-01-11T03:01:37.822Z",
#             "description": "RequestingExecutionToken",
#             "endTime": "2020-01-11T03:01:41.711Z"
#           },
#           {
#             "startTime": "2020-01-11T03:01:37.821Z",
#             "description": "Pending",
#             "endTime": "2020-01-11T03:01:37.822Z"
#           },
#           {
#             "startTime": "2020-01-11T03:01:41.711Z",
#             "description": "WaitingForValueStore",
#             "endTime": "2020-01-11T03:01:41.711Z"
#           }
#         ],
#         "start": "2020-01-11T03:01:37.821Z"
#       }
#     ],
#     "Sharp.MergeFastqR2": [
#       {
#         "executionStatus": "Done",
#         "stdout": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-MergeFastqR2/MergeFastqR2-stdout.log",
#         "backendStatus": "Succeeded",
#         "compressedDockerSize": 26725922,
#         "commandLine": "set -euo pipefail\n\nfilenames=\"/cromwell_root/dp-lab-data/sc-seq/Project_10477/A_mScarlet_HTO/FASTQ/1713_A_mScarlet_HTO_IGO_10477_12_S12_L001_R2_001.fastq.gz /cromwell_root/dp-lab-data/sc-seq/Project_10477/A_mScarlet_HTO/FASTQ/1713_A_mScarlet_HTO_IGO_10477_12_S12_L002_R2_001.fastq.gz\"\n\necho \"${filenames}\"\n\npath_out=\"1713_A_mScarlet_HTO_R2.fastq\"\n\necho \"${path_out}\"\n\n# gunzip and concatenate\nfor filename in $filenames\ndo\n    echo \"$filename > ${path_out}\"\n    gunzip -c ${filename} >> ${path_out}\ndone\n\n# gzip\ngzip ${path_out}",
#         "shardIndex": -1,
#         "outputs": {
#           "out": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-MergeFastqR2/1713_A_mScarlet_HTO_R2.fastq.gz"
#         },
#         "runtimeAttributes": {
#           "failOnStderr": "false",
#           "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/default-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#           "disks": "local-disk /cromwell_root",
#           "continueOnReturnCode": "0",
#           "docker": "ubuntu:18.04",
#           "maxRetries": "0",
#           "cpu": "2",
#           "cpuMin": "1",
#           "noAddress": "false",
#           "zones": "us-east-1a",
#           "memoryMin": "2 GB",
#           "memory": "8 GB"
#         },
#         "callCaching": {
#           "allowResultReuse": false,
#           "effectiveCallCachingMode": "CallCachingOff"
#         },
#         "inputs": {
#           "sampleName": "1713_A_mScarlet_HTO",
#           "readName": "R2",
#           "uriFastq": [
#             "s3://dp-lab-data/sc-seq/Project_10477/A_mScarlet_HTO/FASTQ/1713_A_mScarlet_HTO_IGO_10477_12_S12_L001_R2_001.fastq.gz",
#             "s3://dp-lab-data/sc-seq/Project_10477/A_mScarlet_HTO/FASTQ/1713_A_mScarlet_HTO_IGO_10477_12_S12_L002_R2_001.fastq.gz"
#           ],
#           "dockerImage": "ubuntu:18.04",
#           "numCores": 2
#         },
#         "returnCode": 0,
#         "jobId": "22abf0ff-b8d8-4f41-aaa7-779cafcf815f",
#         "backend": "AWSBATCH",
#         "end": "2020-01-11T02:39:26.599Z",
#         "dockerImageUsed": "ubuntu@sha256:2695d3e10e69cc500a16eae6d6629c803c43ab075fa5ce60813a0fc49c47e859",
#         "stderr": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-MergeFastqR2/MergeFastqR2-stderr.log",
#         "callRoot": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-MergeFastqR2",
#         "attempt": 1,
#         "executionEvents": [
#           {
#             "startTime": "2020-01-11T02:20:07.042Z",
#             "description": "Pending",
#             "endTime": "2020-01-11T02:20:07.042Z"
#           },
#           {
#             "startTime": "2020-01-11T02:39:25.722Z",
#             "description": "UpdatingJobStore",
#             "endTime": "2020-01-11T02:39:26.599Z"
#           },
#           {
#             "startTime": "2020-01-11T02:20:07.969Z",
#             "description": "RunningJob",
#             "endTime": "2020-01-11T02:39:25.722Z"
#           },
#           {
#             "startTime": "2020-01-11T02:20:07.711Z",
#             "description": "WaitingForValueStore",
#             "endTime": "2020-01-11T02:20:07.712Z"
#           },
#           {
#             "startTime": "2020-01-11T02:20:07.712Z",
#             "description": "PreparingJob",
#             "endTime": "2020-01-11T02:20:07.969Z"
#           },
#           {
#             "startTime": "2020-01-11T02:20:07.042Z",
#             "description": "RequestingExecutionToken",
#             "endTime": "2020-01-11T02:20:07.711Z"
#           }
#         ],
#         "start": "2020-01-11T02:20:07.041Z"
#       }
#     ],
#     "Sharp.MergeFastqR1": [
#       {
#         "executionStatus": "Done",
#         "stdout": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-MergeFastqR1/MergeFastqR1-stdout.log",
#         "backendStatus": "Succeeded",
#         "compressedDockerSize": 26725922,
#         "commandLine": "set -euo pipefail\n\nfilenames=\"/cromwell_root/dp-lab-data/sc-seq/Project_10477/A_mScarlet_HTO/FASTQ/1713_A_mScarlet_HTO_IGO_10477_12_S12_L001_R1_001.fastq.gz /cromwell_root/dp-lab-data/sc-seq/Project_10477/A_mScarlet_HTO/FASTQ/1713_A_mScarlet_HTO_IGO_10477_12_S12_L002_R1_001.fastq.gz\"\n\necho \"${filenames}\"\n\npath_out=\"1713_A_mScarlet_HTO_R1.fastq\"\n\necho \"${path_out}\"\n\n# gunzip and concatenate\nfor filename in $filenames\ndo\n    echo \"$filename > ${path_out}\"\n    gunzip -c ${filename} >> ${path_out}\ndone\n\n# gzip\ngzip ${path_out}",
#         "shardIndex": -1,
#         "outputs": {
#           "out": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-MergeFastqR1/1713_A_mScarlet_HTO_R1.fastq.gz"
#         },
#         "runtimeAttributes": {
#           "failOnStderr": "false",
#           "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/default-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#           "disks": "local-disk /cromwell_root",
#           "continueOnReturnCode": "0",
#           "docker": "ubuntu:18.04",
#           "maxRetries": "0",
#           "cpu": "2",
#           "cpuMin": "1",
#           "noAddress": "false",
#           "zones": "us-east-1a",
#           "memoryMin": "2 GB",
#           "memory": "8 GB"
#         },
#         "callCaching": {
#           "allowResultReuse": false,
#           "effectiveCallCachingMode": "CallCachingOff"
#         },
#         "inputs": {
#           "sampleName": "1713_A_mScarlet_HTO",
#           "readName": "R1",
#           "uriFastq": [
#             "s3://dp-lab-data/sc-seq/Project_10477/A_mScarlet_HTO/FASTQ/1713_A_mScarlet_HTO_IGO_10477_12_S12_L001_R1_001.fastq.gz",
#             "s3://dp-lab-data/sc-seq/Project_10477/A_mScarlet_HTO/FASTQ/1713_A_mScarlet_HTO_IGO_10477_12_S12_L002_R1_001.fastq.gz"
#           ],
#           "dockerImage": "ubuntu:18.04",
#           "numCores": 2
#         },
#         "returnCode": 0,
#         "jobId": "8a076922-5a4b-47e4-901d-1af7713615e2",
#         "backend": "AWSBATCH",
#         "end": "2020-01-11T02:32:37.602Z",
#         "dockerImageUsed": "ubuntu@sha256:2695d3e10e69cc500a16eae6d6629c803c43ab075fa5ce60813a0fc49c47e859",
#         "stderr": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-MergeFastqR1/MergeFastqR1-stderr.log",
#         "callRoot": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-MergeFastqR1",
#         "attempt": 1,
#         "executionEvents": [
#           {
#             "startTime": "2020-01-11T02:32:37.030Z",
#             "description": "UpdatingJobStore",
#             "endTime": "2020-01-11T02:32:37.602Z"
#           },
#           {
#             "startTime": "2020-01-11T02:20:09.712Z",
#             "description": "PreparingJob",
#             "endTime": "2020-01-11T02:20:09.715Z"
#           },
#           {
#             "endTime": "2020-01-11T02:20:09.711Z",
#             "startTime": "2020-01-11T02:20:07.042Z",
#             "description": "RequestingExecutionToken"
#           },
#           {
#             "startTime": "2020-01-11T02:20:07.042Z",
#             "description": "Pending",
#             "endTime": "2020-01-11T02:20:07.042Z"
#           },
#           {
#             "startTime": "2020-01-11T02:20:09.715Z",
#             "description": "RunningJob",
#             "endTime": "2020-01-11T02:32:37.030Z"
#           },
#           {
#             "startTime": "2020-01-11T02:20:09.711Z",
#             "description": "WaitingForValueStore",
#             "endTime": "2020-01-11T02:20:09.712Z"
#           }
#         ],
#         "start": "2020-01-11T02:20:07.042Z"
#       }
#     ]
#   },
#   "outputs": {},
#   "actualWorkflowLanguage": "WDL",
#   "id": "af1fa66d-943c-4343-84c7-8d3f476f34c1",
#   "inputs": {
#     "lengthR2": 25,
#     "scRnaSeqPlatform": "10x_v3",
#     "denseCountMatrix": "s3://dp-lab-data/collaborators/tammela/C57BL6/A_mScarlet/seqc-results/1713_A_mScarlet_IGO_10298_B_40_dense.csv",
#     "numExpectedCells": 0,
#     "slidingWindowSearch": false,
#     "cellBarcodeWhiteListMethod": "SeqcDenseCountsMatrixCsv",
#     "sampleName": "1713_A_mScarlet_HTO",
#     "hashTagList": "s3://dp-lab-data/sc-seq/Project_10477/A_mScarlet_HTO/Hashtag_results/tag-list.csv",
#     "umiEndPos": 28,
#     "uriFastqR2": [
#       "s3://dp-lab-data/sc-seq/Project_10477/A_mScarlet_HTO/FASTQ/1713_A_mScarlet_HTO_IGO_10477_12_S12_L001_R2_001.fastq.gz",
#       "s3://dp-lab-data/sc-seq/Project_10477/A_mScarlet_HTO/FASTQ/1713_A_mScarlet_HTO_IGO_10477_12_S12_L002_R2_001.fastq.gz"
#     ],
#     "cbCollapsingDistance": 1,
#     "umiStartPos": 17,
#     "Sharp.CutInDropSpacer.assayVersion": "2",
#     "umiCollapsingDistance": 1,
#     "cbEndPos": 16,
#     "cellBarcodeWhitelistUri": "s3://dp-lab-data/collaborators/tammela/C57BL6/A_mScarlet/seqc-results/1713_A_mScarlet_IGO_10298_B_40_dense.csv",
#     "lengthR1": 28,
#     "uriFastqR1": [
#       "s3://dp-lab-data/sc-seq/Project_10477/A_mScarlet_HTO/FASTQ/1713_A_mScarlet_HTO_IGO_10477_12_S12_L001_R1_001.fastq.gz",
#       "s3://dp-lab-data/sc-seq/Project_10477/A_mScarlet_HTO/FASTQ/1713_A_mScarlet_HTO_IGO_10477_12_S12_L002_R1_001.fastq.gz"
#     ],
#     "cbStartPos": 1,
#     "trimPos": 10,
#     "numCoresForCount": 8
#   },
#   "labels": {
#     "project": "Project 192",
#     "cromwell-workflow-id": "cromwell-af1fa66d-943c-4343-84c7-8d3f476f34c1",
#     "transfer": "-",
#     "comment": "1713_A_mScarlet_HTO",
#     "sample": "1713_A_mScarlet_HTO",
#     "pipelineType": "Sharp",
#     "owner": "masilioi",
#     "destination": "s3://dp-lab-data/sc-seq/Project_10477/A_mScarlet_HTO/Hashtag_results/"
#   },
#   "submission": "2020-01-11T02:20:02.466Z",
#   "status": "Failed",
#   "failures": [
#     {
#       "causedBy": [
#         {
#           "causedBy": [],
#           "message": "Job Sharp.HtoDemuxSeurat:NA:1 exited with return code 1 which has not been declared as a valid return code. See 'continueOnReturnCode' runtime attribute for more details."
#         }
#       ],
#       "message": "Workflow failed"
#     }
#   ],
#   "end": "2020-01-11T04:04:17.363Z",
#   "start": "2020-01-11T02:20:04.917Z"
# }

# %% [markdown]
# ## Get Sample Name

# %%
sample_name = metadata["labels"]["sample"]
sample_name
# Out:
# '1713_A_mScarlet_HTO'

# %% [markdown]
# ## Get Counts

# %%
def download(sample_name, workflow_id, subfolder, items):
    
    if skip_download:
        return
    
    if not isinstance(items, list):
        items = [items]
        
    path_output = f"{path_base_data}/{sample_name}/{workflow_id}/{subfolder}"
    
    os.makedirs(path_output, exist_ok=True)
        
    for item in items:
        cmd_download = f"aws s3 cp {item} {path_output}"
        print(cmd_download)
        os.system(cmd_download)

# %%
try:
    # sharp v0.0.4 (before 2020-10-26)
    meta_cite_seq_count = metadata["calls"]["Sharp.CiteSeqCount"][0]
except:
    # sharp v0.0.5 
    meta_cite_seq_count = metadata["calls"]["Sharp.Preprocess"][0]["subWorkflowMetadata"]["calls"]["Preprocess.CiteSeqCount"][0]

# %%
print(json.dumps(meta_cite_seq_count, indent=2))
# Out:
# {
#   "executionStatus": "Done",
#   "stdout": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/CiteSeqCount-stdout.log",
#   "backendStatus": "Succeeded",
#   "compressedDockerSize": 392564039,
#   "commandLine": "set -euo pipefail\n\nCITE-seq-Count \\\n    -R1 /cromwell_root/dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-TrimR1/R1.fastq.gz \\\n    -R2 /cromwell_root/dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-TrimR2/R2.fastq.gz \\\n    --tags /cromwell_root/dp-lab-data/sc-seq/Project_10477/A_mScarlet_HTO/Hashtag_results/tag-list.csv \\\n    -cbf 1 -cbl 16 \\\n    -umif 17 -umil 28 \\\n    --bc_collapsing_dist 1 \\\n    --umi_collapsing_dist 1 \\\n    --start-trim 10  \\\n    --expected_cells 0 \\\n    --whitelist /cromwell_root/dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-WhitelistFromSeqcDenseMatrix/cb-whitelist.txt \\\n    --output results \\\n    --dense \\\n    --unmapped-tags unmapped.csv \\\n    --threads 8",
#   "shardIndex": -1,
#   "outputs": {
#     "outUncorrected": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/results/uncorrected_cells/dense_umis.tsv",
#     "outReadCount": [
#       "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz",
#       "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz",
#       "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz"
#     ],
#     "outUmiDenseCount": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/results/dense_umis.tsv",
#     "outUnmapped": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/results/unmapped.csv",
#     "outUmiCount": [
#       "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#       "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#       "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#     ],
#     "outReport": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/results/run_report.yaml"
#   },
#   "runtimeAttributes": {
#     "failOnStderr": "false",
#     "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/default-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#     "disks": "local-disk /cromwell_root",
#     "continueOnReturnCode": "0",
#     "docker": "hisplan/cromwell-cite-seq-count:1.4.2-develop",
#     "maxRetries": "0",
#     "cpu": "8",
#     "cpuMin": "1",
#     "noAddress": "false",
#     "zones": "us-east-1a",
#     "memoryMin": "2 GB",
#     "memory": "32 GB"
#   },
#   "callCaching": {
#     "allowResultReuse": false,
#     "effectiveCallCachingMode": "CallCachingOff"
#   },
#   "inputs": {
#     "numExpectedCells": 0,
#     "slidingWindowSearch": false,
#     "hashTagList": "s3://dp-lab-data/sc-seq/Project_10477/A_mScarlet_HTO/Hashtag_results/tag-list.csv",
#     "umiEndPos": 28,
#     "cbCollapsingDistance": 1,
#     "umiStartPos": 17,
#     "fastqR2": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-TrimR2/R2.fastq.gz",
#     "dockerImage": "hisplan/cromwell-cite-seq-count:1.4.2-develop",
#     "fastqR1": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-TrimR1/R1.fastq.gz",
#     "umiCollapsingDistance": 1,
#     "cbEndPos": 16,
#     "cbWhiteList": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-WhitelistFromSeqcDenseMatrix/cb-whitelist.txt",
#     "inputSize": 1.778852440416813,
#     "cbStartPos": 1,
#     "trimPos": 10,
#     "numCores": 8
#   },
#   "returnCode": 0,
#   "jobId": "d4a1e3f1-1ed3-4b2b-ba98-bb97c490421b",
#   "backend": "AWSBATCH",
#   "end": "2020-01-11T03:01:36.600Z",
#   "dockerImageUsed": "hisplan/cromwell-cite-seq-count@sha256:b7e040ec487bf76ef704bbc93ddfc2e2054af873934a25f2d9afb31a18dde07d",
#   "stderr": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount/CiteSeqCount-stderr.log",
#   "callRoot": "s3://dp-lab-batch/cromwell-execution/Sharp/af1fa66d-943c-4343-84c7-8d3f476f34c1/call-CiteSeqCount",
#   "attempt": 1,
#   "executionEvents": [
#     {
#       "startTime": "2020-01-11T02:46:23.711Z",
#       "description": "PreparingJob",
#       "endTime": "2020-01-11T02:46:23.963Z"
#     },
#     {
#       "startTime": "2020-01-11T02:46:23.711Z",
#       "description": "WaitingForValueStore",
#       "endTime": "2020-01-11T02:46:23.711Z"
#     },
#     {
#       "startTime": "2020-01-11T03:01:35.817Z",
#       "description": "UpdatingJobStore",
#       "endTime": "2020-01-11T03:01:36.599Z"
#     },
#     {
#       "startTime": "2020-01-11T02:46:21.892Z",
#       "description": "RequestingExecutionToken",
#       "endTime": "2020-01-11T02:46:23.711Z"
#     },
#     {
#       "startTime": "2020-01-11T02:46:21.891Z",
#       "description": "Pending",
#       "endTime": "2020-01-11T02:46:21.892Z"
#     },
#     {
#       "startTime": "2020-01-11T02:46:23.963Z",
#       "description": "RunningJob",
#       "endTime": "2020-01-11T03:01:35.817Z"
#     }
#   ],
#   "start": "2020-01-11T02:46:21.891Z"
# }

# %% [markdown]
# ### Download Read Count

# %%
download(
    sample_name, workflow_id,
    "reads",
    meta_cite_seq_count["outputs"]["outReadCount"]
)

# %% [markdown]
# ### Download UMI Count

# %%
download(
    sample_name, workflow_id,
    "umis",
    meta_cite_seq_count["outputs"]["outUmiCount"]
)
# Out:
# aws s3 cp s3://dp-lab-batch/cromwell-execution/Sharp/36faf89a-e615-4baa-84a3-3de42994ff9f/call-Preprocess/Preprocess/3db70e37-6b61-4983-90da-d0ece27e59c5/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz ./data/2092_Adeno_fixed_InDrop2_2_HTO/36faf89a-e615-4baa-84a3-3de42994ff9f/umis
# aws s3 cp s3://dp-lab-batch/cromwell-execution/Sharp/36faf89a-e615-4baa-84a3-3de42994ff9f/call-Preprocess/Preprocess/3db70e37-6b61-4983-90da-d0ece27e59c5/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz ./data/2092_Adeno_fixed_InDrop2_2_HTO/36faf89a-e615-4baa-84a3-3de42994ff9f/umis
# aws s3 cp s3://dp-lab-batch/cromwell-execution/Sharp/36faf89a-e615-4baa-84a3-3de42994ff9f/call-Preprocess/Preprocess/3db70e37-6b61-4983-90da-d0ece27e59c5/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz ./data/2092_Adeno_fixed_InDrop2_2_HTO/36faf89a-e615-4baa-84a3-3de42994ff9f/umis

# %% [markdown]
# ## Download Report

# %%
download(
    sample_name, workflow_id,
    "report",
    meta_cite_seq_count["outputs"]["outReport"]
)
# Out:
# aws s3 cp s3://dp-lab-batch/cromwell-execution/Sharp/36faf89a-e615-4baa-84a3-3de42994ff9f/call-Preprocess/Preprocess/3db70e37-6b61-4983-90da-d0ece27e59c5/call-CiteSeqCount/results/run_report.yaml ./data/2092_Adeno_fixed_InDrop2_2_HTO/36faf89a-e615-4baa-84a3-3de42994ff9f/report

# %% [markdown]
# ## Get Demux Classification

# %%
meta_demux = metadata["calls"]["Sharp.HtoDemuxKMeans"][0]

# %%
print(json.dumps(meta_demux, indent=2))
# Out:
# {
#   "executionStatus": "Done",
#   "stdout": "s3://dp-lab-batch/cromwell-execution/Sharp/36faf89a-e615-4baa-84a3-3de42994ff9f/call-HtoDemuxKMeans/HtoDemuxKMeans-stdout.log",
#   "backendStatus": "Succeeded",
#   "compressedDockerSize": 336074657,
#   "commandLine": "set -euo pipefail\n\nmkdir inputs\n\ncp /cromwell_root/dp-lab-batch/cromwell-execution/Sharp/36faf89a-e615-4baa-84a3-3de42994ff9f/call-Preprocess/Preprocess/3db70e37-6b61-4983-90da-d0ece27e59c5/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz /cromwell_root/dp-lab-batch/cromwell-execution/Sharp/36faf89a-e615-4baa-84a3-3de42994ff9f/call-Preprocess/Preprocess/3db70e37-6b61-4983-90da-d0ece27e59c5/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz /cromwell_root/dp-lab-batch/cromwell-execution/Sharp/36faf89a-e615-4baa-84a3-3de42994ff9f/call-Preprocess/Preprocess/3db70e37-6b61-4983-90da-d0ece27e59c5/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz ./inputs/\n\n# --hto-umi-count-dir:  output directory from CITE-seq-Count\n#                       e.g. .../umi-count\n\npython3 /opt/demux_kmeans.py \\\n    --hto-umi-count-dir ./inputs",
#   "shardIndex": -1,
#   "outputs": {
#     "outLog": "s3://dp-lab-batch/cromwell-execution/Sharp/36faf89a-e615-4baa-84a3-3de42994ff9f/call-HtoDemuxKMeans/demux_kmeans.log",
#     "outStats": "s3://dp-lab-batch/cromwell-execution/Sharp/36faf89a-e615-4baa-84a3-3de42994ff9f/call-HtoDemuxKMeans/stats.yml",
#     "outClass": "s3://dp-lab-batch/cromwell-execution/Sharp/36faf89a-e615-4baa-84a3-3de42994ff9f/call-HtoDemuxKMeans/classification.tsv.gz"
#   },
#   "runtimeAttributes": {
#     "failOnStderr": "false",
#     "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/highpriority-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#     "disks": "local-disk /cromwell_root",
#     "continueOnReturnCode": "0",
#     "docker": "hisplan/cromwell-hto-demux-kmeans:0.4.0",
#     "maxRetries": "0",
#     "cpu": "1",
#     "cpuMin": "1",
#     "noAddress": "false",
#     "zones": "us-east-1a",
#     "memoryMin": "2 GB",
#     "memory": "32 GB"
#   },
#   "callCaching": {
#     "allowResultReuse": false,
#     "effectiveCallCachingMode": "CallCachingOff"
#   },
#   "inputs": {
#     "dockerImage": "hisplan/cromwell-hto-demux-kmeans:0.4.0",
#     "numCores": 1,
#     "umiCountFiles": [
#       "s3://dp-lab-batch/cromwell-execution/Sharp/36faf89a-e615-4baa-84a3-3de42994ff9f/call-Preprocess/Preprocess/3db70e37-6b61-4983-90da-d0ece27e59c5/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#       "s3://dp-lab-batch/cromwell-execution/Sharp/36faf89a-e615-4baa-84a3-3de42994ff9f/call-Preprocess/Preprocess/3db70e37-6b61-4983-90da-d0ece27e59c5/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#       "s3://dp-lab-batch/cromwell-execution/Sharp/36faf89a-e615-4baa-84a3-3de42994ff9f/call-Preprocess/Preprocess/3db70e37-6b61-4983-90da-d0ece27e59c5/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#     ]
#   },
#   "returnCode": 0,
#   "jobId": "8a70f4d0-715b-40e6-944f-e7f3c7c2155b",
#   "backend": "AWSBATCH",
#   "end": "2020-10-26T05:54:09.090Z",
#   "dockerImageUsed": "hisplan/cromwell-hto-demux-kmeans@sha256:3354a9f2076346c04c7425721d67726ebd77a93d02dcb6ef3a8cfcd47dfc80b3",
#   "stderr": "s3://dp-lab-batch/cromwell-execution/Sharp/36faf89a-e615-4baa-84a3-3de42994ff9f/call-HtoDemuxKMeans/HtoDemuxKMeans-stderr.log",
#   "callRoot": "s3://dp-lab-batch/cromwell-execution/Sharp/36faf89a-e615-4baa-84a3-3de42994ff9f/call-HtoDemuxKMeans",
#   "attempt": 1,
#   "executionEvents": [
#     {
#       "startTime": "2020-10-26T05:46:05.660Z",
#       "description": "Pending",
#       "endTime": "2020-10-26T05:46:05.660Z"
#     },
#     {
#       "startTime": "2020-10-26T05:46:05.660Z",
#       "description": "RequestingExecutionToken",
#       "endTime": "2020-10-26T05:46:07.269Z"
#     },
#     {
#       "startTime": "2020-10-26T05:46:07.664Z",
#       "description": "RunningJob",
#       "endTime": "2020-10-26T05:54:08.113Z"
#     },
#     {
#       "startTime": "2020-10-26T05:46:07.269Z",
#       "description": "PreparingJob",
#       "endTime": "2020-10-26T05:46:07.664Z"
#     },
#     {
#       "startTime": "2020-10-26T05:54:08.113Z",
#       "description": "UpdatingJobStore",
#       "endTime": "2020-10-26T05:54:09.090Z"
#     },
#     {
#       "startTime": "2020-10-26T05:46:07.269Z",
#       "description": "WaitingForValueStore",
#       "endTime": "2020-10-26T05:46:07.269Z"
#     }
#   ],
#   "start": "2020-10-26T05:46:05.660Z"
# }

# %%
download(
    sample_name, workflow_id,
    "",
    meta_demux["outputs"]["outClass"]
)
# Out:
# aws s3 cp s3://dp-lab-batch/cromwell-execution/Sharp/36faf89a-e615-4baa-84a3-3de42994ff9f/call-HtoDemuxKMeans/classification.tsv.gz ./data/2092_Adeno_fixed_InDrop2_2_HTO/36faf89a-e615-4baa-84a3-3de42994ff9f/

# %% [markdown]
# ## Output Sample Name

# %%
# 1. DO NOT DELETE
# 2. MUST BE THE FINAL LINE
print(sample_name)
# Out:
# 2092_Adeno_fixed_InDrop2_2_HTO
