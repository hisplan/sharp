# %%
import os
import json

import requests
from requests.exceptions import HTTPError
from requests.auth import HTTPBasicAuth

# %% [markdown]
# ## Parameters

# %%
# this cell is tagged `parameters` and will be overridden by papermill

workflow_id = "c3a941bf-62ed-469e-8ee6-d7448cdee457"

path_secrets_file = "/Users/chunj/keys/cromwell-secrets-aws-nvirginia.json"
path_base_data = "./hashtag"
skip_download = False

# %% [markdown]
# ## APIs to Cromwell

# %%
def get_secrets(path_secrets_file):

    with open(path_secrets_file, "rt") as fin:
        data = json.loads(fin.read())

    return data

def prep_api_call(secrets):

    api_version = "v1"
    url = secrets["url"]
    url = f"{url}/api/workflows/{api_version}"

    auth = HTTPBasicAuth(secrets["username"], secrets["password"])

    return url, auth

def get_metadata(secrets, workflow_id):

    base_url, auth = prep_api_call(secrets)

    try:
        response = requests.patch(
            url=f"{base_url}/{workflow_id}/metadata?expandSubWorkflows=true",
            headers={
                "Content-Type": "application/json",
                "Accept": "application/json"
            },
            auth=auth
        )

        # if response.status_code == 200:
        data = response.json()

        return data

    except HTTPError as err:
        print(err)

# %% [markdown]
# ## Get Metadata

# %%
metadata = get_metadata(
    get_secrets(path_secrets_file),
    workflow_id
)

# %%
print(json.dumps(metadata, indent=2))
# Out:
# {
#   "workflowName": "Hashtag",
#   "workflowProcessingEvents": [
#     {
#       "cromwellId": "cromid-aa4a0ba",
#       "description": "PickedUp",
#       "timestamp": "2021-07-26T01:44:57.333Z",
#       "cromwellVersion": "59"
#     },
#     {
#       "cromwellId": "cromid-aa4a0ba",
#       "description": "Finished",
#       "timestamp": "2021-07-26T01:57:04.657Z",
#       "cromwellVersion": "59"
#     }
#   ],
#   "metadataSource": "Unarchived",
#   "actualWorkflowLanguageVersion": "1.0",
#   "submittedFiles": {
#     "workflow": "version 1.0\n\nimport \"modules/Preprocess.wdl\" as Preprocess\nimport \"modules/HtoDemuxSeurat.wdl\" as HtoDemuxSeurat\nimport \"modules/HtoDemuxKMeans.wdl\" as HtoDemuxKMeans\nimport \"modules/Combine.wdl\" as Combine\nimport \"modules/AnnData.wdl\" as AnnData\n\nworkflow Hashtag {\n\n    input {\n        Array[File] uriFastqR1\n        Array[File] uriFastqR2\n\n        Int lengthR1\n        Int lengthR2\n\n        String sampleName\n\n        File cellBarcodeWhitelistUri\n        String cellBarcodeWhiteListMethod\n\n        # set to false if TotalSeq-A is used\n        # set to true if TotalSeq-B or C is used\n        Boolean translate10XBarcodes\n\n        String scRnaSeqPlatform = \"10x_v3\"\n\n        File hashTagList\n\n        # cellular barcode start/end positions\n        Int cbStartPos\n        Int cbEndPos\n\n        # UMI start/end positions\n        Int umiStartPos\n        Int umiEndPos\n\n        # how many bases should we trim before starting to look for hashtag sequence\n        Int trimPos = 0\n\n        # activate sliding window alignement\n        Boolean slidingWindowSearch = false\n\n        # correction\n        Int cbCollapsingDistance\n        Int umiCollapsingDistance\n        Int maxTagError = 2\n\n        Int numExpectedCells\n\n        File denseCountMatrix\n\n        Boolean runSeuratDemux = false\n        Int demuxMode = 1\n        Int minCount = 0\n\n        Map[String, Int] resourceSpec\n\n        # docker-related\n        String dockerRegistry\n    }\n\n    parameter_meta {\n        demuxMode: { help: \"1=default, 2=noisy methanol, 3=aggressively rescue from doublets\" }\n    }\n\n    call Preprocess.Preprocess {\n        input:\n            uriFastqR1 = uriFastqR1,\n            uriFastqR2 = uriFastqR2,\n            lengthR1 = lengthR1,\n            lengthR2 = lengthR2,\n            sampleName = sampleName,\n            cellBarcodeWhitelistUri = cellBarcodeWhitelistUri,\n            cellBarcodeWhiteListMethod = cellBarcodeWhiteListMethod,\n            translate10XBarcodes = translate10XBarcodes,\n            scRnaSeqPlatform = scRnaSeqPlatform,\n            tagList = hashTagList,\n            cbStartPos = cbStartPos,\n            cbEndPos = cbEndPos,\n            umiStartPos = umiStartPos,\n            umiEndPos = umiEndPos,\n            trimPos = trimPos,\n            slidingWindowSearch = slidingWindowSearch,\n            cbCollapsingDistance = cbCollapsingDistance,\n            umiCollapsingDistance = umiCollapsingDistance,\n            maxTagError = maxTagError,\n            numExpectedCells = numExpectedCells,\n            resourceSpec = resourceSpec,\n            dockerRegistry = dockerRegistry\n    }\n\n    # HTO demux using KMeans\n    call HtoDemuxKMeans.HtoDemuxKMeans {\n        input:\n            umiCountFiles = Preprocess.umiCountMatrix,\n            minCount = minCount,\n            mode = demuxMode,\n            dockerRegistry = dockerRegistry\n    }\n\n    # HTO demux using Seurat\n    if (runSeuratDemux == true) {\n\n        call HtoDemuxSeurat.HtoDemuxSeurat {\n            input:\n                umiCountFiles = Preprocess.umiCountMatrix,\n                quantile = 0.99,\n                dockerRegistry = dockerRegistry\n        }\n\n        # correct false positive doublets frm Seurat output\n        call HtoDemuxSeurat.CorrectFalsePositiveDoublets {\n            input:\n                htoClassification = HtoDemuxSeurat.outClassCsv,\n                umiCountFiles = Preprocess.umiCountMatrix,\n                dockerRegistry = dockerRegistry\n        }\n    }\n\n    # combine count matrix with hashtag\n    call Combine.HashedCountMatrix {\n        input:\n            denseCountMatrix = denseCountMatrix,\n            htoClassification = HtoDemuxKMeans.outClass,\n            translate10XBarcodes = translate10XBarcodes,\n            dockerRegistry = dockerRegistry\n    }\n\n    call AnnData.UpdateAnnData {\n        input:\n            sampleName = sampleName,\n ...
#     "root": "",
#     "options": "{\n  \"default_runtime_attributes\": {\n    \"maxRetries\": 3\n  },\n  \"write_to_cache\": true,\n  \"workflow_failure_mode\": \"ContinueWhilePossible\",\n  \"read_from_cache\": true,\n  \"monitoring_script\": \"s3://dp-lab-batch/monitoring.sh\"\n}",
#     "inputs": "{\"Hashtag.cbCollapsingDistance\":1,\"Hashtag.cbEndPos\":16,\"Hashtag.cbStartPos\":1,\"Hashtag.cellBarcodeWhiteListMethod\":\"SeqcDenseCountsMatrixCsv\",\"Hashtag.cellBarcodeWhitelistUri\":\"s3://dp-lab-data/collaborators/hsuk/7xNK/HD1915_7xNK/seqc-results/1973_HD1915_7xNK_IGO_10657_2_dense.csv\",\"Hashtag.denseCountMatrix\":\"s3://dp-lab-data/collaborators/hsuk/7xNK/HD1915_7xNK/seqc-results/1973_HD1915_7xNK_IGO_10657_2_dense.csv\",\"Hashtag.dockerRegistry\":\"hisplan\",\"Hashtag.hashTagList\":\"s3://dp-lab-data/collaborators/hsuk/7xNK/HD1915_7xNK_FB_HTO/Hashtag_results/tag-list.csv\",\"Hashtag.lengthR1\":28,\"Hashtag.lengthR2\":25,\"Hashtag.numExpectedCells\":0,\"Hashtag.resourceSpec\":{\"cpu\":32,\"memory\":64},\"Hashtag.sampleName\":\"1973_HD1915_7xNK_FB_HTO\",\"Hashtag.scRnaSeqPlatform\":\"10x_v3\",\"Hashtag.slidingWindowSearch\":false,\"Hashtag.translate10XBarcodes\":true,\"Hashtag.trimPos\":10,\"Hashtag.umiCollapsingDistance\":1,\"Hashtag.umiEndPos\":28,\"Hashtag.umiStartPos\":17,\"Hashtag.uriFastqR1\":[\"s3://dp-lab-data/collaborators/hsuk/7xNK/HD1915_7xNK_FB_HTO/FASTQ/HD1915_7xNK_FB_IGO_10657_B_2_S2_L001_R1_001.fastq.gz\",\"s3://dp-lab-data/collaborators/hsuk/7xNK/HD1915_7xNK_FB_HTO/FASTQ/HD1915_7xNK_FB_IGO_10657_B_2_S2_L002_R1_001.fastq.gz\"],\"Hashtag.uriFastqR2\":[\"s3://dp-lab-data/collaborators/hsuk/7xNK/HD1915_7xNK_FB_HTO/FASTQ/HD1915_7xNK_FB_IGO_10657_B_2_S2_L001_R2_001.fastq.gz\",\"s3://dp-lab-data/collaborators/hsuk/7xNK/HD1915_7xNK_FB_HTO/FASTQ/HD1915_7xNK_FB_IGO_10657_B_2_S2_L002_R2_001.fastq.gz\"]}",
#     "workflowUrl": "",
#     "labels": "{\n    \"pipelineType\": \"Sharp\",\n    \"project\": \"Project 226\",\n    \"sample\": \"1973_HD1915_7xNK_FB_HTO\",\n    \"owner\": \"chunj\",\n    \"destination\": \"s3://dp-lab-test/sharp/hashtag/10x-v3-totalseq-B/\",\n    \"transfer\": \"-\",\n    \"comment\": \"10x v3 TotalSeq-B\"\n}"
#   },
#   "calls": {
#     "Hashtag.HashedCountMatrix": [
#       {
#         "executionStatus": "Done",
#         "stdout": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HashedCountMatrix/HashedCountMatrix-stdout.log",
#         "backendStatus": "Succeeded",
#         "compressedDockerSize": 585162468,
#         "commandLine": "set -euo pipefail\n\npython3 /opt/combine.py \\\n    --dense-count-matrix /cromwell_root/dp-lab-data/collaborators/hsuk/7xNK/HD1915_7xNK/seqc-results/1973_HD1915_7xNK_IGO_10657_2_dense.csv \\\n    --hto-classification /cromwell_root/dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HtoDemuxKMeans/cacheCopy/classification.tsv.gz \\\n    --hto-gex-mapper /opt/data/10x-hto-gex-mapper.pickle --10x-barcode-translation",
#         "shardIndex": -1,
#         "outputs": {
#           "outClass": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HashedCountMatrix/final-classification.tsv.gz",
#           "outStats": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HashedCountMatrix/stats.yml",
#           "outCountMatrix": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HashedCountMatrix/final-matrix.tsv.gz",
#           "outLog": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HashedCountMatrix/combine.log"
#         },
#         "runtimeAttributes": {
#           "failOnStderr": "false",
#           "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/priority-gwf-core",
#           "disks": "local-disk /cromwell_root",
#           "continueOnReturnCode": "0",
#           "docker": "hisplan/cromwell-hto-adt-postprocess:0.3.3",
#           "scriptBucketName": "dp-lab-gwf-core",
#           "maxRetries": "3",
#           "cpu": "1",
#           "cpuMin": "1",
#           "noAddress": "false",
#           "zones": "us-east-1a",
#           "memoryMin": "2 GB",
#           "memory": "32 GB"
#         },
#         "callCaching": {
#           "allowResultReuse": true,
#           "hit": false,
#           "result": "Cache Miss",
#           "hashes": {
#             "output count": "A87FF679A2F3E71D9181A67B7542122C",
#             "runtime attribute": {
#               "docker": "C0453230DDCB45B1A0824557B543F5BD",
#               "continueOnReturnCode": "CFCD208495D565EF66E7DFF9F98764DA",
#               "failOnStderr": "68934A3E9455FA72420237EB05902327"
#             },
#             "output expression": {
#               "File outClass": "C04B1C13365777BFB952EB2F6AEE4A6A",
#               "File outLog": "B90CB6632AD46D75EBF95C6A3048B1E0",
#               "File outCountMatrix": "9B0B0260823E98E08FC8436A2CF942BF",
#               "File outStats": "33F56C7B084B6CAF4B339B0846FA61B8"
#             },
#             "input count": "8F14E45FCEEA167A5A36DEDD4BEA2543",
#             "backend name": "2267EF43AEF6BB551F414FEC2390F68A",
#             "command template": "7F5DFED98626535279789614C813D42A",
#             "input": {
#               "String dockerImage": "3DC154285188BAE455441FA11F0ABE76",
#               "Boolean translate10XBarcodes": "B326B5062B2F0E69046810717534CB09",
#               "File htoClassification": "\"5b4db38ca2052f608c16ea8d9d888a6a\"",
#               "File denseCountMatrix": "\"6b5163a02cb001ab7255b887011a9dbd-47\"",
#               "Float inputSize": "CCBA546654E0440C7CBDBF75212F345E",
#               "String dockerRegistry": "38A1E69002366B36B0025741498F4427",
#               "Int numCores": "C4CA4238A0B923820DCC509A6F75849B"
#             }
#           },
#           "effectiveCallCachingMode": "ReadAndWriteCache"
#         },
#         "inputs": {
#           "denseCountMatrix": "s3://dp-lab-data/collaborators/hsuk/7xNK/HD1915_7xNK/seqc-results/1973_HD1915_7xNK_IGO_10657_2_dense.csv",
#           "dockerRegistry": "hisplan",
#           "dockerImage": "hisplan/cromwell-hto-adt-postprocess:0.3.3",
#           "htoClassification": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HtoDemuxKMeans/cacheCopy/classification.tsv.gz",
#           "inputSize": 0.36445894464850426,
#           "translate10XBarcodes": true,
#           "numCores": 1
#         },
#         "returnCode": 0,
#         "jobId": "3410d419-4135-425b-9845-cb5aa4f54fb7",
#         "backend": "AWSBATCH",
#         "end": "2021-07-26T01:57:02.697Z",
#         "dockerImageUsed": "hisplan/cromwell-hto-adt-postprocess@sha256:76d06cd1d3619199f234729eae40e551f2954b8720ca6b57663aa72c77472ebd",
#         "stderr": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HashedCountMatrix/HashedCountMatrix-stderr.log",
#         "callRoot": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HashedCountMatrix",
#         "attempt": 1,
#         "executionEvents": [
#           {
#             "startTime": "2021-07-26T01:50:16.874Z",
#             "description": "WaitingForValueStore",
#             "endTime": "2021-07-26T01:50:16.874Z"
#           },
#           {
#             "startTime": "2021-07-26T01:57:01.496Z",
#             "description": "UpdatingCallCache",
#             "endTime": "2021-07-26T01:57:01.716Z"
#           },
#           {
#             "startTime": "2021-07-26T01:50:16.666Z",
#             "description": "Pending",
#             "endTime": "2021-07-26T01:50:16.666Z"
#           },
#           {
#             "startTime": "2021-07-26T01:57:01.716Z",
#             "description": "UpdatingJobStore",
#             "endTime": "2021-07-26T01:57:02.697Z"
#           },
#           {
#             "startTime": "2021-07-26T01:50:17.069Z",
#             "description": "CallCacheReading",
#             "endTime": "2021-07-26T01:50:17.102Z"
#           },
#           {
#             "startTime": "2021-07-26T01:50:16.666Z",
#             "description": "RequestingExecutionToken",
#             "endTime": "2021-07-26T01:50:16.874Z"
#           },
#           {
#             "startTime": "2021-07-26T01:50:16.874Z",
#             "description": "PreparingJob",
#             "endTime": "2021-07-26T01:50:17.069Z"
#           },
#           {
#             "startTime": "2021-07-26T01:50:17.102Z",
#             "description": "RunningJob",
#             "endTime": "2021-07-26T01:57:01.496Z"
#           }
#         ],
#         "start": "2021-07-26T01:50:16.665Z"
#       }
#     ],
#     "Hashtag.HtoDemuxKMeans": [
#       {
#         "executionStatus": "Done",
#         "stdout": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HtoDemuxKMeans/HtoDemuxKMeans-stdout.log",
#         "compressedDockerSize": 331772747,
#         "shardIndex": -1,
#         "outputs": {
#           "outLog": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HtoDemuxKMeans/cacheCopy/demux_kmeans.log",
#           "outStats": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HtoDemuxKMeans/cacheCopy/stats.yml",
#           "outClass": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HtoDemuxKMeans/cacheCopy/classification.tsv.gz"
#         },
#         "runtimeAttributes": {
#           "failOnStderr": "false",
#           "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/priority-gwf-core",
#           "disks": "local-disk /cromwell_root",
#           "continueOnReturnCode": "0",
#           "docker": "hisplan/cromwell-hto-demux-kmeans:0.5.0",
#           "scriptBucketName": "dp-lab-gwf-core",
#           "maxRetries": "3",
#           "cpu": "1",
#           "cpuMin": "1",
#           "noAddress": "false",
#           "zones": "us-east-1a",
#           "memoryMin": "2 GB",
#           "memory": "32 GB"
#         },
#         "callCaching": {
#           "allowResultReuse": true,
#           "hit": true,
#           "result": "Cache Hit: e310f49b-44df-4ed0-a723-738a4ff06480:Hashtag.HtoDemuxKMeans:-1",
#           "hashes": {
#             "output count": "ECCBC87E4B5CE2FE28308FD9F2A7BAF3",
#             "runtime attribute": {
#               "docker": "1450F3A8348454304F37EB0CD4F9F74C",
#               "continueOnReturnCode": "CFCD208495D565EF66E7DFF9F98764DA",
#               "failOnStderr": "68934A3E9455FA72420237EB05902327"
#             },
#             "output expression": {
#               "File outClass": "EA901A865B3AC121C9BFCBB6FEDAF09A",
#               "File outLog": "1CEE887B77436F8BA42E12DD267860F7",
#               "File outStats": "33F56C7B084B6CAF4B339B0846FA61B8"
#             },
#             "input count": "45C48CCE2E2D7FBDEA1AFC51C7C6AD26",
#             "backend name": "2267EF43AEF6BB551F414FEC2390F68A",
#             "command template": "EF9AD0939AE065446D2B027DBE43E956",
#             "input": {
#               "String dockerImage": "87CB22A98A308AE4C12B6553B9C224F5",
#               "File umiCountFiles": [
#                 "\"8bbf85313948c5e03132de41dbddcd3a\"",
#                 "\"d36ce2ccc9ec427e61e1226d6a5a8676\"",
#                 "\"140f710c5a9385b099e0fdac9b3738e1\""
#               ],
#               "Float inputSize": "702DC8D32469F0E2BDAB4BA30D581C90",
#               "Int minCount": "CFCD208495D565EF66E7DFF9F98764DA",
#               "Int mode": "C4CA4238A0B923820DCC509A6F75849B",
#               "String dockerRegistry": "38A1E69002366B36B0025741498F4427",
#               "Int numCores": "C4CA4238A0B923820DCC509A6F75849B"
#             }
#           },
#           "effectiveCallCachingMode": "ReadAndWriteCache"
#         },
#         "inputs": {
#           "umiCountFiles": [
#             "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#             "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#             "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#           ],
#           "dockerRegistry": "hisplan",
#           "dockerImage": "hisplan/cromwell-hto-demux-kmeans:0.5.0",
#           "mode": 1,
#           "inputSize": 0.00022793468087911606,
#           "minCount": 0,
#           "numCores": 1
#         },
#         "returnCode": 0,
#         "backend": "AWSBATCH",
#         "end": "2021-07-26T01:50:14.699Z",
#         "stderr": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HtoDemuxKMeans/HtoDemuxKMeans-stderr.log",
#         "callRoot": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HtoDemuxKMeans",
#         "attempt": 1,
#         "executionEvents": [
#           {
#             "startTime": "2021-07-26T01:50:09.525Z",
#             "description": "Pending",
#             "endTime": "2021-07-26T01:50:09.525Z"
#           },
#           {
#             "startTime": "2021-07-26T01:50:09.525Z",
#             "description": "RequestingExecutionToken",
#             "endTime": "2021-07-26T01:50:10.875Z"
#           },
#           {
#             "startTime": "2021-07-26T01:50:10.875Z",
#             "description": "WaitingForValueStore",
#             "endTime": "2021-07-26T01:50:10.875Z"
#           },
#           {
#             "startTime": "2021-07-26T01:50:10.875Z",
#             "description": "PreparingJob",
#             "endTime": "2021-07-26T01:50:11.356Z"
#           },
#           {
#             "startTime": "2021-07-26T01:50:13.717Z",
#             "description": "UpdatingJobStore",
#             "endTime": "2021-07-26T01:50:14.699Z"
#           },
#           {
#             "startTime": "2021-07-26T01:50:11.356Z",
#             "description": "CallCacheReading",
#             "endTime": "2021-07-26T01:50:11.845Z"
#           },
#           {
#             "startTime": "2021-07-26T01:50:11.845Z",
#             "description": "UpdatingCallCache",
#             "endTime": "2021-07-26T01:50:13.717Z"
#           }
#         ],
#         "start": "2021-07-26T01:50:09.525Z"
#       }
#     ],
#     "Hashtag.Preprocess": [
#       {
#         "executionStatus": "Done",
#         "subWorkflowMetadata": {
#           "workflowName": "Preprocess",
#           "rootWorkflowId": "c3a941bf-62ed-469e-8ee6-d7448cdee457",
#           "calls": {
#             "Preprocess.WhitelistFromSeqcDenseMatrix": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-WhitelistFromSeqcDenseMatrix/WhitelistFromSeqcDenseMatrix-stdout.log",
#                 "compressedDockerSize": 1039356492,
#                 "shardIndex": -1,
#                 "outputs": {
#                   "out": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-WhitelistFromSeqcDenseMatrix/cacheCopy/cb-whitelist.txt"
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/priority-gwf-core",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "hisplan/cromwell-seqc:0.2.9",
#                   "scriptBucketName": "dp-lab-gwf-core",
#                   "maxRetries": "3",
#                   "cpu": "1",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "32 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": true,
#                   "hit": true,
#                   "result": "Cache Hit: 296d6973-1d1b-4767-a1ea-986b8991e685:Preprocess.WhitelistFromSeqcDenseMatrix:-1",
#                   "hashes": {
#                     "output count": "C4CA4238A0B923820DCC509A6F75849B",
#                     "runtime attribute": {
#                       "docker": "548248130BF4F7E97B2F2DBADA05443A",
#                       "continueOnReturnCode": "CFCD208495D565EF66E7DFF9F98764DA",
#                       "failOnStderr": "68934A3E9455FA72420237EB05902327"
#                     },
#                     "output expression": {
#                       "File out": "11D4C16C9B74653A9168DF6C272C2A19"
#                     },
#                     "input count": "E4DA3B7FBBCE2345D7772B0674A318D5",
#                     "backend name": "2267EF43AEF6BB551F414FEC2390F68A",
#                     "command template": "8B47BB32B9F8748223F4FF5390096456",
#                     "input": {
#                       "String dockerImage": "F299ED1E6C44515213B2E1E9DCF03F2F",
#                       "File csvFile": "\"6b5163a02cb001ab7255b887011a9dbd-47\"",
#                       "Float inputSize": "89888B5087355A10462214001A9B8B1C",
#                       "String dockerRegistry": "38A1E69002366B36B0025741498F4427",
#                       "Int numCores": "C4CA4238A0B923820DCC509A6F75849B"
#                     }
#                   },
#                   "effectiveCallCachingMode": "ReadAndWriteCache"
#                 },
#                 "inputs": {
#                   "dockerRegistry": "hisplan",
#                   "dockerImage": "hisplan/cromwell-seqc:0.2.9",
#                   "csvFile": "s3://dp-lab-data/collaborators/hsuk/7xNK/HD1915_7xNK/seqc-results/1973_HD1915_7xNK_IGO_10657_2_dense.csv",
#                   "inputSize": 0.36437771562486887,
#                   "numCores": 1
#                 },
#                 "returnCode": 0,
#                 "backend": "AWSBATCH",
#                 "end": "2021-07-26T01:45:08.698Z",
#                 "stderr": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-WhitelistFromSeqcDenseMatrix/WhitelistFromSeqcDenseMatrix-stderr.log",
#                 "callRoot": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-WhitelistFromSeqcDenseMatrix",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2021-07-26T01:45:03.608Z",
#                     "description": "Pending",
#                     "endTime": "2021-07-26T01:45:03.608Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T01:45:06.981Z",
#                     "description": "CallCacheReading",
#                     "endTime": "2021-07-26T01:45:07.396Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T01:45:07.710Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2021-07-26T01:45:08.698Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T01:45:06.875Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2021-07-26T01:45:06.875Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T01:45:07.396Z",
#                     "description": "UpdatingCallCache",
#                     "endTime": "2021-07-26T01:45:07.710Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T01:45:06.875Z",
#                     "description": "PreparingJob",
#                     "endTime": "2021-07-26T01:45:06.981Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T01:45:03.608Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2021-07-26T01:45:06.875Z"
#                   }
#                 ],
#                 "start": "2021-07-26T01:45:03.607Z"
#               }
#             ],
#             "Preprocess.TrimR1": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-TrimR1/TrimR1-stdout.log",
#                 "compressedDockerSize": 210532600,
#                 "shardIndex": -1,
#                 "outputs": {
#                   "outFile": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-TrimR1/cacheCopy/R1.fastq.gz",
#                   "outTooShortTooLongFiles": [
#                     "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-TrimR1/cacheCopy/glob-c763acd1bbc2c02eb59e93c44eda4fa9/too-short.R1.fastq.gz"
#                   ]
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/priority-gwf-core",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "hisplan/cromwell-cutadapt:2.5",
#                   "scriptBucketName": "dp-lab-gwf-core",
#                   "maxRetries": "3",
#                   "cpu": "4",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "16 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": true,
#                   "hit": true,
#                   "result": "Cache Hit: 296d6973-1d1b-4767-a1ea-986b8991e685:Preprocess.TrimR1:-1",
#                   "hashes": {
#                     "output count": "C81E728D9D4C2F636F067F89CC14862C",
#                     "runtime attribute": {
#                       "docker": "E34FD9F412743311B69327E0386E0392",
#                       "continueOnReturnCode": "CFCD208495D565EF66E7DFF9F98764DA",
#                       "failOnStderr": "68934A3E9455FA72420237EB05902327"
#                     },
#                     "output expression": {
#                       "Array(File) outTooShortTooLongFiles": "691E31671F2E94594A9D9001F732FB28",
#                       "File outFile": "CFE5E63191065897E66F20C60D94ED19"
#                     },
#                     "input count": "1679091C5A880FAF6FB5E6087EB1B2DC",
#                     "backend name": "2267EF43AEF6BB551F414FEC2390F68A",
#                     "command template": "240300DFD7E5F66C7B2F9162F6A1C02B",
#                     "input": {
#                       "String dockerImage": "5F34A812D947CB07E57FBD178CA5245B",
#                       "String outFileName": "196C8A728E9EFD6E8DA0435DE17AE63F",
#                       "Int length": "33E75FF09DD601BBE69F351039152189",
#                       "String dockerRegistry": "38A1E69002366B36B0025741498F4427",
#                       "File fastq": "\"d99e033cffea75b3d2aef259958abf11\"",
#                       "Int numCores": "A87FF679A2F3E71D9181A67B7542122C"
#                     }
#                   },
#                   "effectiveCallCachingMode": "ReadAndWriteCache"
#                 },
#                 "inputs": {
#                   "outFileName": "R1.fastq.gz",
#                   "dockerRegistry": "hisplan",
#                   "dockerImage": "hisplan/cromwell-cutadapt:2.5",
#                   "length": 28,
#                   "fastq": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-MergeFastqR1/cacheCopy/1973_HD1915_7xNK_FB_HTO_R1.fastq.gz",
#                   "numCores": 4
#                 },
#                 "returnCode": 0,
#                 "backend": "AWSBATCH",
#                 "end": "2021-07-26T01:45:26.789Z",
#                 "stderr": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-TrimR1/TrimR1-stderr.log",
#                 "callRoot": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-TrimR1",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2021-07-26T01:45:12.785Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2021-07-26T01:45:16.874Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T01:45:12.785Z",
#                     "description": "Pending",
#                     "endTime": "2021-07-26T01:45:12.785Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T01:45:25.718Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2021-07-26T01:45:26.789Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T01:45:16.914Z",
#                     "description": "CallCacheReading",
#                     "endTime": "2021-07-26T01:45:23.383Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T01:45:16.875Z",
#                     "description": "PreparingJob",
#                     "endTime": "2021-07-26T01:45:16.914Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T01:45:16.874Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2021-07-26T01:45:16.875Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T01:45:23.383Z",
#                     "description": "UpdatingCallCache",
#                     "endTime": "2021-07-26T01:45:25.718Z"
#                   }
#                 ],
#                 "start": "2021-07-26T01:45:12.785Z"
#               }
#             ],
#             "Preprocess.FastQCR2": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-FastQCR2/FastQCR2-stdout.log",
#                 "compressedDockerSize": 138864024,
#                 "shardIndex": -1,
#                 "outputs": {
#                   "outZip": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-FastQCR2/cacheCopy/1973_HD1915_7xNK_FB_HTO_R2_fastqc.zip",
#                   "outHtml": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-FastQCR2/cacheCopy/1973_HD1915_7xNK_FB_HTO_R2_fastqc.html"
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/priority-gwf-core",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "hisplan/cromwell-fastqc:0.11.8",
#                   "scriptBucketName": "dp-lab-gwf-core",
#                   "maxRetries": "3",
#                   "cpu": "4",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "16 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": true,
#                   "hit": true,
#                   "result": "Cache Hit: 296d6973-1d1b-4767-a1ea-986b8991e685:Preprocess.FastQCR2:-1",
#                   "hashes": {
#                     "output count": "C81E728D9D4C2F636F067F89CC14862C",
#                     "runtime attribute": {
#                       "docker": "28FE54A5061CF46FE2DCE56626083670",
#                       "continueOnReturnCode": "CFCD208495D565EF66E7DFF9F98764DA",
#                       "failOnStderr": "68934A3E9455FA72420237EB05902327"
#                     },
#                     "output expression": {
#                       "File outHtml": "2404B6B003CD717DE65EF33FE70129CD",
#                       "File outZip": "DCE4AAB29C491950CC5365ED9B724E4F"
#                     },
#                     "input count": "E4DA3B7FBBCE2345D7772B0674A318D5",
#                     "backend name": "2267EF43AEF6BB551F414FEC2390F68A",
#                     "command template": "1C5DC9BE61D9BEED0312157B3ABFD9F6",
#                     "input": {
#                       "String dockerImage": "0D8B829FED29538CAB75CE867B4A2D1D",
#                       "Float inputSize": "A008DAFF5C1BCEED0624BD005CEA9D25",
#                       "File fastqFile": "\"9195c89e0461abe5b7b9bf330b7b822b\"",
#                       "String dockerRegistry": "38A1E69002366B36B0025741498F4427",
#                       "Int numCores": "A87FF679A2F3E71D9181A67B7542122C"
#                     }
#                   },
#                   "effectiveCallCachingMode": "ReadAndWriteCache"
#                 },
#                 "inputs": {
#                   "dockerRegistry": "hisplan",
#                   "fastqFile": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-MergeFastqR2/cacheCopy/1973_HD1915_7xNK_FB_HTO_R2.fastq.gz",
#                   "dockerImage": "hisplan/cromwell-fastqc:0.11.8",
#                   "inputSize": 0.3349369391798973,
#                   "numCores": 4
#                 },
#                 "returnCode": 0,
#                 "backend": "AWSBATCH",
#                 "end": "2021-07-26T01:45:26.789Z",
#                 "stderr": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-FastQCR2/FastQCR2-stderr.log",
#                 "callRoot": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-FastQCR2",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2021-07-26T01:45:23.665Z",
#                     "description": "UpdatingCallCache",
#                     "endTime": "2021-07-26T01:45:25.718Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T01:45:21.965Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2021-07-26T01:45:22.875Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T01:45:25.718Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2021-07-26T01:45:26.789Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T01:45:22.951Z",
#                     "description": "CallCacheReading",
#                     "endTime": "2021-07-26T01:45:23.665Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T01:45:22.875Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2021-07-26T01:45:22.875Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T01:45:22.875Z",
#                     "description": "PreparingJob",
#                     "endTime": "2021-07-26T01:45:22.951Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T01:45:21.965Z",
#                     "description": "Pending",
#                     "endTime": "2021-07-26T01:45:21.965Z"
#                   }
#                 ],
#                 "start": "2021-07-26T01:45:21.965Z"
#               }
#             ],
#             "Preprocess.CiteSeqCount": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/CiteSeqCount-stdout.log",
#                 "compressedDockerSize": 383353488,
#                 "shardIndex": -1,
#                 "outputs": {
#                   "outUncorrected": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/results/uncorrected_cells/dense_umis.tsv",
#                   "outReadCount": [
#                     "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz",
#                     "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz",
#                     "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz"
#                   ],
#                   "outUnmapped": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/results/unmapped.csv",
#                   "outUmiCount": [
#                     "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#                     "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#                     "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#                   ],
#                   "outReport": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/results/run_report.yaml"
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/priority-gwf-core",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "hisplan/cromwell-cite-seq-count:1.4.2-develop",
#                   "scriptBucketName": "dp-lab-gwf-core",
#                   "maxRetries": "3",
#                   "cpu": "32",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "64 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": true,
#                   "hit": true,
#                   "result": "Cache Hit: 95c18bc7-7aca-4ba0-ab18-7cb3f2c8f0db:Preprocess.CiteSeqCount:-1",
#                   "hashes": {
#                     "output count": "E4DA3B7FBBCE2345D7772B0674A318D5",
#                     "runtime attribute": {
#                       "docker": "02476C60BDC056BAE4513242FA832651",
#                       "continueOnReturnCode": "CFCD208495D565EF66E7DFF9F98764DA",
#                       "failOnStderr": "68934A3E9455FA72420237EB05902327"
#                     },
#                     "output expression": {
#                       "Array(File) outReadCount": "66A2E919454C859047C03B1097A25D2B",
#                       "Array(File) outUmiCount": "EE8DC282E797BD234123DC20962CFB2D",
#                       "File outUnmapped": "F6D4E326A0ED0C0A8AE0D4E6830C6B67",
#                       "File outReport": "74AE7E79E6C32474C38A3A0166370C48",
#                       "File outUncorrected": "56D926164EC1442B5E187AE1B1213BF9"
#                     },
#                     "input count": "98F13708210194C475687BE6106A3B84",
#                     "backend name": "2267EF43AEF6BB551F414FEC2390F68A",
#                     "command template": "9972BA2D6AF0EE95F766B9110BC91E37",
#                     "input": {
#                       "String dockerImage": "EE233B6AC5ECC0A28DD9D172CF8EB928",
#                       "Boolean slidingWindowSearch": "68934A3E9455FA72420237EB05902327",
#                       "Int trimPos": "D3D9446802A44259755D38E6D163E820",
#                       "Int resourceSpec": {
#                         "cpu": "6364D3F0F495B6AB9DCF8D3B5C6E0B01",
#                         "memory": "EA5D2F1C4608232E07D3AA3D998E5135"
#                       },
#                       "File cbWhiteList": "\"c7762e24edecf1b678e5b9ae21e4394b\"",
#                       "File tagList": "\"b8da480af8528cc1b2de0759c97f4e8e\"",
#                       "Int umiStartPos": "70EFDF2EC9B086079795C442636B55FB",
#                       "Float inputSize": "611C15AE6358913988680E7F17CF72C7",
#                       "Int cbEndPos": "C74D97B01EAE257E44AA9D5BADE97BAF",
#                       "Int maxTagError": "C81E728D9D4C2F636F067F89CC14862C",
#                       "Int numExpectedCells": "CFCD208495D565EF66E7DFF9F98764DA",
#                       "Int cbStartPos": "C4CA4238A0B923820DCC509A6F75849B",
#                       "File fastqR2": "\"114598887f2d3b5e9b113ae617def09a\"",
#                       "Int cbCollapsingDistance": "C4CA4238A0B923820DCC509A6F75849B",
#                       "File fastqR1": "\"ae979389a0d974afc55079dd87364e0f\"",
#                       "Int umiCollapsingDistance": "C4CA4238A0B923820DCC509A6F75849B",
#                       "String dockerRegistry": "38A1E69002366B36B0025741498F4427",
#                       "Int umiEndPos": "33E75FF09DD601BBE69F351039152189",
#                       "String version": "7D0396BBD460CF4B0569B60A315B14A0"
#                     }
#                   },
#                   "effectiveCallCachingMode": "ReadAndWriteCache"
#                 },
#                 "inputs": {
#                   "numExpectedCells": 0,
#                   "slidingWindowSearch": false,
#                   "umiEndPos": 28,
#                   "tagList": "s3://dp-lab-data/collaborators/hsuk/7xNK/HD1915_7xNK_FB_HTO/Hashtag_results/tag-list.csv",
#                   "cbCollapsingDistance": 1,
#                   "umiStartPos": 17,
#                   "fastqR2": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-TrimR2/cacheCopy/R2.fastq.gz",
#                   "version": "1.4.2-develop",
#                   "dockerRegistry": "hisplan",
#                   "dockerImage": "hisplan/cromwell-cite-seq-count:1.4.2-develop",
#                   "maxTagError": 2,
#                   "fastqR1": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-TrimR1/cacheCopy/R1.fastq.gz",
#                   "umiCollapsingDistance": 1,
#                   "resourceSpec": {
#                     "memory": 64,
#                     "cpu": 32
#                   },
#                   "cbEndPos": 16,
#                   "cbWhiteList": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-Translate10XBarcodes/cacheCopy/translated-barcodes.txt",
#                   "inputSize": 0.3062760168686509,
#                   "cbStartPos": 1,
#                   "trimPos": 10
#                 },
#                 "returnCode": 0,
#                 "backend": "AWSBATCH",
#                 "end": "2021-07-26T01:45:38.692Z",
#                 "stderr": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/CiteSeqCount-stderr.log",
#                 "callRoot": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2021-07-26T01:45:35.774Z",
#                     "description": "UpdatingCallCache",
#                     "endTime": "2021-07-26T01:45:37.705Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T01:45:34.206Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2021-07-26T01:45:34.875Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T01:45:34.875Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2021-07-26T01:45:34.875Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T01:45:37.705Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2021-07-26T01:45:38.691Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T01:45:34.875Z",
#                     "description": "PreparingJob",
#                     "endTime": "2021-07-26T01:45:35.202Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T01:45:34.206Z",
#                     "description": "Pending",
#                     "endTime": "2021-07-26T01:45:34.206Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T01:45:35.202Z",
#                     "description": "CallCacheReading",
#                     "endTime": "2021-07-26T01:45:35.774Z"
#                   }
#                 ],
#                 "start": "2021-07-26T01:45:34.206Z"
#               }
#             ],
#             "Preprocess.Translate10XBarcodes": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-Translate10XBarcodes/Translate10XBarcodes-stdout.log",
#                 "compressedDockerSize": 344006073,
#                 "shardIndex": -1,
#                 "outputs": {
#                   "out": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-Translate10XBarcodes/cacheCopy/translated-barcodes.txt"
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/priority-gwf-core",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "hisplan/seqc-utils:0.5.0",
# ...
#           "umiCountMatrix": [
#             "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#             "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#             "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#           ],
#           "fastQCR1Html": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-FastQCR1/cacheCopy/1973_HD1915_7xNK_FB_HTO_R1_fastqc.html"
#         },
#         "inputs": {
#           "lengthR2": 25,
#           "scRnaSeqPlatform": "10x_v3",
#           "CiteSeqCount.version": "1.4.2-develop",
#           "numExpectedCells": 0,
#           "slidingWindowSearch": false,
#           "cellBarcodeWhiteListMethod": "SeqcDenseCountsMatrixCsv",
#           "sampleName": "1973_HD1915_7xNK_FB_HTO",
#           "umiEndPos": 28,
#           "tagList": "s3://dp-lab-data/collaborators/hsuk/7xNK/HD1915_7xNK_FB_HTO/Hashtag_results/tag-list.csv",
#           "uriFastqR2": [
#             "s3://dp-lab-data/collaborators/hsuk/7xNK/HD1915_7xNK_FB_HTO/FASTQ/HD1915_7xNK_FB_IGO_10657_B_2_S2_L001_R2_001.fastq.gz",
#             "s3://dp-lab-data/collaborators/hsuk/7xNK/HD1915_7xNK_FB_HTO/FASTQ/HD1915_7xNK_FB_IGO_10657_B_2_S2_L002_R2_001.fastq.gz"
#           ],
#           "cbCollapsingDistance": 1,
#           "umiStartPos": 17,
#           "dockerRegistry": "hisplan",
#           "maxTagError": 2,
#           "umiCollapsingDistance": 1,
#           "resourceSpec": {
#             "memory": 64,
#             "cpu": 32
#           },
#           "cbEndPos": 16,
#           "cellBarcodeWhitelistUri": "s3://dp-lab-data/collaborators/hsuk/7xNK/HD1915_7xNK/seqc-results/1973_HD1915_7xNK_IGO_10657_2_dense.csv",
#           "lengthR1": 28,
#           "uriFastqR1": [
#             "s3://dp-lab-data/collaborators/hsuk/7xNK/HD1915_7xNK_FB_HTO/FASTQ/HD1915_7xNK_FB_IGO_10657_B_2_S2_L001_R1_001.fastq.gz",
#             "s3://dp-lab-data/collaborators/hsuk/7xNK/HD1915_7xNK_FB_HTO/FASTQ/HD1915_7xNK_FB_IGO_10657_B_2_S2_L002_R1_001.fastq.gz"
#           ],
#           "translate10XBarcodes": true,
#           "cbStartPos": 1,
#           "trimPos": 10
#         },
#         "end": "2021-07-26T01:50:07.526Z",
#         "attempt": 1,
#         "executionEvents": [
#           {
#             "startTime": "2021-07-26T01:44:59.465Z",
#             "description": "SubWorkflowPendingState",
#             "endTime": "2021-07-26T01:44:59.465Z"
#           },
#           {
#             "startTime": "2021-07-26T01:44:59.466Z",
#             "description": "SubWorkflowPreparingState",
#             "endTime": "2021-07-26T01:44:59.468Z"
#           },
#           {
#             "startTime": "2021-07-26T01:44:59.468Z",
#             "description": "SubWorkflowRunningState",
#             "endTime": "2021-07-26T01:50:07.526Z"
#           },
#           {
#             "startTime": "2021-07-26T01:44:59.465Z",
#             "description": "WaitingForValueStore",
#             "endTime": "2021-07-26T01:44:59.466Z"
#           }
#         ],
#         "start": "2021-07-26T01:44:59.465Z"
#       }
#     ],
#     "Hashtag.UpdateAnnData": [
#       {
#         "executionStatus": "Done",
#         "stdout": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-UpdateAnnData/UpdateAnnData-stdout.log",
#         "backendStatus": "Succeeded",
#         "compressedDockerSize": 585162468,
#         "commandLine": "set -euo pipefail\n\nmv /cromwell_root/dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-ToAnnData/1973_HD1915_7xNK_FB_HTO.h5ad adata-in.h5ad\n\npython3 /opt/update_adata.py \\\n    --class /cromwell_root/dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HtoDemuxKMeans/cacheCopy/classification.tsv.gz \\\n    --adata-in adata-in.h5ad \\\n    --adata-out 1973_HD1915_7xNK_FB_HTO.h5ad \\\n    --hto-gex-mapper /opt/data/10x-hto-gex-mapper.pickle --10x-barcode-translation",
#         "shardIndex": -1,
#         "outputs": {
#           "outAdata": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-UpdateAnnData/1973_HD1915_7xNK_FB_HTO.h5ad",
#           "outLog": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-UpdateAnnData/update_adata.log"
#         },
#         "runtimeAttributes": {
#           "failOnStderr": "false",
#           "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/priority-gwf-core",
#           "disks": "local-disk /cromwell_root",
#           "continueOnReturnCode": "0",
#           "docker": "hisplan/cromwell-hto-adt-postprocess:0.3.3",
#           "scriptBucketName": "dp-lab-gwf-core",
#           "maxRetries": "3",
#           "cpu": "1",
#           "cpuMin": "1",
#           "noAddress": "false",
#           "zones": "us-east-1a",
#           "memoryMin": "2 GB",
#           "memory": "8 GB"
#         },
#         "callCaching": {
#           "allowResultReuse": true,
#           "hit": false,
#           "result": "Cache Miss",
#           "hashes": {
#             "output count": "C81E728D9D4C2F636F067F89CC14862C",
#             "runtime attribute": {
#               "docker": "C0453230DDCB45B1A0824557B543F5BD",
#               "continueOnReturnCode": "CFCD208495D565EF66E7DFF9F98764DA",
#               "failOnStderr": "68934A3E9455FA72420237EB05902327"
#             },
#             "output expression": {
#               "File outAdata": "4EE81D5D24C9A4E1282BD6EB8F6B1795",
#               "File outLog": "63B662C702F6B88F7FE3F5945CDB2807"
#             },
#             "input count": "C9F0F895FB98AB9159F51FD0297E236D",
#             "backend name": "2267EF43AEF6BB551F414FEC2390F68A",
#             "command template": "3DF6D6BA771231FB653F4E97626EF766",
#             "input": {
#               "String dockerImage": "3DC154285188BAE455441FA11F0ABE76",
#               "Boolean translate10XBarcodes": "B326B5062B2F0E69046810717534CB09",
#               "File htoClassification": "\"5b4db38ca2052f608c16ea8d9d888a6a\"",
#               "String sampleName": "4F3970E8D27B4FE62CBE242131028739",
#               "Float inputSize": "6C0DA0A57BF5AB7323DB673E4A0E0266",
#               "File adata": "\"ce01b674c970a6e97b826cb13479acb7\"",
#               "String dockerRegistry": "38A1E69002366B36B0025741498F4427",
#               "Int numCores": "C4CA4238A0B923820DCC509A6F75849B"
#             }
#           },
#           "effectiveCallCachingMode": "ReadAndWriteCache"
#         },
#         "inputs": {
#           "adata": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-ToAnnData/1973_HD1915_7xNK_FB_HTO.h5ad",
#           "sampleName": "1973_HD1915_7xNK_FB_HTO",
#           "dockerRegistry": "hisplan",
#           "dockerImage": "hisplan/cromwell-hto-adt-postprocess:0.3.3",
#           "htoClassification": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HtoDemuxKMeans/cacheCopy/classification.tsv.gz",
#           "inputSize": 0.001769806258380413,
#           "translate10XBarcodes": true,
#           "numCores": 1
#         },
#         "returnCode": 0,
#         "jobId": "5b72c212-518c-4d35-8193-e374c383c76b",
#         "backend": "AWSBATCH",
#         "end": "2021-07-26T01:54:05.697Z",
#         "dockerImageUsed": "hisplan/cromwell-hto-adt-postprocess@sha256:76d06cd1d3619199f234729eae40e551f2954b8720ca6b57663aa72c77472ebd",
#         "stderr": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-UpdateAnnData/UpdateAnnData-stderr.log",
#         "callRoot": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-UpdateAnnData",
#         "attempt": 1,
#         "executionEvents": [
#           {
#             "startTime": "2021-07-26T01:50:16.666Z",
#             "description": "RequestingExecutionToken",
#             "endTime": "2021-07-26T01:50:18.875Z"
#           },
#           {
#             "startTime": "2021-07-26T01:50:19.062Z",
#             "description": "RunningJob",
#             "endTime": "2021-07-26T01:54:04.607Z"
#           },
#           {
#             "startTime": "2021-07-26T01:50:19.040Z",
#             "description": "CallCacheReading",
#             "endTime": "2021-07-26T01:50:19.062Z"
#           },
#           {
#             "startTime": "2021-07-26T01:54:04.709Z",
#             "description": "UpdatingJobStore",
#             "endTime": "2021-07-26T01:54:05.697Z"
#           },
#           {
#             "startTime": "2021-07-26T01:54:04.607Z",
#             "description": "UpdatingCallCache",
#             "endTime": "2021-07-26T01:54:04.709Z"
#           },
#           {
#             "startTime": "2021-07-26T01:50:16.666Z",
#             "description": "Pending",
#             "endTime": "2021-07-26T01:50:16.666Z"
#           },
#           {
#             "startTime": "2021-07-26T01:50:18.875Z",
#             "description": "PreparingJob",
#             "endTime": "2021-07-26T01:50:19.040Z"
#           },
#           {
#             "startTime": "2021-07-26T01:50:18.875Z",
#             "description": "WaitingForValueStore",
#             "endTime": "2021-07-26T01:50:18.875Z"
#           }
#         ],
#         "start": "2021-07-26T01:50:16.665Z"
#       }
#     ]
#   },
#   "outputs": {
#     "Hashtag.umiCountMatrix": [
#       "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#       "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#       "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#     ],
#     "Hashtag.countReport": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/results/run_report.yaml",
#     "Hashtag.fastQCR1Html": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-FastQCR1/cacheCopy/1973_HD1915_7xNK_FB_HTO_R1_fastqc.html",
#     "Hashtag.fastQCR2Html": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-FastQCR2/cacheCopy/1973_HD1915_7xNK_FB_HTO_R2_fastqc.html",
#     "Hashtag.combinedCountMatrix": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HashedCountMatrix/final-matrix.tsv.gz",
#     "Hashtag.adataRaw": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-ToAnnData/1973_HD1915_7xNK_FB_HTO.h5ad",
#     "Hashtag.adataFinal": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-UpdateAnnData/1973_HD1915_7xNK_FB_HTO.h5ad",
#     "Hashtag.statsHtoDemux_Suppl1": null,
#     "Hashtag.combinedClass": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HashedCountMatrix/final-classification.tsv.gz",
#     "Hashtag.htoClassification_Suppl1": null,
#     "Hashtag.logHtoDemux_Suppl1": null,
#     "Hashtag.htoClassification": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HtoDemuxKMeans/cacheCopy/classification.tsv.gz",
#     "Hashtag.combinedStats": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HashedCountMatrix/stats.yml",
#     "Hashtag.statsHtoDemux": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HtoDemuxKMeans/cacheCopy/stats.yml",
#     "Hashtag.readCountMatrix": [
#       "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz",
#       "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz",
#       "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz"
#     ],
#     "Hashtag.htoClassification_Suppl3": null,
#     "Hashtag.combinedLog": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HashedCountMatrix/combine.log",
#     "Hashtag.htoClassification_Suppl2": null,
#     "Hashtag.logHtoDemux": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HtoDemuxKMeans/cacheCopy/demux_kmeans.log"
#   },
#   "actualWorkflowLanguage": "WDL",
#   "id": "c3a941bf-62ed-469e-8ee6-d7448cdee457",
#   "inputs": {
#     "lengthR2": 25,
#     "scRnaSeqPlatform": "10x_v3",
#     "denseCountMatrix": "s3://dp-lab-data/collaborators/hsuk/7xNK/HD1915_7xNK/seqc-results/1973_HD1915_7xNK_IGO_10657_2_dense.csv",
#     "numExpectedCells": 0,
#     "demuxMode": 1,
#     "slidingWindowSearch": false,
#     "cellBarcodeWhiteListMethod": "SeqcDenseCountsMatrixCsv",
#     "sampleName": "1973_HD1915_7xNK_FB_HTO",
#     "hashTagList": "s3://dp-lab-data/collaborators/hsuk/7xNK/HD1915_7xNK_FB_HTO/Hashtag_results/tag-list.csv",
#     "umiEndPos": 28,
#     "uriFastqR2": [
#       "s3://dp-lab-data/collaborators/hsuk/7xNK/HD1915_7xNK_FB_HTO/FASTQ/HD1915_7xNK_FB_IGO_10657_B_2_S2_L001_R2_001.fastq.gz",
#       "s3://dp-lab-data/collaborators/hsuk/7xNK/HD1915_7xNK_FB_HTO/FASTQ/HD1915_7xNK_FB_IGO_10657_B_2_S2_L002_R2_001.fastq.gz"
#     ],
#     "cbCollapsingDistance": 1,
#     "umiStartPos": 17,
#     "dockerRegistry": "hisplan",
#     "maxTagError": 2,
#     "runSeuratDemux": false,
#     "umiCollapsingDistance": 1,
#     "resourceSpec": {
#       "memory": 64,
#       "cpu": 32
#     },
#     "cbEndPos": 16,
#     "cellBarcodeWhitelistUri": "s3://dp-lab-data/collaborators/hsuk/7xNK/HD1915_7xNK/seqc-results/1973_HD1915_7xNK_IGO_10657_2_dense.csv",
#     "lengthR1": 28,
#     "uriFastqR1": [
#       "s3://dp-lab-data/collaborators/hsuk/7xNK/HD1915_7xNK_FB_HTO/FASTQ/HD1915_7xNK_FB_IGO_10657_B_2_S2_L001_R1_001.fastq.gz",
#       "s3://dp-lab-data/collaborators/hsuk/7xNK/HD1915_7xNK_FB_HTO/FASTQ/HD1915_7xNK_FB_IGO_10657_B_2_S2_L002_R1_001.fastq.gz"
#     ],
#     "translate10XBarcodes": true,
#     "cbStartPos": 1,
#     "trimPos": 10,
#     "minCount": 0
#   },
#   "labels": {
#     "project": "Project 226",
#     "cromwell-workflow-id": "cromwell-c3a941bf-62ed-469e-8ee6-d7448cdee457",
#     "transfer": "done",
#     "comment": "10x v3 TotalSeq-B",
#     "sample": "1973_HD1915_7xNK_FB_HTO",
#     "pipelineType": "Sharp",
#     "owner": "chunj",
#     "destination": "s3://dp-lab-test/sharp/hashtag/10x-v3-totalseq-B/"
#   },
#   "submission": "2021-07-26T01:44:56.488Z",
#   "status": "Succeeded",
#   "end": "2021-07-26T01:57:04.657Z",
#   "start": "2021-07-26T01:44:57.333Z"
# }

# %% [markdown]
# ## Get Sample Name

# %%
sample_name = metadata["labels"]["sample"]
sample_name
# Out:
# '1973_HD1915_7xNK_FB_HTO'

# %% [markdown]
# ## Get Counts

# %%
def download(sample_name, workflow_id, subfolder, items):
    
    if skip_download:
        return
    
    if not isinstance(items, list):
        items = [items]
        
    path_output = f"{path_base_data}/{sample_name}/{workflow_id}/{subfolder}"
    
    os.makedirs(path_output, exist_ok=True)
        
    for item in items:
        cmd_download = f"aws s3 cp {item} {path_output}"
        print(cmd_download)
        os.system(cmd_download)

# %%
try:
    # sharp v0.0.4 (before 2020-10-26)
    workflow_name = "Sharp"
    meta_cite_seq_count = metadata["calls"]["Sharp.CiteSeqCount"][0]
except:
    
    try:
        # sharp v0.0.5
        workflow_name = "Sharp"
        meta_cite_seq_count = metadata["calls"]["Sharp.Preprocess"][0]["subWorkflowMetadata"]["calls"]["Preprocess.CiteSeqCount"][0]
    except:
        # sharp v0.0.9
        workflow_name = "Hashtag"
        meta_cite_seq_count = metadata["calls"]["Hashtag.Preprocess"][0]["subWorkflowMetadata"]["calls"]["Preprocess.CiteSeqCount"][0]

# %%
print(json.dumps(meta_cite_seq_count, indent=2))
# Out:
# {
#   "executionStatus": "Done",
#   "stdout": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/CiteSeqCount-stdout.log",
#   "compressedDockerSize": 383353488,
#   "shardIndex": -1,
#   "outputs": {
#     "outUncorrected": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/results/uncorrected_cells/dense_umis.tsv",
#     "outReadCount": [
#       "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz",
#       "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz",
#       "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz"
#     ],
#     "outUnmapped": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/results/unmapped.csv",
#     "outUmiCount": [
#       "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#       "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#       "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#     ],
#     "outReport": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/results/run_report.yaml"
#   },
#   "runtimeAttributes": {
#     "failOnStderr": "false",
#     "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/priority-gwf-core",
#     "disks": "local-disk /cromwell_root",
#     "continueOnReturnCode": "0",
#     "docker": "hisplan/cromwell-cite-seq-count:1.4.2-develop",
#     "scriptBucketName": "dp-lab-gwf-core",
#     "maxRetries": "3",
#     "cpu": "32",
#     "cpuMin": "1",
#     "noAddress": "false",
#     "zones": "us-east-1a",
#     "memoryMin": "2 GB",
#     "memory": "64 GB"
#   },
#   "callCaching": {
#     "allowResultReuse": true,
#     "hit": true,
#     "result": "Cache Hit: 95c18bc7-7aca-4ba0-ab18-7cb3f2c8f0db:Preprocess.CiteSeqCount:-1",
#     "hashes": {
#       "output count": "E4DA3B7FBBCE2345D7772B0674A318D5",
#       "runtime attribute": {
#         "docker": "02476C60BDC056BAE4513242FA832651",
#         "continueOnReturnCode": "CFCD208495D565EF66E7DFF9F98764DA",
#         "failOnStderr": "68934A3E9455FA72420237EB05902327"
#       },
#       "output expression": {
#         "Array(File) outReadCount": "66A2E919454C859047C03B1097A25D2B",
#         "Array(File) outUmiCount": "EE8DC282E797BD234123DC20962CFB2D",
#         "File outUnmapped": "F6D4E326A0ED0C0A8AE0D4E6830C6B67",
#         "File outReport": "74AE7E79E6C32474C38A3A0166370C48",
#         "File outUncorrected": "56D926164EC1442B5E187AE1B1213BF9"
#       },
#       "input count": "98F13708210194C475687BE6106A3B84",
#       "backend name": "2267EF43AEF6BB551F414FEC2390F68A",
#       "command template": "9972BA2D6AF0EE95F766B9110BC91E37",
#       "input": {
#         "String dockerImage": "EE233B6AC5ECC0A28DD9D172CF8EB928",
#         "Boolean slidingWindowSearch": "68934A3E9455FA72420237EB05902327",
#         "Int trimPos": "D3D9446802A44259755D38E6D163E820",
#         "Int resourceSpec": {
#           "cpu": "6364D3F0F495B6AB9DCF8D3B5C6E0B01",
#           "memory": "EA5D2F1C4608232E07D3AA3D998E5135"
#         },
#         "File cbWhiteList": "\"c7762e24edecf1b678e5b9ae21e4394b\"",
#         "File tagList": "\"b8da480af8528cc1b2de0759c97f4e8e\"",
#         "Int umiStartPos": "70EFDF2EC9B086079795C442636B55FB",
#         "Float inputSize": "611C15AE6358913988680E7F17CF72C7",
#         "Int cbEndPos": "C74D97B01EAE257E44AA9D5BADE97BAF",
#         "Int maxTagError": "C81E728D9D4C2F636F067F89CC14862C",
#         "Int numExpectedCells": "CFCD208495D565EF66E7DFF9F98764DA",
#         "Int cbStartPos": "C4CA4238A0B923820DCC509A6F75849B",
#         "File fastqR2": "\"114598887f2d3b5e9b113ae617def09a\"",
#         "Int cbCollapsingDistance": "C4CA4238A0B923820DCC509A6F75849B",
#         "File fastqR1": "\"ae979389a0d974afc55079dd87364e0f\"",
#         "Int umiCollapsingDistance": "C4CA4238A0B923820DCC509A6F75849B",
#         "String dockerRegistry": "38A1E69002366B36B0025741498F4427",
#         "Int umiEndPos": "33E75FF09DD601BBE69F351039152189",
#         "String version": "7D0396BBD460CF4B0569B60A315B14A0"
#       }
#     },
#     "effectiveCallCachingMode": "ReadAndWriteCache"
#   },
#   "inputs": {
#     "numExpectedCells": 0,
#     "slidingWindowSearch": false,
#     "umiEndPos": 28,
#     "tagList": "s3://dp-lab-data/collaborators/hsuk/7xNK/HD1915_7xNK_FB_HTO/Hashtag_results/tag-list.csv",
#     "cbCollapsingDistance": 1,
#     "umiStartPos": 17,
#     "fastqR2": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-TrimR2/cacheCopy/R2.fastq.gz",
#     "version": "1.4.2-develop",
#     "dockerRegistry": "hisplan",
#     "dockerImage": "hisplan/cromwell-cite-seq-count:1.4.2-develop",
#     "maxTagError": 2,
#     "fastqR1": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-TrimR1/cacheCopy/R1.fastq.gz",
#     "umiCollapsingDistance": 1,
#     "resourceSpec": {
#       "memory": 64,
#       "cpu": 32
#     },
#     "cbEndPos": 16,
#     "cbWhiteList": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-Translate10XBarcodes/cacheCopy/translated-barcodes.txt",
#     "inputSize": 0.3062760168686509,
#     "cbStartPos": 1,
#     "trimPos": 10
#   },
#   "returnCode": 0,
#   "backend": "AWSBATCH",
#   "end": "2021-07-26T01:45:38.692Z",
#   "stderr": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/CiteSeqCount-stderr.log",
#   "callRoot": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount",
#   "attempt": 1,
#   "executionEvents": [
#     {
#       "startTime": "2021-07-26T01:45:35.774Z",
#       "description": "UpdatingCallCache",
#       "endTime": "2021-07-26T01:45:37.705Z"
#     },
#     {
#       "startTime": "2021-07-26T01:45:34.206Z",
#       "description": "RequestingExecutionToken",
#       "endTime": "2021-07-26T01:45:34.875Z"
#     },
#     {
#       "startTime": "2021-07-26T01:45:34.875Z",
#       "description": "WaitingForValueStore",
#       "endTime": "2021-07-26T01:45:34.875Z"
#     },
#     {
#       "startTime": "2021-07-26T01:45:37.705Z",
#       "description": "UpdatingJobStore",
#       "endTime": "2021-07-26T01:45:38.691Z"
#     },
#     {
#       "startTime": "2021-07-26T01:45:34.875Z",
#       "description": "PreparingJob",
#       "endTime": "2021-07-26T01:45:35.202Z"
#     },
#     {
#       "startTime": "2021-07-26T01:45:34.206Z",
#       "description": "Pending",
#       "endTime": "2021-07-26T01:45:34.206Z"
#     },
#     {
#       "startTime": "2021-07-26T01:45:35.202Z",
#       "description": "CallCacheReading",
#       "endTime": "2021-07-26T01:45:35.774Z"
#     }
#   ],
#   "start": "2021-07-26T01:45:34.206Z"
# }

# %% [markdown]
# ### Download Read Count

# %%
download(
    sample_name, workflow_id,
    "reads",
    meta_cite_seq_count["outputs"]["outReadCount"]
)
# Out:
# aws s3 cp s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz ./hashtag/1973_HD1915_7xNK_FB_HTO/c3a941bf-62ed-469e-8ee6-d7448cdee457/reads
# aws s3 cp s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz ./hashtag/1973_HD1915_7xNK_FB_HTO/c3a941bf-62ed-469e-8ee6-d7448cdee457/reads
# aws s3 cp s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz ./hashtag/1973_HD1915_7xNK_FB_HTO/c3a941bf-62ed-469e-8ee6-d7448cdee457/reads

# %% [markdown]
# ### Download UMI Count

# %%
download(
    sample_name, workflow_id,
    "umis",
    meta_cite_seq_count["outputs"]["outUmiCount"]
)
# Out:
# aws s3 cp s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz ./hashtag/1973_HD1915_7xNK_FB_HTO/c3a941bf-62ed-469e-8ee6-d7448cdee457/umis
# aws s3 cp s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz ./hashtag/1973_HD1915_7xNK_FB_HTO/c3a941bf-62ed-469e-8ee6-d7448cdee457/umis
# aws s3 cp s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz ./hashtag/1973_HD1915_7xNK_FB_HTO/c3a941bf-62ed-469e-8ee6-d7448cdee457/umis

# %% [markdown]
# ## Download Report

# %%
download(
    sample_name, workflow_id,
    "report",
    meta_cite_seq_count["outputs"]["outReport"]
)
# Out:
# aws s3 cp s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/results/run_report.yaml ./hashtag/1973_HD1915_7xNK_FB_HTO/c3a941bf-62ed-469e-8ee6-d7448cdee457/report

# %% [markdown]
# ## Get Demux Classification

# %%
meta_demux = metadata["calls"][f"{workflow_name}.HtoDemuxKMeans"][0]

# %%
print(json.dumps(meta_demux, indent=2))
# Out:
# {
#   "executionStatus": "Done",
#   "stdout": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HtoDemuxKMeans/HtoDemuxKMeans-stdout.log",
#   "compressedDockerSize": 331772747,
#   "shardIndex": -1,
#   "outputs": {
#     "outLog": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HtoDemuxKMeans/cacheCopy/demux_kmeans.log",
#     "outStats": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HtoDemuxKMeans/cacheCopy/stats.yml",
#     "outClass": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HtoDemuxKMeans/cacheCopy/classification.tsv.gz"
#   },
#   "runtimeAttributes": {
#     "failOnStderr": "false",
#     "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/priority-gwf-core",
#     "disks": "local-disk /cromwell_root",
#     "continueOnReturnCode": "0",
#     "docker": "hisplan/cromwell-hto-demux-kmeans:0.5.0",
#     "scriptBucketName": "dp-lab-gwf-core",
#     "maxRetries": "3",
#     "cpu": "1",
#     "cpuMin": "1",
#     "noAddress": "false",
#     "zones": "us-east-1a",
#     "memoryMin": "2 GB",
#     "memory": "32 GB"
#   },
#   "callCaching": {
#     "allowResultReuse": true,
#     "hit": true,
#     "result": "Cache Hit: e310f49b-44df-4ed0-a723-738a4ff06480:Hashtag.HtoDemuxKMeans:-1",
#     "hashes": {
#       "output count": "ECCBC87E4B5CE2FE28308FD9F2A7BAF3",
#       "runtime attribute": {
#         "docker": "1450F3A8348454304F37EB0CD4F9F74C",
#         "continueOnReturnCode": "CFCD208495D565EF66E7DFF9F98764DA",
#         "failOnStderr": "68934A3E9455FA72420237EB05902327"
#       },
#       "output expression": {
#         "File outClass": "EA901A865B3AC121C9BFCBB6FEDAF09A",
#         "File outLog": "1CEE887B77436F8BA42E12DD267860F7",
#         "File outStats": "33F56C7B084B6CAF4B339B0846FA61B8"
#       },
#       "input count": "45C48CCE2E2D7FBDEA1AFC51C7C6AD26",
#       "backend name": "2267EF43AEF6BB551F414FEC2390F68A",
#       "command template": "EF9AD0939AE065446D2B027DBE43E956",
#       "input": {
#         "String dockerImage": "87CB22A98A308AE4C12B6553B9C224F5",
#         "File umiCountFiles": [
#           "\"8bbf85313948c5e03132de41dbddcd3a\"",
#           "\"d36ce2ccc9ec427e61e1226d6a5a8676\"",
#           "\"140f710c5a9385b099e0fdac9b3738e1\""
#         ],
#         "Float inputSize": "702DC8D32469F0E2BDAB4BA30D581C90",
#         "Int minCount": "CFCD208495D565EF66E7DFF9F98764DA",
#         "Int mode": "C4CA4238A0B923820DCC509A6F75849B",
#         "String dockerRegistry": "38A1E69002366B36B0025741498F4427",
#         "Int numCores": "C4CA4238A0B923820DCC509A6F75849B"
#       }
#     },
#     "effectiveCallCachingMode": "ReadAndWriteCache"
#   },
#   "inputs": {
#     "umiCountFiles": [
#       "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#       "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#       "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-Preprocess/Preprocess/744288fb-47e7-49ef-83e1-d79443b5b9d3/call-CiteSeqCount/cacheCopy/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#     ],
#     "dockerRegistry": "hisplan",
#     "dockerImage": "hisplan/cromwell-hto-demux-kmeans:0.5.0",
#     "mode": 1,
#     "inputSize": 0.00022793468087911606,
#     "minCount": 0,
#     "numCores": 1
#   },
#   "returnCode": 0,
#   "backend": "AWSBATCH",
#   "end": "2021-07-26T01:50:14.699Z",
#   "stderr": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HtoDemuxKMeans/HtoDemuxKMeans-stderr.log",
#   "callRoot": "s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HtoDemuxKMeans",
#   "attempt": 1,
#   "executionEvents": [
#     {
#       "startTime": "2021-07-26T01:50:09.525Z",
#       "description": "Pending",
#       "endTime": "2021-07-26T01:50:09.525Z"
#     },
#     {
#       "startTime": "2021-07-26T01:50:09.525Z",
#       "description": "RequestingExecutionToken",
#       "endTime": "2021-07-26T01:50:10.875Z"
#     },
#     {
#       "startTime": "2021-07-26T01:50:10.875Z",
#       "description": "WaitingForValueStore",
#       "endTime": "2021-07-26T01:50:10.875Z"
#     },
#     {
#       "startTime": "2021-07-26T01:50:10.875Z",
#       "description": "PreparingJob",
#       "endTime": "2021-07-26T01:50:11.356Z"
#     },
#     {
#       "startTime": "2021-07-26T01:50:13.717Z",
#       "description": "UpdatingJobStore",
#       "endTime": "2021-07-26T01:50:14.699Z"
#     },
#     {
#       "startTime": "2021-07-26T01:50:11.356Z",
#       "description": "CallCacheReading",
#       "endTime": "2021-07-26T01:50:11.845Z"
#     },
#     {
#       "startTime": "2021-07-26T01:50:11.845Z",
#       "description": "UpdatingCallCache",
#       "endTime": "2021-07-26T01:50:13.717Z"
#     }
#   ],
#   "start": "2021-07-26T01:50:09.525Z"
# }

# %%
download(
    sample_name, workflow_id,
    "",
    meta_demux["outputs"]["outClass"]
)
# Out:
# aws s3 cp s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-HtoDemuxKMeans/cacheCopy/classification.tsv.gz ./hashtag/1973_HD1915_7xNK_FB_HTO/c3a941bf-62ed-469e-8ee6-d7448cdee457/

# %% [markdown]
# ## Download Final AnnData

# %%
download(
    sample_name=sample_name, workflow_id=workflow_id, subfolder="", items=metadata["outputs"]["Hashtag.adataFinal"]
)
# Out:
# aws s3 cp s3://dp-lab-gwf-core/cromwell-execution/Hashtag/c3a941bf-62ed-469e-8ee6-d7448cdee457/call-UpdateAnnData/1973_HD1915_7xNK_FB_HTO.h5ad ./hashtag/1973_HD1915_7xNK_FB_HTO/c3a941bf-62ed-469e-8ee6-d7448cdee457/

# %% [markdown]
# ## Output Sample Name

# %%
# 1. DO NOT DELETE
# 2. MUST BE THE FINAL LINE
print(sample_name)
# Out:
# 1973_HD1915_7xNK_FB_HTO
