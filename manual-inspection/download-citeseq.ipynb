# %%
import os
import json

import requests
from requests.exceptions import HTTPError
from requests.auth import HTTPBasicAuth

# %% [markdown]
# ## Parameters

# %%
# this cell is tagged `parameters` and will be overridden by papermill

workflow_id = "bb49f3ef-64cf-434c-89d9-eaf202c46a76"

path_secrets_file = "/Users/chunj/keys/cromwell-secrets-aws-nvirginia.json"
path_base_data = "./citeseq"
skip_download = False

# %% [markdown]
# ## APIs to Cromwell

# %%
def get_secrets(path_secrets_file):

    with open(path_secrets_file, "rt") as fin:
        data = json.loads(fin.read())

    return data

def prep_api_call(secrets):

    api_version = "v1"
    url = secrets["url"]
    url = f"{url}/api/workflows/{api_version}"

    auth = HTTPBasicAuth(secrets["username"], secrets["password"])

    return url, auth

def get_metadata(secrets, workflow_id):

    base_url, auth = prep_api_call(secrets)

    try:
        response = requests.patch(
            url=f"{base_url}/{workflow_id}/metadata?expandSubWorkflows=true",
            headers={
                "Content-Type": "application/json",
                "Accept": "application/json"
            },
            auth=auth
        )

        # if response.status_code == 200:
        data = response.json()

        return data

    except HTTPError as err:
        print(err)

# %% [markdown]
# ## Get Metadata

# %%
metadata = get_metadata(
    get_secrets(path_secrets_file),
    workflow_id
)

# %%
print(json.dumps(metadata, indent=2))
# Out:
# {
#   "workflowName": "CiteSeq",
#   "workflowProcessingEvents": [
#     {
#       "cromwellId": "cromid-aa4a0ba",
#       "description": "Finished",
#       "timestamp": "2021-07-26T04:20:12.908Z",
#       "cromwellVersion": "59"
#     },
#     {
#       "cromwellId": "cromid-aa4a0ba",
#       "description": "PickedUp",
#       "timestamp": "2021-07-26T03:20:46.992Z",
#       "cromwellVersion": "59"
#     }
#   ],
#   "metadataSource": "Unarchived",
#   "actualWorkflowLanguageVersion": "1.0",
#   "submittedFiles": {
#     "workflow": "version 1.0\n\nimport \"modules/Preprocess.wdl\" as Preprocess\n\nworkflow CiteSeq {\n\n    input {\n        Array[File] uriFastqR1\n        Array[File] uriFastqR2\n\n        Int lengthR1\n        Int lengthR2\n\n        String sampleName\n\n        File cellBarcodeWhitelistUri\n        String cellBarcodeWhiteListMethod\n\n        # set to false if TotalSeq-A is used\n        # set to true if TotalSeq-B or C is used\n        Boolean translate10XBarcodes\n\n        String scRnaSeqPlatform = \"10x_v3\"\n\n        File tagList\n\n        # cellular barcode start/end positions\n        Int cbStartPos\n        Int cbEndPos\n\n        # UMI start/end positions\n        Int umiStartPos\n        Int umiEndPos\n\n        # how many bases should we trim before starting to look for hashtag sequence\n        Int trimPos = 0\n\n        # activate sliding window alignement\n        Boolean slidingWindowSearch = false\n\n        # correction\n        Int cbCollapsingDistance\n        Int umiCollapsingDistance\n        Int maxTagError = 2\n\n        Int numExpectedCells\n\n        Map[String, Int] resourceSpec\n\n        # docker-related\n        String dockerRegistry\n    }\n\n    call Preprocess.Preprocess {\n        input:\n            uriFastqR1 = uriFastqR1,\n            uriFastqR2 = uriFastqR2,\n            lengthR1 = lengthR1,\n            lengthR2 = lengthR2,\n            sampleName = sampleName,\n            cellBarcodeWhitelistUri = cellBarcodeWhitelistUri,\n            cellBarcodeWhiteListMethod = cellBarcodeWhiteListMethod,\n            translate10XBarcodes = translate10XBarcodes,\n            scRnaSeqPlatform = scRnaSeqPlatform,\n            tagList = tagList,\n            cbStartPos = cbStartPos,\n            cbEndPos = cbEndPos,\n            umiStartPos = umiStartPos,\n            umiEndPos = umiEndPos,\n            trimPos = trimPos,\n            slidingWindowSearch = slidingWindowSearch,\n            cbCollapsingDistance = cbCollapsingDistance,\n            umiCollapsingDistance = umiCollapsingDistance,\n            maxTagError = maxTagError,\n            numExpectedCells = numExpectedCells,\n            resourceSpec = resourceSpec,\n            dockerRegistry = dockerRegistry\n    }\n\n    output {\n        File fastQCR1Html = Preprocess.fastQCR1Html\n        File fastQCR2Html = Preprocess.fastQCR2Html\n\n        File countReport = Preprocess.countReport\n        Array[File] umiCountMatrix = Preprocess.umiCountMatrix\n        Array[File] readCountMatrix = Preprocess.readCountMatrix\n\n        File adata = Preprocess.adata\n    }\n}\n",
#     "root": "",
#     "options": "{\n  \"default_runtime_attributes\": {\n    \"maxRetries\": 3\n  },\n  \"write_to_cache\": true,\n  \"workflow_failure_mode\": \"ContinueWhilePossible\",\n  \"read_from_cache\": true,\n  \"monitoring_script\": \"s3://dp-lab-batch/monitoring.sh\"\n}",
#     "inputs": "{\"CiteSeq.cbCollapsingDistance\":1,\"CiteSeq.cbEndPos\":16,\"CiteSeq.cbStartPos\":1,\"CiteSeq.cellBarcodeWhiteListMethod\":\"SeqcDenseCountsMatrixCsv\",\"CiteSeq.cellBarcodeWhitelistUri\":\"s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1/seqc-results/2090_CS1429a_T_1_CD45pos_citeseq_1_IGO_11244_17_dense.csv\",\"CiteSeq.dockerRegistry\":\"583643567512.dkr.ecr.us-east-1.amazonaws.com\",\"CiteSeq.lengthR1\":28,\"CiteSeq.lengthR2\":15,\"CiteSeq.numExpectedCells\":0,\"CiteSeq.resourceSpec\":{\"cpu\":4,\"memory\":64},\"CiteSeq.sampleName\":\"2090_CS1429a_T_1_CD45pos_citeseq_1_CITE\",\"CiteSeq.scRnaSeqPlatform\":\"10x_v3\",\"CiteSeq.slidingWindowSearch\":false,\"CiteSeq.tagList\":\"s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1_CITE/Hashtag_results/tag-list.csv\",\"CiteSeq.translate10XBarcodes\":false,\"CiteSeq.trimPos\":0,\"CiteSeq.umiCollapsingDistance\":1,\"CiteSeq.umiEndPos\":28,\"CiteSeq.umiStartPos\":17,\"CiteSeq.uriFastqR1\":[\"s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_1_CITE_IGO_11242_11_S17_L001_R1_001.fastq.gz\",\"s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_1_CITE_IGO_11242_11_S17_L002_R1_001.fastq.gz\"],\"CiteSeq.uriFastqR2\":[\"s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_1_CITE_IGO_11242_11_S17_L001_R2_001.fastq.gz\",\"s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_1_CITE_IGO_11242_11_S17_L002_R2_001.fastq.gz\"]}",
#     "workflowUrl": "",
#     "labels": "{\n    \"pipelineType\": \"CITE-seq\",\n    \"project\": \"HTAN CITE-seq\",\n    \"sample\": \"2090_CS1429a_T_1_CD45pos_citeseq_1_CITE\",\n    \"owner\": \"chunj\",\n    \"destination\": \"s3://dp-lab-test/sharp/citeseq/\",\n    \"transfer\": \"-\",\n    \"comment\": \"CITE-seq\"\n}"
#   },
#   "calls": {
#     "CiteSeq.Preprocess": [
#       {
#         "executionStatus": "Done",
#         "subWorkflowMetadata": {
#           "workflowName": "Preprocess",
#           "rootWorkflowId": "bb49f3ef-64cf-434c-89d9-eaf202c46a76",
#           "calls": {
#             "Preprocess.WhitelistFromSeqcDenseMatrix": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-WhitelistFromSeqcDenseMatrix/WhitelistFromSeqcDenseMatrix-stdout.log",
#                 "backendStatus": "Succeeded",
#                 "commandLine": "set -euo pipefail\n\npython - << EOF\nimport pandas as pd\nfrom seqc.sequence.encodings import DNA3Bit\n\ndf = pd.read_csv(\n    \"/cromwell_root/dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1/seqc-results/2090_CS1429a_T_1_CD45pos_citeseq_1_IGO_11244_17_dense.csv\",\n    index_col=0\n)\n\ndna3bit = DNA3Bit()\n\n# generate CB whitelist based on SEQC results\ncb_whitelist = df.index.map(lambda x: dna3bit.decode(x).decode()).sort_values().to_frame()\n\ncb_whitelist.to_csv(\n    \"cb-whitelist.txt\",\n    header=False, index=False\n)\nEOF",
#                 "shardIndex": -1,
#                 "outputs": {
#                   "out": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-WhitelistFromSeqcDenseMatrix/cb-whitelist.txt"
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/priority-gwf-core",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "583643567512.dkr.ecr.us-east-1.amazonaws.com/cromwell-seqc:0.2.9",
#                   "scriptBucketName": "dp-lab-gwf-core",
#                   "maxRetries": "3",
#                   "cpu": "1",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "32 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": false,
#                   "effectiveCallCachingMode": "CallCachingOff",
#                   "result": "Cache Miss",
#                   "hit": false
#                 },
#                 "inputs": {
#                   "dockerRegistry": "583643567512.dkr.ecr.us-east-1.amazonaws.com",
#                   "dockerImage": "583643567512.dkr.ecr.us-east-1.amazonaws.com/cromwell-seqc:0.2.9",
#                   "csvFile": "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1/seqc-results/2090_CS1429a_T_1_CD45pos_citeseq_1_IGO_11244_17_dense.csv",
#                   "inputSize": 0.13087342493236065,
#                   "numCores": 1
#                 },
#                 "returnCode": 0,
#                 "jobId": "8c39362c-26f5-48e1-8ec7-ee7d21112992",
#                 "backend": "AWSBATCH",
#                 "end": "2021-07-26T03:27:12.686Z",
#                 "dockerImageUsed": "583643567512.dkr.ecr.us-east-1.amazonaws.com/cromwell-seqc:0.2.9",
#                 "stderr": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-WhitelistFromSeqcDenseMatrix/WhitelistFromSeqcDenseMatrix-stderr.log",
#                 "callRoot": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-WhitelistFromSeqcDenseMatrix",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2021-07-26T03:20:56.875Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2021-07-26T03:20:56.875Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:20:56.875Z",
#                     "description": "PreparingJob",
#                     "endTime": "2021-07-26T03:20:56.989Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:20:56.989Z",
#                     "description": "RunningJob",
#                     "endTime": "2021-07-26T03:27:12.042Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:27:12.042Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2021-07-26T03:27:12.686Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:20:53.416Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2021-07-26T03:20:56.875Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:20:53.416Z",
#                     "description": "Pending",
#                     "endTime": "2021-07-26T03:20:53.416Z"
#                   }
#                 ],
#                 "start": "2021-07-26T03:20:53.415Z"
#               }
#             ],
#             "Preprocess.TrimR1": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-TrimR1/TrimR1-stdout.log",
#                 "backendStatus": "Succeeded",
#                 "commandLine": "set -euo pipefail\n\ncutadapt \\\n    --minimum-length 28 \\\n    --length 28 \\\n    --too-short-output too-short.R1.fastq.gz \\\n    --too-long-output too-long.R1.fastq.gz \\\n    -o R1.fastq.gz \\\n    /cromwell_root/dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-MergeFastqR1/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE_R1.fastq.gz",
#                 "shardIndex": -1,
#                 "outputs": {
#                   "outTooShortTooLongFiles": [
#                     "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-TrimR1/glob-c763acd1bbc2c02eb59e93c44eda4fa9/too-short.R1.fastq.gz"
#                   ],
#                   "outFile": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-TrimR1/R1.fastq.gz"
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/priority-gwf-core",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "583643567512.dkr.ecr.us-east-1.amazonaws.com/cromwell-cutadapt:2.5",
#                   "scriptBucketName": "dp-lab-gwf-core",
#                   "maxRetries": "3",
#                   "cpu": "4",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "16 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": false,
#                   "effectiveCallCachingMode": "CallCachingOff",
#                   "result": "Cache Miss",
#                   "hit": false
#                 },
#                 "inputs": {
#                   "outFileName": "R1.fastq.gz",
#                   "dockerRegistry": "583643567512.dkr.ecr.us-east-1.amazonaws.com",
#                   "dockerImage": "583643567512.dkr.ecr.us-east-1.amazonaws.com/cromwell-cutadapt:2.5",
#                   "length": 28,
#                   "fastq": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-MergeFastqR1/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE_R1.fastq.gz",
#                   "numCores": 4
#                 },
#                 "returnCode": 0,
#                 "jobId": "812650ac-bdaa-45ca-bbcd-34adf79145d3",
#                 "backend": "AWSBATCH",
#                 "end": "2021-07-26T03:36:05.710Z",
#                 "dockerImageUsed": "583643567512.dkr.ecr.us-east-1.amazonaws.com/cromwell-cutadapt:2.5",
#                 "stderr": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-TrimR1/TrimR1-stderr.log",
#                 "callRoot": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-TrimR1",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2021-07-26T03:30:58.874Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2021-07-26T03:30:58.875Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:30:55.105Z",
#                     "description": "Pending",
#                     "endTime": "2021-07-26T03:30:55.105Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:30:58.875Z",
#                     "description": "PreparingJob",
#                     "endTime": "2021-07-26T03:30:58.889Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:36:04.806Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2021-07-26T03:36:05.710Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:30:55.105Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2021-07-26T03:30:58.874Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:30:58.889Z",
#                     "description": "RunningJob",
#                     "endTime": "2021-07-26T03:36:04.806Z"
#                   }
#                 ],
#                 "start": "2021-07-26T03:30:55.105Z"
#               }
#             ],
#             "Preprocess.FastQCR2": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-FastQCR2/FastQCR2-stdout.log",
#                 "backendStatus": "Succeeded",
#                 "commandLine": "set -euo pipefail\n\nfastqc -o . /cromwell_root/dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-MergeFastqR2/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE_R2.fastq.gz",
#                 "shardIndex": -1,
#                 "outputs": {
#                   "outHtml": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-FastQCR2/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE_R2_fastqc.html",
#                   "outZip": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-FastQCR2/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE_R2_fastqc.zip"
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/priority-gwf-core",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "583643567512.dkr.ecr.us-east-1.amazonaws.com/cromwell-fastqc:0.11.8",
#                   "scriptBucketName": "dp-lab-gwf-core",
#                   "maxRetries": "3",
#                   "cpu": "4",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "16 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": false,
#                   "effectiveCallCachingMode": "CallCachingOff",
#                   "result": "Cache Miss",
#                   "hit": false
#                 },
#                 "inputs": {
#                   "dockerRegistry": "583643567512.dkr.ecr.us-east-1.amazonaws.com",
#                   "fastqFile": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-MergeFastqR2/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE_R2.fastq.gz",
#                   "dockerImage": "583643567512.dkr.ecr.us-east-1.amazonaws.com/cromwell-fastqc:0.11.8",
#                   "inputSize": 1.6601044880226254,
#                   "numCores": 4
#                 },
#                 "returnCode": 0,
#                 "jobId": "00445da7-ef83-402d-8779-71266ecdffc4",
#                 "backend": "AWSBATCH",
#                 "end": "2021-07-26T03:51:34.690Z",
#                 "dockerImageUsed": "583643567512.dkr.ecr.us-east-1.amazonaws.com/cromwell-fastqc:0.11.8",
#                 "stderr": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-FastQCR2/FastQCR2-stderr.log",
#                 "callRoot": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-FastQCR2",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2021-07-26T03:51:33.871Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2021-07-26T03:51:34.690Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:42:46.875Z",
#                     "description": "PreparingJob",
#                     "endTime": "2021-07-26T03:42:46.984Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:42:46.515Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2021-07-26T03:42:46.875Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:42:46.875Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2021-07-26T03:42:46.875Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:42:46.515Z",
#                     "description": "Pending",
#                     "endTime": "2021-07-26T03:42:46.515Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:42:46.984Z",
#                     "description": "RunningJob",
#                     "endTime": "2021-07-26T03:51:33.871Z"
#                   }
#                 ],
#                 "start": "2021-07-26T03:42:46.515Z"
#               }
#             ],
#             "Preprocess.CiteSeqCount": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/CiteSeqCount-stdout.log",
#                 "backendStatus": "Succeeded",
#                 "commandLine": "set -euo pipefail\n\n# preserve one core for the main process just in case\nlet n_threads=4-1\n\nCITE-seq-Count \\\n    -R1 /cromwell_root/dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-TrimR1/R1.fastq.gz \\\n    -R2 /cromwell_root/dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-TrimR2/R2.fastq.gz \\\n    --tags /cromwell_root/dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1_CITE/Hashtag_results/tag-list.csv \\\n    -cbf 1 -cbl 16 \\\n    -umif 17 -umil 28 \\\n    --bc_collapsing_dist 1 \\\n    --umi_collapsing_dist 1 \\\n    --max-error 2 \\\n    --start-trim 0  \\\n    --expected_cells 0 \\\n    --whitelist /cromwell_root/dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-WhitelistFromSeqcDenseMatrix/cb-whitelist.txt \\\n    --output results \\\n    --unmapped-tags unmapped.csv \\\n    --threads ${n_threads}",
#                 "shardIndex": -1,
#                 "outputs": {
#                   "outUncorrected": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/results/uncorrected_cells/dense_umis.tsv",
#                   "outReadCount": [
#                     "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz",
#                     "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz",
#                     "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz"
#                   ],
#                   "outUnmapped": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/results/unmapped.csv",
#                   "outUmiCount": [
#                     "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#                     "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#                     "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#                   ],
#                   "outReport": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/results/run_report.yaml"
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/priority-gwf-core",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "583643567512.dkr.ecr.us-east-1.amazonaws.com/cromwell-cite-seq-count:1.4.2-develop",
#                   "scriptBucketName": "dp-lab-gwf-core",
#                   "maxRetries": "3",
#                   "cpu": "4",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "64 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": false,
#                   "effectiveCallCachingMode": "CallCachingOff",
#                   "result": "Cache Miss",
#                   "hit": false
#                 },
#                 "inputs": {
#                   "numExpectedCells": 0,
#                   "slidingWindowSearch": false,
#                   "umiEndPos": 28,
#                   "tagList": "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1_CITE/Hashtag_results/tag-list.csv",
#                   "cbCollapsingDistance": 1,
#                   "umiStartPos": 17,
#                   "fastqR2": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-TrimR2/R2.fastq.gz",
#                   "version": "1.4.2-develop",
#                   "dockerRegistry": "583643567512.dkr.ecr.us-east-1.amazonaws.com",
#                   "dockerImage": "583643567512.dkr.ecr.us-east-1.amazonaws.com/cromwell-cite-seq-count:1.4.2-develop",
#                   "maxTagError": 2,
#                   "fastqR1": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-TrimR1/R1.fastq.gz",
#                   "umiCollapsingDistance": 1,
#                   "resourceSpec": {
#                     "memory": 64,
#                     "cpu": 4
#                   },
#                   "cbEndPos": 16,
#                   "cbWhiteList": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-WhitelistFromSeqcDenseMatrix/cb-whitelist.txt",
#                   "inputSize": 1.1543609574437141,
#                   "cbStartPos": 1,
#                   "trimPos": 0
#                 },
#                 "returnCode": 0,
#                 "jobId": "de4aa541-f20e-4e79-affd-a504cc639a9f",
#                 "backend": "AWSBATCH",
#                 "end": "2021-07-26T04:15:59.692Z",
#                 "dockerImageUsed": "583643567512.dkr.ecr.us-east-1.amazonaws.com/cromwell-cite-seq-count:1.4.2-develop",
#                 "stderr": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/CiteSeqCount-stderr.log",
#                 "callRoot": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2021-07-26T03:50:44.845Z",
#                     "description": "Pending",
#                     "endTime": "2021-07-26T03:50:44.845Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:50:45.189Z",
#                     "description": "RunningJob",
#                     "endTime": "2021-07-26T04:15:58.687Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:50:44.845Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2021-07-26T03:50:44.875Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T04:15:58.687Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2021-07-26T04:15:59.692Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:50:44.875Z",
#                     "description": "PreparingJob",
#                     "endTime": "2021-07-26T03:50:45.189Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:50:44.875Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2021-07-26T03:50:44.875Z"
#                   }
#                 ],
#                 "start": "2021-07-26T03:50:44.845Z"
#               }
#             ],
#             "Preprocess.MergeFastqR1": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-MergeFastqR1/MergeFastqR1-stdout.log",
#                 "backendStatus": "Succeeded",
#                 "compressedDockerSize": 28565863,
#                 "commandLine": "set -euo pipefail\n\nfilenames=\"/cromwell_root/dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_1_CITE_IGO_11242_11_S17_L001_R1_001.fastq.gz /cromwell_root/dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_1_CITE_IGO_11242_11_S17_L002_R1_001.fastq.gz\"\n\necho \"${filenames}\"\n\npath_out=\"2090_CS1429a_T_1_CD45pos_citeseq_1_CITE_R1.fastq\"\n\necho \"${path_out}\"\n\nif [ 2 -eq 1 ]\nthen\n    # single file, no need to merge\n    cp ${filenames} ${path_out}.gz\nelse\n    # gunzip and concatenate\n    for filename in $filenames\n    do\n        echo \"$filename > ${path_out}\"\n        gunzip -c ${filename} >> ${path_out}\n    done\n\n    # gzip\n    gzip ${path_out}\nfi",
#                 "shardIndex": -1,
#                 "outputs": {
#                   "out": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-MergeFastqR1/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE_R1.fastq.gz"
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/priority-gwf-core",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "ubuntu:20.04",
#                   "scriptBucketName": "dp-lab-gwf-core",
#                   "maxRetries": "3",
#                   "cpu": "2",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "8 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": true,
#                   "hit": false,
#                   "result": "Cache Miss",
#                   "hashes": {
#                     "output count": "C4CA4238A0B923820DCC509A6F75849B",
#                     "runtime attribute": {
#                       "docker": "84F4991B4143D392843C10A0A3887D4F",
#                       "continueOnReturnCode": "CFCD208495D565EF66E7DFF9F98764DA",
#                       "failOnStderr": "68934A3E9455FA72420237EB05902327"
#                     },
#                     "output expression": {
#                       "File out": "2555085929E2FE9B830A00A80D78FA7C"
#                     },
#                     "input count": "C9F0F895FB98AB9159F51FD0297E236D",
#                     "backend name": "2267EF43AEF6BB551F414FEC2390F68A",
#                     "command template": "9B72116602FA4968E38C53F5DDF80580",
#                     "input": {
#                       "String dockerImage": "0C97FAFF19DF99E5A2BB5EC1C9966807",
#                       "String sampleName": "E1B07295A9F54D227FCC698AC7D7DD4A",
#                       "Float inputSize": "3C5C464A6D9AC8BC4AE7367EE9610E3A",
#                       "String readName": "1FEF8BBE1BF098C953DE85686CA9CC35",
#                       "Int numFastq": "C81E728D9D4C2F636F067F89CC14862C",
#                       "File uriFastq": [
#                         "\"352629f4329854e867ca4b01d59d3a7b-57\"",
#                         "\"4d666e61178c14848c4338b98f1f6abe-57\""
#                       ],
#                       "Int numCores": "C81E728D9D4C2F636F067F89CC14862C"
#                     }
#                   },
#                   "effectiveCallCachingMode": "ReadAndWriteCache"
#                 },
#                 "inputs": {
#                   "sampleName": "2090_CS1429a_T_1_CD45pos_citeseq_1_CITE",
#                   "readName": "R1",
#                   "uriFastq": [
#                     "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_1_CITE_IGO_11242_11_S17_L001_R1_001.fastq.gz",
#                     "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_1_CITE_IGO_11242_11_S17_L002_R1_001.fastq.gz"
#                   ],
#                   "dockerImage": "ubuntu:20.04",
#                   "numFastq": 2,
#                   "inputSize": 0.8893150957301259,
#                   "numCores": 2
#                 },
#                 "returnCode": 0,
#                 "jobId": "95961cb7-46e4-4b39-a73a-f373d44c5bc9",
#                 "backend": "AWSBATCH",
#                 "end": "2021-07-26T03:30:53.682Z",
#                 "dockerImageUsed": "ubuntu@sha256:778fdd9f62a6d7c0e53a97489ab3db17738bc5c1acf09a18738a2a674025eae6",
#                 "stderr": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-MergeFastqR1/MergeFastqR1-stderr.log",
#                 "callRoot": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-MergeFastqR1",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2021-07-26T03:20:55.025Z",
#                     "description": "RunningJob",
#                     "endTime": "2021-07-26T03:30:52.583Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:20:51.366Z",
#                     "description": "Pending",
#                     "endTime": "2021-07-26T03:20:51.366Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:20:54.875Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2021-07-26T03:20:54.875Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:20:51.366Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2021-07-26T03:20:54.875Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:30:52.704Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2021-07-26T03:30:53.682Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:20:54.875Z",
#                     "description": "PreparingJob",
#                     "endTime": "2021-07-26T03:20:55.014Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:30:52.583Z",
#                     "description": "UpdatingCallCache",
#                     "endTime": "2021-07-26T03:30:52.704Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:20:55.014Z",
#                     "description": "CallCacheReading",
#                     "endTime": "2021-07-26T03:20:55.025Z"
#                   }
#                 ],
#                 "start": "2021-07-26T03:20:51.365Z"
#               }
#             ],
#             "Preprocess.CountReads": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CountReads/CountReads-stdout.log",
#                 "backendStatus": "Succeeded",
#                 "commandLine": "set -euo pipefail\n\npigz -dc /cromwell_root/dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-TrimR1/R1.fastq.gz | awk 'NR % 4 == 2' | wc -l",
#                 "shardIndex": -1,
#                 "outputs": {
#                   "numOfReads": 42687903
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/priority-gwf-core",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "583643567512.dkr.ecr.us-east-1.amazonaws.com/cromwell-pigz:2.4",
#                   "scriptBucketName": "dp-lab-gwf-core",
#                   "maxRetries": "3",
#                   "cpu": "4",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "8 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": false,
#                   "effectiveCallCachingMode": "CallCachingOff",
#                   "result": "Cache Miss",
#                   "hit": false
#                 },
#                 "inputs": {
#                   "fastq": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-TrimR1/R1.fastq.gz",
#                   "dockerRegistry": "583643567512.dkr.ecr.us-east-1.amazonaws.com",
#                   "dockerImage": "583643567512.dkr.ecr.us-east-1.amazonaws.com/cromwell-pigz:2.4",
#                   "inputSize": 0.7429014770314097
#                 },
#                 "returnCode": 0,
#                 "jobId": "703a2186-d0bd-49f9-9158-6d2af5ce2628",
#                 "backend": "AWSBATCH",
#                 "end": "2021-07-26T03:37:18.698Z",
#                 "dockerImageUsed": "583643567512.dkr.ecr.us-east-1.amazonaws.com/cromwell-pigz:2.4",
#                 "stderr": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CountReads/CountReads-stderr.log",
#                 "callRoot": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CountReads",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2021-07-26T03:36:09.236Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2021-07-26T03:36:10.875Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:37:17.665Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2021-07-26T03:37:18.698Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:36:10.875Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2021-07-26T03:36:10.875Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:36:09.236Z",
#                     "description": "Pending",
#                     "endTime": "2021-07-26T03:36:09.236Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:36:10.875Z",
#                     "description": "PreparingJob",
#                     "endTime": "2021-07-26T03:36:11.022Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:36:11.022Z",
#                     "description": "RunningJob",
#                     "endTime": "2021-07-26T03:37:17.665Z"
#                   }
#                 ],
#                 "start": "2021-07-26T03:36:09.235Z"
#               }
#             ],
#             "Preprocess.TrimR2": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-TrimR2/TrimR2-stdout.log",
#                 "backendStatus": "Succeeded",
#                 "commandLine": "set -euo pipefail\n\ncutadapt \\\n    --minimum-length 15 \\\n    --length 15 \\\n    --too-short-output too-short.R2.fastq.gz \\\n    --too-long-output too-long.R2.fastq.gz \\\n    -o R2.fastq.gz \\\n    /cromwell_root/dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-MergeFastqR2/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE_R2.fastq.gz",
#                 "shardIndex": -1,
#                 "outputs": {
#                   "outTooShortTooLongFiles": [
#                     "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-TrimR2/glob-0ee15da47465f38e299b3bd7f7bbe3be/too-short.R2.fastq.gz"
#                   ],
#                   "outFile": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-TrimR2/R2.fastq.gz"
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/priority-gwf-core",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "583643567512.dkr.ecr.us-east-1.amazonaws.com/cromwell-cutadapt:2.5",
#                   "scriptBucketName": "dp-lab-gwf-core",
#                   "maxRetries": "3",
#                   "cpu": "4",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "16 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": false,
#                   "effectiveCallCachingMode": "CallCachingOff",
#                   "result": "Cache Miss",
#                   "hit": false
#                 },
#                 "inputs": {
#                   "outFileName": "R2.fastq.gz",
#                   "dockerRegistry": "583643567512.dkr.ecr.us-east-1.amazonaws.com",
#                   "dockerImage": "583643567512.dkr.ecr.us-east-1.amazonaws.com/cromwell-cutadapt:2.5",
#                   "length": 15,
#                   "fastq": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-MergeFastqR2/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE_R2.fastq.gz",
#                   "numCores": 4
#                 },
#                 "returnCode": 0,
#                 "jobId": "d9cb7225-b79c-43b9-9a8c-6f3bf40fccef",
#                 "backend": "AWSBATCH",
#                 "end": "2021-07-26T03:50:43.699Z",
#                 "dockerImageUsed": "583643567512.dkr.ecr.us-east-1.amazonaws.com/cromwell-cutadapt:2.5",
#                 "stderr": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-TrimR2/TrimR2-stderr.log",
#                 "callRoot": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-TrimR2",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2021-07-26T03:42:46.515Z",
#                     "description": "Pending",
#                     "endTime": "2021-07-26T03:42:46.515Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:42:48.875Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2021-07-26T03:42:48.876Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:42:48.876Z",
#                     "description": "PreparingJob",
#                     "endTime": "2021-07-26T03:42:48.901Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:50:43.405Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2021-07-26T03:50:43.699Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:42:46.515Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2021-07-26T03:42:48.875Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:42:48.901Z",
#                     "description": "RunningJob",
#                     "endTime": "2021-07-26T03:50:43.405Z"
#                   }
#                 ],
#                 "start": "2021-07-26T03:42:46.515Z"
#               }
#             ],
#             "Preprocess.FastQCR1": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-FastQCR1/FastQCR1-stdout.log",
#                 "backendStatus": "Succeeded",
#                 "commandLine": "set -euo pipefail\n\nfastqc -o . /cromwell_root/dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-MergeFastqR1/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE_R1.fastq.gz",
#                 "shardIndex": -1,
#                 "outputs": {
#                   "outHtml": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-FastQCR1/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE_R1_fastqc.html",
#                   "outZip": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-FastQCR1/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE_R1_fastqc.zip"
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/priority-gwf-core",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "583643567512.dkr.ecr.us-east-1.amazonaws.com/cromwell-fastqc:0.11.8",
#                   "scriptBucketName": "dp-lab-gwf-core",
#                   "maxRetries": "3",
#                   "cpu": "4",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "16 GB"
#                 },
#                 "callCaching": {
# ...
#                     "endTime": "2021-07-26T04:16:01.445Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T04:16:02.875Z",
#                     "description": "PreparingJob",
#                     "endTime": "2021-07-26T04:16:03.464Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T04:16:02.875Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2021-07-26T04:16:02.875Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T04:20:08.762Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2021-07-26T04:20:09.700Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T04:16:01.445Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2021-07-26T04:16:02.875Z"
#                   }
#                 ],
#                 "start": "2021-07-26T04:16:01.445Z"
#               }
#             ]
#           },
#           "outputs": {
#             "Preprocess.fastQCR2Html": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-FastQCR2/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE_R2_fastqc.html",
#             "Preprocess.fastQCR1Html": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-FastQCR1/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE_R1_fastqc.html",
#             "Preprocess.adata": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-ToAnnData/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE.h5ad",
#             "Preprocess.readCountMatrix": [
#               "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz",
#               "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz",
#               "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz"
#             ],
#             "Preprocess.countReport": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/results/run_report.yaml",
#             "Preprocess.umiCountMatrix": [
#               "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#               "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#               "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#             ]
#           },
#           "workflowRoot": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/",
#           "id": "09c7a69b-5bf3-48a4-90a9-0c84d254102d",
#           "inputs": {
#             "lengthR2": 15,
#             "scRnaSeqPlatform": "10x_v3",
#             "CiteSeqCount.version": "1.4.2-develop",
#             "numExpectedCells": 0,
#             "slidingWindowSearch": false,
#             "cellBarcodeWhiteListMethod": "SeqcDenseCountsMatrixCsv",
#             "sampleName": "2090_CS1429a_T_1_CD45pos_citeseq_1_CITE",
#             "umiEndPos": 28,
#             "tagList": "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1_CITE/Hashtag_results/tag-list.csv",
#             "uriFastqR2": [
#               "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_1_CITE_IGO_11242_11_S17_L001_R2_001.fastq.gz",
#               "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_1_CITE_IGO_11242_11_S17_L002_R2_001.fastq.gz"
#             ],
#             "cbCollapsingDistance": 1,
#             "umiStartPos": 17,
#             "dockerRegistry": "583643567512.dkr.ecr.us-east-1.amazonaws.com",
#             "maxTagError": 2,
#             "umiCollapsingDistance": 1,
#             "resourceSpec": {
#               "memory": 64,
#               "cpu": 4
#             },
#             "cbEndPos": 16,
#             "cellBarcodeWhitelistUri": "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1/seqc-results/2090_CS1429a_T_1_CD45pos_citeseq_1_IGO_11244_17_dense.csv",
#             "lengthR1": 28,
#             "uriFastqR1": [
#               "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_1_CITE_IGO_11242_11_S17_L001_R1_001.fastq.gz",
#               "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_1_CITE_IGO_11242_11_S17_L002_R1_001.fastq.gz"
#             ],
#             "translate10XBarcodes": false,
#             "cbStartPos": 1,
#             "trimPos": 0
#           },
#           "status": "Succeeded",
#           "parentWorkflowId": "bb49f3ef-64cf-434c-89d9-eaf202c46a76",
#           "end": "2021-07-26T04:20:11.345Z",
#           "start": "2021-07-26T03:20:49.246Z"
#         },
#         "shardIndex": -1,
#         "outputs": {
#           "readCountMatrix": [
#             "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz",
#             "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz",
#             "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz"
#           ],
#           "adata": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-ToAnnData/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE.h5ad",
#           "countReport": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/results/run_report.yaml",
#           "fastQCR2Html": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-FastQCR2/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE_R2_fastqc.html",
#           "umiCountMatrix": [
#             "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#             "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#             "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#           ],
#           "fastQCR1Html": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-FastQCR1/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE_R1_fastqc.html"
#         },
#         "inputs": {
#           "lengthR2": 15,
#           "scRnaSeqPlatform": "10x_v3",
#           "CiteSeqCount.version": "1.4.2-develop",
#           "numExpectedCells": 0,
#           "slidingWindowSearch": false,
#           "cellBarcodeWhiteListMethod": "SeqcDenseCountsMatrixCsv",
#           "sampleName": "2090_CS1429a_T_1_CD45pos_citeseq_1_CITE",
#           "umiEndPos": 28,
#           "tagList": "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1_CITE/Hashtag_results/tag-list.csv",
#           "uriFastqR2": [
#             "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_1_CITE_IGO_11242_11_S17_L001_R2_001.fastq.gz",
#             "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_1_CITE_IGO_11242_11_S17_L002_R2_001.fastq.gz"
#           ],
#           "cbCollapsingDistance": 1,
#           "umiStartPos": 17,
#           "dockerRegistry": "583643567512.dkr.ecr.us-east-1.amazonaws.com",
#           "maxTagError": 2,
#           "umiCollapsingDistance": 1,
#           "resourceSpec": {
#             "memory": 64,
#             "cpu": 4
#           },
#           "cbEndPos": 16,
#           "cellBarcodeWhitelistUri": "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1/seqc-results/2090_CS1429a_T_1_CD45pos_citeseq_1_IGO_11244_17_dense.csv",
#           "lengthR1": 28,
#           "uriFastqR1": [
#             "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_1_CITE_IGO_11242_11_S17_L001_R1_001.fastq.gz",
#             "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_1_CITE_IGO_11242_11_S17_L002_R1_001.fastq.gz"
#           ],
#           "translate10XBarcodes": false,
#           "cbStartPos": 1,
#           "trimPos": 0
#         },
#         "end": "2021-07-26T04:20:11.346Z",
#         "attempt": 1,
#         "executionEvents": [
#           {
#             "startTime": "2021-07-26T03:20:49.246Z",
#             "description": "WaitingForValueStore",
#             "endTime": "2021-07-26T03:20:49.246Z"
#           },
#           {
#             "startTime": "2021-07-26T03:20:49.246Z",
#             "description": "SubWorkflowPreparingState",
#             "endTime": "2021-07-26T03:20:49.254Z"
#           },
#           {
#             "startTime": "2021-07-26T03:20:49.245Z",
#             "description": "SubWorkflowPendingState",
#             "endTime": "2021-07-26T03:20:49.246Z"
#           },
#           {
#             "startTime": "2021-07-26T03:20:49.254Z",
#             "description": "SubWorkflowRunningState",
#             "endTime": "2021-07-26T04:20:11.345Z"
#           }
#         ],
#         "start": "2021-07-26T03:20:49.245Z"
#       }
#     ]
#   },
#   "outputs": {
#     "CiteSeq.umiCountMatrix": [
#       "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#       "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#       "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#     ],
#     "CiteSeq.fastQCR1Html": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-FastQCR1/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE_R1_fastqc.html",
#     "CiteSeq.readCountMatrix": [
#       "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz",
#       "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz",
#       "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz"
#     ],
#     "CiteSeq.adata": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-ToAnnData/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE.h5ad",
#     "CiteSeq.countReport": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/results/run_report.yaml",
#     "CiteSeq.fastQCR2Html": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-FastQCR2/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE_R2_fastqc.html"
#   },
#   "actualWorkflowLanguage": "WDL",
#   "id": "bb49f3ef-64cf-434c-89d9-eaf202c46a76",
#   "inputs": {
#     "lengthR2": 15,
#     "scRnaSeqPlatform": "10x_v3",
#     "numExpectedCells": 0,
#     "slidingWindowSearch": false,
#     "cellBarcodeWhiteListMethod": "SeqcDenseCountsMatrixCsv",
#     "sampleName": "2090_CS1429a_T_1_CD45pos_citeseq_1_CITE",
#     "umiEndPos": 28,
#     "tagList": "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1_CITE/Hashtag_results/tag-list.csv",
#     "uriFastqR2": [
#       "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_1_CITE_IGO_11242_11_S17_L001_R2_001.fastq.gz",
#       "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_1_CITE_IGO_11242_11_S17_L002_R2_001.fastq.gz"
#     ],
#     "cbCollapsingDistance": 1,
#     "umiStartPos": 17,
#     "dockerRegistry": "583643567512.dkr.ecr.us-east-1.amazonaws.com",
#     "maxTagError": 2,
#     "umiCollapsingDistance": 1,
#     "resourceSpec": {
#       "memory": 64,
#       "cpu": 4
#     },
#     "cbEndPos": 16,
#     "cellBarcodeWhitelistUri": "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1/seqc-results/2090_CS1429a_T_1_CD45pos_citeseq_1_IGO_11244_17_dense.csv",
#     "lengthR1": 28,
#     "uriFastqR1": [
#       "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_1_CITE_IGO_11242_11_S17_L001_R1_001.fastq.gz",
#       "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_1_CITE_IGO_11242_11_S17_L002_R1_001.fastq.gz"
#     ],
#     "translate10XBarcodes": false,
#     "cbStartPos": 1,
#     "trimPos": 0
#   },
#   "labels": {
#     "project": "HTAN CITE-seq",
#     "cromwell-workflow-id": "cromwell-bb49f3ef-64cf-434c-89d9-eaf202c46a76",
#     "transfer": "done",
#     "comment": "CITE-seq",
#     "flag": "follow-up",
#     "sample": "2090_CS1429a_T_1_CD45pos_citeseq_1_CITE",
#     "pipelineType": "CITE-seq",
#     "owner": "chunj",
#     "destination": "s3://dp-lab-test/sharp/citeseq/"
#   },
#   "submission": "2021-07-26T03:20:33.391Z",
#   "status": "Succeeded",
#   "end": "2021-07-26T04:20:12.908Z",
#   "start": "2021-07-26T03:20:46.992Z"
# }

# %% [markdown]
# ## Get Sample Name

# %%
sample_name = metadata["labels"]["sample"]
sample_name
# Out:
# '2090_CS1429a_T_1_CD45pos_citeseq_1_CITE'

# %% [markdown]
# ## Get Counts

# %%
def download(sample_name, workflow_id, subfolder, items):
    
    if skip_download:
        return
    
    if not isinstance(items, list):
        items = [items]
        
    path_output = f"{path_base_data}/{sample_name}/{workflow_id}/{subfolder}"
    
    os.makedirs(path_output, exist_ok=True)
        
    for item in items:
        cmd_download = f"aws s3 cp {item} {path_output}"
        print(cmd_download)
        os.system(cmd_download)

# %%
meta_cite_seq_count = metadata["calls"]["CiteSeq.Preprocess"][0]["subWorkflowMetadata"]["calls"]["Preprocess.CiteSeqCount"][0]

# %%
print(json.dumps(meta_cite_seq_count, indent=2))
# Out:
# {
#   "executionStatus": "Done",
#   "stdout": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/CiteSeqCount-stdout.log",
#   "backendStatus": "Succeeded",
#   "commandLine": "set -euo pipefail\n\n# preserve one core for the main process just in case\nlet n_threads=4-1\n\nCITE-seq-Count \\\n    -R1 /cromwell_root/dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-TrimR1/R1.fastq.gz \\\n    -R2 /cromwell_root/dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-TrimR2/R2.fastq.gz \\\n    --tags /cromwell_root/dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1_CITE/Hashtag_results/tag-list.csv \\\n    -cbf 1 -cbl 16 \\\n    -umif 17 -umil 28 \\\n    --bc_collapsing_dist 1 \\\n    --umi_collapsing_dist 1 \\\n    --max-error 2 \\\n    --start-trim 0  \\\n    --expected_cells 0 \\\n    --whitelist /cromwell_root/dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-WhitelistFromSeqcDenseMatrix/cb-whitelist.txt \\\n    --output results \\\n    --unmapped-tags unmapped.csv \\\n    --threads ${n_threads}",
#   "shardIndex": -1,
#   "outputs": {
#     "outUncorrected": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/results/uncorrected_cells/dense_umis.tsv",
#     "outReadCount": [
#       "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz",
#       "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz",
#       "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz"
#     ],
#     "outUnmapped": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/results/unmapped.csv",
#     "outUmiCount": [
#       "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#       "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#       "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#     ],
#     "outReport": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/results/run_report.yaml"
#   },
#   "runtimeAttributes": {
#     "failOnStderr": "false",
#     "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/priority-gwf-core",
#     "disks": "local-disk /cromwell_root",
#     "continueOnReturnCode": "0",
#     "docker": "583643567512.dkr.ecr.us-east-1.amazonaws.com/cromwell-cite-seq-count:1.4.2-develop",
#     "scriptBucketName": "dp-lab-gwf-core",
#     "maxRetries": "3",
#     "cpu": "4",
#     "cpuMin": "1",
#     "noAddress": "false",
#     "zones": "us-east-1a",
#     "memoryMin": "2 GB",
#     "memory": "64 GB"
#   },
#   "callCaching": {
#     "allowResultReuse": false,
#     "effectiveCallCachingMode": "CallCachingOff",
#     "result": "Cache Miss",
#     "hit": false
#   },
#   "inputs": {
#     "numExpectedCells": 0,
#     "slidingWindowSearch": false,
#     "umiEndPos": 28,
#     "tagList": "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_1_CITE/Hashtag_results/tag-list.csv",
#     "cbCollapsingDistance": 1,
#     "umiStartPos": 17,
#     "fastqR2": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-TrimR2/R2.fastq.gz",
#     "version": "1.4.2-develop",
#     "dockerRegistry": "583643567512.dkr.ecr.us-east-1.amazonaws.com",
#     "dockerImage": "583643567512.dkr.ecr.us-east-1.amazonaws.com/cromwell-cite-seq-count:1.4.2-develop",
#     "maxTagError": 2,
#     "fastqR1": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-TrimR1/R1.fastq.gz",
#     "umiCollapsingDistance": 1,
#     "resourceSpec": {
#       "memory": 64,
#       "cpu": 4
#     },
#     "cbEndPos": 16,
#     "cbWhiteList": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-WhitelistFromSeqcDenseMatrix/cb-whitelist.txt",
#     "inputSize": 1.1543609574437141,
#     "cbStartPos": 1,
#     "trimPos": 0
#   },
#   "returnCode": 0,
#   "jobId": "de4aa541-f20e-4e79-affd-a504cc639a9f",
#   "backend": "AWSBATCH",
#   "end": "2021-07-26T04:15:59.692Z",
#   "dockerImageUsed": "583643567512.dkr.ecr.us-east-1.amazonaws.com/cromwell-cite-seq-count:1.4.2-develop",
#   "stderr": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/CiteSeqCount-stderr.log",
#   "callRoot": "s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount",
#   "attempt": 1,
#   "executionEvents": [
#     {
#       "startTime": "2021-07-26T03:50:44.845Z",
#       "description": "Pending",
#       "endTime": "2021-07-26T03:50:44.845Z"
#     },
#     {
#       "startTime": "2021-07-26T03:50:45.189Z",
#       "description": "RunningJob",
#       "endTime": "2021-07-26T04:15:58.687Z"
#     },
#     {
#       "startTime": "2021-07-26T03:50:44.845Z",
#       "description": "RequestingExecutionToken",
#       "endTime": "2021-07-26T03:50:44.875Z"
#     },
#     {
#       "startTime": "2021-07-26T04:15:58.687Z",
#       "description": "UpdatingJobStore",
#       "endTime": "2021-07-26T04:15:59.692Z"
#     },
#     {
#       "startTime": "2021-07-26T03:50:44.875Z",
#       "description": "PreparingJob",
#       "endTime": "2021-07-26T03:50:45.189Z"
#     },
#     {
#       "startTime": "2021-07-26T03:50:44.875Z",
#       "description": "WaitingForValueStore",
#       "endTime": "2021-07-26T03:50:44.875Z"
#     }
#   ],
#   "start": "2021-07-26T03:50:44.845Z"
# }

# %% [markdown]
# ### Download Read Count

# %%
download(
    sample_name, workflow_id,
    "reads",
    meta_cite_seq_count["outputs"]["outReadCount"]
)
# Out:
# aws s3 cp s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz ./citeseq/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE/bb49f3ef-64cf-434c-89d9-eaf202c46a76/reads
# aws s3 cp s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz ./citeseq/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE/bb49f3ef-64cf-434c-89d9-eaf202c46a76/reads
# aws s3 cp s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz ./citeseq/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE/bb49f3ef-64cf-434c-89d9-eaf202c46a76/reads

# %% [markdown]
# ### Download UMI Count

# %%
download(
    sample_name, workflow_id,
    "umis",
    meta_cite_seq_count["outputs"]["outUmiCount"]
)
# Out:
# aws s3 cp s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz ./citeseq/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE/bb49f3ef-64cf-434c-89d9-eaf202c46a76/umis
# aws s3 cp s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz ./citeseq/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE/bb49f3ef-64cf-434c-89d9-eaf202c46a76/umis
# aws s3 cp s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz ./citeseq/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE/bb49f3ef-64cf-434c-89d9-eaf202c46a76/umis

# %% [markdown]
# ## Download Report

# %%
download(
    sample_name, workflow_id,
    "report",
    meta_cite_seq_count["outputs"]["outReport"]
)
# Out:
# aws s3 cp s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-CiteSeqCount/results/run_report.yaml ./citeseq/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE/bb49f3ef-64cf-434c-89d9-eaf202c46a76/report

# %% [markdown]
# ## Download AnnData

# %%
download(
    sample_name=sample_name, workflow_id=workflow_id, subfolder="", items=metadata["outputs"]["CiteSeq.adata"]
)
# Out:
# aws s3 cp s3://dp-lab-gwf-core/cromwell-execution/CiteSeq/bb49f3ef-64cf-434c-89d9-eaf202c46a76/call-Preprocess/Preprocess/09c7a69b-5bf3-48a4-90a9-0c84d254102d/call-ToAnnData/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE.h5ad ./citeseq/2090_CS1429a_T_1_CD45pos_citeseq_1_CITE/bb49f3ef-64cf-434c-89d9-eaf202c46a76/

# %% [markdown]
# ## Output Sample Name

# %%
# 1. DO NOT DELETE
# 2. MUST BE THE FINAL LINE
print(sample_name)
# Out:
# 2090_CS1429a_T_1_CD45pos_citeseq_1_CITE
