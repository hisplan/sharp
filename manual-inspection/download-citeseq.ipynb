# %%
import os
import json

import requests
from requests.exceptions import HTTPError
from requests.auth import HTTPBasicAuth

# %% [markdown]
# ## Parameters

# %%
# this cell is tagged `parameters` and will be overridden by papermill

workflow_id = "9c72e274-712a-4137-811c-4f1d6cc2eeb1"

path_secrets_file = "/Users/chunj/keys/secrets-aws.json"
path_base_data = "./citeseq"
skip_download = False

# %% [markdown]
# ## APIs to Cromwell

# %%
def get_secrets(path_secrets_file):

    with open(path_secrets_file, "rt") as fin:
        data = json.loads(fin.read())

    return data

def prep_api_call(secrets):

    api_version = "v1"
    url = secrets["url"]
    url = f"{url}/api/workflows/{api_version}"

    auth = HTTPBasicAuth(secrets["username"], secrets["password"])

    return url, auth

def get_metadata(secrets, workflow_id):

    base_url, auth = prep_api_call(secrets)

    try:
        response = requests.patch(
            url=f"{base_url}/{workflow_id}/metadata?expandSubWorkflows=true",
            headers={
                "Content-Type": "application/json",
                "Accept": "application/json"
            },
            auth=auth
        )

        # if response.status_code == 200:
        data = response.json()

        return data

    except HTTPError as err:
        print(err)

# %% [markdown]
# ## Get Metadata

# %%
metadata = get_metadata(
    get_secrets(path_secrets_file),
    workflow_id
)

# %%
print(json.dumps(metadata, indent=2))
# Out:
# {
#   "workflowName": "CiteSeq",
#   "workflowProcessingEvents": [
#     {
#       "cromwellId": "cromid-553c754",
#       "description": "Finished",
#       "timestamp": "2020-10-27T04:16:04.433Z",
#       "cromwellVersion": "51"
#     },
#     {
#       "cromwellId": "cromid-553c754",
#       "description": "PickedUp",
#       "timestamp": "2020-10-27T03:27:26.635Z",
#       "cromwellVersion": "51"
#     }
#   ],
#   "metadataSource": "Unarchived",
#   "actualWorkflowLanguageVersion": "1.0",
#   "submittedFiles": {
#     "workflow": "version 1.0\n\nimport \"modules/Preprocess.wdl\" as Preprocess\nimport \"modules/ToAnnData.wdl\" as ToAnnData\n\nworkflow CiteSeq {\n\n    input {\n        Array[File] uriFastqR1\n        Array[File] uriFastqR2\n\n        Int lengthR1\n        Int lengthR2\n\n        String sampleName\n\n        File cellBarcodeWhitelistUri\n        String cellBarcodeWhiteListMethod\n\n        # set to false if TotalSeq-A is used\n        # set to true if TotalSeq-B or C is used\n        Boolean translate10XBarcodes\n\n        String scRnaSeqPlatform = \"10x_v3\"\n\n        File tagList\n\n        # cellular barcode start/end positions\n        Int cbStartPos\n        Int cbEndPos\n\n        # UMI start/end positions\n        Int umiStartPos\n        Int umiEndPos\n\n        # how many bases should we trim before starting to look for hashtag sequence\n        Int trimPos = 0\n\n        # activate sliding window alignement\n        Boolean slidingWindowSearch = false\n\n        # correction\n        Int cbCollapsingDistance\n        Int umiCollapsingDistance\n        Int maxTagError = 2\n\n        Int numExpectedCells\n\n        File denseCountMatrix\n\n        Boolean runSeuratDemux = false\n\n        Map[String, Int] resourceSpec\n    }\n\n    call Preprocess.Preprocess {\n        input:\n            uriFastqR1 = uriFastqR1,\n            uriFastqR2 = uriFastqR2,\n            lengthR1 = lengthR1,\n            lengthR2 = lengthR2,\n            sampleName = sampleName,\n            cellBarcodeWhitelistUri = cellBarcodeWhitelistUri,\n            cellBarcodeWhiteListMethod = cellBarcodeWhiteListMethod,\n            translate10XBarcodes = translate10XBarcodes,\n            scRnaSeqPlatform = scRnaSeqPlatform,\n            tagList = tagList,\n            cbStartPos = cbStartPos,\n            cbEndPos = cbEndPos,\n            umiStartPos = umiStartPos,\n            umiEndPos = umiEndPos,\n            trimPos = trimPos,\n            slidingWindowSearch = slidingWindowSearch,\n            cbCollapsingDistance = cbCollapsingDistance,\n            umiCollapsingDistance = umiCollapsingDistance,\n            maxTagError = maxTagError,\n            numExpectedCells = numExpectedCells,\n            denseCountMatrix = denseCountMatrix,\n            runSeuratDemux = runSeuratDemux,\n            resourceSpec = resourceSpec\n    }\n\n    call ToAnnData.CiteSeqToAnnData {\n        input:\n            sampleName = sampleName,\n            tagList = tagList,\n            umiCountFiles = Preprocess.umiCountMatrix,\n            readCountFiles = Preprocess.readCountMatrix\n    }\n\n    output {\n        File fastQCR1Html = Preprocess.fastQCR1Html\n        File fastQCR2Html = Preprocess.fastQCR2Html\n\n        File countReport = Preprocess.countReport\n        Array[File] umiCountMatrix = Preprocess.umiCountMatrix\n        Array[File] readCountMatrix = Preprocess.readCountMatrix\n\n        File adata = CiteSeqToAnnData.outAdata\n    }\n}\n",
#     "root": "",
#     "options": "{\n  \"monitoring_script\": \"s3://dp-lab-batch/monitoring.sh\",\n  \"read_from_cache\": true,\n  \"workflow_failure_mode\": \"ContinueWhilePossible\",\n  \"write_to_cache\": true\n}",
#     "inputs": "{\"CiteSeq.cbCollapsingDistance\":1,\"CiteSeq.cbEndPos\":16,\"CiteSeq.cbStartPos\":1,\"CiteSeq.cellBarcodeWhiteListMethod\":\"SeqcDenseCountsMatrixCsv\",\"CiteSeq.cellBarcodeWhitelistUri\":\"s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_2/seqc-results/2091_CS1429a_T_1_CD45pos_citeseq_2_IGO_11242_14_dense.csv\",\"CiteSeq.denseCountMatrix\":\"s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_2/seqc-results/2091_CS1429a_T_1_CD45pos_citeseq_2_IGO_11242_14_dense.csv\",\"CiteSeq.lengthR1\":28,\"CiteSeq.lengthR2\":15,\"CiteSeq.numExpectedCells\":0,\"CiteSeq.resourceSpec\":{\"cpu\":4,\"memory\":64},\"CiteSeq.sampleName\":\"2091_CS1429a_T_1_CD45pos_citeseq_2_CITE\",\"CiteSeq.scRnaSeqPlatform\":\"10x_v3\",\"CiteSeq.slidingWindowSearch\":false,\"CiteSeq.tagList\":\"s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/Hashtag_results/tag-list.csv\",\"CiteSeq.translate10XBarcodes\":false,\"CiteSeq.trimPos\":0,\"CiteSeq.umiCollapsingDistance\":1,\"CiteSeq.umiEndPos\":28,\"CiteSeq.umiStartPos\":17,\"CiteSeq.uriFastqR1\":[\"s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_2_CITE_IGO_11244_16_S2_R1_001.fastq.gz\"],\"CiteSeq.uriFastqR2\":[\"s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_2_CITE_IGO_11244_16_S2_R2_001.fastq.gz\"]}",
#     "workflowUrl": "",
#     "labels": "{\n    \"pipelineType\": \"CITE-seq\",\n    \"project\": \"Project 230\",\n    \"sample\": \"2091_CS1429a_T_1_CD45pos_citeseq_2_CITE\",\n    \"owner\": \"chunj\",\n    \"destination\": \"s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_2/CITE-seq-results/\",\n    \"transfer\": \"-\",\n    \"comment\": \"CITE-seq Pipeline\"\n}"
#   },
#   "calls": {
#     "CiteSeq.CiteSeqToAnnData": [
#       {
#         "executionStatus": "Done",
#         "stdout": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-CiteSeqToAnnData/CiteSeqToAnnData-stdout.log",
#         "backendStatus": "Succeeded",
#         "compressedDockerSize": 459883916,
#         "commandLine": "set -euo pipefail\n\nmkdir umi-counts\ncp /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz ./umi-counts/\n\nmkdir read-counts\ncp /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz ./read-counts/\n\npython3 /opt/citeseq_to_adata.py \\\n    --sample 2091_CS1429a_T_1_CD45pos_citeseq_2_CITE \\\n    --tag-list /cromwell_root/dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/Hashtag_results/tag-list.csv \\\n    --umi-counts ./umi-counts/ \\\n    --read-counts ./read-counts/",
#         "shardIndex": -1,
#         "outputs": {
#           "outAdata": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-CiteSeqToAnnData/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE.CITE-seq.h5ad",
#           "outLog": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-CiteSeqToAnnData/citeseq_to_adata.log"
#         },
#         "runtimeAttributes": {
#           "failOnStderr": "false",
#           "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/highpriority-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#           "disks": "local-disk /cromwell_root",
#           "continueOnReturnCode": "0",
#           "docker": "hisplan/cromwell-hto-adt-postprocess:0.3.1",
#           "maxRetries": "0",
#           "cpu": "1",
#           "cpuMin": "1",
#           "noAddress": "false",
#           "zones": "us-east-1a",
#           "memoryMin": "2 GB",
#           "memory": "8 GB"
#         },
#         "callCaching": {
#           "allowResultReuse": false,
#           "effectiveCallCachingMode": "CallCachingOff"
#         },
#         "inputs": {
#           "umiCountFiles": [
#             "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#             "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#             "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#           ],
#           "sampleName": "2091_CS1429a_T_1_CD45pos_citeseq_2_CITE",
#           "tagList": "s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/Hashtag_results/tag-list.csv",
#           "dockerImage": "hisplan/cromwell-hto-adt-postprocess:0.3.1",
#           "readCountFiles": [
#             "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz",
#             "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz",
#             "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz"
#           ],
#           "inputSize": 0.0010110056027770042,
#           "numCores": 1
#         },
#         "returnCode": 0,
#         "jobId": "10f53ea7-b46d-46c7-8fe9-0de24abad539",
#         "backend": "AWSBATCH",
#         "end": "2020-10-27T04:16:03.097Z",
#         "dockerImageUsed": "hisplan/cromwell-hto-adt-postprocess@sha256:e3e46490e248de656be665bd480a9fbe479fec0d24a8a36ae56e0c600574a63d",
#         "stderr": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-CiteSeqToAnnData/CiteSeqToAnnData-stderr.log",
#         "callRoot": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-CiteSeqToAnnData",
#         "attempt": 1,
#         "executionEvents": [
#           {
#             "startTime": "2020-10-27T04:15:00.179Z",
#             "description": "Pending",
#             "endTime": "2020-10-27T04:15:00.180Z"
#           },
#           {
#             "startTime": "2020-10-27T04:15:01.269Z",
#             "description": "WaitingForValueStore",
#             "endTime": "2020-10-27T04:15:01.269Z"
#           },
#           {
#             "startTime": "2020-10-27T04:16:02.808Z",
#             "description": "UpdatingJobStore",
#             "endTime": "2020-10-27T04:16:03.097Z"
#           },
#           {
#             "startTime": "2020-10-27T04:15:00.180Z",
#             "description": "RequestingExecutionToken",
#             "endTime": "2020-10-27T04:15:01.269Z"
#           },
#           {
#             "startTime": "2020-10-27T04:15:02.021Z",
#             "description": "RunningJob",
#             "endTime": "2020-10-27T04:16:02.808Z"
#           },
#           {
#             "startTime": "2020-10-27T04:15:01.269Z",
#             "description": "PreparingJob",
#             "endTime": "2020-10-27T04:15:02.021Z"
#           }
#         ],
#         "start": "2020-10-27T04:15:00.179Z"
#       }
#     ],
#     "CiteSeq.Preprocess": [
#       {
#         "executionStatus": "Done",
#         "subWorkflowMetadata": {
#           "workflowName": "Preprocess",
#           "rootWorkflowId": "9c72e274-712a-4137-811c-4f1d6cc2eeb1",
#           "calls": {
#             "Preprocess.WhitelistFromSeqcDenseMatrix": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-WhitelistFromSeqcDenseMatrix/WhitelistFromSeqcDenseMatrix-stdout.log",
#                 "backendStatus": "Succeeded",
#                 "compressedDockerSize": 826994110,
#                 "commandLine": "set -euo pipefail\n\npython - << EOF\nimport pandas as pd\nfrom seqc.sequence.encodings import DNA3Bit\n\ndf = pd.read_csv(\n    \"/cromwell_root/dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_2/seqc-results/2091_CS1429a_T_1_CD45pos_citeseq_2_IGO_11242_14_dense.csv\",\n    index_col=0\n)\n\ndna3bit = DNA3Bit()\n\n# generate CB whitelist based on SEQC results\ncb_whitelist = df.index.map(lambda x: dna3bit.decode(x).decode()).sort_values().to_frame()\n\ncb_whitelist.to_csv(\n    \"cb-whitelist.txt\",\n    header=False, index=False\n)\nEOF",
#                 "shardIndex": -1,
#                 "outputs": {
#                   "out": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-WhitelistFromSeqcDenseMatrix/cb-whitelist.txt"
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/highpriority-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "hisplan/cromwell-seqc:0.2.5",
#                   "maxRetries": "0",
#                   "cpu": "1",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "16 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": false,
#                   "effectiveCallCachingMode": "CallCachingOff"
#                 },
#                 "inputs": {
#                   "numCores": 1,
#                   "csvFile": "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_2/seqc-results/2091_CS1429a_T_1_CD45pos_citeseq_2_IGO_11242_14_dense.csv",
#                   "dockerImage": "hisplan/cromwell-seqc:0.2.5",
#                   "inputSize": 0.13264490384608507
#                 },
#                 "returnCode": 0,
#                 "jobId": "0a5f883d-5428-45f7-b9b0-31c6264c1ce5",
#                 "backend": "AWSBATCH",
#                 "end": "2020-10-27T03:34:13.086Z",
#                 "dockerImageUsed": "hisplan/cromwell-seqc@sha256:97b72c9be5bf308db59ddb1073480aee597c559a5e7c48426174876def54da36",
#                 "stderr": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-WhitelistFromSeqcDenseMatrix/WhitelistFromSeqcDenseMatrix-stderr.log",
#                 "callRoot": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-WhitelistFromSeqcDenseMatrix",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2020-10-27T03:27:32.999Z",
#                     "description": "Pending",
#                     "endTime": "2020-10-27T03:27:33.000Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:27:35.269Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2020-10-27T03:27:35.269Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:27:33.000Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2020-10-27T03:27:35.269Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:34:12.911Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2020-10-27T03:34:13.086Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:27:35.269Z",
#                     "description": "PreparingJob",
#                     "endTime": "2020-10-27T03:27:35.552Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:27:35.552Z",
#                     "description": "RunningJob",
#                     "endTime": "2020-10-27T03:34:12.911Z"
#                   }
#                 ],
#                 "start": "2020-10-27T03:27:32.999Z"
#               }
#             ],
#             "Preprocess.TrimR1": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-TrimR1/TrimR1-stdout.log",
#                 "backendStatus": "Succeeded",
#                 "compressedDockerSize": 210532600,
#                 "commandLine": "set -euo pipefail\n\ncutadapt \\\n    --minimum-length 28 \\\n    --length 28 \\\n    --too-short-output too-short.R1.fastq.gz \\\n    --too-long-output too-long.R1.fastq.gz \\\n    -o R1.fastq.gz \\\n    /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-MergeFastqR1/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R1.fastq.gz",
#                 "shardIndex": -1,
#                 "outputs": {
#                   "outFile": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-TrimR1/R1.fastq.gz",
#                   "outTooShortTooLongFiles": [
#                     "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-TrimR1/glob-c763acd1bbc2c02eb59e93c44eda4fa9/too-short.R1.fastq.gz"
#                   ]
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/highpriority-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "hisplan/cromwell-cutadapt:2.5",
#                   "maxRetries": "0",
#                   "cpu": "4",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "16 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": false,
#                   "effectiveCallCachingMode": "CallCachingOff"
#                 },
#                 "inputs": {
#                   "outFileName": "R1.fastq.gz",
#                   "dockerImage": "hisplan/cromwell-cutadapt:2.5",
#                   "length": 28,
#                   "fastq": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-MergeFastqR1/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R1.fastq.gz",
#                   "numCores": 4
#                 },
#                 "returnCode": 0,
#                 "jobId": "fb5998ba-a99f-40f0-bc9c-ec9de7d5395d",
#                 "backend": "AWSBATCH",
#                 "end": "2020-10-27T03:43:05.087Z",
#                 "dockerImageUsed": "hisplan/cromwell-cutadapt@sha256:483a1e6f3d77c8e6ac363cd103d26b8dd3d99f57554adc90463f08969b454b38",
#                 "stderr": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-TrimR1/TrimR1-stderr.log",
#                 "callRoot": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-TrimR1",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2020-10-27T03:43:04.436Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2020-10-27T03:43:05.087Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:38:03.290Z",
#                     "description": "Pending",
#                     "endTime": "2020-10-27T03:38:03.290Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:38:05.898Z",
#                     "description": "RunningJob",
#                     "endTime": "2020-10-27T03:43:04.436Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:38:03.290Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2020-10-27T03:38:05.269Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:38:05.269Z",
#                     "description": "PreparingJob",
#                     "endTime": "2020-10-27T03:38:05.898Z"
#                   },
#                   {
#                     "description": "WaitingForValueStore",
#                     "endTime": "2020-10-27T03:38:05.269Z",
#                     "startTime": "2020-10-27T03:38:05.269Z"
#                   }
#                 ],
#                 "start": "2020-10-27T03:38:03.290Z"
#               }
#             ],
#             "Preprocess.FastQCR2": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-FastQCR2/FastQCR2-stdout.log",
#                 "backendStatus": "Succeeded",
#                 "compressedDockerSize": 138864024,
#                 "commandLine": "set -euo pipefail\n\nfastqc -o . /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-MergeFastqR2/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R2.fastq.gz",
#                 "shardIndex": -1,
#                 "outputs": {
#                   "outHtml": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-FastQCR2/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R2_fastqc.html",
#                   "outZip": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-FastQCR2/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R2_fastqc.zip"
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/highpriority-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "hisplan/cromwell-fastqc:0.11.8",
#                   "maxRetries": "0",
#                   "cpu": "4",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "16 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": false,
#                   "effectiveCallCachingMode": "CallCachingOff"
#                 },
#                 "inputs": {
#                   "numCores": 4,
#                   "dockerImage": "hisplan/cromwell-fastqc:0.11.8",
#                   "fastqFile": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-MergeFastqR2/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R2.fastq.gz",
#                   "inputSize": 1.514231831766665
#                 },
#                 "returnCode": 0,
#                 "jobId": "77cb60ad-f079-4b9c-ac3a-78a67f0fe573",
#                 "backend": "AWSBATCH",
#                 "end": "2020-10-27T03:48:59.140Z",
#                 "dockerImageUsed": "hisplan/cromwell-fastqc@sha256:1b92481e73c96240701f1ecb7b02e8fde9dfbe4ba344a2756d37a1aa696cabb6",
#                 "stderr": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-FastQCR2/FastQCR2-stderr.log",
#                 "callRoot": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-FastQCR2",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2020-10-27T03:44:21.269Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2020-10-27T03:44:21.269Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:44:21.313Z",
#                     "description": "RunningJob",
#                     "endTime": "2020-10-27T03:48:58.580Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:48:58.580Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2020-10-27T03:48:59.140Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:44:20.660Z",
#                     "description": "Pending",
#                     "endTime": "2020-10-27T03:44:20.660Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:44:20.660Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2020-10-27T03:44:21.269Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:44:21.269Z",
#                     "description": "PreparingJob",
#                     "endTime": "2020-10-27T03:44:21.313Z"
#                   }
#                 ],
#                 "start": "2020-10-27T03:44:20.660Z"
#               }
#             ],
#             "Preprocess.CiteSeqCount": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/CiteSeqCount-stdout.log",
#                 "backendStatus": "Succeeded",
#                 "compressedDockerSize": 392564039,
#                 "commandLine": "set -euo pipefail\n\n# preserve one core for the main process just in case\nlet n_threads=4-1\n\nCITE-seq-Count \\\n    -R1 /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-TrimR1/R1.fastq.gz \\\n    -R2 /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-TrimR2/R2.fastq.gz \\\n    --tags /cromwell_root/dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/Hashtag_results/tag-list.csv \\\n    -cbf 1 -cbl 16 \\\n    -umif 17 -umil 28 \\\n    --bc_collapsing_dist 1 \\\n    --umi_collapsing_dist 1 \\\n    --max-error 2 \\\n    --start-trim 0  \\\n    --expected_cells 0 \\\n    --whitelist /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-WhitelistFromSeqcDenseMatrix/cb-whitelist.txt \\\n    --output results \\\n    --unmapped-tags unmapped.csv \\\n    --threads ${n_threads}",
#                 "shardIndex": -1,
#                 "outputs": {
#                   "outUncorrected": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/results/uncorrected_cells/dense_umis.tsv",
#                   "outReadCount": [
#                     "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz",
#                     "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz",
#                     "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz"
#                   ],
#                   "outUnmapped": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/results/unmapped.csv",
#                   "outUmiCount": [
#                     "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#                     "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#                     "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#                   ],
#                   "outReport": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/results/run_report.yaml"
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/highpriority-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "hisplan/cromwell-cite-seq-count:1.4.2-develop",
#                   "maxRetries": "0",
#                   "cpu": "4",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "64 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": false,
#                   "effectiveCallCachingMode": "CallCachingOff"
#                 },
#                 "inputs": {
#                   "numExpectedCells": 0,
#                   "slidingWindowSearch": false,
#                   "umiEndPos": 28,
#                   "tagList": "s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/Hashtag_results/tag-list.csv",
#                   "cbCollapsingDistance": 1,
#                   "umiStartPos": 17,
#                   "fastqR2": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-TrimR2/R2.fastq.gz",
#                   "dockerImage": "hisplan/cromwell-cite-seq-count:1.4.2-develop",
#                   "maxTagError": 2,
#                   "fastqR1": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-TrimR1/R1.fastq.gz",
#                   "umiCollapsingDistance": 1,
#                   "resourceSpec": {
#                     "memory": 64,
#                     "cpu": 4
#                   },
#                   "cbEndPos": 16,
#                   "cbWhiteList": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-WhitelistFromSeqcDenseMatrix/cb-whitelist.txt",
#                   "inputSize": 1.0062666703015566,
#                   "cbStartPos": 1,
#                   "trimPos": 0
#                 },
#                 "returnCode": 0,
#                 "jobId": "9d50683d-fae9-4456-8e07-84dd7533e5cd",
#                 "backend": "AWSBATCH",
#                 "end": "2020-10-27T04:14:57.092Z",
#                 "dockerImageUsed": "hisplan/cromwell-cite-seq-count@sha256:b7e040ec487bf76ef704bbc93ddfc2e2054af873934a25f2d9afb31a18dde07d",
#                 "stderr": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/CiteSeqCount-stderr.log",
#                 "callRoot": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2020-10-27T03:49:18.390Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2020-10-27T03:49:19.269Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:49:19.874Z",
#                     "description": "RunningJob",
#                     "endTime": "2020-10-27T04:14:56.690Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:49:18.390Z",
#                     "description": "Pending",
#                     "endTime": "2020-10-27T03:49:18.390Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T04:14:56.690Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2020-10-27T04:14:57.092Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:49:19.269Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2020-10-27T03:49:19.270Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:49:19.270Z",
#                     "description": "PreparingJob",
#                     "endTime": "2020-10-27T03:49:19.874Z"
#                   }
#                 ],
#                 "start": "2020-10-27T03:49:18.389Z"
#               }
#             ],
#             "Preprocess.MergeFastqR1": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-MergeFastqR1/MergeFastqR1-stdout.log",
#                 "backendStatus": "Succeeded",
#                 "compressedDockerSize": 26702626,
#                 "commandLine": "set -euo pipefail\n\nfilenames=\"/cromwell_root/dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_2_CITE_IGO_11244_16_S2_R1_001.fastq.gz\"\n\necho \"${filenames}\"\n\npath_out=\"2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R1.fastq\"\n\necho \"${path_out}\"\n\n# gunzip and concatenate\nfor filename in $filenames\ndo\n    echo \"$filename > ${path_out}\"\n    gunzip -c ${filename} >> ${path_out}\ndone\n\n# gzip\ngzip ${path_out}",
#                 "shardIndex": -1,
#                 "outputs": {
#                   "out": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-MergeFastqR1/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R1.fastq.gz"
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/highpriority-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "ubuntu:18.04",
#                   "maxRetries": "0",
#                   "cpu": "2",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "8 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": false,
#                   "effectiveCallCachingMode": "CallCachingOff"
#                 },
#                 "inputs": {
#                   "sampleName": "2091_CS1429a_T_1_CD45pos_citeseq_2_CITE",
#                   "readName": "R1",
#                   "uriFastq": [
#                     "s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_2_CITE_IGO_11244_16_S2_R1_001.fastq.gz"
#                   ],
#                   "dockerImage": "ubuntu:18.04",
#                   "numCores": 2
#                 },
#                 "returnCode": 0,
#                 "jobId": "2dd61d7b-b847-41ad-ae1d-7878c25ca676",
#                 "backend": "AWSBATCH",
#                 "end": "2020-10-27T03:38:02.095Z",
#                 "dockerImageUsed": "ubuntu@sha256:45c6f8f1b2fe15adaa72305616d69a6cd641169bc8b16886756919e7c01fa48b",
#                 "stderr": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-MergeFastqR1/MergeFastqR1-stderr.log",
#                 "callRoot": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-MergeFastqR1",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2020-10-27T03:27:33.270Z",
#                     "description": "PreparingJob",
#                     "endTime": "2020-10-27T03:27:33.275Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:27:33.275Z",
#                     "description": "RunningJob",
#                     "endTime": "2020-10-27T03:38:01.112Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:27:33.269Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2020-10-27T03:27:33.270Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:27:30.962Z",
#                     "description": "Pending",
#                     "endTime": "2020-10-27T03:27:30.962Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:38:01.112Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2020-10-27T03:38:02.095Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:27:30.962Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2020-10-27T03:27:33.269Z"
#                   }
#                 ],
#                 "start": "2020-10-27T03:27:30.961Z"
#               }
#             ],
#             "Preprocess.TrimR2": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-TrimR2/TrimR2-stdout.log",
#                 "backendStatus": "Succeeded",
#                 "compressedDockerSize": 210532600,
#                 "commandLine": "set -euo pipefail\n\ncutadapt \\\n    --minimum-length 15 \\\n    --length 15 \\\n    --too-short-output too-short.R2.fastq.gz \\\n    --too-long-output too-long.R2.fastq.gz \\\n    -o R2.fastq.gz \\\n    /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-MergeFastqR2/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R2.fastq.gz",
#                 "shardIndex": -1,
#                 "outputs": {
#                   "outFile": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-TrimR2/R2.fastq.gz",
#                   "outTooShortTooLongFiles": [
#                     "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-TrimR2/glob-0ee15da47465f38e299b3bd7f7bbe3be/too-short.R2.fastq.gz"
#                   ]
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/highpriority-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "hisplan/cromwell-cutadapt:2.5",
#                   "maxRetries": "0",
#                   "cpu": "4",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "16 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": false,
#                   "effectiveCallCachingMode": "CallCachingOff"
#                 },
#                 "inputs": {
#                   "outFileName": "R2.fastq.gz",
#                   "dockerImage": "hisplan/cromwell-cutadapt:2.5",
#                   "length": 15,
#                   "fastq": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-MergeFastqR2/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R2.fastq.gz",
#                   "numCores": 4
#                 },
#                 "returnCode": 0,
#                 "jobId": "23ee1e33-2aad-40da-b1c9-dfa75af54b5f",
#                 "backend": "AWSBATCH",
#                 "end": "2020-10-27T03:49:17.096Z",
#                 "dockerImageUsed": "hisplan/cromwell-cutadapt@sha256:483a1e6f3d77c8e6ac363cd103d26b8dd3d99f57554adc90463f08969b454b38",
#                 "stderr": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-TrimR2/TrimR2-stderr.log",
#                 "callRoot": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-TrimR2",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2020-10-27T03:49:16.700Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2020-10-27T03:49:17.096Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:44:20.660Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2020-10-27T03:44:23.270Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:44:23.275Z",
#                     "description": "RunningJob",
#                     "endTime": "2020-10-27T03:49:16.700Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:44:23.270Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2020-10-27T03:44:23.270Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:44:20.660Z",
#                     "description": "Pending",
#                     "endTime": "2020-10-27T03:44:20.660Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:44:23.270Z",
#                     "description": "PreparingJob",
#                     "endTime": "2020-10-27T03:44:23.275Z"
#                   }
#                 ],
#                 "start": "2020-10-27T03:44:20.660Z"
#               }
#             ],
#             "Preprocess.FastQCR1": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-FastQCR1/FastQCR1-stdout.log",
#                 "backendStatus": "Succeeded",
#                 "compressedDockerSize": 138864024,
#                 "commandLine": "set -euo pipefail\n\nfastqc -o . /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-MergeFastqR1/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R1.fastq.gz",
#                 "shardIndex": -1,
#                 "outputs": {
#                   "outHtml": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-FastQCR1/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R1_fastqc.html",
#                   "outZip": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-FastQCR1/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R1_fastqc.zip"
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/highpriority-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "hisplan/cromwell-fastqc:0.11.8",
#                   "maxRetries": "0",
#                   "cpu": "4",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "16 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": false,
#                   "effectiveCallCachingMode": "CallCachingOff"
#                 },
#                 "inputs": {
#                   "numCores": 4,
#                   "dockerImage": "hisplan/cromwell-fastqc:0.11.8",
#                   "fastqFile": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-MergeFastqR1/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R1.fastq.gz",
#                   "inputSize": 0.6679004793986678
#                 },
#                 "returnCode": 0,
#                 "jobId": "8e4e34ea-a9a4-49a0-b7a5-8d4e5b80034f",
#                 "backend": "AWSBATCH",
#                 "end": "2020-10-27T03:45:53.096Z",
#                 "dockerImageUsed": "hisplan/cromwell-fastqc@sha256:1b92481e73c96240701f1ecb7b02e8fde9dfbe4ba344a2756d37a1aa696cabb6",
#                 "stderr": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-FastQCR1/FastQCR1-stderr.log",
# ...
#                     "s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_2_CITE_IGO_11244_16_S2_R2_001.fastq.gz"
#                   ],
#                   "dockerImage": "ubuntu:18.04",
#                   "numCores": 2
#                 },
#                 "returnCode": 0,
#                 "jobId": "4b866120-e819-491b-9cfa-68e80739880f",
#                 "backend": "AWSBATCH",
#                 "end": "2020-10-27T03:44:19.096Z",
#                 "dockerImageUsed": "ubuntu@sha256:45c6f8f1b2fe15adaa72305616d69a6cd641169bc8b16886756919e7c01fa48b",
#                 "stderr": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-MergeFastqR2/MergeFastqR2-stderr.log",
#                 "callRoot": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-MergeFastqR2",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2020-10-27T03:27:31.848Z",
#                     "description": "RunningJob",
#                     "endTime": "2020-10-27T03:44:18.200Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:27:30.961Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2020-10-27T03:27:31.269Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:27:31.269Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2020-10-27T03:27:31.269Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:27:31.269Z",
#                     "description": "PreparingJob",
#                     "endTime": "2020-10-27T03:27:31.848Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:27:30.961Z",
#                     "description": "Pending",
#                     "endTime": "2020-10-27T03:27:30.961Z"
#                   },
#                   {
#                     "startTime": "2020-10-27T03:44:18.200Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2020-10-27T03:44:19.096Z"
#                   }
#                 ],
#                 "start": "2020-10-27T03:27:30.961Z"
#               }
#             ]
#           },
#           "outputs": {
#             "Preprocess.fastQCR2Html": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-FastQCR2/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R2_fastqc.html",
#             "Preprocess.fastQCR1Html": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-FastQCR1/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R1_fastqc.html",
#             "Preprocess.readCountMatrix": [
#               "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz",
#               "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz",
#               "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz"
#             ],
#             "Preprocess.countReport": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/results/run_report.yaml",
#             "Preprocess.umiCountMatrix": [
#               "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#               "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#               "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#             ]
#           },
#           "workflowRoot": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/",
#           "id": "5820c268-1c20-45a3-b6c6-e032cc764a1e",
#           "inputs": {
#             "lengthR2": 15,
#             "scRnaSeqPlatform": "10x_v3",
#             "denseCountMatrix": "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_2/seqc-results/2091_CS1429a_T_1_CD45pos_citeseq_2_IGO_11242_14_dense.csv",
#             "numExpectedCells": 0,
#             "slidingWindowSearch": false,
#             "cellBarcodeWhiteListMethod": "SeqcDenseCountsMatrixCsv",
#             "sampleName": "2091_CS1429a_T_1_CD45pos_citeseq_2_CITE",
#             "umiEndPos": 28,
#             "tagList": "s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/Hashtag_results/tag-list.csv",
#             "uriFastqR2": [
#               "s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_2_CITE_IGO_11244_16_S2_R2_001.fastq.gz"
#             ],
#             "cbCollapsingDistance": 1,
#             "umiStartPos": 17,
#             "maxTagError": 2,
#             "runSeuratDemux": false,
#             "umiCollapsingDistance": 1,
#             "resourceSpec": {
#               "memory": 64,
#               "cpu": 4
#             },
#             "cbEndPos": 16,
#             "cellBarcodeWhitelistUri": "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_2/seqc-results/2091_CS1429a_T_1_CD45pos_citeseq_2_IGO_11242_14_dense.csv",
#             "lengthR1": 28,
#             "uriFastqR1": [
#               "s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_2_CITE_IGO_11244_16_S2_R1_001.fastq.gz"
#             ],
#             "translate10XBarcodes": false,
#             "cbStartPos": 1,
#             "trimPos": 0
#           },
#           "status": "Succeeded",
#           "parentWorkflowId": "9c72e274-712a-4137-811c-4f1d6cc2eeb1",
#           "end": "2020-10-27T04:14:58.140Z",
#           "start": "2020-10-27T03:27:28.890Z"
#         },
#         "shardIndex": -1,
#         "outputs": {
#           "readCountMatrix": [
#             "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz",
#             "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz",
#             "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz"
#           ],
#           "countReport": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/results/run_report.yaml",
#           "fastQCR2Html": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-FastQCR2/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R2_fastqc.html",
#           "umiCountMatrix": [
#             "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#             "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#             "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#           ],
#           "fastQCR1Html": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-FastQCR1/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R1_fastqc.html"
#         },
#         "inputs": {
#           "lengthR2": 15,
#           "scRnaSeqPlatform": "10x_v3",
#           "denseCountMatrix": "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_2/seqc-results/2091_CS1429a_T_1_CD45pos_citeseq_2_IGO_11242_14_dense.csv",
#           "numExpectedCells": 0,
#           "slidingWindowSearch": false,
#           "cellBarcodeWhiteListMethod": "SeqcDenseCountsMatrixCsv",
#           "sampleName": "2091_CS1429a_T_1_CD45pos_citeseq_2_CITE",
#           "umiEndPos": 28,
#           "tagList": "s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/Hashtag_results/tag-list.csv",
#           "uriFastqR2": [
#             "s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_2_CITE_IGO_11244_16_S2_R2_001.fastq.gz"
#           ],
#           "cbCollapsingDistance": 1,
#           "umiStartPos": 17,
#           "maxTagError": 2,
#           "runSeuratDemux": false,
#           "umiCollapsingDistance": 1,
#           "resourceSpec": {
#             "memory": 64,
#             "cpu": 4
#           },
#           "cbEndPos": 16,
#           "cellBarcodeWhitelistUri": "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_2/seqc-results/2091_CS1429a_T_1_CD45pos_citeseq_2_IGO_11242_14_dense.csv",
#           "lengthR1": 28,
#           "uriFastqR1": [
#             "s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_2_CITE_IGO_11244_16_S2_R1_001.fastq.gz"
#           ],
#           "translate10XBarcodes": false,
#           "cbStartPos": 1,
#           "trimPos": 0
#         },
#         "end": "2020-10-27T04:14:58.140Z",
#         "attempt": 1,
#         "executionEvents": [
#           {
#             "startTime": "2020-10-27T03:27:28.901Z",
#             "description": "SubWorkflowRunningState",
#             "endTime": "2020-10-27T04:14:58.140Z"
#           },
#           {
#             "startTime": "2020-10-27T03:27:28.890Z",
#             "description": "WaitingForValueStore",
#             "endTime": "2020-10-27T03:27:28.890Z"
#           },
#           {
#             "startTime": "2020-10-27T03:27:28.890Z",
#             "description": "SubWorkflowPreparingState",
#             "endTime": "2020-10-27T03:27:28.901Z"
#           },
#           {
#             "startTime": "2020-10-27T03:27:28.890Z",
#             "description": "SubWorkflowPendingState",
#             "endTime": "2020-10-27T03:27:28.890Z"
#           }
#         ],
#         "start": "2020-10-27T03:27:28.890Z"
#       }
#     ]
#   },
#   "outputs": {
#     "CiteSeq.umiCountMatrix": [
#       "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#       "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#       "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#     ],
#     "CiteSeq.fastQCR1Html": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-FastQCR1/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R1_fastqc.html",
#     "CiteSeq.readCountMatrix": [
#       "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz",
#       "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz",
#       "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz"
#     ],
#     "CiteSeq.adata": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-CiteSeqToAnnData/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE.CITE-seq.h5ad",
#     "CiteSeq.countReport": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/results/run_report.yaml",
#     "CiteSeq.fastQCR2Html": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-FastQCR2/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R2_fastqc.html"
#   },
#   "actualWorkflowLanguage": "WDL",
#   "id": "9c72e274-712a-4137-811c-4f1d6cc2eeb1",
#   "inputs": {
#     "lengthR2": 15,
#     "scRnaSeqPlatform": "10x_v3",
#     "denseCountMatrix": "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_2/seqc-results/2091_CS1429a_T_1_CD45pos_citeseq_2_IGO_11242_14_dense.csv",
#     "numExpectedCells": 0,
#     "slidingWindowSearch": false,
#     "cellBarcodeWhiteListMethod": "SeqcDenseCountsMatrixCsv",
#     "sampleName": "2091_CS1429a_T_1_CD45pos_citeseq_2_CITE",
#     "umiEndPos": 28,
#     "tagList": "s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/Hashtag_results/tag-list.csv",
#     "uriFastqR2": [
#       "s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_2_CITE_IGO_11244_16_S2_R2_001.fastq.gz"
#     ],
#     "cbCollapsingDistance": 1,
#     "umiStartPos": 17,
#     "maxTagError": 2,
#     "runSeuratDemux": false,
#     "umiCollapsingDistance": 1,
#     "resourceSpec": {
#       "memory": 64,
#       "cpu": 4
#     },
#     "cbEndPos": 16,
#     "cellBarcodeWhitelistUri": "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_2/seqc-results/2091_CS1429a_T_1_CD45pos_citeseq_2_IGO_11242_14_dense.csv",
#     "lengthR1": 28,
#     "uriFastqR1": [
#       "s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_2_CITE_IGO_11244_16_S2_R1_001.fastq.gz"
#     ],
#     "translate10XBarcodes": false,
#     "cbStartPos": 1,
#     "trimPos": 0
#   },
#   "labels": {
#     "project": "Project 230",
#     "cromwell-workflow-id": "cromwell-9c72e274-712a-4137-811c-4f1d6cc2eeb1",
#     "transfer": "done",
#     "comment": "CITE-seq Pipeline",
#     "sample": "2091_CS1429a_T_1_CD45pos_citeseq_2_CITE",
#     "pipelineType": "CITE-seq",
#     "owner": "chunj",
#     "destination": "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_2/CITE-seq-results/"
#   },
#   "submission": "2020-10-27T03:27:11.414Z",
#   "status": "Succeeded",
#   "end": "2020-10-27T04:16:04.433Z",
#   "start": "2020-10-27T03:27:26.636Z"
# }

# %% [markdown]
# ## Get Sample Name

# %%
sample_name = metadata["labels"]["sample"]
sample_name
# Out:
# '2091_CS1429a_T_1_CD45pos_citeseq_2_CITE'

# %% [markdown]
# ## Get Counts

# %%
def download(sample_name, workflow_id, subfolder, items):
    
    if skip_download:
        return
    
    if not isinstance(items, list):
        items = [items]
        
    path_output = f"{path_base_data}/{sample_name}/{workflow_id}/{subfolder}"
    
    os.makedirs(path_output, exist_ok=True)
        
    for item in items:
        cmd_download = f"aws s3 cp {item} {path_output}"
        print(cmd_download)
        os.system(cmd_download)

# %%
meta_cite_seq_count = metadata["calls"]["CiteSeq.Preprocess"][0]["subWorkflowMetadata"]["calls"]["Preprocess.CiteSeqCount"][0]

# %%
print(json.dumps(meta_cite_seq_count, indent=2))
# Out:
# {
#   "executionStatus": "Done",
#   "stdout": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/CiteSeqCount-stdout.log",
#   "backendStatus": "Succeeded",
#   "compressedDockerSize": 392564039,
#   "commandLine": "set -euo pipefail\n\n# preserve one core for the main process just in case\nlet n_threads=4-1\n\nCITE-seq-Count \\\n    -R1 /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-TrimR1/R1.fastq.gz \\\n    -R2 /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-TrimR2/R2.fastq.gz \\\n    --tags /cromwell_root/dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/Hashtag_results/tag-list.csv \\\n    -cbf 1 -cbl 16 \\\n    -umif 17 -umil 28 \\\n    --bc_collapsing_dist 1 \\\n    --umi_collapsing_dist 1 \\\n    --max-error 2 \\\n    --start-trim 0  \\\n    --expected_cells 0 \\\n    --whitelist /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-WhitelistFromSeqcDenseMatrix/cb-whitelist.txt \\\n    --output results \\\n    --unmapped-tags unmapped.csv \\\n    --threads ${n_threads}",
#   "shardIndex": -1,
#   "outputs": {
#     "outUncorrected": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/results/uncorrected_cells/dense_umis.tsv",
#     "outReadCount": [
#       "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz",
#       "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz",
#       "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz"
#     ],
#     "outUnmapped": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/results/unmapped.csv",
#     "outUmiCount": [
#       "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#       "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#       "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#     ],
#     "outReport": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/results/run_report.yaml"
#   },
#   "runtimeAttributes": {
#     "failOnStderr": "false",
#     "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/highpriority-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#     "disks": "local-disk /cromwell_root",
#     "continueOnReturnCode": "0",
#     "docker": "hisplan/cromwell-cite-seq-count:1.4.2-develop",
#     "maxRetries": "0",
#     "cpu": "4",
#     "cpuMin": "1",
#     "noAddress": "false",
#     "zones": "us-east-1a",
#     "memoryMin": "2 GB",
#     "memory": "64 GB"
#   },
#   "callCaching": {
#     "allowResultReuse": false,
#     "effectiveCallCachingMode": "CallCachingOff"
#   },
#   "inputs": {
#     "numExpectedCells": 0,
#     "slidingWindowSearch": false,
#     "umiEndPos": 28,
#     "tagList": "s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/Hashtag_results/tag-list.csv",
#     "cbCollapsingDistance": 1,
#     "umiStartPos": 17,
#     "fastqR2": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-TrimR2/R2.fastq.gz",
#     "dockerImage": "hisplan/cromwell-cite-seq-count:1.4.2-develop",
#     "maxTagError": 2,
#     "fastqR1": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-TrimR1/R1.fastq.gz",
#     "umiCollapsingDistance": 1,
#     "resourceSpec": {
#       "memory": 64,
#       "cpu": 4
#     },
#     "cbEndPos": 16,
#     "cbWhiteList": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-WhitelistFromSeqcDenseMatrix/cb-whitelist.txt",
#     "inputSize": 1.0062666703015566,
#     "cbStartPos": 1,
#     "trimPos": 0
#   },
#   "returnCode": 0,
#   "jobId": "9d50683d-fae9-4456-8e07-84dd7533e5cd",
#   "backend": "AWSBATCH",
#   "end": "2020-10-27T04:14:57.092Z",
#   "dockerImageUsed": "hisplan/cromwell-cite-seq-count@sha256:b7e040ec487bf76ef704bbc93ddfc2e2054af873934a25f2d9afb31a18dde07d",
#   "stderr": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/CiteSeqCount-stderr.log",
#   "callRoot": "s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount",
#   "attempt": 1,
#   "executionEvents": [
#     {
#       "startTime": "2020-10-27T03:49:18.390Z",
#       "description": "RequestingExecutionToken",
#       "endTime": "2020-10-27T03:49:19.269Z"
#     },
#     {
#       "startTime": "2020-10-27T03:49:19.874Z",
#       "description": "RunningJob",
#       "endTime": "2020-10-27T04:14:56.690Z"
#     },
#     {
#       "startTime": "2020-10-27T03:49:18.390Z",
#       "description": "Pending",
#       "endTime": "2020-10-27T03:49:18.390Z"
#     },
#     {
#       "startTime": "2020-10-27T04:14:56.690Z",
#       "description": "UpdatingJobStore",
#       "endTime": "2020-10-27T04:14:57.092Z"
#     },
#     {
#       "startTime": "2020-10-27T03:49:19.269Z",
#       "description": "WaitingForValueStore",
#       "endTime": "2020-10-27T03:49:19.270Z"
#     },
#     {
#       "startTime": "2020-10-27T03:49:19.270Z",
#       "description": "PreparingJob",
#       "endTime": "2020-10-27T03:49:19.874Z"
#     }
#   ],
#   "start": "2020-10-27T03:49:18.389Z"
# }

# %% [markdown]
# ### Download Read Count

# %%
download(
    sample_name, workflow_id,
    "reads",
    meta_cite_seq_count["outputs"]["outReadCount"]
)
# Out:
# aws s3 cp s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz ./citeseq/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE/9c72e274-712a-4137-811c-4f1d6cc2eeb1/reads
# aws s3 cp s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz ./citeseq/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE/9c72e274-712a-4137-811c-4f1d6cc2eeb1/reads
# aws s3 cp s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz ./citeseq/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE/9c72e274-712a-4137-811c-4f1d6cc2eeb1/reads

# %% [markdown]
# ### Download UMI Count

# %%
download(
    sample_name, workflow_id,
    "umis",
    meta_cite_seq_count["outputs"]["outUmiCount"]
)
# Out:
# aws s3 cp s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz ./citeseq/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE/9c72e274-712a-4137-811c-4f1d6cc2eeb1/umis
# aws s3 cp s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz ./citeseq/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE/9c72e274-712a-4137-811c-4f1d6cc2eeb1/umis
# aws s3 cp s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz ./citeseq/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE/9c72e274-712a-4137-811c-4f1d6cc2eeb1/umis

# %% [markdown]
# ## Download Report

# %%
download(
    sample_name, workflow_id,
    "report",
    meta_cite_seq_count["outputs"]["outReport"]
)
# Out:
# aws s3 cp s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/results/run_report.yaml ./citeseq/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE/9c72e274-712a-4137-811c-4f1d6cc2eeb1/report

# %% [markdown]
# ## Download h5ad

# %%
meta_adata = metadata["calls"]["CiteSeq.CiteSeqToAnnData"][0]

# %%
meta_adata
# Out:
# {'executionStatus': 'Done',
#  'stdout': 's3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-CiteSeqToAnnData/CiteSeqToAnnData-stdout.log',
#  'backendStatus': 'Succeeded',
#  'compressedDockerSize': 459883916,
#  'commandLine': 'set -euo pipefail\n\nmkdir umi-counts\ncp /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz ./umi-counts/\n\nmkdir read-counts\ncp /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz ./read-counts/\n\npython3 /opt/citeseq_to_adata.py \\\n    --sample 2091_CS1429a_T_1_CD45pos_citeseq_2_CITE \\\n    --tag-list /cromwell_root/dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/Hashtag_results/tag-list.csv \\\n    --umi-counts ./umi-counts/ \\\n    --read-counts ./read-counts/',
#  'shardIndex': -1,
#  'outputs': {'outAdata': 's3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-CiteSeqToAnnData/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE.CITE-seq.h5ad',
#   'outLog': 's3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-CiteSeqToAnnData/citeseq_to_adata.log'},
#  'runtimeAttributes': {'failOnStderr': 'false',
#   'queueArn': 'arn:aws:batch:us-east-1:583643567512:job-queue/highpriority-65029950-87aa-11e9-b6ad-0e16aabfe77c',
#   'disks': 'local-disk /cromwell_root',
#   'continueOnReturnCode': '0',
#   'docker': 'hisplan/cromwell-hto-adt-postprocess:0.3.1',
#   'maxRetries': '0',
#   'cpu': '1',
#   'cpuMin': '1',
#   'noAddress': 'false',
#   'zones': 'us-east-1a',
#   'memoryMin': '2 GB',
#   'memory': '8 GB'},
#  'callCaching': {'allowResultReuse': False,
#   'effectiveCallCachingMode': 'CallCachingOff'},
#  'inputs': {'umiCountFiles': ['s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz',
#    's3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz',
#    's3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz'],
#   'sampleName': '2091_CS1429a_T_1_CD45pos_citeseq_2_CITE',
#   'tagList': 's3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/Hashtag_results/tag-list.csv',
#   'dockerImage': 'hisplan/cromwell-hto-adt-postprocess:0.3.1',
#   'readCountFiles': ['s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz',
#    's3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz',
#    's3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-Preprocess/Preprocess/5820c268-1c20-45a3-b6c6-e032cc764a1e/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz'],
#   'inputSize': 0.0010110056027770042,
#   'numCores': 1},
#  'returnCode': 0,
#  'jobId': '10f53ea7-b46d-46c7-8fe9-0de24abad539',
#  'backend': 'AWSBATCH',
#  'end': '2020-10-27T04:16:03.097Z',
#  'dockerImageUsed': 'hisplan/cromwell-hto-adt-postprocess@sha256:e3e46490e248de656be665bd480a9fbe479fec0d24a8a36ae56e0c600574a63d',
#  'stderr': 's3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-CiteSeqToAnnData/CiteSeqToAnnData-stderr.log',
#  'callRoot': 's3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-CiteSeqToAnnData',
#  'attempt': 1,
#  'executionEvents': [{'startTime': '2020-10-27T04:15:00.179Z',
#    'description': 'Pending',
#    'endTime': '2020-10-27T04:15:00.180Z'},
#   {'startTime': '2020-10-27T04:15:01.269Z',
#    'description': 'WaitingForValueStore',
#    'endTime': '2020-10-27T04:15:01.269Z'},
#   {'startTime': '2020-10-27T04:16:02.808Z',
#    'description': 'UpdatingJobStore',
#    'endTime': '2020-10-27T04:16:03.097Z'},
#   {'startTime': '2020-10-27T04:15:00.180Z',
#    'description': 'RequestingExecutionToken',
#    'endTime': '2020-10-27T04:15:01.269Z'},
#   {'startTime': '2020-10-27T04:15:02.021Z',
#    'description': 'RunningJob',
#    'endTime': '2020-10-27T04:16:02.808Z'},
#   {'startTime': '2020-10-27T04:15:01.269Z',
#    'description': 'PreparingJob',
#    'endTime': '2020-10-27T04:15:02.021Z'}],
#  'start': '2020-10-27T04:15:00.179Z'}

# %%
download(
    sample_name=sample_name,
    workflow_id=workflow_id,
    subfolder="",
    items=meta_adata["outputs"]["outAdata"]
)
# Out:
# aws s3 cp s3://dp-lab-batch/cromwell-execution/CiteSeq/9c72e274-712a-4137-811c-4f1d6cc2eeb1/call-CiteSeqToAnnData/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE.CITE-seq.h5ad ./citeseq/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE/9c72e274-712a-4137-811c-4f1d6cc2eeb1/

# %% [markdown]
# ## Output Sample Name

# %%
# 1. DO NOT DELETE
# 2. MUST BE THE FINAL LINE
print(sample_name)
# Out:
# 2091_CS1429a_T_1_CD45pos_citeseq_2_CITE
