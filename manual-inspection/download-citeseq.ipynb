# %%
import os
import json

import requests
from requests.exceptions import HTTPError
from requests.auth import HTTPBasicAuth

# %% [markdown]
# ## Parameters

# %%
# this cell is tagged `parameters` and will be overridden by papermill

workflow_id = "eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6"

path_secrets_file = "/Users/chunj/keys/secrets-aws.json"
path_base_data = "./citeseq"
skip_download = False

# %% [markdown]
# ## APIs to Cromwell

# %%
def get_secrets(path_secrets_file):

    with open(path_secrets_file, "rt") as fin:
        data = json.loads(fin.read())

    return data

def prep_api_call(secrets):

    api_version = "v1"
    url = secrets["url"]
    url = f"{url}/api/workflows/{api_version}"

    auth = HTTPBasicAuth(secrets["username"], secrets["password"])

    return url, auth

def get_metadata(secrets, workflow_id):

    base_url, auth = prep_api_call(secrets)

    try:
        response = requests.patch(
            url=f"{base_url}/{workflow_id}/metadata?expandSubWorkflows=true",
            headers={
                "Content-Type": "application/json",
                "Accept": "application/json"
            },
            auth=auth
        )

        # if response.status_code == 200:
        data = response.json()

        return data

    except HTTPError as err:
        print(err)

# %% [markdown]
# ## Get Metadata

# %%
metadata = get_metadata(
    get_secrets(path_secrets_file),
    workflow_id
)

# %%
print(json.dumps(metadata, indent=2))
# Out:
# {
#   "workflowName": "CiteSeq",
#   "workflowProcessingEvents": [
#     {
#       "cromwellId": "cromid-8866130",
#       "description": "PickedUp",
#       "timestamp": "2020-10-16T21:09:46.834Z",
#       "cromwellVersion": "48"
#     },
#     {
#       "cromwellId": "cromid-8866130",
#       "description": "Finished",
#       "timestamp": "2020-10-16T21:55:52.479Z",
#       "cromwellVersion": "48"
#     }
#   ],
#   "metadataSource": "Unarchived",
#   "actualWorkflowLanguageVersion": "1.0",
#   "submittedFiles": {
#     "workflow": "version 1.0\n\nimport \"modules/Preprocess.wdl\" as Preprocess\n\nworkflow CiteSeq {\n\n    input {\n        Array[File] uriFastqR1\n        Array[File] uriFastqR2\n\n        Int lengthR1\n        Int lengthR2\n\n        String sampleName\n\n        File cellBarcodeWhitelistUri\n        String cellBarcodeWhiteListMethod\n\n        # set to false if TotalSeq-A is used\n        # set to true if TotalSeq-B or C is used\n        Boolean translate10XBarcodes\n\n        String scRnaSeqPlatform = \"10x_v3\"\n\n        File tagList\n\n        # cellular barcode start/end positions\n        Int cbStartPos\n        Int cbEndPos\n\n        # UMI start/end positions\n        Int umiStartPos\n        Int umiEndPos\n\n        # how many bases should we trim before starting to look for hashtag sequence\n        Int trimPos = 0\n\n        # activate sliding window alignement\n        Boolean slidingWindowSearch = false\n\n        # correction\n        Int cbCollapsingDistance\n        Int umiCollapsingDistance\n        Int maxTagError = 2\n\n        Int numExpectedCells\n\n        Int numCoresForCount\n\n        File denseCountMatrix\n\n        Boolean runSeuratDemux = false\n    }\n\n    call Preprocess.Preprocess {\n        input:\n            uriFastqR1 = uriFastqR1,\n            uriFastqR2 = uriFastqR2,\n            lengthR1 = lengthR1,\n            lengthR2 = lengthR2,\n            sampleName = sampleName,\n            cellBarcodeWhitelistUri = cellBarcodeWhitelistUri,\n            cellBarcodeWhiteListMethod = cellBarcodeWhiteListMethod,\n            translate10XBarcodes = translate10XBarcodes,\n            scRnaSeqPlatform = scRnaSeqPlatform,\n            tagList = tagList,\n            cbStartPos = cbStartPos,\n            cbEndPos = cbEndPos,\n            umiStartPos = umiStartPos,\n            umiEndPos = umiEndPos,\n            trimPos = trimPos,\n            slidingWindowSearch = slidingWindowSearch,\n            cbCollapsingDistance = cbCollapsingDistance,\n            umiCollapsingDistance = umiCollapsingDistance,\n            maxTagError = maxTagError,\n            numExpectedCells = numExpectedCells,\n            numCoresForCount = numCoresForCount,\n            denseCountMatrix = denseCountMatrix,\n            runSeuratDemux = runSeuratDemux\n    }\n\n    output {\n        File fastQCR1Html = Preprocess.fastQCR1Html\n        File fastQCR2Html = Preprocess.fastQCR2Html\n\n        File countReport = Preprocess.countReport\n        Array[File] umiCountMatrix = Preprocess.umiCountMatrix\n        Array[File] readCountMatrix = Preprocess.readCountMatrix\n    }\n}\n",
#     "root": "",
#     "options": "{\n  \"monitoring_script\": \"s3://dp-lab-batch/monitoring.sh\",\n  \"read_from_cache\": true,\n  \"workflow_failure_mode\": \"ContinueWhilePossible\",\n  \"write_to_cache\": true\n}",
#     "inputs": "{\"CiteSeq.cbCollapsingDistance\":1,\"CiteSeq.cbEndPos\":16,\"CiteSeq.cbStartPos\":1,\"CiteSeq.cellBarcodeWhiteListMethod\":\"SeqcDenseCountsMatrixCsv\",\"CiteSeq.cellBarcodeWhitelistUri\":\"s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_2/seqc-results/2091_CS1429a_T_1_CD45pos_citeseq_2_IGO_11242_14_dense.csv\",\"CiteSeq.denseCountMatrix\":\"s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_2/seqc-results/2091_CS1429a_T_1_CD45pos_citeseq_2_IGO_11242_14_dense.csv\",\"CiteSeq.lengthR1\":28,\"CiteSeq.lengthR2\":15,\"CiteSeq.numCoresForCount\":8,\"CiteSeq.numExpectedCells\":0,\"CiteSeq.sampleName\":\"2091_CS1429a_T_1_CD45pos_citeseq_2_CITE\",\"CiteSeq.scRnaSeqPlatform\":\"10x_v3\",\"CiteSeq.slidingWindowSearch\":false,\"CiteSeq.tagList\":\"s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/Hashtag_results/tag-list.csv\",\"CiteSeq.translate10XBarcodes\":false,\"CiteSeq.trimPos\":0,\"CiteSeq.umiCollapsingDistance\":1,\"CiteSeq.umiEndPos\":28,\"CiteSeq.umiStartPos\":17,\"CiteSeq.uriFastqR1\":[\"s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_2_CITE_IGO_11244_16_S2_R1_001.fastq.gz\"],\"CiteSeq.uriFastqR2\":[\"s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_2_CITE_IGO_11244_16_S2_R2_001.fastq.gz\"]}",
#     "workflowUrl": "",
#     "labels": "{\n    \"pipelineType\": \"CITE-seq\",\n    \"project\": \"Project 230\",\n    \"sample\": \"2091_CS1429a_T_1_CD45pos_citeseq_2_CITE\",\n    \"owner\": \"chunj\",\n    \"destination\": \"s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_2/Hashtag_results/CS1429a_T_1_CD45pos_citeseq_2_CITE/Hashtag_results/\",\n    \"transfer\": \"-\",\n    \"comment\": \"CITE-seq Pipeline\"\n}"
#   },
#   "calls": {
#     "CiteSeq.Preprocess": [
#       {
#         "executionStatus": "Done",
#         "subWorkflowMetadata": {
#           "workflowName": "Preprocess",
#           "rootWorkflowId": "eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6",
#           "calls": {
#             "Preprocess.WhitelistFromSeqcDenseMatrix": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-WhitelistFromSeqcDenseMatrix/WhitelistFromSeqcDenseMatrix-stdout.log",
#                 "backendStatus": "Succeeded",
#                 "compressedDockerSize": 826994110,
#                 "commandLine": "set -euo pipefail\n\npython - << EOF\nimport pandas as pd\nfrom seqc.sequence.encodings import DNA3Bit\n\ndf = pd.read_csv(\n    \"/cromwell_root/dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_2/seqc-results/2091_CS1429a_T_1_CD45pos_citeseq_2_IGO_11242_14_dense.csv\",\n    index_col=0\n)\n\ndna3bit = DNA3Bit()\n\n# generate CB whitelist based on SEQC results\ncb_whitelist = df.index.map(lambda x: dna3bit.decode(x).decode()).sort_values().to_frame()\n\ncb_whitelist.to_csv(\n    \"cb-whitelist.txt\",\n    header=False, index=False\n)\nEOF",
#                 "shardIndex": -1,
#                 "outputs": {
#                   "out": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-WhitelistFromSeqcDenseMatrix/cb-whitelist.txt"
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/highpriority-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "hisplan/cromwell-seqc:0.2.5",
#                   "maxRetries": "0",
#                   "cpu": "1",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "16 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": false,
#                   "effectiveCallCachingMode": "CallCachingOff"
#                 },
#                 "inputs": {
#                   "numCores": 1,
#                   "csvFile": "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_2/seqc-results/2091_CS1429a_T_1_CD45pos_citeseq_2_IGO_11242_14_dense.csv",
#                   "dockerImage": "hisplan/cromwell-seqc:0.2.5",
#                   "inputSize": 0.13264490384608507
#                 },
#                 "returnCode": 0,
#                 "jobId": "1fba51b6-12a5-4ceb-85f4-0dc9438e1e6e",
#                 "backend": "AWSBATCH",
#                 "end": "2020-10-16T21:15:04.993Z",
#                 "dockerImageUsed": "hisplan/cromwell-seqc@sha256:97b72c9be5bf308db59ddb1073480aee597c559a5e7c48426174876def54da36",
#                 "stderr": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-WhitelistFromSeqcDenseMatrix/WhitelistFromSeqcDenseMatrix-stderr.log",
#                 "callRoot": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-WhitelistFromSeqcDenseMatrix",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2020-10-16T21:15:04.614Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2020-10-16T21:15:04.993Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:10:00.215Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2020-10-16T21:10:00.216Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:10:00.216Z",
#                     "description": "PreparingJob",
#                     "endTime": "2020-10-16T21:10:00.781Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:09:53.536Z",
#                     "description": "Pending",
#                     "endTime": "2020-10-16T21:09:53.537Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:10:00.781Z",
#                     "description": "RunningJob",
#                     "endTime": "2020-10-16T21:15:04.614Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:09:53.537Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2020-10-16T21:10:00.215Z"
#                   }
#                 ],
#                 "start": "2020-10-16T21:09:53.536Z"
#               }
#             ],
#             "Preprocess.TrimR1": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-TrimR1/TrimR1-stdout.log",
#                 "backendStatus": "Succeeded",
#                 "compressedDockerSize": 210532600,
#                 "commandLine": "set -euo pipefail\n\ncutadapt \\\n    --minimum-length 28 \\\n    --length 28 \\\n    --too-short-output too-short.R1.fastq.gz \\\n    --too-long-output too-long.R1.fastq.gz \\\n    -o R1.fastq.gz \\\n    /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-MergeFastqR1/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R1.fastq.gz",
#                 "shardIndex": -1,
#                 "outputs": {
#                   "outTooShortTooLongFiles": [
#                     "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-TrimR1/glob-c763acd1bbc2c02eb59e93c44eda4fa9/too-short.R1.fastq.gz"
#                   ],
#                   "outFile": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-TrimR1/R1.fastq.gz"
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/highpriority-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "hisplan/cromwell-cutadapt:2.5",
#                   "maxRetries": "0",
#                   "cpu": "4",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "16 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": false,
#                   "effectiveCallCachingMode": "CallCachingOff"
#                 },
#                 "inputs": {
#                   "outFileName": "R1.fastq.gz",
#                   "dockerImage": "hisplan/cromwell-cutadapt:2.5",
#                   "length": 28,
#                   "fastq": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-MergeFastqR1/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R1.fastq.gz",
#                   "numCores": 4
#                 },
#                 "returnCode": 0,
#                 "jobId": "be70b524-7564-41a2-b689-c2c07bf78e1e",
#                 "backend": "AWSBATCH",
#                 "end": "2020-10-16T21:25:45.998Z",
#                 "dockerImageUsed": "hisplan/cromwell-cutadapt@sha256:483a1e6f3d77c8e6ac363cd103d26b8dd3d99f57554adc90463f08969b454b38",
#                 "stderr": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-TrimR1/TrimR1-stderr.log",
#                 "callRoot": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-TrimR1",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2020-10-16T21:19:48.719Z",
#                     "description": "RunningJob",
#                     "endTime": "2020-10-16T21:25:45.651Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:19:48.216Z",
#                     "description": "PreparingJob",
#                     "endTime": "2020-10-16T21:19:48.719Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:19:48.187Z",
#                     "description": "Pending",
#                     "endTime": "2020-10-16T21:19:48.187Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:25:45.651Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2020-10-16T21:25:45.998Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:19:48.215Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2020-10-16T21:19:48.216Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:19:48.187Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2020-10-16T21:19:48.215Z"
#                   }
#                 ],
#                 "start": "2020-10-16T21:19:48.187Z"
#               }
#             ],
#             "Preprocess.FastQCR2": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-FastQCR2/FastQCR2-stdout.log",
#                 "backendStatus": "Succeeded",
#                 "compressedDockerSize": 138864024,
#                 "commandLine": "set -euo pipefail\n\nfastqc -o . /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-MergeFastqR2/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R2.fastq.gz",
#                 "shardIndex": -1,
#                 "outputs": {
#                   "outHtml": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-FastQCR2/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R2_fastqc.html",
#                   "outZip": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-FastQCR2/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R2_fastqc.zip"
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/highpriority-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "hisplan/cromwell-fastqc:0.11.8",
#                   "maxRetries": "0",
#                   "cpu": "4",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "16 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": false,
#                   "effectiveCallCachingMode": "CallCachingOff"
#                 },
#                 "inputs": {
#                   "numCores": 4,
#                   "dockerImage": "hisplan/cromwell-fastqc:0.11.8",
#                   "fastqFile": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-MergeFastqR2/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R2.fastq.gz",
#                   "inputSize": 1.514231831766665
#                 },
#                 "returnCode": 0,
#                 "jobId": "433e9b77-123a-423f-ab9a-4923091c2958",
#                 "backend": "AWSBATCH",
#                 "end": "2020-10-16T21:32:59.993Z",
#                 "dockerImageUsed": "hisplan/cromwell-fastqc@sha256:1b92481e73c96240701f1ecb7b02e8fde9dfbe4ba344a2756d37a1aa696cabb6",
#                 "stderr": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-FastQCR2/FastQCR2-stderr.log",
#                 "callRoot": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-FastQCR2",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2020-10-16T21:28:20.215Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2020-10-16T21:28:20.216Z"
#                   },
#                   {
#                     "description": "Pending",
#                     "endTime": "2020-10-16T21:28:17.157Z",
#                     "startTime": "2020-10-16T21:28:17.157Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:28:17.157Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2020-10-16T21:28:20.215Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:28:20.216Z",
#                     "description": "PreparingJob",
#                     "endTime": "2020-10-16T21:28:20.272Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:32:59.133Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2020-10-16T21:32:59.993Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:28:20.272Z",
#                     "description": "RunningJob",
#                     "endTime": "2020-10-16T21:32:59.133Z"
#                   }
#                 ],
#                 "start": "2020-10-16T21:28:17.157Z"
#               }
#             ],
#             "Preprocess.CiteSeqCount": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/CiteSeqCount-stdout.log",
#                 "backendStatus": "Succeeded",
#                 "compressedDockerSize": 392564039,
#                 "commandLine": "set -euo pipefail\n\nCITE-seq-Count \\\n    -R1 /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-TrimR1/R1.fastq.gz \\\n    -R2 /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-TrimR2/R2.fastq.gz \\\n    --tags /cromwell_root/dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/Hashtag_results/tag-list.csv \\\n    -cbf 1 -cbl 16 \\\n    -umif 17 -umil 28 \\\n    --bc_collapsing_dist 1 \\\n    --umi_collapsing_dist 1 \\\n    --max-error 2 \\\n    --start-trim 0  \\\n    --expected_cells 0 \\\n    --whitelist /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-WhitelistFromSeqcDenseMatrix/cb-whitelist.txt \\\n    --output results \\\n    --dense \\\n    --unmapped-tags unmapped.csv \\\n    --threads 8",
#                 "shardIndex": -1,
#                 "outputs": {
#                   "outUncorrected": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/results/uncorrected_cells/dense_umis.tsv",
#                   "outReadCount": [
#                     "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz",
#                     "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz",
#                     "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz"
#                   ],
#                   "outUmiDenseCount": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/results/dense_umis.tsv",
#                   "outUnmapped": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/results/unmapped.csv",
#                   "outUmiCount": [
#                     "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#                     "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#                     "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#                   ],
#                   "outReport": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/results/run_report.yaml"
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/highpriority-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "hisplan/cromwell-cite-seq-count:1.4.2-develop",
#                   "maxRetries": "0",
#                   "cpu": "8",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "32 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": false,
#                   "effectiveCallCachingMode": "CallCachingOff"
#                 },
#                 "inputs": {
#                   "numExpectedCells": 0,
#                   "slidingWindowSearch": false,
#                   "umiEndPos": 28,
#                   "tagList": "s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/Hashtag_results/tag-list.csv",
#                   "cbCollapsingDistance": 1,
#                   "umiStartPos": 17,
#                   "fastqR2": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-TrimR2/R2.fastq.gz",
#                   "dockerImage": "hisplan/cromwell-cite-seq-count:1.4.2-develop",
#                   "maxTagError": 2,
#                   "fastqR1": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-TrimR1/R1.fastq.gz",
#                   "umiCollapsingDistance": 1,
#                   "cbEndPos": 16,
#                   "cbWhiteList": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-WhitelistFromSeqcDenseMatrix/cb-whitelist.txt",
#                   "inputSize": 1.0061920136213303,
#                   "cbStartPos": 1,
#                   "trimPos": 0,
#                   "numCores": 8
#                 },
#                 "returnCode": 0,
#                 "jobId": "9f4969ef-2097-46b1-8f5e-bb6df1c63230",
#                 "backend": "AWSBATCH",
#                 "end": "2020-10-16T21:55:49.994Z",
#                 "dockerImageUsed": "hisplan/cromwell-cite-seq-count@sha256:b7e040ec487bf76ef704bbc93ddfc2e2054af873934a25f2d9afb31a18dde07d",
#                 "stderr": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/CiteSeqCount-stderr.log",
#                 "callRoot": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2020-10-16T21:32:42.511Z",
#                     "description": "RunningJob",
#                     "endTime": "2020-10-16T21:55:49.837Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:55:49.837Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2020-10-16T21:55:49.994Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:32:40.307Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2020-10-16T21:32:42.205Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:32:42.206Z",
#                     "description": "PreparingJob",
#                     "endTime": "2020-10-16T21:32:42.511Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:32:40.306Z",
#                     "description": "Pending",
#                     "endTime": "2020-10-16T21:32:40.307Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:32:42.205Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2020-10-16T21:32:42.206Z"
#                   }
#                 ],
#                 "start": "2020-10-16T21:32:40.306Z"
#               }
#             ],
#             "Preprocess.MergeFastqR1": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-MergeFastqR1/MergeFastqR1-stdout.log",
#                 "backendStatus": "Succeeded",
#                 "compressedDockerSize": 26702626,
#                 "commandLine": "set -euo pipefail\n\nfilenames=\"/cromwell_root/dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_2_CITE_IGO_11244_16_S2_R1_001.fastq.gz\"\n\necho \"${filenames}\"\n\npath_out=\"2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R1.fastq\"\n\necho \"${path_out}\"\n\n# gunzip and concatenate\nfor filename in $filenames\ndo\n    echo \"$filename > ${path_out}\"\n    gunzip -c ${filename} >> ${path_out}\ndone\n\n# gzip\ngzip ${path_out}",
#                 "shardIndex": -1,
#                 "outputs": {
#                   "out": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-MergeFastqR1/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R1.fastq.gz"
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/highpriority-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "ubuntu:18.04",
#                   "maxRetries": "0",
#                   "cpu": "2",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "8 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": false,
#                   "effectiveCallCachingMode": "CallCachingOff"
#                 },
#                 "inputs": {
#                   "sampleName": "2091_CS1429a_T_1_CD45pos_citeseq_2_CITE",
#                   "readName": "R1",
#                   "uriFastq": [
#                     "s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_2_CITE_IGO_11244_16_S2_R1_001.fastq.gz"
#                   ],
#                   "dockerImage": "ubuntu:18.04",
#                   "numCores": 2
#                 },
#                 "returnCode": 0,
#                 "jobId": "9f396ac3-6597-40f7-981d-d6076b1c8d9c",
#                 "backend": "AWSBATCH",
#                 "end": "2020-10-16T21:19:47.001Z",
#                 "dockerImageUsed": "ubuntu@sha256:45c6f8f1b2fe15adaa72305616d69a6cd641169bc8b16886756919e7c01fa48b",
#                 "stderr": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-MergeFastqR1/MergeFastqR1-stderr.log",
#                 "callRoot": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-MergeFastqR1",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "endTime": "2020-10-16T21:09:51.497Z",
#                     "startTime": "2020-10-16T21:09:51.497Z",
#                     "description": "Pending"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:09:52.216Z",
#                     "description": "PreparingJob",
#                     "endTime": "2020-10-16T21:09:52.901Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:09:51.497Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2020-10-16T21:09:52.216Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:19:46.406Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2020-10-16T21:19:47.001Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:09:52.901Z",
#                     "description": "RunningJob",
#                     "endTime": "2020-10-16T21:19:46.406Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:09:52.216Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2020-10-16T21:09:52.216Z"
#                   }
#                 ],
#                 "start": "2020-10-16T21:09:51.496Z"
#               }
#             ],
#             "Preprocess.TrimR2": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-TrimR2/TrimR2-stdout.log",
#                 "backendStatus": "Succeeded",
#                 "compressedDockerSize": 210532600,
#                 "commandLine": "set -euo pipefail\n\ncutadapt \\\n    --minimum-length 15 \\\n    --length 15 \\\n    --too-short-output too-short.R2.fastq.gz \\\n    --too-long-output too-long.R2.fastq.gz \\\n    -o R2.fastq.gz \\\n    /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-MergeFastqR2/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R2.fastq.gz",
#                 "shardIndex": -1,
#                 "outputs": {
#                   "outTooShortTooLongFiles": [
#                     "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-TrimR2/glob-0ee15da47465f38e299b3bd7f7bbe3be/too-short.R2.fastq.gz"
#                   ],
#                   "outFile": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-TrimR2/R2.fastq.gz"
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/highpriority-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "hisplan/cromwell-cutadapt:2.5",
#                   "maxRetries": "0",
#                   "cpu": "4",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "16 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": false,
#                   "effectiveCallCachingMode": "CallCachingOff"
#                 },
#                 "inputs": {
#                   "outFileName": "R2.fastq.gz",
#                   "dockerImage": "hisplan/cromwell-cutadapt:2.5",
#                   "length": 15,
#                   "fastq": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-MergeFastqR2/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R2.fastq.gz",
#                   "numCores": 4
#                 },
#                 "returnCode": 0,
#                 "jobId": "a6f7c207-d680-4837-af51-638715e17867",
#                 "backend": "AWSBATCH",
#                 "end": "2020-10-16T21:32:38.999Z",
#                 "dockerImageUsed": "hisplan/cromwell-cutadapt@sha256:483a1e6f3d77c8e6ac363cd103d26b8dd3d99f57554adc90463f08969b454b38",
#                 "stderr": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-TrimR2/TrimR2-stderr.log",
#                 "callRoot": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-TrimR2",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2020-10-16T21:32:37.992Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2020-10-16T21:32:38.999Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:28:17.157Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2020-10-16T21:28:18.215Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:28:18.215Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2020-10-16T21:28:18.215Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:28:18.215Z",
#                     "description": "PreparingJob",
#                     "endTime": "2020-10-16T21:28:18.222Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:28:18.222Z",
#                     "description": "RunningJob",
#                     "endTime": "2020-10-16T21:32:37.992Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:28:17.156Z",
#                     "description": "Pending",
#                     "endTime": "2020-10-16T21:28:17.157Z"
#                   }
#                 ],
#                 "start": "2020-10-16T21:28:17.156Z"
#               }
#             ],
#             "Preprocess.FastQCR1": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-FastQCR1/FastQCR1-stdout.log",
#                 "backendStatus": "Succeeded",
#                 "compressedDockerSize": 138864024,
#                 "commandLine": "set -euo pipefail\n\nfastqc -o . /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-MergeFastqR1/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R1.fastq.gz",
#                 "shardIndex": -1,
#                 "outputs": {
#                   "outHtml": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-FastQCR1/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R1_fastqc.html",
#                   "outZip": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-FastQCR1/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R1_fastqc.zip"
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/highpriority-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "hisplan/cromwell-fastqc:0.11.8",
#                   "maxRetries": "0",
#                   "cpu": "4",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "16 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": false,
#                   "effectiveCallCachingMode": "CallCachingOff"
#                 },
#                 "inputs": {
#                   "numCores": 4,
#                   "dockerImage": "hisplan/cromwell-fastqc:0.11.8",
#                   "fastqFile": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-MergeFastqR1/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R1.fastq.gz",
#                   "inputSize": 0.6679004793986678
#                 },
#                 "returnCode": 0,
#                 "jobId": "2d02caaf-eec8-46b9-b635-72d4bdecd560",
#                 "backend": "AWSBATCH",
#                 "end": "2020-10-16T21:26:36.000Z",
#                 "dockerImageUsed": "hisplan/cromwell-fastqc@sha256:1b92481e73c96240701f1ecb7b02e8fde9dfbe4ba344a2756d37a1aa696cabb6",
#                 "stderr": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-FastQCR1/FastQCR1-stderr.log",
#                 "callRoot": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-FastQCR1",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2020-10-16T21:19:50.215Z",
#                     "description": "PreparingJob",
#                     "endTime": "2020-10-16T21:19:50.498Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:26:35.473Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2020-10-16T21:26:36.000Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:19:48.187Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2020-10-16T21:19:50.215Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:19:50.215Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2020-10-16T21:19:50.215Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:19:48.187Z",
#                     "description": "Pending",
#                     "endTime": "2020-10-16T21:19:48.187Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:19:50.498Z",
#                     "description": "RunningJob",
#                     "endTime": "2020-10-16T21:26:35.473Z"
#                   }
#                 ],
#                 "start": "2020-10-16T21:19:48.186Z"
#               }
#             ],
#             "Preprocess.MergeFastqR2": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-MergeFastqR2/MergeFastqR2-stdout.log",
#                 "backendStatus": "Succeeded",
#                 "compressedDockerSize": 26702626,
#                 "commandLine": "set -euo pipefail\n\nfilenames=\"/cromwell_root/dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_2_CITE_IGO_11244_16_S2_R2_001.fastq.gz\"\n\necho \"${filenames}\"\n\npath_out=\"2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R2.fastq\"\n\necho \"${path_out}\"\n\n# gunzip and concatenate\nfor filename in $filenames\ndo\n    echo \"$filename > ${path_out}\"\n    gunzip -c ${filename} >> ${path_out}\ndone\n\n# gzip\ngzip ${path_out}",
#                 "shardIndex": -1,
#                 "outputs": {
#                   "out": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-MergeFastqR2/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R2.fastq.gz"
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/highpriority-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "ubuntu:18.04",
#                   "maxRetries": "0",
#                   "cpu": "2",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "8 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": false,
#                   "effectiveCallCachingMode": "CallCachingOff"
#                 },
#                 "inputs": {
#                   "sampleName": "2091_CS1429a_T_1_CD45pos_citeseq_2_CITE",
#                   "readName": "R2",
#                   "uriFastq": [
#                     "s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_2_CITE_IGO_11244_16_S2_R2_001.fastq.gz"
#                   ],
#                   "dockerImage": "ubuntu:18.04",
#                   "numCores": 2
#                 },
#                 "returnCode": 0,
#                 "jobId": "5bcc6bb0-8645-45b8-8016-d52df6f79857",
#                 "backend": "AWSBATCH",
#                 "end": "2020-10-16T21:28:15.997Z",
#                 "dockerImageUsed": "ubuntu@sha256:45c6f8f1b2fe15adaa72305616d69a6cd641169bc8b16886756919e7c01fa48b",
#                 "stderr": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-MergeFastqR2/MergeFastqR2-stderr.log",
#                 "callRoot": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-MergeFastqR2",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2020-10-16T21:09:56.216Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2020-10-16T21:09:56.216Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:28:15.189Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2020-10-16T21:28:15.997Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:09:56.216Z",
#                     "description": "PreparingJob",
#                     "endTime": "2020-10-16T21:09:56.223Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:09:51.497Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2020-10-16T21:09:56.216Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:09:51.497Z",
#                     "description": "Pending",
#                     "endTime": "2020-10-16T21:09:51.497Z"
#                   },
#                   {
#                     "startTime": "2020-10-16T21:09:56.223Z",
#                     "description": "RunningJob",
#                     "endTime": "2020-10-16T21:28:15.189Z"
#                   }
#                 ],
#                 "start": "2020-10-16T21:09:51.497Z"
#               }
#             ]
#           },
#           "outputs": {
#             "Preprocess.fastQCR2Html": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-FastQCR2/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R2_fastqc.html",
#             "Preprocess.fastQCR1Html": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-FastQCR1/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R1_fastqc.html",
#             "Preprocess.readCountMatrix": [
#               "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz",
#               "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz",
#               "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz"
#             ],
#             "Preprocess.countReport": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/results/run_report.yaml",
#             "Preprocess.umiCountMatrix": [
#               "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#               "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#               "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#             ]
#           },
#           "workflowRoot": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/",
#           "id": "e96102a6-b8fc-4b51-990a-14ec9f61e854",
#           "inputs": {
#             "lengthR2": 15,
#             "scRnaSeqPlatform": "10x_v3",
#             "denseCountMatrix": "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_2/seqc-results/2091_CS1429a_T_1_CD45pos_citeseq_2_IGO_11242_14_dense.csv",
#             "numExpectedCells": 0,
#             "slidingWindowSearch": false,
#             "cellBarcodeWhiteListMethod": "SeqcDenseCountsMatrixCsv",
#             "sampleName": "2091_CS1429a_T_1_CD45pos_citeseq_2_CITE",
#             "umiEndPos": 28,
#             "tagList": "s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/Hashtag_results/tag-list.csv",
#             "uriFastqR2": [
#               "s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_2_CITE_IGO_11244_16_S2_R2_001.fastq.gz"
#             ],
#             "cbCollapsingDistance": 1,
#             "umiStartPos": 17,
#             "maxTagError": 2,
#             "runSeuratDemux": false,
#             "umiCollapsingDistance": 1,
#             "cbEndPos": 16,
#             "cellBarcodeWhitelistUri": "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_2/seqc-results/2091_CS1429a_T_1_CD45pos_citeseq_2_IGO_11242_14_dense.csv",
#             "lengthR1": 28,
#             "uriFastqR1": [
#               "s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_2_CITE_IGO_11244_16_S2_R1_001.fastq.gz"
#             ],
#             "translate10XBarcodes": false,
#             "cbStartPos": 1,
#             "trimPos": 0,
#             "numCoresForCount": 8
#           },
#           "status": "Succeeded",
#           "parentWorkflowId": "eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6",
#           "end": "2020-10-16T21:55:51.087Z",
#           "start": "2020-10-16T21:09:49.432Z"
#         },
#         "shardIndex": -1,
#         "outputs": {
#           "readCountMatrix": [
#             "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz",
#             "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz",
#             "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz"
#           ],
#           "countReport": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/results/run_report.yaml",
#           "fastQCR2Html": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-FastQCR2/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R2_fastqc.html",
#           "umiCountMatrix": [
#             "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#             "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#             "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#           ],
#           "fastQCR1Html": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-FastQCR1/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R1_fastqc.html"
#         },
#         "inputs": {
#           "lengthR2": 15,
#           "scRnaSeqPlatform": "10x_v3",
#           "denseCountMatrix": "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_2/seqc-results/2091_CS1429a_T_1_CD45pos_citeseq_2_IGO_11242_14_dense.csv",
#           "numExpectedCells": 0,
#           "slidingWindowSearch": false,
#           "cellBarcodeWhiteListMethod": "SeqcDenseCountsMatrixCsv",
#           "sampleName": "2091_CS1429a_T_1_CD45pos_citeseq_2_CITE",
#           "umiEndPos": 28,
#           "tagList": "s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/Hashtag_results/tag-list.csv",
#           "uriFastqR2": [
#             "s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_2_CITE_IGO_11244_16_S2_R2_001.fastq.gz"
#           ],
#           "cbCollapsingDistance": 1,
#           "umiStartPos": 17,
#           "maxTagError": 2,
#           "runSeuratDemux": false,
#           "umiCollapsingDistance": 1,
#           "cbEndPos": 16,
#           "cellBarcodeWhitelistUri": "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_2/seqc-results/2091_CS1429a_T_1_CD45pos_citeseq_2_IGO_11242_14_dense.csv",
#           "lengthR1": 28,
#           "uriFastqR1": [
#             "s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_2_CITE_IGO_11244_16_S2_R1_001.fastq.gz"
#           ],
#           "translate10XBarcodes": false,
#           "cbStartPos": 1,
#           "trimPos": 0,
#           "numCoresForCount": 8
#         },
#         "end": "2020-10-16T21:55:51.088Z",
#         "attempt": 1,
#         "executionEvents": [
#           {
#             "startTime": "2020-10-16T21:09:49.446Z",
#             "description": "SubWorkflowRunningState",
#             "endTime": "2020-10-16T21:55:51.087Z"
#           },
#           {
#             "startTime": "2020-10-16T21:09:49.422Z",
#             "description": "WaitingForValueStore",
#             "endTime": "2020-10-16T21:09:49.433Z"
#           },
#           {
#             "startTime": "2020-10-16T21:09:49.415Z",
#             "description": "SubWorkflowPendingState",
#             "endTime": "2020-10-16T21:09:49.422Z"
#           },
#           {
#             "startTime": "2020-10-16T21:09:49.433Z",
#             "description": "SubWorkflowPreparingState",
#             "endTime": "2020-10-16T21:09:49.446Z"
#           }
#         ],
#         "start": "2020-10-16T21:09:49.412Z"
#       }
#     ]
#   },
#   "outputs": {
#     "CiteSeq.umiCountMatrix": [
#       "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#       "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#       "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#     ],
#     "CiteSeq.fastQCR1Html": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-FastQCR1/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R1_fastqc.html",
#     "CiteSeq.readCountMatrix": [
#       "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz",
#       "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz",
#       "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz"
#     ],
#     "CiteSeq.countReport": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/results/run_report.yaml",
#     "CiteSeq.fastQCR2Html": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-FastQCR2/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE_R2_fastqc.html"
#   },
#   "actualWorkflowLanguage": "WDL",
#   "id": "eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6",
#   "inputs": {
#     "lengthR2": 15,
#     "scRnaSeqPlatform": "10x_v3",
#     "denseCountMatrix": "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_2/seqc-results/2091_CS1429a_T_1_CD45pos_citeseq_2_IGO_11242_14_dense.csv",
#     "numExpectedCells": 0,
#     "slidingWindowSearch": false,
#     "cellBarcodeWhiteListMethod": "SeqcDenseCountsMatrixCsv",
#     "sampleName": "2091_CS1429a_T_1_CD45pos_citeseq_2_CITE",
#     "umiEndPos": 28,
#     "tagList": "s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/Hashtag_results/tag-list.csv",
#     "uriFastqR2": [
#       "s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_2_CITE_IGO_11244_16_S2_R2_001.fastq.gz"
#     ],
#     "cbCollapsingDistance": 1,
#     "umiStartPos": 17,
#     "maxTagError": 2,
#     "runSeuratDemux": false,
#     "umiCollapsingDistance": 1,
#     "cbEndPos": 16,
#     "cellBarcodeWhitelistUri": "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_2/seqc-results/2091_CS1429a_T_1_CD45pos_citeseq_2_IGO_11242_14_dense.csv",
#     "lengthR1": 28,
#     "uriFastqR1": [
#       "s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/FASTQ/CS1429a_T_1_CD45pos_citeseq_2_CITE_IGO_11244_16_S2_R1_001.fastq.gz"
#     ],
#     "translate10XBarcodes": false,
#     "cbStartPos": 1,
#     "trimPos": 0,
#     "numCoresForCount": 8
#   },
#   "labels": {
#     "project": "Project 230",
#     "cromwell-workflow-id": "cromwell-eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6",
#     "transfer": "failed",
#     "comment": "CITE-seq Pipeline",
#     "sample": "2091_CS1429a_T_1_CD45pos_citeseq_2_CITE",
#     "pipelineType": "CITE-seq",
#     "owner": "chunj",
#     "destination": "s3://dp-lab-data/SCRI_Projects/HTAN_CITEseq/CS1429a_T_1_CD45pos_citeseq_2/CITE-seq_results/"
#   },
#   "submission": "2020-10-16T21:09:33.710Z",
#   "status": "Succeeded",
#   "end": "2020-10-16T21:55:52.479Z",
#   "start": "2020-10-16T21:09:46.835Z"
# }

# %% [markdown]
# ## Get Sample Name

# %%
sample_name = metadata["labels"]["sample"]
sample_name
# Out:
# '2091_CS1429a_T_1_CD45pos_citeseq_2_CITE'

# %% [markdown]
# ## Get Counts

# %%
def download(sample_name, workflow_id, subfolder, items):
    
    if skip_download:
        return
    
    if not isinstance(items, list):
        items = [items]
        
    path_output = f"{path_base_data}/{sample_name}/{workflow_id}/{subfolder}"
    
    os.makedirs(path_output, exist_ok=True)
        
    for item in items:
        cmd_download = f"aws s3 cp {item} {path_output}"
        print(cmd_download)
        os.system(cmd_download)

# %%
meta_cite_seq_count = metadata["calls"]["CiteSeq.Preprocess"][0]["subWorkflowMetadata"]["calls"]["Preprocess.CiteSeqCount"][0]

# %%
print(json.dumps(meta_cite_seq_count, indent=2))
# Out:
# {
#   "executionStatus": "Done",
#   "stdout": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/CiteSeqCount-stdout.log",
#   "backendStatus": "Succeeded",
#   "compressedDockerSize": 392564039,
#   "commandLine": "set -euo pipefail\n\nCITE-seq-Count \\\n    -R1 /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-TrimR1/R1.fastq.gz \\\n    -R2 /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-TrimR2/R2.fastq.gz \\\n    --tags /cromwell_root/dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/Hashtag_results/tag-list.csv \\\n    -cbf 1 -cbl 16 \\\n    -umif 17 -umil 28 \\\n    --bc_collapsing_dist 1 \\\n    --umi_collapsing_dist 1 \\\n    --max-error 2 \\\n    --start-trim 0  \\\n    --expected_cells 0 \\\n    --whitelist /cromwell_root/dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-WhitelistFromSeqcDenseMatrix/cb-whitelist.txt \\\n    --output results \\\n    --dense \\\n    --unmapped-tags unmapped.csv \\\n    --threads 8",
#   "shardIndex": -1,
#   "outputs": {
#     "outUncorrected": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/results/uncorrected_cells/dense_umis.tsv",
#     "outReadCount": [
#       "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz",
#       "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz",
#       "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz"
#     ],
#     "outUmiDenseCount": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/results/dense_umis.tsv",
#     "outUnmapped": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/results/unmapped.csv",
#     "outUmiCount": [
#       "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#       "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#       "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#     ],
#     "outReport": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/results/run_report.yaml"
#   },
#   "runtimeAttributes": {
#     "failOnStderr": "false",
#     "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/highpriority-65029950-87aa-11e9-b6ad-0e16aabfe77c",
#     "disks": "local-disk /cromwell_root",
#     "continueOnReturnCode": "0",
#     "docker": "hisplan/cromwell-cite-seq-count:1.4.2-develop",
#     "maxRetries": "0",
#     "cpu": "8",
#     "cpuMin": "1",
#     "noAddress": "false",
#     "zones": "us-east-1a",
#     "memoryMin": "2 GB",
#     "memory": "32 GB"
#   },
#   "callCaching": {
#     "allowResultReuse": false,
#     "effectiveCallCachingMode": "CallCachingOff"
#   },
#   "inputs": {
#     "numExpectedCells": 0,
#     "slidingWindowSearch": false,
#     "umiEndPos": 28,
#     "tagList": "s3://dp-lab-data/sc-seq/Project_11244/CS1429a_T_1_CD45pos_citeseq_2_CITE/Hashtag_results/tag-list.csv",
#     "cbCollapsingDistance": 1,
#     "umiStartPos": 17,
#     "fastqR2": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-TrimR2/R2.fastq.gz",
#     "dockerImage": "hisplan/cromwell-cite-seq-count:1.4.2-develop",
#     "maxTagError": 2,
#     "fastqR1": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-TrimR1/R1.fastq.gz",
#     "umiCollapsingDistance": 1,
#     "cbEndPos": 16,
#     "cbWhiteList": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-WhitelistFromSeqcDenseMatrix/cb-whitelist.txt",
#     "inputSize": 1.0061920136213303,
#     "cbStartPos": 1,
#     "trimPos": 0,
#     "numCores": 8
#   },
#   "returnCode": 0,
#   "jobId": "9f4969ef-2097-46b1-8f5e-bb6df1c63230",
#   "backend": "AWSBATCH",
#   "end": "2020-10-16T21:55:49.994Z",
#   "dockerImageUsed": "hisplan/cromwell-cite-seq-count@sha256:b7e040ec487bf76ef704bbc93ddfc2e2054af873934a25f2d9afb31a18dde07d",
#   "stderr": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/CiteSeqCount-stderr.log",
#   "callRoot": "s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount",
#   "attempt": 1,
#   "executionEvents": [
#     {
#       "startTime": "2020-10-16T21:32:42.511Z",
#       "description": "RunningJob",
#       "endTime": "2020-10-16T21:55:49.837Z"
#     },
#     {
#       "startTime": "2020-10-16T21:55:49.837Z",
#       "description": "UpdatingJobStore",
#       "endTime": "2020-10-16T21:55:49.994Z"
#     },
#     {
#       "startTime": "2020-10-16T21:32:40.307Z",
#       "description": "RequestingExecutionToken",
#       "endTime": "2020-10-16T21:32:42.205Z"
#     },
#     {
#       "startTime": "2020-10-16T21:32:42.206Z",
#       "description": "PreparingJob",
#       "endTime": "2020-10-16T21:32:42.511Z"
#     },
#     {
#       "startTime": "2020-10-16T21:32:40.306Z",
#       "description": "Pending",
#       "endTime": "2020-10-16T21:32:40.307Z"
#     },
#     {
#       "startTime": "2020-10-16T21:32:42.205Z",
#       "description": "WaitingForValueStore",
#       "endTime": "2020-10-16T21:32:42.206Z"
#     }
#   ],
#   "start": "2020-10-16T21:32:40.306Z"
# }

# %% [markdown]
# ### Download Read Count

# %%
download(
    sample_name, workflow_id,
    "reads",
    meta_cite_seq_count["outputs"]["outReadCount"]
)
# Out:
# aws s3 cp s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz ./citeseq/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/reads
# aws s3 cp s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz ./citeseq/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/reads
# aws s3 cp s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz ./citeseq/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/reads

# %% [markdown]
# ### Download UMI Count

# %%
download(
    sample_name, workflow_id,
    "umis",
    meta_cite_seq_count["outputs"]["outUmiCount"]
)
# Out:
# aws s3 cp s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz ./citeseq/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/umis
# aws s3 cp s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz ./citeseq/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/umis
# aws s3 cp s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz ./citeseq/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/umis

# %% [markdown]
# ## Download Report

# %%
download(
    sample_name, workflow_id,
    "report",
    meta_cite_seq_count["outputs"]["outReport"]
)
# Out:
# aws s3 cp s3://dp-lab-batch/cromwell-execution/CiteSeq/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/call-Preprocess/Preprocess/e96102a6-b8fc-4b51-990a-14ec9f61e854/call-CiteSeqCount/results/run_report.yaml ./citeseq/2091_CS1429a_T_1_CD45pos_citeseq_2_CITE/eb5f81d3-cb16-4436-80f0-c8c0a2ed04d6/report

# %% [markdown]
# ## Output Sample Name

# %%
# 1. DO NOT DELETE
# 2. MUST BE THE FINAL LINE
print(sample_name)
# Out:
# 2091_CS1429a_T_1_CD45pos_citeseq_2_CITE
