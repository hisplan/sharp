# %%
import pandas as pd
import numpy as np
import os
import yaml

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

# %% [markdown]
# ## Parameters

# %%
# this cell is tagged `parameters` and will be overridden by papermill
sample_name = "1904_C7_cond_1_HTO"
workflow_id = "08778704-c763-4145-a951-b8af53cc45cc"
path_data = os.path.join("./hashtag/", sample_name, workflow_id)

# %% [markdown]
# ## Run Report

# %%
# !cat $path_data/report/run_report.yaml
# Out:
# Date: 2020-07-17
# Running time: 1.0 hour, 25.0 minutes, 15.75 seconds
# CITE-seq-Count Version: 1.4.3
# Reads processed: 56902257
# Percentage mapped: 94
# Percentage unmapped: 6
# Uncorrected cells: 3
# Correction:
# 	Cell barcodes collapsing threshold: 1
# 	Cell barcodes corrected: 95210
# 	UMI collapsing threshold: 1
# 	UMIs corrected: 477024
# Run parameters:
# 	Read1_filename: /cromwell_root/dp-lab-batch/cromwell-execution/Sharp/08778704-c763-4145-a951-b8af53cc45cc/call-TrimR1/R1.fastq.gz
# 	Read2_filename: /cromwell_root/dp-lab-batch/cromwell-execution/Sharp/08778704-c763-4145-a951-b8af53cc45cc/call-TrimR2/R2.fastq.gz
# 	Cell barcode:
# 		First position: 1
# 		Last position: 16
# 	UMI barcode:
# 		First position: 17
# 		Last position: 28
# 	Expected cells: 0
# 	Tags max errors: 2
# 	Start trim: 0

# %%
with open(os.path.join(path_data, "report/run_report.yaml"), "rt") as fin:
    # report file contains tabs
    # run_report = yaml.load(fin, Loader=yaml.FullLoader)        
    run_report = fin.read().replace("\t", "  ")
    run_report = yaml.load(run_report, Loader=yaml.FullLoader)

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Read

# %%
# backward compatibility
# new version of HtoDemuxKMeans generates "classification.tsv.gz"
class_filename = "classification.tsv.gz"
if not os.path.isfile(os.path.join(path_data, class_filename)):
    class_filename = "final-" + class_filename

# %%
class_filename
# Out:
# 'final-classification.tsv.gz'

# %%
df_class = pd.read_csv(
    os.path.join(path_data, class_filename),
    sep="\t",
    compression="gzip",
    index_col=0
)

# %%
df_class
# Out:
#                   hashID
# 120703409084764    A0306
# 120703409154909    A0306
# 120703409343732    A0301
# 120703455028974  Doublet
# 120718456207715    A0306
# ...                  ...
# 241109193898332    A0306
# 241109220415709    A0306
# 241109239451037    A0306
# 241109239543707    A0306
# 241184489494381    A0306
#
# [2572 rows x 1 columns]

# %%
df_class.shape
# Out:
# (2572, 1)

# %% [markdown]
# ### Numeric to ACGT

# %%
from dna3bit import DNA3Bit

# %%
dna3bit = DNA3Bit()

# %%
new_index = df_class.index.map(lambda x: dna3bit.decode(x).decode())

# %%
df_class.index = new_index

# %%
df_class
# Out:
#                    hashID
# TTTATGCTCAAGAGTA    A0306
# TTTATGCTCACCGGTG    A0306
# TTTATGCTCGAACTCA    A0301
# TTTATGCCATCCTTGC  Doublet
# TTTAGTCAGACTAGAT    A0306
# ...                   ...
# CCCAACTTCCGTAGTA    A0306
# CCCAACTGTTCGATTG    A0306
# CCCAACTCAATACCTG    A0306
# CCCAACTCAACTTCTT    A0306
# CCCGGAATCAAGTGGG    A0306
#
# [2572 rows x 1 columns]

# %% [markdown]
# ### Results

# %%
df_stats = df_class.groupby(by="hashID").size()
df_stats
# Out:
# hashID
# A0301       745
# A0302        21
# A0303        25
# A0304        16
# A0305        40
# A0306      1660
# Doublet      65
# dtype: int64

# %%
df_stats.sum()
# Out:
# 2572

# %%
# sum excluding doublets
df_stats[ df_stats.index != "Doublet" ].sum()
# Out:
# 2507

# %% [markdown]
# ### Pie Chart

# %%
labels = [label.upper() if label != "Doublet" else "Doublet/Negative" for label in df_stats.index]
labels
# Out:
# ['A0301', 'A0302', 'A0303', 'A0304', 'A0305', 'A0306', 'Doublet/Negative']

# %% [markdown]
# #### Pie 1

# %%
fig = plt.figure(figsize=(6,6), facecolor="white")
ax = fig.add_subplot(111)

def func_autopct(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:,d})".format(pct, absolute)

wedges, _, autotexts = ax.pie(
    df_stats,
    labels=labels,
    autopct=lambda pct: func_autopct(pct, df_stats),    
    shadow=True, startangle=90
)

for autotext in autotexts:
    autotext.set_color('white')
    autotext.set_fontsize(10)
    autotext.set_fontweight('bold')

ax.axis('equal')
ax.legend(
    wedges,
    labels,
    title="Hashtag",
    loc="center left",
    bbox_to_anchor=(1.3, 0.0, 0.5, 1)
)

plt.show()

# %% [markdown]
# #### Pie 2

# %%
fig = plt.figure(figsize=(6,6), facecolor="white")
ax = fig.add_subplot(111)

def func_autopct(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:,d})".format(pct, absolute)

cmap = plt.get_cmap("tab20c")

wedges, _, autotexts = ax.pie(
    df_stats,
    explode=[0.05] * len(df_stats),
    wedgeprops=dict(width=0.5, edgecolor='w'),
    autopct='%1.1f%%',
    pctdistance=0.7,
    shadow=False,
    startangle=90,
    rotatelabels=True
)

kw = dict(arrowprops=dict(arrowstyle="-"), zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1) / 2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(
        labels[i], xy=(x, y), xytext=(1.1 * np.sign(x), y),
        horizontalalignment=horizontalalignment, **kw
    )

for i, autotext in enumerate(autotexts):
    autotext.set_color('black')
    autotext.set_fontsize(10)
    autotext.set_rotation(0)
    autotext.set_backgroundcolor("white")
    
ax.axis('equal')
ax.legend(
    wedges,
    labels,
    title="Hashtag",
    bbox_to_anchor=(1.2, 0.0, 0.5, 1)
)

plt.show()

# %% [markdown]
# ### Distribution

# %%
df_dist = df_stats.drop(labels=["Doublet"])
df_dist
# Out:
# hashID
# A0301     745
# A0302      21
# A0303      25
# A0304      16
# A0305      40
# A0306    1660
# dtype: int64

# %%
fig = plt.figure(figsize=(6,6), facecolor="white")
ax = fig.add_subplot(111)

ax.bar(df_dist.index, np.log(list(df_dist.values)), color="lightgray")
    
ax.set_ylabel("Log(count)", fontweight="bold")
ax.set_title(sample_name, fontsize=14, fontweight="heavy")
ax.tick_params(axis="x", rotation=90)
    
if len(df_dist) != 0:
    num_hashtags = len(df_dist.values)
    ax.hlines(y=np.log(max(df_dist.values)), xmin=-1, xmax=num_hashtags, colors='red', linestyles='-', lw=2)
    ax.hlines(y=np.log(min(df_dist.values)), xmin=-1, xmax=num_hashtags, colors='red', linestyles='-', lw=2)    
    ax.hlines(y=np.log(np.mean(list(df_dist.values))), xmin=-1, xmax=num_hashtags, colors='orange', linestyles='--', lw=1)    

plt.tight_layout()

plt.show()

# %% [markdown]
# ## Reads Count

# %%
import numpy as np
import scipy.io

# %%
mtx = scipy.io.mmread(
    os.path.join(path_data, "reads/matrix.mtx.gz")
)

# %%
barcodes = pd.read_csv(
    os.path.join(path_data, "reads/barcodes.tsv.gz"),
    sep="\t", 
    compression="gzip",
    header=None
)

# %%
features = pd.read_csv(
    os.path.join(path_data, "reads/features.tsv.gz"),
    sep="\t",
    compression="gzip",
    header=None
)

# %%
df_reads = pd.DataFrame(
    mtx.T.todense(),
    index=barcodes[0],
    columns=features[0]
)

# %%
df_reads
# Out:
# 0                 A0301-ACCCACCAGTAAGAC  A0302-GGTCGAGAGCATTCA  \
# 0
# AATTCCTCATAGAATG                  12809                      2
# AACCTTTTCGTAGGGA                     12                     24
# TACACCCGTTTCGCTC                  18114                      0
# ACACTGACACCAGTTA                      1                      0
# AAAGTCCGTGCCTGAC                  19084                      0
# ...                                 ...                    ...
# GCGAGAATCACCATGA                     16                     89
# CTAGGTACAAGGCGTA                     20                     26
# CTGCGAGTCTGAATCG                     15                     17
# AGGCCACGTAATGCTC                      3                     81
# TCGTGGGAGGCGAAGG                     16                     14
#
# 0                 A0303-CTTGCCGCATGTCAT  A0304-AAAGCATTCTTCACG  \
# 0
# AATTCCTCATAGAATG                      3                      2
# AACCTTTTCGTAGGGA                      0                      1
# TACACCCGTTTCGCTC                      5                      0
# ACACTGACACCAGTTA                      0                      0
# AAAGTCCGTGCCTGAC                      1                      0
# ...                                 ...                    ...
# GCGAGAATCACCATGA                      0                      0
# CTAGGTACAAGGCGTA                      0                     10
# CTGCGAGTCTGAATCG                      0                      0
# AGGCCACGTAATGCTC                      0                      2
# TCGTGGGAGGCGAAGG                      0                      5
#
# 0                 A0305-CTTTGTCTTTGTGAG  A0306-TATGCTGCCACGGTA  unmapped
# 0
# AATTCCTCATAGAATG                      0                     20       241
# AACCTTTTCGTAGGGA                      0                  17637       470
# TACACCCGTTTCGCTC                      0                     16       294
# ACACTGACACCAGTTA                      0                      0        10
# AAAGTCCGTGCCTGAC                      3                     61       341
# ...                                 ...                    ...       ...
# GCGAGAATCACCATGA                      0                  19185       365
# CTAGGTACAAGGCGTA                      2                  15645       339
# CTGCGAGTCTGAATCG                      0                   8599       200
# AGGCCACGTAATGCTC                      1                  14048       320
# TCGTGGGAGGCGAAGG                      0                   7559       171
#
# [2572 rows x 7 columns]

# %% [markdown]
# ### Matrix vs. Run Report

# %%
df_reads.sum().sum(), run_report["Reads processed"]
# Out:
# (43500914, 56902257)

# %%
df_reads.sum().sum() / run_report["Reads processed"] * 100
# Out:
# 76.44848604159937

# %% [markdown]
# ### Total Reads per Hashtag

# %%
df_reads.sum()
# Out:
# 0
# A0301-ACCCACCAGTAAGAC    13815454
# A0302-GGTCGAGAGCATTCA      679743
# A0303-CTTGCCGCATGTCAT      542529
# A0304-AAAGCATTCTTCACG      568818
# A0305-CTTTGTCTTTGTGAG      256863
# A0306-TATGCTGCCACGGTA    26725669
# unmapped                   911838
# dtype: int64

# %% [markdown]
# ### Total Reads per Celluar Barcode

# %%
df_reads.sum(axis=1)
# Out:
# 0
# AATTCCTCATAGAATG    13077
# AACCTTTTCGTAGGGA    18144
# TACACCCGTTTCGCTC    18429
# ACACTGACACCAGTTA       11
# AAAGTCCGTGCCTGAC    19490
#                     ...
# GCGAGAATCACCATGA    19655
# CTAGGTACAAGGCGTA    16042
# CTGCGAGTCTGAATCG     8831
# AGGCCACGTAATGCTC    14455
# TCGTGGGAGGCGAAGG     7765
# Length: 2572, dtype: int64

# %% [markdown]
# ### Total Reads (except unmapped)

# %%
df_reads.iloc[:,:-1].sum().sum()
# Out:
# 42589076

# %% [markdown]
# ### Zero Rows

# %%
len(df_reads.sum(axis=1) == 0)
# Out:
# 2572

# %%
len(df_reads[ df_reads.sum(axis=1) == 0 ]) / len(df_reads)
# Out:
# 0.005443234836702955

# %% [markdown]
# ### First Hashtag

# %%
# remove "Doublet" and pick the first hashtag
hashtags = list(set(df_class.hashID.unique()) - set(["Doublet"]))
first_hashtag = hashtags[0] if len(hashtags) > 0 else None
first_hashtag
# Out:
# 'A0301'

# %%
df_reads.loc[ df_class[ df_class.hashID == first_hashtag ].index ].sort_values(by=df_reads.columns[0], ascending=False)
# Out:
# 0                 A0301-ACCCACCAGTAAGAC  A0302-GGTCGAGAGCATTCA  \
# ATCCATTGTCGAACAG                  47432                      0
# GCTGCAGCACTGTGAT                  43518                     10
# GCTTCACAGCAACAAT                  43483                      1
# AGGTCATCAGAACCGA                  42530                      0
# GCCGATGTCCGATTAG                  41214                      2
# ...                                 ...                    ...
# ACGTACAGTCAGATTC                     35                      0
# CCTATCGCATCCGTTC                     21                      0
# AGTCAACAGCAGTTCC                     20                      0
# GTCATTTTCTGCGACA                      1                      0
# ACACTGACACCAGTTA                      1                      0
#
# 0                 A0303-CTTGCCGCATGTCAT  A0304-AAAGCATTCTTCACG  \
# ATCCATTGTCGAACAG                     24                      1
# GCTGCAGCACTGTGAT                     14                      2
# GCTTCACAGCAACAAT                     11                      0
# AGGTCATCAGAACCGA                      1                      0
# GCCGATGTCCGATTAG                     15                      0
# ...                                 ...                    ...
# ACGTACAGTCAGATTC                      0                      0
# CCTATCGCATCCGTTC                      0                      0
# AGTCAACAGCAGTTCC                      0                      0
# GTCATTTTCTGCGACA                      0                      0
# ACACTGACACCAGTTA                      0                      0
#
# 0                 A0305-CTTTGTCTTTGTGAG  A0306-TATGCTGCCACGGTA  unmapped
# ATCCATTGTCGAACAG                      3                     32       804
# GCTGCAGCACTGTGAT                      0                     43       701
# GCTTCACAGCAACAAT                      1                     21       766
# AGGTCATCAGAACCGA                      1                     32       702
# GCCGATGTCCGATTAG                      2                     40       686
# ...                                 ...                    ...       ...
# ACGTACAGTCAGATTC                      0                     11         0
# CCTATCGCATCCGTTC                      0                      7        10
# AGTCAACAGCAGTTCC                      0                      0         0
# GTCATTTTCTGCGACA                      0                      0         0
# ACACTGACACCAGTTA                      0                      0        10
#
# [745 rows x 7 columns]

# %% [markdown]
# ### Overall Stats

# %%
df_reads.sum(axis=1).sort_values(ascending=False).describe()
# Out:
# count     2572.000000
# mean     16913.263608
# std       7221.985785
# min          0.000000
# 25%      13527.000000
# 50%      16154.000000
# 75%      19469.750000
# max      55178.000000
# dtype: float64

# %% [markdown]
# ### 95 Percentile

# %%
percentile_95 = df_reads.sum(axis=1).describe(percentiles=[0.95])["95%"]
percentile_95
# Out:
# 31206.499999999985

# %%
df_reads[ df_reads.sum(axis=1) > percentile_95 ]
# Out:
# 0                 A0301-ACCCACCAGTAAGAC  A0302-GGTCGAGAGCATTCA  \
# 0
# TCTACATCAACTACGT                  19621                     77
# ATAGGCTGTCTCCTGT                      5                     80
# GACCAATTCCATCACC                  37441                      0
# GAACTGTGTTCTTGCC                     34                     62
# TATATCCGTCATCTAG                  32648                      2
# ...                                 ...                    ...
# TAGGAGGCACATAGCT                  39839                      0
# TCGGTCTAGGAGAGGC                     15                     69
# AACGGGACATAGATCC                  31819                      0
# GAGTTACCAGCAGGAT                     29                     72
# CTGTACCCATTCACCC                    111                  33042
#
# 0                 A0303-CTTGCCGCATGTCAT  A0304-AAAGCATTCTTCACG  \
# 0
# TCTACATCAACTACGT                     11                      0
# ATAGGCTGTCTCCTGT                      0                      2
# GACCAATTCCATCACC                     11                      1
# GAACTGTGTTCTTGCC                      1                      0
# TATATCCGTCATCTAG                      0                      0
# ...                                 ...                    ...
# TAGGAGGCACATAGCT                      8                      0
# TCGGTCTAGGAGAGGC                      0                      0
# AACGGGACATAGATCC                     10                      0
# GAGTTACCAGCAGGAT                      0                      0
# CTGTACCCATTCACCC                      0                      0
#
# 0                 A0305-CTTTGTCTTTGTGAG  A0306-TATGCTGCCACGGTA  unmapped
# 0
# TCTACATCAACTACGT                      0                  16877       725
# ATAGGCTGTCTCCTGT                      2                  30689       765
# GACCAATTCCATCACC                      0                     36       603
# GAACTGTGTTCTTGCC                      0                  30516       734
# TATATCCGTCATCTAG                      2                     38       524
# ...                                 ...                    ...       ...
# TAGGAGGCACATAGCT                      0                     40       760
# TCGGTCTAGGAGAGGC                      0                  30649       797
# AACGGGACATAGATCC                      0                     38       523
# GAGTTACCAGCAGGAT                      1                  39176      1022
# CTGTACCCATTCACCC                      0                     34       618
#
# [129 rows x 7 columns]

# %%
df_reads[ df_reads.sum(axis=1) > percentile_95 ].sample(5, random_state=0)
# Out:
# 0                 A0301-ACCCACCAGTAAGAC  A0302-GGTCGAGAGCATTCA  \
# 0
# CCTTCAGCATCGCTGG                    586                     63
# CCCAACTCAATACCTG                     27                     78
# TGGAGGAAGGCGTTAG                      5                     93
# TTACAGGAGGTTCACT                    107                  35783
# GTATTTCAGACCAACG                     93                  33791
#
# 0                 A0303-CTTGCCGCATGTCAT  A0304-AAAGCATTCTTCACG  \
# 0
# CCTTCAGCATCGCTGG                      0                      1
# CCCAACTCAATACCTG                      0                      0
# TGGAGGAAGGCGTTAG                      1                      0
# TTACAGGAGGTTCACT                      2                      4
# GTATTTCAGACCAACG                      0                      5
#
# 0                 A0305-CTTTGTCTTTGTGAG  A0306-TATGCTGCCACGGTA  unmapped
# 0
# CCTTCAGCATCGCTGG                     10                  39086       949
# CCCAACTCAATACCTG                      1                  42624       973
# TGGAGGAAGGCGTTAG                      0                  30497       660
# TTACAGGAGGTTCACT                      0                     64       614
# GTATTTCAGACCAACG                      0                     32       703

# %%
df_reads[ df_reads.sum(axis=1) > percentile_95 ].sample(5, random_state=0).sum(axis=1)
# Out:
# 0
# CCTTCAGCATCGCTGG    40695
# CCCAACTCAATACCTG    43703
# TGGAGGAAGGCGTTAG    31256
# TTACAGGAGGTTCACT    36574
# GTATTTCAGACCAACG    34624
# dtype: int64

# %% [markdown]
# ### Histogram (sum of reads across hashtags)

# %%
fig, ax = plt.subplots(figsize=(6,6), facecolor="white")

ax.hist(df_reads.sum(axis=1).sort_values(ascending=False), bins=50)

ax.set_xlabel("Reads", fontweight="bold")
ax.set_ylabel("Frequency (Log)", fontweight="bold")
ax.set_title("Histogram (sum of reads across hashtags)", fontweight="bold")

plt.yscale("log")
plt.show()

# %% [markdown]
# ### Histogram (sum of reads per hashtag)

# %%
fig, ax = plt.subplots(figsize=(6, 6), facecolor="white")
    
for idx, col in enumerate(df_reads.columns[:-1]):
    
    df_tmp = df_reads.iloc[:,idx].sort_values(ascending=False)

    ax.hist(df_tmp, bins=50, alpha=0.7, label=col)

ax.set_xlabel("Reads", fontweight="bold")
ax.set_ylabel("Frequency (Log)", fontweight="bold")
ax.tick_params(axis="x", rotation=45)
ax.set_title("Histogram (sum of reads per hashtag)", fontweight="bold")
ax.grid(b=True, linestyle="--")
ax.legend()

plt.yscale("log")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Unmapped

# %%
df_reads.sort_values(by="unmapped", ascending=False).iloc[:,-1]
# Out:
# 0
# CGGAATTAGGAACGAA    1191
# TTGAACGTCAGCCTCT    1101
# GATGATCCACTTCAAG    1055
# GGCAGTCTCTTCGGTC    1044
# GAGTTACCAGCAGGAT    1022
#                     ...
# GTCATTTTCTGCGACA       0
# ATGCGATCATGAAGTA       0
# TTTATGCCATCCTTGC       0
# CCTTCAGCAGGCACTC       0
# ACGTACAGTCAGATTC       0
# Name: unmapped, Length: 2572, dtype: int64

# %%
df_reads.unmapped.sum()
# Out:
# 911838

# %% [markdown]
# ## UMI Count

# %%
mtx = scipy.io.mmread(
    os.path.join(path_data, "umis/matrix.mtx.gz")
)

# %%
barcodes = pd.read_csv(
    os.path.join(path_data, "umis/barcodes.tsv.gz"),
    sep="\t", 
    compression="gzip",
    header=None
)

# %%
features = pd.read_csv(
    os.path.join(path_data, "umis/features.tsv.gz"),
    sep="\t",
    compression="gzip",
    header=None
)

# %%
df_umis = pd.DataFrame(
    mtx.T.todense(),
    index=barcodes[0],
    columns=features[0]
)

# %%
df_umis
# Out:
# 0                 A0301-ACCCACCAGTAAGAC  A0302-GGTCGAGAGCATTCA  \
# 0
# AATTCCTCATAGAATG                   4506                      1
# AACCTTTTCGTAGGGA                      8                      7
# TACACCCGTTTCGCTC                   6297                      0
# ACACTGACACCAGTTA                      1                      0
# AAAGTCCGTGCCTGAC                   6539                      0
# ...                                 ...                    ...
# GCGAGAATCACCATGA                      7                     17
# CTAGGTACAAGGCGTA                     11                      8
# CTGCGAGTCTGAATCG                      7                      5
# AGGCCACGTAATGCTC                      3                     15
# TCGTGGGAGGCGAAGG                      7                      3
#
# 0                 A0303-CTTGCCGCATGTCAT  A0304-AAAGCATTCTTCACG  \
# 0
# AATTCCTCATAGAATG                      2                      1
# AACCTTTTCGTAGGGA                      0                      1
# TACACCCGTTTCGCTC                      1                      0
# ACACTGACACCAGTTA                      0                      0
# AAAGTCCGTGCCTGAC                      1                      0
# ...                                 ...                    ...
# GCGAGAATCACCATGA                      0                      0
# CTAGGTACAAGGCGTA                      0                      4
# CTGCGAGTCTGAATCG                      0                      0
# AGGCCACGTAATGCTC                      0                      1
# TCGTGGGAGGCGAAGG                      0                      2
#
# 0                 A0305-CTTTGTCTTTGTGAG  A0306-TATGCTGCCACGGTA  unmapped
# 0
# AATTCCTCATAGAATG                      0                      8        94
# AACCTTTTCGTAGGGA                      0                   6255       182
# TACACCCGTTTCGCTC                      0                      8       107
# ACACTGACACCAGTTA                      0                      0         4
# AAAGTCCGTGCCTGAC                      1                     25       131
# ...                                 ...                    ...       ...
# GCGAGAATCACCATGA                      0                   6611       151
# CTAGGTACAAGGCGTA                      1                   5513       122
# CTGCGAGTCTGAATCG                      0                   3022        72
# AGGCCACGTAATGCTC                      1                   4664       111
# TCGTGGGAGGCGAAGG                      0                   3238        76
#
# [2572 rows x 7 columns]

# %% [markdown]
# ### Histogram (sum of UMIs across hashtag)

# %%
fig, ax = plt.subplots(figsize=(6, 6), facecolor="white")

ax.hist(df_umis.values.sum(axis=1), bins=30)
ax.set_xlabel("Total UMIs per Cell Barcode")
ax.set_ylabel("Frequency")

plt.tight_layout
plt.show()

# %% [markdown]
# ## Reads per UMI

# %% [markdown]
# ### Calculate

# %%
# reads divided by UMI, replace NaN with zero
df_reads_per_umi = (df_reads / df_umis).replace(to_replace=np.NaN, value=0)
# remove the "unmapped" column
df_reads_per_umi = df_reads_per_umi.iloc[:,0:-1]
df_reads_per_umi
# Out:
# 0                 A0301-ACCCACCAGTAAGAC  A0302-GGTCGAGAGCATTCA  \
# 0
# AATTCCTCATAGAATG               2.842654               2.000000
# AACCTTTTCGTAGGGA               1.500000               3.428571
# TACACCCGTTTCGCTC               2.876608               0.000000
# ACACTGACACCAGTTA               1.000000               0.000000
# AAAGTCCGTGCCTGAC               2.918489               0.000000
# ...                                 ...                    ...
# GCGAGAATCACCATGA               2.285714               5.235294
# CTAGGTACAAGGCGTA               1.818182               3.250000
# CTGCGAGTCTGAATCG               2.142857               3.400000
# AGGCCACGTAATGCTC               1.000000               5.400000
# TCGTGGGAGGCGAAGG               2.285714               4.666667
#
# 0                 A0303-CTTGCCGCATGTCAT  A0304-AAAGCATTCTTCACG  \
# 0
# AATTCCTCATAGAATG                    1.5                    2.0
# AACCTTTTCGTAGGGA                    0.0                    1.0
# TACACCCGTTTCGCTC                    5.0                    0.0
# ACACTGACACCAGTTA                    0.0                    0.0
# AAAGTCCGTGCCTGAC                    1.0                    0.0
# ...                                 ...                    ...
# GCGAGAATCACCATGA                    0.0                    0.0
# CTAGGTACAAGGCGTA                    0.0                    2.5
# CTGCGAGTCTGAATCG                    0.0                    0.0
# AGGCCACGTAATGCTC                    0.0                    2.0
# TCGTGGGAGGCGAAGG                    0.0                    2.5
#
# 0                 A0305-CTTTGTCTTTGTGAG  A0306-TATGCTGCCACGGTA
# 0
# AATTCCTCATAGAATG                    0.0               2.500000
# AACCTTTTCGTAGGGA                    0.0               2.819664
# TACACCCGTTTCGCTC                    0.0               2.000000
# ACACTGACACCAGTTA                    0.0               0.000000
# AAAGTCCGTGCCTGAC                    3.0               2.440000
# ...                                 ...                    ...
# GCGAGAATCACCATGA                    0.0               2.901982
# CTAGGTACAAGGCGTA                    2.0               2.837838
# CTGCGAGTCTGAATCG                    0.0               2.845467
# AGGCCACGTAATGCTC                    1.0               3.012007
# TCGTGGGAGGCGAAGG                    0.0               2.334466
#
# [2572 rows x 6 columns]

# %%
sum_umis = df_umis.sum(axis=1).sum()
sum_reads = df_reads.sum(axis=1).sum()

# %%
reads_per_umi = sum_reads / sum_umis
reads_per_umi
# Out:
# 2.8754077622612577

# %% [markdown]
# ### Histogram

# %%
fig, ax = plt.subplots(figsize=(6,6), facecolor="white")

n, bins, _ = ax.hist(np.ravel(df_reads_per_umi.values), bins=50, color="lightgray")
ax.vlines(x=reads_per_umi, ymin=0, ymax=np.max(n), color="red", linestyle="--", lw=2, label="Average")

ax.set_xlabel("Reads per UMI", fontweight="bold")
ax.set_ylabel("Frequency", fontweight="bold")
ax.set_title("Histogram", fontweight="bold")
ax.legend()

plt.show()

# %% [markdown]
# ## Merge (UMI + Class)

# %%
df_umi_class = pd.merge(
    df_umis, df_class,
    left_index=True, right_index=True,
    how="inner"
)

# %%
df_umi_class
# Out:
#                   A0301-ACCCACCAGTAAGAC  A0302-GGTCGAGAGCATTCA  \
# AATTCCTCATAGAATG                   4506                      1
# AACCTTTTCGTAGGGA                      8                      7
# TACACCCGTTTCGCTC                   6297                      0
# ACACTGACACCAGTTA                      1                      0
# AAAGTCCGTGCCTGAC                   6539                      0
# ...                                 ...                    ...
# GCGAGAATCACCATGA                      7                     17
# CTAGGTACAAGGCGTA                     11                      8
# CTGCGAGTCTGAATCG                      7                      5
# AGGCCACGTAATGCTC                      3                     15
# TCGTGGGAGGCGAAGG                      7                      3
#
#                   A0303-CTTGCCGCATGTCAT  A0304-AAAGCATTCTTCACG  \
# AATTCCTCATAGAATG                      2                      1
# AACCTTTTCGTAGGGA                      0                      1
# TACACCCGTTTCGCTC                      1                      0
# ACACTGACACCAGTTA                      0                      0
# AAAGTCCGTGCCTGAC                      1                      0
# ...                                 ...                    ...
# GCGAGAATCACCATGA                      0                      0
# CTAGGTACAAGGCGTA                      0                      4
# CTGCGAGTCTGAATCG                      0                      0
# AGGCCACGTAATGCTC                      0                      1
# TCGTGGGAGGCGAAGG                      0                      2
#
#                   A0305-CTTTGTCTTTGTGAG  A0306-TATGCTGCCACGGTA  unmapped  \
# AATTCCTCATAGAATG                      0                      8        94
# AACCTTTTCGTAGGGA                      0                   6255       182
# TACACCCGTTTCGCTC                      0                      8       107
# ACACTGACACCAGTTA                      0                      0         4
# AAAGTCCGTGCCTGAC                      1                     25       131
# ...                                 ...                    ...       ...
# GCGAGAATCACCATGA                      0                   6611       151
# CTAGGTACAAGGCGTA                      1                   5513       122
# CTGCGAGTCTGAATCG                      0                   3022        72
# AGGCCACGTAATGCTC                      1                   4664       111
# TCGTGGGAGGCGAAGG                      0                   3238        76
#
#                  hashID
# AATTCCTCATAGAATG  A0301
# AACCTTTTCGTAGGGA  A0306
# TACACCCGTTTCGCTC  A0301
# ACACTGACACCAGTTA  A0301
# AAAGTCCGTGCCTGAC  A0301
# ...                 ...
# GCGAGAATCACCATGA  A0306
# CTAGGTACAAGGCGTA  A0306
# CTGCGAGTCTGAATCG  A0306
# AGGCCACGTAATGCTC  A0306
# TCGTGGGAGGCGAAGG  A0306
#
# [2572 rows x 8 columns]

# %% [markdown]
# ## UMI (one vs. rest)

# %% [markdown]
# - Ideally, the winning one shouldn't be winning by having less than e.g. 10 UMIs?
# - Ideally, the losing ones should have UMIs close to zero.

# %% [markdown]
# ### All

# %%
num_hashtags = len(df_umi_class.columns[:-2])
num_cols = 4
num_rows = num_hashtags / num_cols + 1

fig = plt.figure(figsize=(20, num_rows * 4), facecolor="white")

idx_plot = 0

for hashtag in sorted(hashtags):
    
    idx_plot += 1
    
    ax = fig.add_subplot(num_rows, num_cols, idx_plot)

    df_tmp = df_umi_class[ df_umi_class.hashID == hashtag ].iloc[:,0:-2]
    df_tmp.columns = list(map(lambda col: col.split("-")[0], df_tmp.columns))

    sns.stripplot(data=df_tmp, ax=ax)

    ax.set_title(f"UMI ({hashtag} vs. rest)")
    ax.tick_params(axis="x", rotation=90)
    ax.grid(b=True, linestyle="--")
#     ax.set_yscale("log")
    
    for tick in ax.xaxis.get_major_ticks():
        if tick.label.get_text() == hashtag:
            tick.label.set_color("black")
        else:
            tick.label.set_color("gray")

plt.tight_layout()
plt.show()
# Out:
# /Users/chunj/opt/miniconda3/envs/sharp/lib/python3.7/site-packages/ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   del sys.path[0]
# /Users/chunj/opt/miniconda3/envs/sharp/lib/python3.7/site-packages/ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   del sys.path[0]
# /Users/chunj/opt/miniconda3/envs/sharp/lib/python3.7/site-packages/ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   del sys.path[0]
# /Users/chunj/opt/miniconda3/envs/sharp/lib/python3.7/site-packages/ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   del sys.path[0]
# /Users/chunj/opt/miniconda3/envs/sharp/lib/python3.7/site-packages/ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   del sys.path[0]
# /Users/chunj/opt/miniconda3/envs/sharp/lib/python3.7/site-packages/ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   del sys.path[0]

# %% [markdown]
# ### 25th Percentile

# %%
umi_sum_percentile_25 = df_umi_class.iloc[:,0:-2].sum(axis=1).describe()["25%"]
umi_sum_percentile_25
# Out:
# 4596.0

# %%
df_umi_class[ (df_umi_class.iloc[:,0:-2].sum(axis=1) < umi_sum_percentile_25) & (df_umi_class.hashID != "Doublet") ]
# Out:
#                   A0301-ACCCACCAGTAAGAC  A0302-GGTCGAGAGCATTCA  \
# AATTCCTCATAGAATG                   4506                      1
# ACACTGACACCAGTTA                      1                      0
# TTACCATTCCCGTAAA                      4                      2
# GGGACAAAGTAACGTA                     22                     10
# TGCGATACAAACTAAG                      5                      2
# ...                                 ...                    ...
# AGTCACAGTGAGGAAA                      8                      7
# TTTCAGTGTAGCGTAG                      9                      2
# AGGATAATCTACTATC                   4227                      0
# CTGCGAGTCTGAATCG                      7                      5
# TCGTGGGAGGCGAAGG                      7                      3
#
#                   A0303-CTTGCCGCATGTCAT  A0304-AAAGCATTCTTCACG  \
# AATTCCTCATAGAATG                      2                      1
# ACACTGACACCAGTTA                      0                      0
# TTACCATTCCCGTAAA                      0                      0
# GGGACAAAGTAACGTA                      1                      1
# TGCGATACAAACTAAG                      0                      0
# ...                                 ...                    ...
# AGTCACAGTGAGGAAA                      0                      1
# TTTCAGTGTAGCGTAG                      0                      0
# AGGATAATCTACTATC                      1                      0
# CTGCGAGTCTGAATCG                      0                      0
# TCGTGGGAGGCGAAGG                      0                      2
#
#                   A0305-CTTTGTCTTTGTGAG  A0306-TATGCTGCCACGGTA  unmapped  \
# AATTCCTCATAGAATG                      0                      8        94
# ACACTGACACCAGTTA                      0                      0         4
# TTACCATTCCCGTAAA                      0                   1009        24
# GGGACAAAGTAACGTA                      0                   4023       118
# TGCGATACAAACTAAG                      0                   3865        85
# ...                                 ...                    ...       ...
# AGTCACAGTGAGGAAA                      0                   4286       123
# TTTCAGTGTAGCGTAG                      0                   3192        62
# AGGATAATCTACTATC                      0                      5        79
# CTGCGAGTCTGAATCG                      0                   3022        72
# TCGTGGGAGGCGAAGG                      0                   3238        76
#
#                  hashID
# AATTCCTCATAGAATG  A0301
# ACACTGACACCAGTTA  A0301
# TTACCATTCCCGTAAA  A0306
# GGGACAAAGTAACGTA  A0306
# TGCGATACAAACTAAG  A0306
# ...                 ...
# AGTCACAGTGAGGAAA  A0306
# TTTCAGTGTAGCGTAG  A0306
# AGGATAATCTACTATC  A0301
# CTGCGAGTCTGAATCG  A0306
# TCGTGGGAGGCGAAGG  A0306
#
# [614 rows x 8 columns]

# %%
num_hashtags = len(df_umi_class.columns[:-2])
num_cols = 4
num_rows = num_hashtags / num_cols + 1

fig = plt.figure(figsize=(20, num_rows * 4), facecolor="white")

idx_plot = 0

for hashtag in sorted(hashtags):
    
    idx_plot += 1
    
    ax = fig.add_subplot(num_rows, num_cols, idx_plot)

    df_tmp = df_umi_class[ (df_umi_class.iloc[:,0:-2].sum(axis=1) < umi_sum_percentile_25) & (df_umi_class.hashID == hashtag) ].iloc[:,0:-2]
    df_tmp.columns = list(map(lambda col: col.split("-")[0], df_tmp.columns))

    sns.stripplot(data=df_tmp, ax=ax)

    ax.set_title(f"UMI ({hashtag} vs. rest)")
    ax.tick_params(axis="x", rotation=90)
    ax.grid(b=True, linestyle="--")
    
    for tick in ax.xaxis.get_major_ticks():
        if tick.label.get_text() == hashtag:
            tick.label.set_color("black")
        else:
            tick.label.set_color("gray")

plt.tight_layout()
plt.show()
# Out:
# /Users/chunj/opt/miniconda3/envs/sharp/lib/python3.7/site-packages/ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   del sys.path[0]
# /Users/chunj/opt/miniconda3/envs/sharp/lib/python3.7/site-packages/ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   del sys.path[0]
# /Users/chunj/opt/miniconda3/envs/sharp/lib/python3.7/site-packages/ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   del sys.path[0]
# /Users/chunj/opt/miniconda3/envs/sharp/lib/python3.7/site-packages/ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   del sys.path[0]
# /Users/chunj/opt/miniconda3/envs/sharp/lib/python3.7/site-packages/ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   del sys.path[0]
# /Users/chunj/opt/miniconda3/envs/sharp/lib/python3.7/site-packages/ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   del sys.path[0]

# %% [markdown]
# ## UMI Distribution

# %%
num_hashtags = len(df_umi_class.columns[:-2])
num_cols = 4
num_rows = num_hashtags / num_cols + 1

fig = plt.figure(figsize=(20, num_rows * 4), facecolor="white")

idx_plot = 0

for idx, col in enumerate(df_umi_class.columns[:-2]):

    idx_plot += 1
    ax = fig.add_subplot(num_rows, num_cols, idx_plot)
    
    df_tmp = df_umi_class.iloc[:,idx].sort_values(ascending=False)

    ax.hist(df_tmp, bins=10, alpha=0.7, label=col)

    ax.set_xlabel("UMIs", fontweight="bold")
    ax.set_ylabel("Frequency (Log)", fontweight="bold")
    ax.tick_params(axis="x", rotation=45)
    ax.set_title(f"UMI ({col})", fontweight="bold")
    ax.grid(b=True, linestyle="--")
    ax.set_yscale("log")
    ax.legend()

plt.tight_layout()
plt.show()
# Out:
# /Users/chunj/opt/miniconda3/envs/sharp/lib/python3.7/site-packages/ipykernel_launcher.py:12: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   if sys.path[0] == '':

# %% [markdown]
# ## Negative Check

# %%
df2 = df_umi_class.copy()

# %%
df2 = df2.assign(total=df2.iloc[:,:-2].sum(axis=1))
df2
# Out:
#                   A0301-ACCCACCAGTAAGAC  A0302-GGTCGAGAGCATTCA  \
# AATTCCTCATAGAATG                   4506                      1
# AACCTTTTCGTAGGGA                      8                      7
# TACACCCGTTTCGCTC                   6297                      0
# ACACTGACACCAGTTA                      1                      0
# AAAGTCCGTGCCTGAC                   6539                      0
# ...                                 ...                    ...
# GCGAGAATCACCATGA                      7                     17
# CTAGGTACAAGGCGTA                     11                      8
# CTGCGAGTCTGAATCG                      7                      5
# AGGCCACGTAATGCTC                      3                     15
# TCGTGGGAGGCGAAGG                      7                      3
#
#                   A0303-CTTGCCGCATGTCAT  A0304-AAAGCATTCTTCACG  \
# AATTCCTCATAGAATG                      2                      1
# AACCTTTTCGTAGGGA                      0                      1
# TACACCCGTTTCGCTC                      1                      0
# ACACTGACACCAGTTA                      0                      0
# AAAGTCCGTGCCTGAC                      1                      0
# ...                                 ...                    ...
# GCGAGAATCACCATGA                      0                      0
# CTAGGTACAAGGCGTA                      0                      4
# CTGCGAGTCTGAATCG                      0                      0
# AGGCCACGTAATGCTC                      0                      1
# TCGTGGGAGGCGAAGG                      0                      2
#
#                   A0305-CTTTGTCTTTGTGAG  A0306-TATGCTGCCACGGTA  unmapped  \
# AATTCCTCATAGAATG                      0                      8        94
# AACCTTTTCGTAGGGA                      0                   6255       182
# TACACCCGTTTCGCTC                      0                      8       107
# ACACTGACACCAGTTA                      0                      0         4
# AAAGTCCGTGCCTGAC                      1                     25       131
# ...                                 ...                    ...       ...
# GCGAGAATCACCATGA                      0                   6611       151
# CTAGGTACAAGGCGTA                      1                   5513       122
# CTGCGAGTCTGAATCG                      0                   3022        72
# AGGCCACGTAATGCTC                      1                   4664       111
# TCGTGGGAGGCGAAGG                      0                   3238        76
#
#                  hashID  total
# AATTCCTCATAGAATG  A0301   4518
# AACCTTTTCGTAGGGA  A0306   6271
# TACACCCGTTTCGCTC  A0301   6306
# ACACTGACACCAGTTA  A0301      1
# AAAGTCCGTGCCTGAC  A0301   6566
# ...                 ...    ...
# GCGAGAATCACCATGA  A0306   6635
# CTAGGTACAAGGCGTA  A0306   5537
# CTGCGAGTCTGAATCG  A0306   3034
# AGGCCACGTAATGCTC  A0306   4684
# TCGTGGGAGGCGAAGG  A0306   3250
#
# [2572 rows x 9 columns]

# %%
df2.sort_values(by="total", ascending=False, inplace=True)

# %% [markdown]
# ### Zero Rows

# %%
df2.loc[ df2.total == 0 ]
# Out:
#                   A0301-ACCCACCAGTAAGAC  A0302-GGTCGAGAGCATTCA  \
# CATCCACCACCTCGTT                      0                      0
# ATAGACCTCGGTGTTA                      0                      0
# CCGGTAGTCACGACTA                      0                      0
# TGGGCGTGTGAGTGAC                      0                      0
# GGGAGATCAGTTTACG                      0                      0
# CGAGGAAGTGGACCTC                      0                      0
# TGTTCCGGTAAGTGTA                      0                      0
# TCACAAGTCAACTCTT                      0                      0
# GTCGTAATCTGGCCTC                      0                      0
# ATTCTACGTGAGCGAT                      0                      0
# CTACATTCAGGGATTG                      0                      0
# ATGCGATCATGAAGTA                      0                      0
# TTAGGCAGTTCTCATT                      0                      0
# TTGCGTCTCCGTAGTA                      0                      0
# TTTATGCCATCCTTGC                      0                      0
# TTGCGTCGTAATTGGA                      0                      0
# ACGATGTCACGGCGTT                      0                      0
# TGTCCCAGTGGGTATG                      0                      0
# TAGACCAGTACGAAAT                      0                      0
# CGTCCATAGCCTTGAT                      0                      0
#
#                   A0303-CTTGCCGCATGTCAT  A0304-AAAGCATTCTTCACG  \
# CATCCACCACCTCGTT                      0                      0
# ATAGACCTCGGTGTTA                      0                      0
# CCGGTAGTCACGACTA                      0                      0
# TGGGCGTGTGAGTGAC                      0                      0
# GGGAGATCAGTTTACG                      0                      0
# CGAGGAAGTGGACCTC                      0                      0
# TGTTCCGGTAAGTGTA                      0                      0
# TCACAAGTCAACTCTT                      0                      0
# GTCGTAATCTGGCCTC                      0                      0
# ATTCTACGTGAGCGAT                      0                      0
# CTACATTCAGGGATTG                      0                      0
# ATGCGATCATGAAGTA                      0                      0
# TTAGGCAGTTCTCATT                      0                      0
# TTGCGTCTCCGTAGTA                      0                      0
# TTTATGCCATCCTTGC                      0                      0
# TTGCGTCGTAATTGGA                      0                      0
# ACGATGTCACGGCGTT                      0                      0
# TGTCCCAGTGGGTATG                      0                      0
# TAGACCAGTACGAAAT                      0                      0
# CGTCCATAGCCTTGAT                      0                      0
#
#                   A0305-CTTTGTCTTTGTGAG  A0306-TATGCTGCCACGGTA  unmapped  \
# CATCCACCACCTCGTT                      0                      0         0
# ATAGACCTCGGTGTTA                      0                      0         0
# CCGGTAGTCACGACTA                      0                      0         0
# TGGGCGTGTGAGTGAC                      0                      0         1
# GGGAGATCAGTTTACG                      0                      0         1
# CGAGGAAGTGGACCTC                      0                      0         1
# TGTTCCGGTAAGTGTA                      0                      0         0
# TCACAAGTCAACTCTT                      0                      0         0
# GTCGTAATCTGGCCTC                      0                      0         0
# ATTCTACGTGAGCGAT                      0                      0         0
# CTACATTCAGGGATTG                      0                      0         0
# ATGCGATCATGAAGTA                      0                      0         0
# TTAGGCAGTTCTCATT                      0                      0         0
# TTGCGTCTCCGTAGTA                      0                      0         1
# TTTATGCCATCCTTGC                      0                      0         0
# TTGCGTCGTAATTGGA                      0                      0         0
# ACGATGTCACGGCGTT                      0                      0         1
# TGTCCCAGTGGGTATG                      0                      0         0
# TAGACCAGTACGAAAT                      0                      0         0
# CGTCCATAGCCTTGAT                      0                      0         1
#
#                    hashID  total
# CATCCACCACCTCGTT  Doublet      0
# ATAGACCTCGGTGTTA  Doublet      0
# CCGGTAGTCACGACTA  Doublet      0
# TGGGCGTGTGAGTGAC  Doublet      0
# GGGAGATCAGTTTACG  Doublet      0
# CGAGGAAGTGGACCTC  Doublet      0
# TGTTCCGGTAAGTGTA  Doublet      0
# TCACAAGTCAACTCTT  Doublet      0
# GTCGTAATCTGGCCTC  Doublet      0
# ATTCTACGTGAGCGAT  Doublet      0
# CTACATTCAGGGATTG  Doublet      0
# ATGCGATCATGAAGTA  Doublet      0
# TTAGGCAGTTCTCATT  Doublet      0
# TTGCGTCTCCGTAGTA  Doublet      0
# TTTATGCCATCCTTGC  Doublet      0
# TTGCGTCGTAATTGGA  Doublet      0
# ACGATGTCACGGCGTT  Doublet      0
# TGTCCCAGTGGGTATG  Doublet      0
# TAGACCAGTACGAAAT  Doublet      0
# CGTCCATAGCCTTGAT  Doublet      0

# %%
df2.loc[ df2.total == 0 ].shape
# Out:
# (20, 9)

# %%
len(df2.loc[ df2.total == 0 ]) / len(df2) * 100.0
# Out:
# 0.7776049766718507

# %% [markdown]
# ### Singlets

# %%
df2[ df2.hashID != "Doublet" ]
# Out:
#                   A0301-ACCCACCAGTAAGAC  A0302-GGTCGAGAGCATTCA  \
# ATCCATTGTCGAACAG                  15805                      0
# TGGGCTGAGTCGCCAC                     12                     28
# TTCTAACGTGCTCTCT                     15                      8
# GCTGCAGCACTGTGAT                  14934                      3
# GGGTATTTCTTTCCAA                     14                     22
# ...                                 ...                    ...
# ACACTGACACCAGTTA                      1                      0
# GTCATTTTCTGCGACA                      1                      0
# GGGAGATAGTGATCGG                      0                      0
# CGGACACAGGGCATGT                      0                      1
# TGGGAAGTCCGCTGTT                      0                      0
#
#                   A0303-CTTGCCGCATGTCAT  A0304-AAAGCATTCTTCACG  \
# ATCCATTGTCGAACAG                      6                      1
# TGGGCTGAGTCGCCAC                      0                      0
# TTCTAACGTGCTCTCT                      0                      1
# GCTGCAGCACTGTGAT                      4                      2
# GGGTATTTCTTTCCAA                      1                      0
# ...                                 ...                    ...
# ACACTGACACCAGTTA                      0                      0
# GTCATTTTCTGCGACA                      0                      0
# GGGAGATAGTGATCGG                      0                      0
# CGGACACAGGGCATGT                      0                      0
# TGGGAAGTCCGCTGTT                      0                      0
#
#                   A0305-CTTTGTCTTTGTGAG  A0306-TATGCTGCCACGGTA  unmapped  \
# ATCCATTGTCGAACAG                      1                     19       303
# TGGGCTGAGTCGCCAC                      0                  15218       397
# TTCTAACGTGCTCTCT                      0                  15136       365
# GCTGCAGCACTGTGAT                      0                     18       270
# GGGTATTTCTTTCCAA                      0                  14846       385
# ...                                 ...                    ...       ...
# ACACTGACACCAGTTA                      0                      0         4
# GTCATTTTCTGCGACA                      0                      0         0
# GGGAGATAGTGATCGG                      0                      1         1
# CGGACACAGGGCATGT                      0                      0         1
# TGGGAAGTCCGCTGTT                      0                      1         0
#
#                  hashID  total
# ATCCATTGTCGAACAG  A0301  15832
# TGGGCTGAGTCGCCAC  A0306  15258
# TTCTAACGTGCTCTCT  A0306  15160
# GCTGCAGCACTGTGAT  A0301  14961
# GGGTATTTCTTTCCAA  A0306  14883
# ...                 ...    ...
# ACACTGACACCAGTTA  A0301      1
# GTCATTTTCTGCGACA  A0301      1
# GGGAGATAGTGATCGG  A0306      1
# CGGACACAGGGCATGT  A0302      1
# TGGGAAGTCCGCTGTT  A0306      1
#
# [2507 rows x 9 columns]

# %%
df2[ (df2.hashID != "Doublet") & (df2.total < 10) ]
# Out:
#                   A0301-ACCCACCAGTAAGAC  A0302-GGTCGAGAGCATTCA  \
# CCTATCGCATCCGTTC                      7                      0
# GTATTGGAGGTTCTGC                      1                      0
# ATCATTCTCTAACCGG                      0                      0
# TCGTAGACAAAGCGGT                      0                      0
# ACACTGACACCAGTTA                      1                      0
# GTCATTTTCTGCGACA                      1                      0
# GGGAGATAGTGATCGG                      0                      0
# CGGACACAGGGCATGT                      0                      1
# TGGGAAGTCCGCTGTT                      0                      0
#
#                   A0303-CTTGCCGCATGTCAT  A0304-AAAGCATTCTTCACG  \
# CCTATCGCATCCGTTC                      0                      0
# GTATTGGAGGTTCTGC                      0                      0
# ATCATTCTCTAACCGG                      0                      0
# TCGTAGACAAAGCGGT                      0                      0
# ACACTGACACCAGTTA                      0                      0
# GTCATTTTCTGCGACA                      0                      0
# GGGAGATAGTGATCGG                      0                      0
# CGGACACAGGGCATGT                      0                      0
# TGGGAAGTCCGCTGTT                      0                      0
#
#                   A0305-CTTTGTCTTTGTGAG  A0306-TATGCTGCCACGGTA  unmapped  \
# CCTATCGCATCCGTTC                      0                      2         2
# GTATTGGAGGTTCTGC                      0                      7         0
# ATCATTCTCTAACCGG                      0                      5         0
# TCGTAGACAAAGCGGT                      0                      5         0
# ACACTGACACCAGTTA                      0                      0         4
# GTCATTTTCTGCGACA                      0                      0         0
# GGGAGATAGTGATCGG                      0                      1         1
# CGGACACAGGGCATGT                      0                      0         1
# TGGGAAGTCCGCTGTT                      0                      1         0
#
#                  hashID  total
# CCTATCGCATCCGTTC  A0301      9
# GTATTGGAGGTTCTGC  A0306      8
# ATCATTCTCTAACCGG  A0306      5
# TCGTAGACAAAGCGGT  A0306      5
# ACACTGACACCAGTTA  A0301      1
# GTCATTTTCTGCGACA  A0301      1
# GGGAGATAGTGATCGG  A0306      1
# CGGACACAGGGCATGT  A0302      1
# TGGGAAGTCCGCTGTT  A0306      1

# %%
df2[ (df2.hashID != "Doublet") & (df2.total < 10) ].shape
# Out:
# (9, 9)

# %%
df2[ (df2.hashID != "Doublet") & (df2.total >= 10) ]
# Out:
#                   A0301-ACCCACCAGTAAGAC  A0302-GGTCGAGAGCATTCA  \
# ATCCATTGTCGAACAG                  15805                      0
# TGGGCTGAGTCGCCAC                     12                     28
# TTCTAACGTGCTCTCT                     15                      8
# GCTGCAGCACTGTGAT                  14934                      3
# GGGTATTTCTTTCCAA                     14                     22
# ...                                 ...                    ...
# GCCAGGTAGATGGGCT                     40                      0
# GCACTAAAGATTAGTG                      3                      0
# ATGGGTTCAGCTCTCT                     20                      0
# AGTCAACAGCAGTTCC                     19                      0
# ACGTACAGTCAGATTC                     13                      0
#
#                   A0303-CTTGCCGCATGTCAT  A0304-AAAGCATTCTTCACG  \
# ATCCATTGTCGAACAG                      6                      1
# TGGGCTGAGTCGCCAC                      0                      0
# TTCTAACGTGCTCTCT                      0                      1
# GCTGCAGCACTGTGAT                      4                      2
# GGGTATTTCTTTCCAA                      1                      0
# ...                                 ...                    ...
# GCCAGGTAGATGGGCT                      0                      0
# GCACTAAAGATTAGTG                      0                      0
# ATGGGTTCAGCTCTCT                      0                      0
# AGTCAACAGCAGTTCC                      0                      0
# ACGTACAGTCAGATTC                      0                      0
#
#                   A0305-CTTTGTCTTTGTGAG  A0306-TATGCTGCCACGGTA  unmapped  \
# ATCCATTGTCGAACAG                      1                     19       303
# TGGGCTGAGTCGCCAC                      0                  15218       397
# TTCTAACGTGCTCTCT                      0                  15136       365
# GCTGCAGCACTGTGAT                      0                     18       270
# GGGTATTTCTTTCCAA                      0                  14846       385
# ...                                 ...                    ...       ...
# GCCAGGTAGATGGGCT                      0                      7         1
# GCACTAAAGATTAGTG                      0                     28         1
# ATGGGTTCAGCTCTCT                      0                      0         1
# AGTCAACAGCAGTTCC                      0                      0         0
# ACGTACAGTCAGATTC                      0                      3         0
#
#                  hashID  total
# ATCCATTGTCGAACAG  A0301  15832
# TGGGCTGAGTCGCCAC  A0306  15258
# TTCTAACGTGCTCTCT  A0306  15160
# GCTGCAGCACTGTGAT  A0301  14961
# GGGTATTTCTTTCCAA  A0306  14883
# ...                 ...    ...
# GCCAGGTAGATGGGCT  A0301     47
# GCACTAAAGATTAGTG  A0306     31
# ATGGGTTCAGCTCTCT  A0301     20
# AGTCAACAGCAGTTCC  A0301     19
# ACGTACAGTCAGATTC  A0301     16
#
# [2498 rows x 9 columns]

# %% [markdown]
# ### Doublets

# %%
df2[ df2.hashID == "Doublet" ]
# Out:
#                   A0301-ACCCACCAGTAAGAC  A0302-GGTCGAGAGCATTCA  \
# CGTGAATTCGGTAGAG                   7370                     12
# GACTCTCGTGCACAAG                   2944                  15437
# TTCCTAAGTAGGCAGT                   9366                     11
# TTGAACGTCAGCCTCT                   5350                     24
# GTCCTCACACGGTCTG                   5607                     10
# ...                                 ...                    ...
# TTGCGTCGTAATTGGA                      0                      0
# ACGATGTCACGGCGTT                      0                      0
# TGTCCCAGTGGGTATG                      0                      0
# TAGACCAGTACGAAAT                      0                      0
# CGTCCATAGCCTTGAT                      0                      0
#
#                   A0303-CTTGCCGCATGTCAT  A0304-AAAGCATTCTTCACG  \
# CGTGAATTCGGTAGAG                      3                  11565
# GACTCTCGTGCACAAG                      2                      1
# TTCCTAAGTAGGCAGT                   8739                      8
# TTGAACGTCAGCCTCT                      1                      1
# GTCCTCACACGGTCTG                      2                      1
# ...                                 ...                    ...
# TTGCGTCGTAATTGGA                      0                      0
# ACGATGTCACGGCGTT                      0                      0
# TGTCCCAGTGGGTATG                      0                      0
# TAGACCAGTACGAAAT                      0                      0
# CGTCCATAGCCTTGAT                      0                      0
#
#                   A0305-CTTTGTCTTTGTGAG  A0306-TATGCTGCCACGGTA  unmapped  \
# CGTGAATTCGGTAGAG                      0                     20       310
# GACTCTCGTGCACAAG                      0                    157       444
# TTCCTAAGTAGGCAGT                      0                     17       335
# TTGAACGTCAGCCTCT                      0                  12251       413
# GTCCTCACACGGTCTG                      0                   9938       367
# ...                                 ...                    ...       ...
# TTGCGTCGTAATTGGA                      0                      0         0
# ACGATGTCACGGCGTT                      0                      0         1
# TGTCCCAGTGGGTATG                      0                      0         0
# TAGACCAGTACGAAAT                      0                      0         0
# CGTCCATAGCCTTGAT                      0                      0         1
#
#                    hashID  total
# CGTGAATTCGGTAGAG  Doublet  18970
# GACTCTCGTGCACAAG  Doublet  18541
# TTCCTAAGTAGGCAGT  Doublet  18141
# TTGAACGTCAGCCTCT  Doublet  17627
# GTCCTCACACGGTCTG  Doublet  15558
# ...                   ...    ...
# TTGCGTCGTAATTGGA  Doublet      0
# ACGATGTCACGGCGTT  Doublet      0
# TGTCCCAGTGGGTATG  Doublet      0
# TAGACCAGTACGAAAT  Doublet      0
# CGTCCATAGCCTTGAT  Doublet      0
#
# [65 rows x 9 columns]

# %%
fig, ax = plt.subplots(figsize=(6, 6), facecolor="white")

ax.plot(range(0, len(df2[ df2.hashID == "Doublet" ])), np.log(df2[ df2.hashID == "Doublet" ].total + 1))
ax.set_ylabel("molecule sum")
ax.set_xlabel("cell barcode")
ax.set_title("Doublets Only")
ax.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
df2[ (df2.hashID == "Doublet") & (df2.total < 10) ]
# Out:
#                   A0301-ACCCACCAGTAAGAC  A0302-GGTCGAGAGCATTCA  \
# CATCAAGAGAATTGTG                      1                      1
# TCTATCATCTCAGCGA                      2                      0
# CATCCACCACCTCGTT                      0                      0
# ATAGACCTCGGTGTTA                      0                      0
# CCGGTAGTCACGACTA                      0                      0
# TGGGCGTGTGAGTGAC                      0                      0
# GGGAGATCAGTTTACG                      0                      0
# CGAGGAAGTGGACCTC                      0                      0
# TGTTCCGGTAAGTGTA                      0                      0
# TCACAAGTCAACTCTT                      0                      0
# GTCGTAATCTGGCCTC                      0                      0
# ATTCTACGTGAGCGAT                      0                      0
# CTACATTCAGGGATTG                      0                      0
# ATGCGATCATGAAGTA                      0                      0
# TTAGGCAGTTCTCATT                      0                      0
# TTGCGTCTCCGTAGTA                      0                      0
# TTTATGCCATCCTTGC                      0                      0
# TTGCGTCGTAATTGGA                      0                      0
# ACGATGTCACGGCGTT                      0                      0
# TGTCCCAGTGGGTATG                      0                      0
# TAGACCAGTACGAAAT                      0                      0
# CGTCCATAGCCTTGAT                      0                      0
#
#                   A0303-CTTGCCGCATGTCAT  A0304-AAAGCATTCTTCACG  \
# CATCAAGAGAATTGTG                      0                      0
# TCTATCATCTCAGCGA                      0                      0
# CATCCACCACCTCGTT                      0                      0
# ATAGACCTCGGTGTTA                      0                      0
# CCGGTAGTCACGACTA                      0                      0
# TGGGCGTGTGAGTGAC                      0                      0
# GGGAGATCAGTTTACG                      0                      0
# CGAGGAAGTGGACCTC                      0                      0
# TGTTCCGGTAAGTGTA                      0                      0
# TCACAAGTCAACTCTT                      0                      0
# GTCGTAATCTGGCCTC                      0                      0
# ATTCTACGTGAGCGAT                      0                      0
# CTACATTCAGGGATTG                      0                      0
# ATGCGATCATGAAGTA                      0                      0
# TTAGGCAGTTCTCATT                      0                      0
# TTGCGTCTCCGTAGTA                      0                      0
# TTTATGCCATCCTTGC                      0                      0
# TTGCGTCGTAATTGGA                      0                      0
# ACGATGTCACGGCGTT                      0                      0
# TGTCCCAGTGGGTATG                      0                      0
# TAGACCAGTACGAAAT                      0                      0
# CGTCCATAGCCTTGAT                      0                      0
#
#                   A0305-CTTTGTCTTTGTGAG  A0306-TATGCTGCCACGGTA  unmapped  \
# CATCAAGAGAATTGTG                      0                      1         0
# TCTATCATCTCAGCGA                      0                      1         0
# CATCCACCACCTCGTT                      0                      0         0
# ATAGACCTCGGTGTTA                      0                      0         0
# CCGGTAGTCACGACTA                      0                      0         0
# TGGGCGTGTGAGTGAC                      0                      0         1
# GGGAGATCAGTTTACG                      0                      0         1
# CGAGGAAGTGGACCTC                      0                      0         1
# TGTTCCGGTAAGTGTA                      0                      0         0
# TCACAAGTCAACTCTT                      0                      0         0
# GTCGTAATCTGGCCTC                      0                      0         0
# ATTCTACGTGAGCGAT                      0                      0         0
# CTACATTCAGGGATTG                      0                      0         0
# ATGCGATCATGAAGTA                      0                      0         0
# TTAGGCAGTTCTCATT                      0                      0         0
# TTGCGTCTCCGTAGTA                      0                      0         1
# TTTATGCCATCCTTGC                      0                      0         0
# TTGCGTCGTAATTGGA                      0                      0         0
# ACGATGTCACGGCGTT                      0                      0         1
# TGTCCCAGTGGGTATG                      0                      0         0
# TAGACCAGTACGAAAT                      0                      0         0
# CGTCCATAGCCTTGAT                      0                      0         1
#
#                    hashID  total
# CATCAAGAGAATTGTG  Doublet      3
# TCTATCATCTCAGCGA  Doublet      3
# CATCCACCACCTCGTT  Doublet      0
# ATAGACCTCGGTGTTA  Doublet      0
# CCGGTAGTCACGACTA  Doublet      0
# TGGGCGTGTGAGTGAC  Doublet      0
# GGGAGATCAGTTTACG  Doublet      0
# CGAGGAAGTGGACCTC  Doublet      0
# TGTTCCGGTAAGTGTA  Doublet      0
# TCACAAGTCAACTCTT  Doublet      0
# GTCGTAATCTGGCCTC  Doublet      0
# ATTCTACGTGAGCGAT  Doublet      0
# CTACATTCAGGGATTG  Doublet      0
# ATGCGATCATGAAGTA  Doublet      0
# TTAGGCAGTTCTCATT  Doublet      0
# TTGCGTCTCCGTAGTA  Doublet      0
# TTTATGCCATCCTTGC  Doublet      0
# TTGCGTCGTAATTGGA  Doublet      0
# ACGATGTCACGGCGTT  Doublet      0
# TGTCCCAGTGGGTATG  Doublet      0
# TAGACCAGTACGAAAT  Doublet      0
# CGTCCATAGCCTTGAT  Doublet      0

# %%
df2[ (df2.hashID == "Doublet") & (df2.total >= 10) ]
# Out:
#                   A0301-ACCCACCAGTAAGAC  A0302-GGTCGAGAGCATTCA  \
# CGTGAATTCGGTAGAG                   7370                     12
# GACTCTCGTGCACAAG                   2944                  15437
# TTCCTAAGTAGGCAGT                   9366                     11
# TTGAACGTCAGCCTCT                   5350                     24
# GTCCTCACACGGTCTG                   5607                     10
# GCCATTCAGTCATGAA                   5664                     13
# TTGTTGTCACTGCATA                   7733                     10
# TTCCGGTTCAACTACG                   6242                     11
# ATTCAGGTCACGGGCT                     25                     16
# GATGCTACAAGCCTGC                   7192                      5
# CGCCAGAGTTGTTGCA                     17                     17
# GGCTTGGCAGAGATTA                     21                     25
# GATAGCTAGCGATGAC                     10                     13
# GGTAATCGTACCAGAG                   7549                      6
# TCTACATCAACTACGT                   6731                     12
# ACAGAAAAGCAGGCAT                   8655                      6
# ATTCAGGTCTCATAGG                   5156                      9
# CAACGGCCATCCGGTG                   5455                      9
# CTCCAACCAACTGTGT                   4698                     12
# ACTGTCCAGGGTGAGG                   6359                      8
# GGCAGTCTCTTCGGTC                   4522                     24
# AACGTCACACTTCAAG                   4773                      7
# CAAAGAAGTGGGCTTC                   5978                      5
# AAAGGATGTTGACTAC                   4069                      7
# AATTTCCAGGATACAT                   5702                     10
# GGGCGTTCACCGTCTT                   4210                      3
# CTCCCTCGTCGCTCGA                   8465                      2
# CTTAGGACATCGTGCG                   7149                      3
# GCGTTTCGTTAGAGTA                   2516                     15
# TTCCTTCCACAACGAG                   1899                      9
# AGACTCACAGAATGTA                   4327                      7
# AAACGAACAGCAGTGA                   1805                      6
# GTCGCGAAGGCCTGCT                   4518                      5
# TCAGGTAAGCCGAACA                    966                      9
# TTCTTCCAGCGCCGTT                    420                      5
# GCACGTGAGTAAGACT                    354                     12
# TAAGTCGTCTAAGCGT                    325                      1
# TTTCACACAGCTATAC                    257                      8
# TTGGATGAGGGACACT                    178                      0
# AGACTCAGTAGCGTTT                    124                      1
# CACACAAAGTGGGAAA                      5                      0
# CCTTCAGCAGGCACTC                      9                      0
# GTAATGCAGGATTTAG                      7                      0
#
#                   A0303-CTTGCCGCATGTCAT  A0304-AAAGCATTCTTCACG  \
# CGTGAATTCGGTAGAG                      3                  11565
# GACTCTCGTGCACAAG                      2                      1
# TTCCTAAGTAGGCAGT                   8739                      8
# TTGAACGTCAGCCTCT                      1                      1
# GTCCTCACACGGTCTG                      2                      1
# GCCATTCAGTCATGAA                      1                      1
# TTGTTGTCACTGCATA                      4                      0
# TTCCGGTTCAACTACG                      3                      1
# ATTCAGGTCACGGGCT                      0                   8729
# GATGCTACAAGCCTGC                      0                      3
# CGCCAGAGTTGTTGCA                   8491                      8
# GGCTTGGCAGAGATTA                   8098                     12
# GATAGCTAGCGATGAC                      2                   9439
# GGTAATCGTACCAGAG                      1                      0
# TCTACATCAACTACGT                      4                      0
# ACAGAAAAGCAGGCAT                      0                      0
# ATTCAGGTCTCATAGG                      2                      0
# CAACGGCCATCCGGTG                      1                      0
# CTCCAACCAACTGTGT                      3                      2
# ACTGTCCAGGGTGAGG                      1                      0
# GGCAGTCTCTTCGGTC                      0                      2
# AACGTCACACTTCAAG                      0                      1
# CAAAGAAGTGGGCTTC                      2                      1
# AAAGGATGTTGACTAC                      5                      2
# AATTTCCAGGATACAT                      2                      3
# GGGCGTTCACCGTCTT                      1                      0
# CTCCCTCGTCGCTCGA                      4                      1
# CTTAGGACATCGTGCG                      3                      1
# GCGTTTCGTTAGAGTA                      0                      0
# TTCCTTCCACAACGAG                      0                      0
# AGACTCACAGAATGTA                      0                      1
# AAACGAACAGCAGTGA                      1                      2
# GTCGCGAAGGCCTGCT                      1                      0
# TCAGGTAAGCCGAACA                      0                      2
# TTCTTCCAGCGCCGTT                      2                      1
# GCACGTGAGTAAGACT                      0                      0
# TAAGTCGTCTAAGCGT                      0                      0
# TTTCACACAGCTATAC                      0                      2
# TTGGATGAGGGACACT                      0                      2
# AGACTCAGTAGCGTTT                      0                      1
# CACACAAAGTGGGAAA                      0                      2
# CCTTCAGCAGGCACTC                      0                      0
# GTAATGCAGGATTTAG                      0                      0
#
#                   A0305-CTTTGTCTTTGTGAG  A0306-TATGCTGCCACGGTA  unmapped  \
# CGTGAATTCGGTAGAG                      0                     20       310
# GACTCTCGTGCACAAG                      0                    157       444
# TTCCTAAGTAGGCAGT                      0                     17       335
# TTGAACGTCAGCCTCT                      0                  12251       413
# GTCCTCACACGGTCTG                      0                   9938       367
# GCCATTCAGTCATGAA                      0                   9350       350
# TTGTTGTCACTGCATA                      0                   6779       299
# TTCCGGTTCAACTACG                      0                   7922       300
# ATTCAGGTCACGGGCT                      0                   5160       268
# GATGCTACAAGCCTGC                      0                   6443       263
# CGCCAGAGTTGTTGCA                      1                   5048       269
# GGCTTGGCAGAGATTA                      0                   5398       276
# GATAGCTAGCGATGAC                      0                   4049       251
# GGTAATCGTACCAGAG                      1                   5880       314
# TCTACATCAACTACGT                      0                   5946       261
# ACAGAAAAGCAGGCAT                      0                   3824       292
# ATTCAGGTCTCATAGG                      0                   6336       221
# CAACGGCCATCCGGTG                      0                   5561       241
# CTCCAACCAACTGTGT                      1                   5981       236
# ACTGTCCAGGGTGAGG                      0                   4289       235
# GGCAGTCTCTTCGGTC                      0                   5375       295
# AACGTCACACTTCAAG                      0                   4925       209
# CAAAGAAGTGGGCTTC                      1                   3586       225
# AAAGGATGTTGACTAC                      0                   5460       239
# AATTTCCAGGATACAT                      0                   3725       225
# GGGCGTTCACCGTCTT                      0                   5149       186
# CTCCCTCGTCGCTCGA                      0                    344       133
# CTTAGGACATCGTGCG                      0                   1281       174
# GCGTTTCGTTAGAGTA                      1                   5872       186
# TTCCTTCCACAACGAG                      0                   6426       221
# AGACTCACAGAATGTA                      1                   3632       178
# AAACGAACAGCAGTGA                      0                   5740       197
# GTCGCGAAGGCCTGCT                      0                   2754       140
# TCAGGTAAGCCGAACA                      0                   6174       187
# TTCTTCCAGCGCCGTT                      0                   5677       134
# GCACGTGAGTAAGACT                      0                   5116       164
# TAAGTCGTCTAAGCGT                      0                   4919       134
# TTTCACACAGCTATAC                      0                   3988       100
# TTGGATGAGGGACACT                      0                     24         4
# AGACTCAGTAGCGTTT                      0                     22         4
# CACACAAAGTGGGAAA                      0                      9         3
# CCTTCAGCAGGCACTC                      0                      5         0
# GTAATGCAGGATTTAG                      0                      5         2
#
#                    hashID  total
# CGTGAATTCGGTAGAG  Doublet  18970
# GACTCTCGTGCACAAG  Doublet  18541
# TTCCTAAGTAGGCAGT  Doublet  18141
# TTGAACGTCAGCCTCT  Doublet  17627
# GTCCTCACACGGTCTG  Doublet  15558
# GCCATTCAGTCATGAA  Doublet  15029
# TTGTTGTCACTGCATA  Doublet  14526
# TTCCGGTTCAACTACG  Doublet  14179
# ATTCAGGTCACGGGCT  Doublet  13930
# GATGCTACAAGCCTGC  Doublet  13643
# CGCCAGAGTTGTTGCA  Doublet  13582
# GGCTTGGCAGAGATTA  Doublet  13554
# GATAGCTAGCGATGAC  Doublet  13513
# GGTAATCGTACCAGAG  Doublet  13437
# TCTACATCAACTACGT  Doublet  12693
# ACAGAAAAGCAGGCAT  Doublet  12485
# ATTCAGGTCTCATAGG  Doublet  11503
# CAACGGCCATCCGGTG  Doublet  11026
# CTCCAACCAACTGTGT  Doublet  10697
# ACTGTCCAGGGTGAGG  Doublet  10657
# GGCAGTCTCTTCGGTC  Doublet   9923
# AACGTCACACTTCAAG  Doublet   9706
# CAAAGAAGTGGGCTTC  Doublet   9573
# AAAGGATGTTGACTAC  Doublet   9543
# AATTTCCAGGATACAT  Doublet   9442
# GGGCGTTCACCGTCTT  Doublet   9363
# CTCCCTCGTCGCTCGA  Doublet   8816
# CTTAGGACATCGTGCG  Doublet   8437
# GCGTTTCGTTAGAGTA  Doublet   8404
# TTCCTTCCACAACGAG  Doublet   8334
# AGACTCACAGAATGTA  Doublet   7968
# AAACGAACAGCAGTGA  Doublet   7554
# GTCGCGAAGGCCTGCT  Doublet   7278
# TCAGGTAAGCCGAACA  Doublet   7151
# TTCTTCCAGCGCCGTT  Doublet   6105
# GCACGTGAGTAAGACT  Doublet   5482
# TAAGTCGTCTAAGCGT  Doublet   5245
# TTTCACACAGCTATAC  Doublet   4255
# TTGGATGAGGGACACT  Doublet    204
# AGACTCAGTAGCGTTT  Doublet    148
# CACACAAAGTGGGAAA  Doublet     16
# CCTTCAGCAGGCACTC  Doublet     14
# GTAATGCAGGATTTAG  Doublet     12

# %% [markdown]
# ## Max vs. Rest Sum

# %%
fig, ax = plt.subplots(figsize=(6, 6), facecolor="white")

df_sorted = pd.DataFrame(
    np.vstack(df2.iloc[:,:-3].apply(lambda row: sorted(row, reverse=True), axis=1)),
    index=df_umi_class.index
)
dfx = df_sorted.copy()
dfx = dfx.assign(rest=df_sorted.iloc[:,1:].sum(axis=1))
dfx = dfx.assign(maxx=df_sorted.max(axis=1))

ax.scatter(range(len(dfx)), dfx.maxx, c="navy", s=5, alpha=0.5, label="max")
ax.scatter(range(len(dfx)), dfx.rest, c="orange", s=5, alpha=0.5, label="rest sum")
ax.legend()
ax.set_title(sample_name)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Classifiy Negatives Using Inflection Points

# %%
def find_inflection_points(umi_sum, window_size=10, window_size2=10):
    
    # skip the first ten points
    umi_sum = umi_sum[10:]
    
    if window_size > 0:
        ms2 = pd.Series(umi_sum).rolling(window_size).mean()
    else:
        ms2 = umi_sum

    d1 = np.diff(ms2)

    if window_size2 > 0:
        ms3 = pd.Series(d1).rolling(window_size2).mean()
        d2 = np.diff(ms3)
    else:
        d2 = np.diff(d1)

    # throw out an extra 5% of cells from where the inflection point is found.
    # these cells are empirically determined to have "transition" library sizes
    # that confound downstream analysis

    inflection_pts = np.where(d2 == 0)[0]

    if len(inflection_pts) == 0:
        # no points have 2nd derivate=0
        # remove nan, abs, and find the one that is most close to zero
        # sort in asending order and pick the first five
        print("plan B")
        inflection_pts = np.argsort(d2[~np.isnan(d2)])[:10]
        inflection_pts = np.sort(inflection_pts)

    return inflection_pts, d1, d2, ms2

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn import metrics

def fit_linear(x, y):
    model = LinearRegression()
    model.fit(x.reshape(-1, 1), y)
    y_pred = model.predict(x.reshape(-1, 1))
    
    return y_pred, model.coef_[0], model.intercept_

def fit_polynomial(x, y):
    polynomial_features= PolynomialFeatures(degree=3)
    X = polynomial_features.fit_transform(x.reshape(-1,1))    
    
    model = LinearRegression()
    model.fit(X, y)
    
    y_pred = model.predict(X)
    
    return y_pred, model.coef_, model.intercept_

# %%
cutoffs = []

fig, ax = plt.subplots(figsize=(6, 6), facecolor="white")
  
x = np.array(range(0, len(df2)))
ms = np.log(df2.total + 1)
inflection_pts, d1, d2, ms2 = find_inflection_points(ms, 10, 10)
y_pred, _, intercept_poly = fit_polynomial(x, ms)    
mse_poly = metrics.mean_squared_error(ms, y_pred)
_, slope, intercept_linear = fit_linear(x, ms)

#     inflection_pt = inflection_pts[0]
#     inflection_pt = inflection_pts[-1]

if intercept_poly < 4:
    inflection_pt = inflection_pts[0]
elif intercept_poly < 5 and mse_poly >= 0.2:
    inflection_pt = inflection_pts[0]
else:
    if slope < -0.003:
        # fixme: we have no good inflection points     
        inflection_pt = int(len(df_umi_class) * 0.95)
    else:
        # 95% point
        inflection_pt = inflection_pts[int(len(inflection_pts)*0.99)]

cutoffs.append(inflection_pt)

ax.plot(range(0, len(df2)), np.log(df2.total + 1))
ax.set_ylabel("molecule sum")
ax.set_xlabel("cell barcode")
ax.vlines(x=inflection_pt, ymin=0, ymax=np.log(np.max(df2.total)), linestyle='--', label="cutoff")
ax.set_title(sample_name)
ax.legend()

plt.show()
# Out:
# plan B

# %%
inflection_pt
# Out:
# 2511

# %%
inflection_pts
# Out:
# array([2498, 2499, 2500, 2502, 2503, 2504, 2505, 2506, 2507, 2511])

# %%
df3 = df2.copy()

# %%
df3 = df3.assign(hashID2=df3.hashID)

# %%
df3
# Out:
#                   A0301-ACCCACCAGTAAGAC  A0302-GGTCGAGAGCATTCA  \
# CGTGAATTCGGTAGAG                   7370                     12
# GACTCTCGTGCACAAG                   2944                  15437
# TTCCTAAGTAGGCAGT                   9366                     11
# TTGAACGTCAGCCTCT                   5350                     24
# ATCCATTGTCGAACAG                  15805                      0
# ...                                 ...                    ...
# TTGCGTCGTAATTGGA                      0                      0
# ACGATGTCACGGCGTT                      0                      0
# TGTCCCAGTGGGTATG                      0                      0
# TAGACCAGTACGAAAT                      0                      0
# CGTCCATAGCCTTGAT                      0                      0
#
#                   A0303-CTTGCCGCATGTCAT  A0304-AAAGCATTCTTCACG  \
# CGTGAATTCGGTAGAG                      3                  11565
# GACTCTCGTGCACAAG                      2                      1
# TTCCTAAGTAGGCAGT                   8739                      8
# TTGAACGTCAGCCTCT                      1                      1
# ATCCATTGTCGAACAG                      6                      1
# ...                                 ...                    ...
# TTGCGTCGTAATTGGA                      0                      0
# ACGATGTCACGGCGTT                      0                      0
# TGTCCCAGTGGGTATG                      0                      0
# TAGACCAGTACGAAAT                      0                      0
# CGTCCATAGCCTTGAT                      0                      0
#
#                   A0305-CTTTGTCTTTGTGAG  A0306-TATGCTGCCACGGTA  unmapped  \
# CGTGAATTCGGTAGAG                      0                     20       310
# GACTCTCGTGCACAAG                      0                    157       444
# TTCCTAAGTAGGCAGT                      0                     17       335
# TTGAACGTCAGCCTCT                      0                  12251       413
# ATCCATTGTCGAACAG                      1                     19       303
# ...                                 ...                    ...       ...
# TTGCGTCGTAATTGGA                      0                      0         0
# ACGATGTCACGGCGTT                      0                      0         1
# TGTCCCAGTGGGTATG                      0                      0         0
# TAGACCAGTACGAAAT                      0                      0         0
# CGTCCATAGCCTTGAT                      0                      0         1
#
#                    hashID  total  hashID2
# CGTGAATTCGGTAGAG  Doublet  18970  Doublet
# GACTCTCGTGCACAAG  Doublet  18541  Doublet
# TTCCTAAGTAGGCAGT  Doublet  18141  Doublet
# TTGAACGTCAGCCTCT  Doublet  17627  Doublet
# ATCCATTGTCGAACAG    A0301  15832    A0301
# ...                   ...    ...      ...
# TTGCGTCGTAATTGGA  Doublet      0  Doublet
# ACGATGTCACGGCGTT  Doublet      0  Doublet
# TGTCCCAGTGGGTATG  Doublet      0  Doublet
# TAGACCAGTACGAAAT  Doublet      0  Doublet
# CGTCCATAGCCTTGAT  Doublet      0  Doublet
#
# [2572 rows x 10 columns]

# %%
df3.loc[ df3[inflection_pt:].index, "hashID2" ] = "Negative"

# %%
df3 = df3.loc[:, list(df_umis.columns) + ["hashID", "hashID2", "total"]]
df3
# Out:
#                   A0301-ACCCACCAGTAAGAC  A0302-GGTCGAGAGCATTCA  \
# CGTGAATTCGGTAGAG                   7370                     12
# GACTCTCGTGCACAAG                   2944                  15437
# TTCCTAAGTAGGCAGT                   9366                     11
# TTGAACGTCAGCCTCT                   5350                     24
# ATCCATTGTCGAACAG                  15805                      0
# ...                                 ...                    ...
# TTGCGTCGTAATTGGA                      0                      0
# ACGATGTCACGGCGTT                      0                      0
# TGTCCCAGTGGGTATG                      0                      0
# TAGACCAGTACGAAAT                      0                      0
# CGTCCATAGCCTTGAT                      0                      0
#
#                   A0303-CTTGCCGCATGTCAT  A0304-AAAGCATTCTTCACG  \
# CGTGAATTCGGTAGAG                      3                  11565
# GACTCTCGTGCACAAG                      2                      1
# TTCCTAAGTAGGCAGT                   8739                      8
# TTGAACGTCAGCCTCT                      1                      1
# ATCCATTGTCGAACAG                      6                      1
# ...                                 ...                    ...
# TTGCGTCGTAATTGGA                      0                      0
# ACGATGTCACGGCGTT                      0                      0
# TGTCCCAGTGGGTATG                      0                      0
# TAGACCAGTACGAAAT                      0                      0
# CGTCCATAGCCTTGAT                      0                      0
#
#                   A0305-CTTTGTCTTTGTGAG  A0306-TATGCTGCCACGGTA  unmapped  \
# CGTGAATTCGGTAGAG                      0                     20       310
# GACTCTCGTGCACAAG                      0                    157       444
# TTCCTAAGTAGGCAGT                      0                     17       335
# TTGAACGTCAGCCTCT                      0                  12251       413
# ATCCATTGTCGAACAG                      1                     19       303
# ...                                 ...                    ...       ...
# TTGCGTCGTAATTGGA                      0                      0         0
# ACGATGTCACGGCGTT                      0                      0         1
# TGTCCCAGTGGGTATG                      0                      0         0
# TAGACCAGTACGAAAT                      0                      0         0
# CGTCCATAGCCTTGAT                      0                      0         1
#
#                    hashID   hashID2  total
# CGTGAATTCGGTAGAG  Doublet   Doublet  18970
# GACTCTCGTGCACAAG  Doublet   Doublet  18541
# TTCCTAAGTAGGCAGT  Doublet   Doublet  18141
# TTGAACGTCAGCCTCT  Doublet   Doublet  17627
# ATCCATTGTCGAACAG    A0301     A0301  15832
# ...                   ...       ...    ...
# TTGCGTCGTAATTGGA  Doublet  Negative      0
# ACGATGTCACGGCGTT  Doublet  Negative      0
# TGTCCCAGTGGGTATG  Doublet  Negative      0
# TAGACCAGTACGAAAT  Doublet  Negative      0
# CGTCCATAGCCTTGAT  Doublet  Negative      0
#
# [2572 rows x 10 columns]

# %%
# before
df3.groupby("hashID").size()
# Out:
# hashID
# A0301       745
# A0302        21
# A0303        25
# A0304        16
# A0305        40
# A0306      1660
# Doublet      65
# dtype: int64

# %%
# after
df3.groupby("hashID2").size()
# Out:
# hashID2
# A0301        731
# A0302         20
# A0303         25
# A0304         16
# A0305         37
# A0306       1644
# Doublet       38
# Negative      61
# dtype: int64

# %%
df3_difference = df3[ df3.hashID != df3.hashID2 ]
df3_difference
# Out:
#                   A0301-ACCCACCAGTAAGAC  A0302-GGTCGAGAGCATTCA  \
# AAGCGTTAGATGTTGA                      2                      1
# CTGAGCGAGAGTCAAT                      3                      1
# TCTGTCGGTGCATGAG                      8                      0
# TTGCGTCGTGGTATGG                      0                      0
# AAGTCGTTCACACCCT                    601                      0
# ...                                 ...                    ...
# TTGCGTCGTAATTGGA                      0                      0
# ACGATGTCACGGCGTT                      0                      0
# TGTCCCAGTGGGTATG                      0                      0
# TAGACCAGTACGAAAT                      0                      0
# CGTCCATAGCCTTGAT                      0                      0
#
#                   A0303-CTTGCCGCATGTCAT  A0304-AAAGCATTCTTCACG  \
# AAGCGTTAGATGTTGA                      0                      0
# CTGAGCGAGAGTCAAT                      0                      0
# TCTGTCGGTGCATGAG                      0                      1
# TTGCGTCGTGGTATGG                      0                      0
# AAGTCGTTCACACCCT                      0                      0
# ...                                 ...                    ...
# TTGCGTCGTAATTGGA                      0                      0
# ACGATGTCACGGCGTT                      0                      0
# TGTCCCAGTGGGTATG                      0                      0
# TAGACCAGTACGAAAT                      0                      0
# CGTCCATAGCCTTGAT                      0                      0
#
#                   A0305-CTTTGTCTTTGTGAG  A0306-TATGCTGCCACGGTA  unmapped  \
# AAGCGTTAGATGTTGA                    676                      4        11
# CTGAGCGAGAGTCAAT                      0                    630        12
# TCTGTCGGTGCATGAG                    610                      6        16
# TTGCGTCGTGGTATGG                      0                    612        14
# AAGTCGTTCACACCCT                      0                      3        13
# ...                                 ...                    ...       ...
# TTGCGTCGTAATTGGA                      0                      0         0
# ACGATGTCACGGCGTT                      0                      0         1
# TGTCCCAGTGGGTATG                      0                      0         0
# TAGACCAGTACGAAAT                      0                      0         0
# CGTCCATAGCCTTGAT                      0                      0         1
#
#                    hashID   hashID2  total
# AAGCGTTAGATGTTGA    A0305  Negative    683
# CTGAGCGAGAGTCAAT    A0306  Negative    634
# TCTGTCGGTGCATGAG    A0305  Negative    625
# TTGCGTCGTGGTATGG    A0306  Negative    612
# AAGTCGTTCACACCCT    A0301  Negative    604
# ...                   ...       ...    ...
# TTGCGTCGTAATTGGA  Doublet  Negative      0
# ACGATGTCACGGCGTT  Doublet  Negative      0
# TGTCCCAGTGGGTATG  Doublet  Negative      0
# TAGACCAGTACGAAAT  Doublet  Negative      0
# CGTCCATAGCCTTGAT  Doublet  Negative      0
#
# [61 rows x 10 columns]

# %%
df3_difference.groupby(["hashID", "hashID2"]).size()
# Out:
# hashID   hashID2
# A0301    Negative    14
# A0302    Negative     1
# A0305    Negative     3
# A0306    Negative    16
# Doublet  Negative    27
# dtype: int64

# %% [markdown]
# ## UMAP

# %%
def clr_normalize_each_cell(adata, inplace=True):
    """Normalize count vector for each cell, i.e. for each row of .X"""

    import numpy as np
    import scipy

    def seurat_clr(x):
        # TODO: support sparseness
        s = np.sum(np.log1p(x[x > 0]))
        exp = np.exp(s / len(x))
        return np.log1p(x / exp)

    if not inplace:
        adata = adata.copy()

    # apply to dense or sparse matrix, along axis. returns dense matrix
    adata.X = np.apply_along_axis(
        seurat_clr, 1, (adata.X.A if scipy.sparse.issparse(adata.X) else adata.X)
    )
    return adata

# %%
import scanpy as sc

# %%
sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.settings.set_figure_params(dpi=80, facecolor='white')

# %%
adata = sc.AnnData(
    X=df_umis.iloc[:, :-1]
)

# %%
adata.raw = adata

# %%
clr_normalize_each_cell(adata)
# Out:
# AnnData object with n_obs × n_vars = 2572 × 6

# %%
sc.pp.log1p(adata)

# %%
sc.pp.neighbors(adata)
# Out:
# computing neighbors
#     using data matrix X directly
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:03)

# %%
sc.tl.leiden(adata, resolution=0.05, random_state=42)
# Out:
# running Leiden clustering
#     finished: found 8 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:00)

# %%
sc.tl.umap(adata)
# Out:
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:04)

# %%
fig, axs = plt.subplots(ncols=2, figsize=(12,6))

sc.pl.umap(
    adata,
    color=["leiden"],
    ax=axs[0], show=False
)

sc.pl.umap(
    adata,
    color=["leiden"],
    legend_loc="on data",
    legend_fontsize=15,
    legend_fontoutline=5,
    ax=axs[1], show=False
)

plt.tight_layout()
plt.show()

# %%
adata.obs["hashID"] = df3.hashID
adata.obs["hashID2"] = df3.hashID2

# %%
fig, axs = plt.subplots(ncols=2, figsize=(12,6))

sc.pl.umap(
    adata,
    color=["hashID"],
    ax=axs[0], show=False
)

sc.pl.umap(
    adata,
    color=["hashID"],
    legend_loc="on data",
    legend_fontsize=10,
    legend_fontoutline=5,
    ax=axs[1], show=False
)

plt.tight_layout()
plt.show()
# Out:
# /Users/chunj/opt/miniconda3/envs/sharp/lib/python3.7/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])
# ... storing 'hashID' as categorical
# ... storing 'hashID2' as categorical

# %%
fig, axs = plt.subplots(ncols=2, figsize=(12,6))

sc.pl.umap(
    adata,
    color=["hashID2"],
    ax=axs[0], show=False
)

sc.pl.umap(
    adata,
    color=["hashID2"],
    legend_loc="on data",
    legend_fontsize=10,
    legend_fontoutline=5,
    ax=axs[1], show=False
)

plt.tight_layout()
plt.show()

# %%
from matplotlib.colors import ListedColormap

my_cmap1 = ListedColormap(sns.color_palette("Blues").as_hex())
my_cmap2 = sns.color_palette("Paired").as_hex()
my_cmap2[0] = "lightgray"
my_cmap2 = ListedColormap(my_cmap2)

# %%
sc.pl.umap(
    adata,
    color=df_umis.columns[:-1],
    color_map=my_cmap1,
    size=30,
    ncols=3,
)

# %%
sc.pl.umap(
    adata,
    color=df_umis.columns[:-1],
    color_map=my_cmap2,
    size=30,
    ncols=3,
)
