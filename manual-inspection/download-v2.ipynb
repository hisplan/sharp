# %%
import os
import json

import requests
from requests.exceptions import HTTPError
from requests.auth import HTTPBasicAuth

# %% [markdown]
# ## Parameters

# %%
# this cell is tagged `parameters` and will be overridden by papermill
workflow_name = "asapseq"
workflow_id = "dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6"

path_secrets_file = "/Users/chunj/keys/cromwell-secrets-aws-nvirginia.json"
path_base_data = "./asapseq"
skip_download = False

# %%
# name conversion to match the actually WDL workflow name
names = {
    "hashtag": "Hashtag",
    "citeseq": "CiteSeq",
    "asapseq": "AsapSeq",
    "cellplex": "Hashtag"
}

# %%
workflow_name = names[workflow_name]
workflow_name
# Out:
# 'AsapSeq'

# %% [markdown]
# ## APIs to Cromwell

# %%
def get_secrets(path_secrets_file):

    with open(path_secrets_file, "rt") as fin:
        data = json.loads(fin.read())

    return data

def prep_api_call(secrets):

    api_version = "v1"
    url = secrets["url"]
    url = f"{url}/api/workflows/{api_version}"

    auth = HTTPBasicAuth(secrets["username"], secrets["password"])

    return url, auth

def get_metadata(secrets, workflow_id):

    base_url, auth = prep_api_call(secrets)

    try:
        response = requests.patch(
            url=f"{base_url}/{workflow_id}/metadata?expandSubWorkflows=true",
            headers={
                "Content-Type": "application/json",
                "Accept": "application/json"
            },
            auth=auth
        )

        # if response.status_code == 200:
        data = response.json()

        return data

    except HTTPError as err:
        print(err)

# %% [markdown]
# ## Get Metadata

# %%
metadata = get_metadata(
    get_secrets(path_secrets_file),
    workflow_id
)

# %%
print(json.dumps(metadata, indent=2))
# Out:
# {
#   "workflowName": "AsapSeq",
#   "workflowProcessingEvents": [
#     {
#       "cromwellId": "cromid-aa4a0ba",
#       "description": "Finished",
#       "timestamp": "2021-07-26T03:55:21.758Z",
#       "cromwellVersion": "59"
#     },
#     {
#       "cromwellId": "cromid-aa4a0ba",
#       "description": "PickedUp",
#       "timestamp": "2021-07-26T03:20:46.992Z",
#       "cromwellVersion": "59"
#     }
#   ],
#   "metadataSource": "Unarchived",
#   "actualWorkflowLanguageVersion": "1.0",
#   "submittedFiles": {
#     "workflow": "version 1.0\n\nimport \"modules/Preprocess.wdl\" as Preprocess\nimport \"modules/HtoDemuxSeurat.wdl\" as HtoDemuxSeurat\nimport \"modules/HtoDemuxKMeans.wdl\" as HtoDemuxKMeans\nimport \"modules/ReformatFastq.wdl\" as ReformatFastq\nimport \"modules/AnnData.wdl\" as AnnData\n\nworkflow AsapSeq {\n\n    input {\n        Array[File] fastqR1\n        Array[File] fastqR2\n        Array[File] fastqR3\n\n        String conjugation = \"TotalSeqA\"\n        Boolean noReverseComplementR2 = false\n\n        Int lengthR1\n        Int lengthR2\n\n        String sampleName\n\n        File cellBarcodeWhitelistUri\n        String cellBarcodeWhiteListMethod\n\n        # set to false if TotalSeq-A is used\n        # set to true if TotalSeq-B or C is used\n        Boolean translate10XBarcodes\n\n        String scRnaSeqPlatform = \"10x_v3\"\n\n        File hashTagList\n\n        # cellular barcode start/end positions\n        Int cbStartPos\n        Int cbEndPos\n\n        # UMI start/end positions\n        Int umiStartPos\n        Int umiEndPos\n\n        # how many bases should we trim before starting to look for hashtag sequence\n        Int trimPos = 0\n\n        # activate sliding window alignement\n        Boolean slidingWindowSearch = false\n\n        # correction\n        Int cbCollapsingDistance\n        Int umiCollapsingDistance\n        Int maxTagError = 2\n\n        Int numExpectedCells\n\n        Boolean runSeuratDemux = false\n        Int demuxMode = 1\n        Int minCount = 0\n\n        Map[String, Int] resourceSpec\n\n        # docker-related\n        String dockerRegistry\n    }\n\n    parameter_meta {\n        demuxMode: { help: \"1=default, 2=noisy methanol, 3=aggressively rescue from doublets\" }\n    }\n\n    call ReformatFastq.ReformatAsapSeqFastq {\n        input:\n            fastqR1 = fastqR1,\n            fastqR2 = fastqR2,\n            fastqR3 = fastqR3,\n            sampleName = sampleName,\n            conjugation = conjugation,\n            noReverseComplementR2 = noReverseComplementR2,\n            numCores = 4,\n            dockerRegistry = dockerRegistry\n    }\n\n    call Preprocess.Preprocess {\n        input:\n            uriFastqR1 = [ReformatAsapSeqFastq.outFastqR1],\n            uriFastqR2 = [ReformatAsapSeqFastq.outFastqR2],\n            lengthR1 = lengthR1,\n            lengthR2 = lengthR2,\n            sampleName = sampleName,\n            cellBarcodeWhitelistUri = cellBarcodeWhitelistUri,\n            cellBarcodeWhiteListMethod = cellBarcodeWhiteListMethod,\n            translate10XBarcodes = translate10XBarcodes,\n            scRnaSeqPlatform = scRnaSeqPlatform,\n            tagList = hashTagList,\n            cbStartPos = cbStartPos,\n            cbEndPos = cbEndPos,\n            umiStartPos = umiStartPos,\n            umiEndPos = umiEndPos,\n            trimPos = trimPos,\n            slidingWindowSearch = slidingWindowSearch,\n            cbCollapsingDistance = cbCollapsingDistance,\n            umiCollapsingDistance = umiCollapsingDistance,\n            maxTagError = maxTagError,\n            numExpectedCells = numExpectedCells,\n            resourceSpec = resourceSpec,\n            dockerRegistry = dockerRegistry\n    }\n\n    # HTO demux using KMeans\n    call HtoDemuxKMeans.HtoDemuxKMeans {\n        input:\n            umiCountFiles = Preprocess.umiCountMatrix,\n            minCount = minCount,\n            mode = demuxMode,\n            dockerRegistry = dockerRegistry\n    }\n\n    # HTO demux using Seurat\n    if (runSeuratDemux == true) {\n\n        call HtoDemuxSeurat.HtoDemuxSeurat {\n            input:\n                umiCountFiles = Preprocess.umiCountMatrix,\n                quantile = 0.99,\n                dockerRegistry = dockerRegistry\n        }\n\n        # correct false positive doublets frm Seurat output\n        call HtoDemuxSeurat.CorrectFalsePositiveDoublets {\n            input:\n                htoClassification = HtoDemuxSeurat.outClassCsv,\n              ...
#     "root": "",
#     "options": "{\n  \"default_runtime_attributes\": {\n    \"maxRetries\": 3\n  },\n  \"write_to_cache\": true,\n  \"workflow_failure_mode\": \"ContinueWhilePossible\",\n  \"read_from_cache\": true,\n  \"monitoring_script\": \"s3://dp-lab-batch/monitoring.sh\"\n}",
#     "inputs": "{\"AsapSeq.cbCollapsingDistance\":1,\"AsapSeq.cbEndPos\":16,\"AsapSeq.cbStartPos\":1,\"AsapSeq.cellBarcodeWhiteListMethod\":\"10x\",\"AsapSeq.cellBarcodeWhitelistUri\":\"s3://dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC/CR-results/count/outs/filtered_peak_bc_matrix/barcodes.tsv\",\"AsapSeq.conjugation\":\"TotalSeqA\",\"AsapSeq.dockerRegistry\":\"hisplan\",\"AsapSeq.fastqR1\":[\"s3://dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC_HTO/FASTQ/ASAPseq_test_HTO_IGO_11671_3_S3_L001_R1_001.fastq.gz\",\"s3://dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC_HTO/FASTQ/ASAPseq_test_HTO_IGO_11671_3_S3_L002_R1_001.fastq.gz\"],\"AsapSeq.fastqR2\":[\"s3://dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC_HTO/FASTQ/ASAPseq_test_HTO_IGO_11671_3_S3_L001_R2_001.fastq.gz\",\"s3://dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC_HTO/FASTQ/ASAPseq_test_HTO_IGO_11671_3_S3_L002_R2_001.fastq.gz\"],\"AsapSeq.fastqR3\":[\"s3://dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC_HTO/FASTQ/ASAPseq_test_HTO_IGO_11671_3_S3_L001_R3_001.fastq.gz\",\"s3://dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC_HTO/FASTQ/ASAPseq_test_HTO_IGO_11671_3_S3_L002_R3_001.fastq.gz\"],\"AsapSeq.hashTagList\":\"s3://dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC_HTO/Hashtag_results/tag-list.csv\",\"AsapSeq.lengthR1\":26,\"AsapSeq.lengthR2\":15,\"AsapSeq.noReverseComplementR2\":false,\"AsapSeq.numExpectedCells\":0,\"AsapSeq.resourceSpec\":{\"cpu\":4,\"memory\":-1},\"AsapSeq.sampleName\":\"ASAPseq_test_HTO_IGO_11671_3\",\"AsapSeq.translate10XBarcodes\":false,\"AsapSeq.umiCollapsingDistance\":1,\"AsapSeq.umiEndPos\":26,\"AsapSeq.umiStartPos\":17}",
#     "workflowUrl": "",
#     "labels": "{\n    \"pipelineType\": \"ASAP-seq\",\n    \"project\": \"TechDev\",\n    \"sample\": \"asapseq-test\",\n    \"owner\": \"chunj\",\n    \"destination\": \"s3://dp-lab-test/sharp/asap-seq/TSA/\",\n    \"transfer\": \"-\",\n    \"comment\": \"ASAP-seq TSA\"    \n}\n"
#   },
#   "calls": {
#     "AsapSeq.UpdateAnnData": [
#       {
#         "executionStatus": "Done",
#         "stdout": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-UpdateAnnData/UpdateAnnData-stdout.log",
#         "backendStatus": "Succeeded",
#         "compressedDockerSize": 585162468,
#         "commandLine": "set -euo pipefail\n\nmv /cromwell_root/dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-ToAnnData/ASAPseq_test_HTO_IGO_11671_3.h5ad adata-in.h5ad\n\npython3 /opt/update_adata.py \\\n    --class /cromwell_root/dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-HtoDemuxKMeans/classification.tsv.gz \\\n    --adata-in adata-in.h5ad \\\n    --adata-out ASAPseq_test_HTO_IGO_11671_3.h5ad \\\n    --hto-gex-mapper /opt/data/10x-hto-gex-mapper.pickle",
#         "shardIndex": -1,
#         "outputs": {
#           "outAdata": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-UpdateAnnData/ASAPseq_test_HTO_IGO_11671_3.h5ad",
#           "outLog": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-UpdateAnnData/update_adata.log"
#         },
#         "runtimeAttributes": {
#           "failOnStderr": "false",
#           "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/priority-gwf-core",
#           "disks": "local-disk /cromwell_root",
#           "continueOnReturnCode": "0",
#           "docker": "hisplan/cromwell-hto-adt-postprocess:0.3.3",
#           "scriptBucketName": "dp-lab-gwf-core",
#           "maxRetries": "3",
#           "cpu": "1",
#           "cpuMin": "1",
#           "noAddress": "false",
#           "zones": "us-east-1a",
#           "memoryMin": "2 GB",
#           "memory": "8 GB"
#         },
#         "callCaching": {
#           "allowResultReuse": true,
#           "hit": false,
#           "result": "Cache Miss",
#           "hashes": {
#             "output count": "C81E728D9D4C2F636F067F89CC14862C",
#             "runtime attribute": {
#               "docker": "C0453230DDCB45B1A0824557B543F5BD",
#               "continueOnReturnCode": "CFCD208495D565EF66E7DFF9F98764DA",
#               "failOnStderr": "68934A3E9455FA72420237EB05902327"
#             },
#             "output expression": {
#               "File outAdata": "4EE81D5D24C9A4E1282BD6EB8F6B1795",
#               "File outLog": "63B662C702F6B88F7FE3F5945CDB2807"
#             },
#             "input count": "C9F0F895FB98AB9159F51FD0297E236D",
#             "backend name": "2267EF43AEF6BB551F414FEC2390F68A",
#             "command template": "3DF6D6BA771231FB653F4E97626EF766",
#             "input": {
#               "String dockerImage": "3DC154285188BAE455441FA11F0ABE76",
#               "Boolean translate10XBarcodes": "68934A3E9455FA72420237EB05902327",
#               "File htoClassification": "\"78d776bace97130b62385534a27df181\"",
#               "String sampleName": "2A9B9BAE1D763C2C9BF73C2672EF48A7",
#               "Float inputSize": "2153278AE9DC76911279FD9A39CFE5D6",
#               "File adata": "\"494890e3d32e28763e56f8b666f816b2\"",
#               "String dockerRegistry": "38A1E69002366B36B0025741498F4427",
#               "Int numCores": "C4CA4238A0B923820DCC509A6F75849B"
#             }
#           },
#           "effectiveCallCachingMode": "ReadAndWriteCache"
#         },
#         "inputs": {
#           "adata": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-ToAnnData/ASAPseq_test_HTO_IGO_11671_3.h5ad",
#           "sampleName": "ASAPseq_test_HTO_IGO_11671_3",
#           "dockerRegistry": "hisplan",
#           "dockerImage": "hisplan/cromwell-hto-adt-postprocess:0.3.3",
#           "htoClassification": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-HtoDemuxKMeans/classification.tsv.gz",
#           "inputSize": 0.0025334246456623077,
#           "translate10XBarcodes": false,
#           "numCores": 1
#         },
#         "returnCode": 0,
#         "jobId": "54eff014-03e2-4bb4-8228-79381ab62fa8",
#         "backend": "AWSBATCH",
#         "end": "2021-07-26T03:55:20.689Z",
#         "dockerImageUsed": "hisplan/cromwell-hto-adt-postprocess@sha256:76d06cd1d3619199f234729eae40e551f2954b8720ca6b57663aa72c77472ebd",
#         "stderr": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-UpdateAnnData/UpdateAnnData-stderr.log",
#         "callRoot": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-UpdateAnnData",
#         "attempt": 1,
#         "executionEvents": [
#           {
#             "startTime": "2021-07-26T03:53:56.875Z",
#             "description": "WaitingForValueStore",
#             "endTime": "2021-07-26T03:53:56.875Z"
#           },
#           {
#             "startTime": "2021-07-26T03:55:19.714Z",
#             "description": "UpdatingJobStore",
#             "endTime": "2021-07-26T03:55:20.689Z"
#           },
#           {
#             "startTime": "2021-07-26T03:53:57.074Z",
#             "description": "RunningJob",
#             "endTime": "2021-07-26T03:55:19.585Z"
#           },
#           {
#             "startTime": "2021-07-26T03:55:19.585Z",
#             "description": "UpdatingCallCache",
#             "endTime": "2021-07-26T03:55:19.714Z"
#           },
#           {
#             "startTime": "2021-07-26T03:53:57.056Z",
#             "description": "CallCacheReading",
#             "endTime": "2021-07-26T03:53:57.074Z"
#           },
#           {
#             "startTime": "2021-07-26T03:53:56.875Z",
#             "description": "PreparingJob",
#             "endTime": "2021-07-26T03:53:57.056Z"
#           },
#           {
#             "startTime": "2021-07-26T03:53:55.076Z",
#             "description": "RequestingExecutionToken",
#             "endTime": "2021-07-26T03:53:56.875Z"
#           },
#           {
#             "startTime": "2021-07-26T03:53:55.076Z",
#             "description": "Pending",
#             "endTime": "2021-07-26T03:53:55.076Z"
#           }
#         ],
#         "start": "2021-07-26T03:53:55.075Z"
#       }
#     ],
#     "AsapSeq.ReformatAsapSeqFastq": [
#       {
#         "executionStatus": "Done",
#         "stdout": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-ReformatAsapSeqFastq/ReformatAsapSeqFastq-stdout.log",
#         "compressedDockerSize": 206663891,
#         "shardIndex": -1,
#         "outputs": {
#           "outFastqR2": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-ReformatAsapSeqFastq/cacheCopy/ASAPseq_test_HTO_IGO_11671_3_R2.fastq.gz",
#           "outFastqR1": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-ReformatAsapSeqFastq/cacheCopy/ASAPseq_test_HTO_IGO_11671_3_R1.fastq.gz"
#         },
#         "runtimeAttributes": {
#           "failOnStderr": "false",
#           "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/priority-gwf-core",
#           "disks": "local-disk /cromwell_root",
#           "continueOnReturnCode": "0",
#           "docker": "hisplan/cromwell-asap2kite:0.0.1",
#           "scriptBucketName": "dp-lab-gwf-core",
#           "maxRetries": "3",
#           "cpu": "4",
#           "cpuMin": "1",
#           "noAddress": "false",
#           "zones": "us-east-1a",
#           "memoryMin": "2 GB",
#           "memory": "64 GB"
#         },
#         "callCaching": {
#           "allowResultReuse": true,
#           "hit": true,
#           "result": "Cache Hit: 831524c5-090f-422e-9501-30d04ead148f:AsapSeq.ReformatAsapSeqFastq:-1",
#           "hashes": {
#             "output count": "C81E728D9D4C2F636F067F89CC14862C",
#             "runtime attribute": {
#               "docker": "07E14F3257B7FA62A180034BEFFECE7E",
#               "continueOnReturnCode": "CFCD208495D565EF66E7DFF9F98764DA",
#               "failOnStderr": "68934A3E9455FA72420237EB05902327"
#             },
#             "output expression": {
#               "File outFastqR2": "07E852AE12CBE427155E5AFE90DB7E7B",
#               "File outFastqR1": "DD2EFDAB82D359C003845F73A6BC6013"
#             },
#             "input count": "C51CE410C124A10E0DB5E4B97FC2AF39",
#             "backend name": "2267EF43AEF6BB551F414FEC2390F68A",
#             "command template": "B75223166BD5A1B78F2C6BCFDF6910FA",
#             "input": {
#               "String dockerImage": "82F19720F1BD6F5E679A674CD0A600EC",
#               "String conjugation": "98309F1A096505E8E766F18A40441367",
#               "String sampleName": "2A9B9BAE1D763C2C9BF73C2672EF48A7",
#               "Float inputSize": "E4C3B9741C9E1AE00F10033DBF6BBD01",
#               "File fastqR2": [
#                 "\"b4e01b71530d3b41166ff27b6bafec00-40\"",
#                 "\"e5437f4e6b8cdbcc8ef32d89ed2d5f78-40\""
#               ],
#               "File fastqR1": [
#                 "\"cd0190d5f229d7f2985c361b9d7a2da6-64\"",
#                 "\"da23cfb5801582d1ff932a49a3ee8b0e-62\""
#               ],
#               "File fastqR3": [
#                 "\"b98d1fe056bd2abf426174b40cf40d51-54\"",
#                 "\"e0263e0df82c8904125b62a8e81c008b-53\""
#               ],
#               "String dockerRegistry": "38A1E69002366B36B0025741498F4427",
#               "Boolean noReverseComplementR2": "68934A3E9455FA72420237EB05902327",
#               "Int numCores": "A87FF679A2F3E71D9181A67B7542122C"
#             }
#           },
#           "effectiveCallCachingMode": "ReadAndWriteCache"
#         },
#         "inputs": {
#           "fastqR3": [
#             "s3://dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC_HTO/FASTQ/ASAPseq_test_HTO_IGO_11671_3_S3_L001_R3_001.fastq.gz",
#             "s3://dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC_HTO/FASTQ/ASAPseq_test_HTO_IGO_11671_3_S3_L002_R3_001.fastq.gz"
#           ],
#           "sampleName": "ASAPseq_test_HTO_IGO_11671_3",
#           "conjugation": "TotalSeqA",
#           "noReverseComplementR2": false,
#           "fastqR2": [
#             "s3://dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC_HTO/FASTQ/ASAPseq_test_HTO_IGO_11671_3_S3_L001_R2_001.fastq.gz",
#             "s3://dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC_HTO/FASTQ/ASAPseq_test_HTO_IGO_11671_3_S3_L002_R2_001.fastq.gz"
#           ],
#           "dockerRegistry": "hisplan",
#           "dockerImage": "hisplan/cromwell-asap2kite:0.0.1",
#           "fastqR1": [
#             "s3://dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC_HTO/FASTQ/ASAPseq_test_HTO_IGO_11671_3_S3_L001_R1_001.fastq.gz",
#             "s3://dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC_HTO/FASTQ/ASAPseq_test_HTO_IGO_11671_3_S3_L002_R1_001.fastq.gz"
#           ],
#           "inputSize": 2.417165263555944,
#           "numCores": 4
#         },
#         "returnCode": 0,
#         "backend": "AWSBATCH",
#         "end": "2021-07-26T03:21:20.681Z",
#         "stderr": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-ReformatAsapSeqFastq/ReformatAsapSeqFastq-stderr.log",
#         "callRoot": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-ReformatAsapSeqFastq",
#         "attempt": 1,
#         "executionEvents": [
#           {
#             "startTime": "2021-07-26T03:21:17.709Z",
#             "description": "UpdatingCallCache",
#             "endTime": "2021-07-26T03:21:19.702Z"
#           },
#           {
#             "startTime": "2021-07-26T03:20:50.875Z",
#             "description": "PreparingJob",
#             "endTime": "2021-07-26T03:20:51.569Z"
#           },
#           {
#             "startTime": "2021-07-26T03:20:49.286Z",
#             "description": "Pending",
#             "endTime": "2021-07-26T03:20:49.286Z"
#           },
#           {
#             "startTime": "2021-07-26T03:20:50.875Z",
#             "description": "WaitingForValueStore",
#             "endTime": "2021-07-26T03:20:50.875Z"
#           },
#           {
#             "startTime": "2021-07-26T03:20:51.569Z",
#             "description": "CallCacheReading",
#             "endTime": "2021-07-26T03:21:17.709Z"
#           },
#           {
#             "startTime": "2021-07-26T03:20:49.286Z",
#             "description": "RequestingExecutionToken",
#             "endTime": "2021-07-26T03:20:50.875Z"
#           },
#           {
#             "startTime": "2021-07-26T03:21:19.702Z",
#             "description": "UpdatingJobStore",
#             "endTime": "2021-07-26T03:21:20.681Z"
#           }
#         ],
#         "start": "2021-07-26T03:20:49.286Z"
#       }
#     ],
#     "AsapSeq.Preprocess": [
#       {
#         "executionStatus": "Done",
#         "subWorkflowMetadata": {
#           "workflowName": "Preprocess",
#           "rootWorkflowId": "dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6",
#           "calls": {
#             "Preprocess.WhitelistFrom10x": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-WhitelistFrom10x/WhitelistFrom10x-stdout.log",
#                 "compressedDockerSize": 344006073,
#                 "shardIndex": -1,
#                 "outputs": {
#                   "outLog": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-WhitelistFrom10x/cacheCopy/extract_barcodes.log",
#                   "outFilteredBarcodes1234": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-WhitelistFrom10x/cacheCopy/results/barcodes.1234.txt",
#                   "outFilteredBarcodesACGT": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-WhitelistFrom10x/cacheCopy/results/barcodes.acgt.txt"
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/priority-gwf-core",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "hisplan/seqc-utils:0.5.0",
#                   "scriptBucketName": "dp-lab-gwf-core",
#                   "maxRetries": "3",
#                   "cpu": "1",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "16 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": true,
#                   "hit": true,
#                   "result": "Cache Hit: 968e1d93-8cb3-4b19-b44a-d97f48e8aabd:Preprocess.WhitelistFrom10x:-1",
#                   "hashes": {
#                     "output count": "ECCBC87E4B5CE2FE28308FD9F2A7BAF3",
#                     "runtime attribute": {
#                       "docker": "D99C98A9A6331BD36B1E499721055180",
#                       "continueOnReturnCode": "CFCD208495D565EF66E7DFF9F98764DA",
#                       "failOnStderr": "68934A3E9455FA72420237EB05902327"
#                     },
#                     "output expression": {
#                       "File outFilteredBarcodes1234": "3858BD235BDDDCA25E090008DBE0FD17",
#                       "File outLog": "DEE4323306C5E1FC5A37F5F10241ED3B",
#                       "File outFilteredBarcodesACGT": "25768AA7878FD052AC2001733508EBE9"
#                     },
#                     "input count": "A87FF679A2F3E71D9181A67B7542122C",
#                     "backend name": "2267EF43AEF6BB551F414FEC2390F68A",
#                     "command template": "0C1BD7A3CE2C2E467F10C038079BDEF3",
#                     "input": {
#                       "File filteredBarcodes": "\"1b0545f029aa3ac75e4b2b6c3377fd91\"",
#                       "String dockerRegistry": "38A1E69002366B36B0025741498F4427",
#                       "String dockerImage": "A2F3547A964E4F13F4639D4CB3E4220C",
#                       "Float inputSize": "B2EF3C592A92DFA834A1C70DC1F554B5"
#                     }
#                   },
#                   "effectiveCallCachingMode": "ReadAndWriteCache"
#                 },
#                 "inputs": {
#                   "filteredBarcodes": "s3://dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC/CR-results/count/outs/filtered_peak_bc_matrix/barcodes.tsv",
#                   "dockerRegistry": "hisplan",
#                   "dockerImage": "hisplan/seqc-utils:0.5.0",
#                   "inputSize": 0.00031529180705547333
#                 },
#                 "returnCode": 0,
#                 "backend": "AWSBATCH",
#                 "end": "2021-07-26T03:21:32.685Z",
#                 "stderr": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-WhitelistFrom10x/WhitelistFrom10x-stderr.log",
#                 "callRoot": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-WhitelistFrom10x",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2021-07-26T03:21:28.874Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2021-07-26T03:21:28.875Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:21:26.055Z",
#                     "description": "Pending",
#                     "endTime": "2021-07-26T03:21:26.055Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:21:28.875Z",
#                     "description": "PreparingJob",
#                     "endTime": "2021-07-26T03:21:29.166Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:21:29.783Z",
#                     "description": "UpdatingCallCache",
#                     "endTime": "2021-07-26T03:21:31.710Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:21:31.710Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2021-07-26T03:21:32.685Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:21:26.055Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2021-07-26T03:21:28.874Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:21:29.166Z",
#                     "description": "CallCacheReading",
#                     "endTime": "2021-07-26T03:21:29.783Z"
#                   }
#                 ],
#                 "start": "2021-07-26T03:21:26.055Z"
#               }
#             ],
#             "Preprocess.TrimR1": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-TrimR1/TrimR1-stdout.log",
#                 "compressedDockerSize": 210532600,
#                 "shardIndex": -1,
#                 "outputs": {
#                   "outTooShortTooLongFiles": [
#                     "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-TrimR1/cacheCopy/glob-c763acd1bbc2c02eb59e93c44eda4fa9/too-short.R1.fastq.gz"
#                   ],
#                   "outFile": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-TrimR1/cacheCopy/R1.fastq.gz"
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/priority-gwf-core",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "hisplan/cromwell-cutadapt:2.5",
#                   "scriptBucketName": "dp-lab-gwf-core",
#                   "maxRetries": "3",
#                   "cpu": "4",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "16 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": true,
#                   "hit": true,
#                   "result": "Cache Hit: 1ba00944-a780-4e1e-b468-df577bf1013a:Preprocess.TrimR1:-1",
#                   "hashes": {
#                     "output count": "C81E728D9D4C2F636F067F89CC14862C",
#                     "runtime attribute": {
#                       "docker": "E34FD9F412743311B69327E0386E0392",
#                       "continueOnReturnCode": "CFCD208495D565EF66E7DFF9F98764DA",
#                       "failOnStderr": "68934A3E9455FA72420237EB05902327"
#                     },
#                     "output expression": {
#                       "Array(File) outTooShortTooLongFiles": "691E31671F2E94594A9D9001F732FB28",
#                       "File outFile": "CFE5E63191065897E66F20C60D94ED19"
#                     },
#                     "input count": "1679091C5A880FAF6FB5E6087EB1B2DC",
#                     "backend name": "2267EF43AEF6BB551F414FEC2390F68A",
#                     "command template": "240300DFD7E5F66C7B2F9162F6A1C02B",
#                     "input": {
#                       "String dockerImage": "5F34A812D947CB07E57FBD178CA5245B",
#                       "String outFileName": "196C8A728E9EFD6E8DA0435DE17AE63F",
#                       "Int length": "4E732CED3463D06DE0CA9A15B6153677",
#                       "String dockerRegistry": "38A1E69002366B36B0025741498F4427",
#                       "File fastq": "\"ff17b57444d745a12f46800a7b252988-88\"",
#                       "Int numCores": "A87FF679A2F3E71D9181A67B7542122C"
#                     }
#                   },
#                   "effectiveCallCachingMode": "ReadAndWriteCache"
#                 },
#                 "inputs": {
#                   "outFileName": "R1.fastq.gz",
#                   "dockerRegistry": "hisplan",
#                   "dockerImage": "hisplan/cromwell-cutadapt:2.5",
#                   "length": 26,
#                   "fastq": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-MergeFastqR1/ASAPseq_test_HTO_IGO_11671_3_R1.fastq.gz",
#                   "numCores": 4
#                 },
#                 "returnCode": 0,
#                 "backend": "AWSBATCH",
#                 "end": "2021-07-26T03:26:20.676Z",
#                 "stderr": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-TrimR1/TrimR1-stderr.log",
#                 "callRoot": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-TrimR1",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2021-07-26T03:26:18.961Z",
#                     "description": "UpdatingCallCache",
#                     "endTime": "2021-07-26T03:26:19.699Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:25:52.875Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2021-07-26T03:25:52.875Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:25:49.135Z",
#                     "description": "Pending",
#                     "endTime": "2021-07-26T03:25:49.135Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:25:49.135Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2021-07-26T03:25:52.875Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:25:52.889Z",
#                     "description": "CallCacheReading",
#                     "endTime": "2021-07-26T03:26:18.961Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:25:52.875Z",
#                     "description": "PreparingJob",
#                     "endTime": "2021-07-26T03:25:52.889Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:26:19.699Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2021-07-26T03:26:20.676Z"
#                   }
#                 ],
#                 "start": "2021-07-26T03:25:49.135Z"
#               }
#             ],
#             "Preprocess.FastQCR2": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-FastQCR2/FastQCR2-stdout.log",
#                 "compressedDockerSize": 138864024,
#                 "shardIndex": -1,
#                 "outputs": {
#                   "outHtml": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-FastQCR2/cacheCopy/ASAPseq_test_HTO_IGO_11671_3_R2_fastqc.html",
#                   "outZip": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-FastQCR2/cacheCopy/ASAPseq_test_HTO_IGO_11671_3_R2_fastqc.zip"
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/priority-gwf-core",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "hisplan/cromwell-fastqc:0.11.8",
#                   "scriptBucketName": "dp-lab-gwf-core",
#                   "maxRetries": "3",
#                   "cpu": "4",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "16 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": true,
#                   "hit": true,
#                   "result": "Cache Hit: 1ba00944-a780-4e1e-b468-df577bf1013a:Preprocess.FastQCR2:-1",
#                   "hashes": {
#                     "output count": "C81E728D9D4C2F636F067F89CC14862C",
#                     "runtime attribute": {
#                       "docker": "28FE54A5061CF46FE2DCE56626083670",
#                       "continueOnReturnCode": "CFCD208495D565EF66E7DFF9F98764DA",
#                       "failOnStderr": "68934A3E9455FA72420237EB05902327"
#                     },
#                     "output expression": {
#                       "File outHtml": "2404B6B003CD717DE65EF33FE70129CD",
#                       "File outZip": "DCE4AAB29C491950CC5365ED9B724E4F"
#                     },
#                     "input count": "E4DA3B7FBBCE2345D7772B0674A318D5",
#                     "backend name": "2267EF43AEF6BB551F414FEC2390F68A",
#                     "command template": "1C5DC9BE61D9BEED0312157B3ABFD9F6",
#                     "input": {
#                       "String dockerImage": "0D8B829FED29538CAB75CE867B4A2D1D",
#                       "Float inputSize": "3877B6E52A9013723626B763B90DBCC1",
#                       "File fastqFile": "\"86c14bafdf4734641ff0e0c0003ef037-85\"",
#                       "String dockerRegistry": "38A1E69002366B36B0025741498F4427",
#                       "Int numCores": "A87FF679A2F3E71D9181A67B7542122C"
#                     }
#                   },
#                   "effectiveCallCachingMode": "ReadAndWriteCache"
#                 },
#                 "inputs": {
#                   "dockerRegistry": "hisplan",
#                   "fastqFile": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-MergeFastqR2/ASAPseq_test_HTO_IGO_11671_3_R2.fastq.gz",
#                   "dockerImage": "hisplan/cromwell-fastqc:0.11.8",
#                   "inputSize": 0.6584466937929392,
#                   "numCores": 4
#                 },
#                 "returnCode": 0,
#                 "backend": "AWSBATCH",
#                 "end": "2021-07-26T03:25:38.689Z",
#                 "stderr": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-FastQCR2/FastQCR2-stderr.log",
#                 "callRoot": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-FastQCR2",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2021-07-26T03:25:33.845Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2021-07-26T03:25:34.875Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:25:36.088Z",
#                     "description": "UpdatingCallCache",
#                     "endTime": "2021-07-26T03:25:37.702Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:25:37.702Z",
#                     "description": "UpdatingJobStore",
#                     "endTime": "2021-07-26T03:25:38.689Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:25:35.180Z",
#                     "description": "CallCacheReading",
#                     "endTime": "2021-07-26T03:25:36.088Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:25:33.845Z",
#                     "description": "Pending",
#                     "endTime": "2021-07-26T03:25:33.845Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:25:34.875Z",
#                     "description": "PreparingJob",
#                     "endTime": "2021-07-26T03:25:35.180Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:25:34.875Z",
#                     "description": "WaitingForValueStore",
#                     "endTime": "2021-07-26T03:25:34.875Z"
#                   }
#                 ],
#                 "start": "2021-07-26T03:25:33.845Z"
#               }
#             ],
#             "Preprocess.CiteSeqCount": [
#               {
#                 "executionStatus": "Done",
#                 "stdout": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/CiteSeqCount-stdout.log",
#                 "backendStatus": "Succeeded",
#                 "compressedDockerSize": 383353488,
#                 "commandLine": "set -euo pipefail\n\n# preserve one core for the main process just in case\nlet n_threads=4-1\n\nCITE-seq-Count \\\n    -R1 /cromwell_root/dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-TrimR1/cacheCopy/R1.fastq.gz \\\n    -R2 /cromwell_root/dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-TrimR2/cacheCopy/R2.fastq.gz \\\n    --tags /cromwell_root/dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC_HTO/Hashtag_results/tag-list.csv \\\n    -cbf 1 -cbl 16 \\\n    -umif 17 -umil 26 \\\n    --bc_collapsing_dist 1 \\\n    --umi_collapsing_dist 1 \\\n    --max-error 2 \\\n    --start-trim 0  \\\n    --expected_cells 0 \\\n    --whitelist /cromwell_root/dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-WhitelistFrom10x/cacheCopy/results/barcodes.acgt.txt \\\n    --output results \\\n    --unmapped-tags unmapped.csv \\\n    --threads ${n_threads}",
#                 "shardIndex": -1,
#                 "outputs": {
#                   "outUncorrected": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/results/uncorrected_cells/dense_umis.tsv",
#                   "outReadCount": [
#                     "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz",
#                     "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz",
#                     "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz"
#                   ],
#                   "outUnmapped": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/results/unmapped.csv",
#                   "outUmiCount": [
#                     "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#                     "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#                     "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#                   ],
#                   "outReport": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/results/run_report.yaml"
#                 },
#                 "runtimeAttributes": {
#                   "failOnStderr": "false",
#                   "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/priority-gwf-core",
#                   "disks": "local-disk /cromwell_root",
#                   "continueOnReturnCode": "0",
#                   "docker": "hisplan/cromwell-cite-seq-count:1.4.2-develop",
#                   "scriptBucketName": "dp-lab-gwf-core",
#                   "maxRetries": "3",
#                   "cpu": "4",
#                   "cpuMin": "1",
#                   "noAddress": "false",
#                   "zones": "us-east-1a",
#                   "memoryMin": "2 GB",
#                   "memory": "64 GB"
#                 },
#                 "callCaching": {
#                   "allowResultReuse": true,
#                   "hit": false,
#                   "result": "Cache Miss",
#                   "hashes": {
#                     "output count": "E4DA3B7FBBCE2345D7772B0674A318D5",
#                     "runtime attribute": {
#                       "docker": "02476C60BDC056BAE4513242FA832651",
#                       "continueOnReturnCode": "CFCD208495D565EF66E7DFF9F98764DA",
#                       "failOnStderr": "68934A3E9455FA72420237EB05902327"
#                     },
#                     "output expression": {
#                       "Array(File) outReadCount": "66A2E919454C859047C03B1097A25D2B",
#                       "Array(File) outUmiCount": "EE8DC282E797BD234123DC20962CFB2D",
#                       "File outUnmapped": "F6D4E326A0ED0C0A8AE0D4E6830C6B67",
#                       "File outReport": "74AE7E79E6C32474C38A3A0166370C48",
#                       "File outUncorrected": "56D926164EC1442B5E187AE1B1213BF9"
#                     },
#                     "input count": "98F13708210194C475687BE6106A3B84",
#                     "backend name": "2267EF43AEF6BB551F414FEC2390F68A",
#                     "command template": "9972BA2D6AF0EE95F766B9110BC91E37",
#                     "input": {
#                       "String dockerImage": "EE233B6AC5ECC0A28DD9D172CF8EB928",
#                       "Boolean slidingWindowSearch": "68934A3E9455FA72420237EB05902327",
#                       "Int trimPos": "CFCD208495D565EF66E7DFF9F98764DA",
#                       "Int resourceSpec": {
#                         "cpu": "A87FF679A2F3E71D9181A67B7542122C",
#                         "memory": "EA5D2F1C4608232E07D3AA3D998E5135"
#                       },
#                       "File cbWhiteList": "\"d3797336206f4d588dac8ecf5926f2e4\"",
#                       "File tagList": "\"b9b4b7630d7a19fdd666c99a130c334a\"",
#                       "Int umiStartPos": "70EFDF2EC9B086079795C442636B55FB",
#                       "Float inputSize": "5F45F10022224CBD4E507C3FC7CEBECD",
#                       "Int cbEndPos": "C74D97B01EAE257E44AA9D5BADE97BAF",
#                       "Int maxTagError": "C81E728D9D4C2F636F067F89CC14862C",
#                       "Int numExpectedCells": "CFCD208495D565EF66E7DFF9F98764DA",
#                       "Int cbStartPos": "C4CA4238A0B923820DCC509A6F75849B",
#                       "File fastqR2": "\"69d8c8d38e86336b97fee551a2749324\"",
#                       "Int cbCollapsingDistance": "C4CA4238A0B923820DCC509A6F75849B",
#                       "File fastqR1": "\"80d85dbf23a62f628319fe4168f12f33\"",
#                       "Int umiCollapsingDistance": "C4CA4238A0B923820DCC509A6F75849B",
#                       "String dockerRegistry": "38A1E69002366B36B0025741498F4427",
#                       "Int umiEndPos": "4E732CED3463D06DE0CA9A15B6153677",
#                       "String version": "7D0396BBD460CF4B0569B60A315B14A0"
#                     }
#                   },
#                   "effectiveCallCachingMode": "ReadAndWriteCache"
#                 },
#                 "inputs": {
#                   "numExpectedCells": 0,
#                   "slidingWindowSearch": false,
#                   "umiEndPos": 26,
#                   "tagList": "s3://dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC_HTO/Hashtag_results/tag-list.csv",
#                   "cbCollapsingDistance": 1,
#                   "umiStartPos": 17,
#                   "fastqR2": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-TrimR2/cacheCopy/R2.fastq.gz",
#                   "version": "1.4.2-develop",
#                   "dockerRegistry": "hisplan",
#                   "dockerImage": "hisplan/cromwell-cite-seq-count:1.4.2-develop",
#                   "maxTagError": 2,
#                   "fastqR1": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-TrimR1/cacheCopy/R1.fastq.gz",
#                   "umiCollapsingDistance": 1,
#                   "resourceSpec": {
#                     "memory": 64,
#                     "cpu": 4
#                   },
#                   "cbEndPos": 16,
#                   "cbWhiteList": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-WhitelistFrom10x/cacheCopy/results/barcodes.acgt.txt",
#                   "inputSize": 1.1121320994570851,
#                   "cbStartPos": 1,
#                   "trimPos": 0
#                 },
#                 "returnCode": 0,
#                 "jobId": "1406be20-e3d2-4bf4-9e0c-d97b7e2e968d",
#                 "backend": "AWSBATCH",
#                 "end": "2021-07-26T03:40:17.685Z",
#                 "dockerImageUsed": "hisplan/cromwell-cite-seq-count@sha256:b3ef27a844fd455ec03696d8f9f5343e01f9b01e9bdeeb0179af316d63bd9c0d",
#                 "stderr": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/CiteSeqCount-stderr.log",
#                 "callRoot": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount",
#                 "attempt": 1,
#                 "executionEvents": [
#                   {
#                     "startTime": "2021-07-26T03:27:18.896Z",
#                     "description": "RequestingExecutionToken",
#                     "endTime": "2021-07-26T03:27:20.875Z"
#                   },
#                   {
#                     "startTime": "2021-07-26T03:27:22.236Z",
# ...
#           ],
#           "fastQCR1Html": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-FastQCR1/cacheCopy/ASAPseq_test_HTO_IGO_11671_3_R1_fastqc.html"
#         },
#         "inputs": {
#           "lengthR2": 15,
#           "scRnaSeqPlatform": "10x_v3",
#           "CiteSeqCount.version": "1.4.2-develop",
#           "numExpectedCells": 0,
#           "slidingWindowSearch": false,
#           "cellBarcodeWhiteListMethod": "10x",
#           "sampleName": "ASAPseq_test_HTO_IGO_11671_3",
#           "umiEndPos": 26,
#           "tagList": "s3://dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC_HTO/Hashtag_results/tag-list.csv",
#           "uriFastqR2": [
#             "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-ReformatAsapSeqFastq/cacheCopy/ASAPseq_test_HTO_IGO_11671_3_R2.fastq.gz"
#           ],
#           "cbCollapsingDistance": 1,
#           "umiStartPos": 17,
#           "dockerRegistry": "hisplan",
#           "maxTagError": 2,
#           "umiCollapsingDistance": 1,
#           "resourceSpec": {
#             "memory": -1,
#             "cpu": 4
#           },
#           "cbEndPos": 16,
#           "cellBarcodeWhitelistUri": "s3://dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC/CR-results/count/outs/filtered_peak_bc_matrix/barcodes.tsv",
#           "lengthR1": 26,
#           "uriFastqR1": [
#             "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-ReformatAsapSeqFastq/cacheCopy/ASAPseq_test_HTO_IGO_11671_3_R1.fastq.gz"
#           ],
#           "translate10XBarcodes": false,
#           "cbStartPos": 1,
#           "trimPos": 0
#         },
#         "end": "2021-07-26T03:44:51.875Z",
#         "attempt": 1,
#         "executionEvents": [
#           {
#             "startTime": "2021-07-26T03:21:21.926Z",
#             "description": "SubWorkflowPreparingState",
#             "endTime": "2021-07-26T03:21:21.929Z"
#           },
#           {
#             "startTime": "2021-07-26T03:21:21.925Z",
#             "description": "WaitingForValueStore",
#             "endTime": "2021-07-26T03:21:21.926Z"
#           },
#           {
#             "startTime": "2021-07-26T03:21:21.929Z",
#             "description": "SubWorkflowRunningState",
#             "endTime": "2021-07-26T03:44:51.875Z"
#           },
#           {
#             "startTime": "2021-07-26T03:21:21.925Z",
#             "description": "SubWorkflowPendingState",
#             "endTime": "2021-07-26T03:21:21.925Z"
#           }
#         ],
#         "start": "2021-07-26T03:21:21.925Z"
#       }
#     ],
#     "AsapSeq.HtoDemuxKMeans": [
#       {
#         "executionStatus": "Done",
#         "stdout": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-HtoDemuxKMeans/HtoDemuxKMeans-stdout.log",
#         "backendStatus": "Succeeded",
#         "compressedDockerSize": 331772747,
#         "commandLine": "set -euo pipefail\n\nmkdir inputs\n\ncp /cromwell_root/dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz /cromwell_root/dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz /cromwell_root/dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz ./inputs/\n\n# --hto-umi-count-dir:  output directory from CITE-seq-Count\n#                       e.g. .../umi-count\n# --mode: 1=default, 2=noisy methanol, 3=aggressively rescue from doublets\n\npython3 /opt/demux_kmeans.py \\\n    --hto-umi-count-dir ./inputs \\\n    --min-count 0 \\\n    --mode 1",
#         "shardIndex": -1,
#         "outputs": {
#           "outLog": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-HtoDemuxKMeans/demux_kmeans.log",
#           "outStats": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-HtoDemuxKMeans/stats.yml",
#           "outClass": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-HtoDemuxKMeans/classification.tsv.gz"
#         },
#         "runtimeAttributes": {
#           "failOnStderr": "false",
#           "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/priority-gwf-core",
#           "disks": "local-disk /cromwell_root",
#           "continueOnReturnCode": "0",
#           "docker": "hisplan/cromwell-hto-demux-kmeans:0.5.0",
#           "scriptBucketName": "dp-lab-gwf-core",
#           "maxRetries": "3",
#           "cpu": "1",
#           "cpuMin": "1",
#           "noAddress": "false",
#           "zones": "us-east-1a",
#           "memoryMin": "2 GB",
#           "memory": "32 GB"
#         },
#         "callCaching": {
#           "allowResultReuse": true,
#           "hit": false,
#           "result": "Cache Miss",
#           "hashes": {
#             "output count": "ECCBC87E4B5CE2FE28308FD9F2A7BAF3",
#             "runtime attribute": {
#               "docker": "1450F3A8348454304F37EB0CD4F9F74C",
#               "continueOnReturnCode": "CFCD208495D565EF66E7DFF9F98764DA",
#               "failOnStderr": "68934A3E9455FA72420237EB05902327"
#             },
#             "output expression": {
#               "File outClass": "EA901A865B3AC121C9BFCBB6FEDAF09A",
#               "File outLog": "1CEE887B77436F8BA42E12DD267860F7",
#               "File outStats": "33F56C7B084B6CAF4B339B0846FA61B8"
#             },
#             "input count": "45C48CCE2E2D7FBDEA1AFC51C7C6AD26",
#             "backend name": "2267EF43AEF6BB551F414FEC2390F68A",
#             "command template": "EF9AD0939AE065446D2B027DBE43E956",
#             "input": {
#               "String dockerImage": "87CB22A98A308AE4C12B6553B9C224F5",
#               "File umiCountFiles": [
#                 "\"9e81596d350453766979e76b39791389\"",
#                 "\"8dc5f6661f6839afaefd2e79682d9c8b\"",
#                 "\"5ef76c974818b7402be4e446ca695e65\""
#               ],
#               "Float inputSize": "A5AB1F7AB9B071FF4B05E041BE2C9A6F",
#               "Int minCount": "CFCD208495D565EF66E7DFF9F98764DA",
#               "Int mode": "C4CA4238A0B923820DCC509A6F75849B",
#               "String dockerRegistry": "38A1E69002366B36B0025741498F4427",
#               "Int numCores": "C4CA4238A0B923820DCC509A6F75849B"
#             }
#           },
#           "effectiveCallCachingMode": "ReadAndWriteCache"
#         },
#         "inputs": {
#           "umiCountFiles": [
#             "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#             "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#             "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#           ],
#           "dockerRegistry": "hisplan",
#           "dockerImage": "hisplan/cromwell-hto-demux-kmeans:0.5.0",
#           "mode": 1,
#           "inputSize": 0.00029148999601602554,
#           "minCount": 0,
#           "numCores": 1
#         },
#         "returnCode": 0,
#         "jobId": "c3dccfd2-3e16-42c6-87c9-ceaca09c950c",
#         "backend": "AWSBATCH",
#         "end": "2021-07-26T03:53:53.683Z",
#         "dockerImageUsed": "hisplan/cromwell-hto-demux-kmeans@sha256:9887da8376d59c850ca6bce555e0c6af7aed32f3ddfe87102ed3665601641100",
#         "stderr": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-HtoDemuxKMeans/HtoDemuxKMeans-stderr.log",
#         "callRoot": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-HtoDemuxKMeans",
#         "attempt": 1,
#         "executionEvents": [
#           {
#             "startTime": "2021-07-26T03:44:55.383Z",
#             "description": "RunningJob",
#             "endTime": "2021-07-26T03:53:49.746Z"
#           },
#           {
#             "startTime": "2021-07-26T03:44:54.875Z",
#             "description": "PreparingJob",
#             "endTime": "2021-07-26T03:44:55.361Z"
#           },
#           {
#             "startTime": "2021-07-26T03:53:49.746Z",
#             "description": "UpdatingCallCache",
#             "endTime": "2021-07-26T03:53:52.706Z"
#           },
#           {
#             "startTime": "2021-07-26T03:44:54.875Z",
#             "description": "WaitingForValueStore",
#             "endTime": "2021-07-26T03:44:54.875Z"
#           },
#           {
#             "startTime": "2021-07-26T03:44:53.895Z",
#             "description": "Pending",
#             "endTime": "2021-07-26T03:44:53.895Z"
#           },
#           {
#             "startTime": "2021-07-26T03:53:52.706Z",
#             "description": "UpdatingJobStore",
#             "endTime": "2021-07-26T03:53:53.683Z"
#           },
#           {
#             "startTime": "2021-07-26T03:44:55.361Z",
#             "description": "CallCacheReading",
#             "endTime": "2021-07-26T03:44:55.383Z"
#           },
#           {
#             "startTime": "2021-07-26T03:44:53.895Z",
#             "description": "RequestingExecutionToken",
#             "endTime": "2021-07-26T03:44:54.875Z"
#           }
#         ],
#         "start": "2021-07-26T03:44:53.895Z"
#       }
#     ]
#   },
#   "outputs": {
#     "AsapSeq.logHtoDemux": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-HtoDemuxKMeans/demux_kmeans.log",
#     "AsapSeq.adataRaw": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-ToAnnData/ASAPseq_test_HTO_IGO_11671_3.h5ad",
#     "AsapSeq.umiCountMatrix": [
#       "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#       "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#       "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#     ],
#     "AsapSeq.readCountMatrix": [
#       "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz",
#       "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz",
#       "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz"
#     ],
#     "AsapSeq.logHtoDemux_Suppl1": null,
#     "AsapSeq.reformattedR1": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-ReformatAsapSeqFastq/cacheCopy/ASAPseq_test_HTO_IGO_11671_3_R1.fastq.gz",
#     "AsapSeq.adataFinal": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-UpdateAnnData/ASAPseq_test_HTO_IGO_11671_3.h5ad",
#     "AsapSeq.countReport": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/results/run_report.yaml",
#     "AsapSeq.htoClassification_Suppl3": null,
#     "AsapSeq.reformattedR2": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-ReformatAsapSeqFastq/cacheCopy/ASAPseq_test_HTO_IGO_11671_3_R2.fastq.gz",
#     "AsapSeq.htoClassification_Suppl2": null,
#     "AsapSeq.statsHtoDemux_Suppl1": null,
#     "AsapSeq.fastQCR1Html": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-FastQCR1/cacheCopy/ASAPseq_test_HTO_IGO_11671_3_R1_fastqc.html",
#     "AsapSeq.htoClassification_Suppl1": null,
#     "AsapSeq.htoClassification": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-HtoDemuxKMeans/classification.tsv.gz",
#     "AsapSeq.statsHtoDemux": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-HtoDemuxKMeans/stats.yml",
#     "AsapSeq.fastQCR2Html": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-FastQCR2/cacheCopy/ASAPseq_test_HTO_IGO_11671_3_R2_fastqc.html"
#   },
#   "actualWorkflowLanguage": "WDL",
#   "id": "dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6",
#   "inputs": {
#     "lengthR2": 15,
#     "scRnaSeqPlatform": "10x_v3",
#     "numExpectedCells": 0,
#     "demuxMode": 1,
#     "slidingWindowSearch": false,
#     "cellBarcodeWhiteListMethod": "10x",
#     "fastqR3": [
#       "s3://dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC_HTO/FASTQ/ASAPseq_test_HTO_IGO_11671_3_S3_L001_R3_001.fastq.gz",
#       "s3://dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC_HTO/FASTQ/ASAPseq_test_HTO_IGO_11671_3_S3_L002_R3_001.fastq.gz"
#     ],
#     "sampleName": "ASAPseq_test_HTO_IGO_11671_3",
#     "conjugation": "TotalSeqA",
#     "hashTagList": "s3://dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC_HTO/Hashtag_results/tag-list.csv",
#     "noReverseComplementR2": false,
#     "umiEndPos": 26,
#     "cbCollapsingDistance": 1,
#     "umiStartPos": 17,
#     "fastqR2": [
#       "s3://dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC_HTO/FASTQ/ASAPseq_test_HTO_IGO_11671_3_S3_L001_R2_001.fastq.gz",
#       "s3://dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC_HTO/FASTQ/ASAPseq_test_HTO_IGO_11671_3_S3_L002_R2_001.fastq.gz"
#     ],
#     "dockerRegistry": "hisplan",
#     "maxTagError": 2,
#     "fastqR1": [
#       "s3://dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC_HTO/FASTQ/ASAPseq_test_HTO_IGO_11671_3_S3_L001_R1_001.fastq.gz",
#       "s3://dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC_HTO/FASTQ/ASAPseq_test_HTO_IGO_11671_3_S3_L002_R1_001.fastq.gz"
#     ],
#     "runSeuratDemux": false,
#     "umiCollapsingDistance": 1,
#     "resourceSpec": {
#       "memory": -1,
#       "cpu": 4
#     },
#     "cbEndPos": 16,
#     "cellBarcodeWhitelistUri": "s3://dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC/CR-results/count/outs/filtered_peak_bc_matrix/barcodes.tsv",
#     "lengthR1": 26,
#     "translate10XBarcodes": false,
#     "cbStartPos": 1,
#     "trimPos": 0,
#     "minCount": 0
#   },
#   "labels": {
#     "project": "TechDev",
#     "cromwell-workflow-id": "cromwell-dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6",
#     "transfer": "failed",
#     "comment": "ASAP-seq TSA",
#     "flag": "follow-up",
#     "sample": "asapseq-test",
#     "pipelineType": "ASAP-seq",
#     "owner": "chunj",
#     "destination": "s3://dp-lab-test/sharp/asap-seq/TSA/"
#   },
#   "submission": "2021-07-26T03:20:41.133Z",
#   "status": "Succeeded",
#   "end": "2021-07-26T03:55:21.758Z",
#   "start": "2021-07-26T03:20:46.992Z"
# }

# %% [markdown]
# ## Get Sample Name

# %%
sample_name = metadata["labels"]["sample"]
sample_name
# Out:
# 'asapseq-test'

# %% [markdown]
# ## Get Counts

# %%
def download(sample_name, workflow_id, subfolder, items):
    
    if skip_download:
        return
    
    if not isinstance(items, list):
        items = [items]
        
    path_output = f"{path_base_data}/{sample_name}/{workflow_id}/{subfolder}"
    
    os.makedirs(path_output, exist_ok=True)
        
    for item in items:
        cmd_download = f"aws s3 cp {item} {path_output}"
        print(cmd_download)
        os.system(cmd_download)

# %%
meta_cite_seq_count = metadata["calls"][f"{workflow_name}.Preprocess"][0]["subWorkflowMetadata"]["calls"]["Preprocess.CiteSeqCount"][0]

# %%
print(json.dumps(meta_cite_seq_count, indent=2))
# Out:
# {
#   "executionStatus": "Done",
#   "stdout": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/CiteSeqCount-stdout.log",
#   "backendStatus": "Succeeded",
#   "compressedDockerSize": 383353488,
#   "commandLine": "set -euo pipefail\n\n# preserve one core for the main process just in case\nlet n_threads=4-1\n\nCITE-seq-Count \\\n    -R1 /cromwell_root/dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-TrimR1/cacheCopy/R1.fastq.gz \\\n    -R2 /cromwell_root/dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-TrimR2/cacheCopy/R2.fastq.gz \\\n    --tags /cromwell_root/dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC_HTO/Hashtag_results/tag-list.csv \\\n    -cbf 1 -cbl 16 \\\n    -umif 17 -umil 26 \\\n    --bc_collapsing_dist 1 \\\n    --umi_collapsing_dist 1 \\\n    --max-error 2 \\\n    --start-trim 0  \\\n    --expected_cells 0 \\\n    --whitelist /cromwell_root/dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-WhitelistFrom10x/cacheCopy/results/barcodes.acgt.txt \\\n    --output results \\\n    --unmapped-tags unmapped.csv \\\n    --threads ${n_threads}",
#   "shardIndex": -1,
#   "outputs": {
#     "outUncorrected": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/results/uncorrected_cells/dense_umis.tsv",
#     "outReadCount": [
#       "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz",
#       "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz",
#       "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz"
#     ],
#     "outUnmapped": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/results/unmapped.csv",
#     "outUmiCount": [
#       "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz",
#       "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz",
#       "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz"
#     ],
#     "outReport": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/results/run_report.yaml"
#   },
#   "runtimeAttributes": {
#     "failOnStderr": "false",
#     "queueArn": "arn:aws:batch:us-east-1:583643567512:job-queue/priority-gwf-core",
#     "disks": "local-disk /cromwell_root",
#     "continueOnReturnCode": "0",
#     "docker": "hisplan/cromwell-cite-seq-count:1.4.2-develop",
#     "scriptBucketName": "dp-lab-gwf-core",
#     "maxRetries": "3",
#     "cpu": "4",
#     "cpuMin": "1",
#     "noAddress": "false",
#     "zones": "us-east-1a",
#     "memoryMin": "2 GB",
#     "memory": "64 GB"
#   },
#   "callCaching": {
#     "allowResultReuse": true,
#     "hit": false,
#     "result": "Cache Miss",
#     "hashes": {
#       "output count": "E4DA3B7FBBCE2345D7772B0674A318D5",
#       "runtime attribute": {
#         "docker": "02476C60BDC056BAE4513242FA832651",
#         "continueOnReturnCode": "CFCD208495D565EF66E7DFF9F98764DA",
#         "failOnStderr": "68934A3E9455FA72420237EB05902327"
#       },
#       "output expression": {
#         "Array(File) outReadCount": "66A2E919454C859047C03B1097A25D2B",
#         "Array(File) outUmiCount": "EE8DC282E797BD234123DC20962CFB2D",
#         "File outUnmapped": "F6D4E326A0ED0C0A8AE0D4E6830C6B67",
#         "File outReport": "74AE7E79E6C32474C38A3A0166370C48",
#         "File outUncorrected": "56D926164EC1442B5E187AE1B1213BF9"
#       },
#       "input count": "98F13708210194C475687BE6106A3B84",
#       "backend name": "2267EF43AEF6BB551F414FEC2390F68A",
#       "command template": "9972BA2D6AF0EE95F766B9110BC91E37",
#       "input": {
#         "String dockerImage": "EE233B6AC5ECC0A28DD9D172CF8EB928",
#         "Boolean slidingWindowSearch": "68934A3E9455FA72420237EB05902327",
#         "Int trimPos": "CFCD208495D565EF66E7DFF9F98764DA",
#         "Int resourceSpec": {
#           "cpu": "A87FF679A2F3E71D9181A67B7542122C",
#           "memory": "EA5D2F1C4608232E07D3AA3D998E5135"
#         },
#         "File cbWhiteList": "\"d3797336206f4d588dac8ecf5926f2e4\"",
#         "File tagList": "\"b9b4b7630d7a19fdd666c99a130c334a\"",
#         "Int umiStartPos": "70EFDF2EC9B086079795C442636B55FB",
#         "Float inputSize": "5F45F10022224CBD4E507C3FC7CEBECD",
#         "Int cbEndPos": "C74D97B01EAE257E44AA9D5BADE97BAF",
#         "Int maxTagError": "C81E728D9D4C2F636F067F89CC14862C",
#         "Int numExpectedCells": "CFCD208495D565EF66E7DFF9F98764DA",
#         "Int cbStartPos": "C4CA4238A0B923820DCC509A6F75849B",
#         "File fastqR2": "\"69d8c8d38e86336b97fee551a2749324\"",
#         "Int cbCollapsingDistance": "C4CA4238A0B923820DCC509A6F75849B",
#         "File fastqR1": "\"80d85dbf23a62f628319fe4168f12f33\"",
#         "Int umiCollapsingDistance": "C4CA4238A0B923820DCC509A6F75849B",
#         "String dockerRegistry": "38A1E69002366B36B0025741498F4427",
#         "Int umiEndPos": "4E732CED3463D06DE0CA9A15B6153677",
#         "String version": "7D0396BBD460CF4B0569B60A315B14A0"
#       }
#     },
#     "effectiveCallCachingMode": "ReadAndWriteCache"
#   },
#   "inputs": {
#     "numExpectedCells": 0,
#     "slidingWindowSearch": false,
#     "umiEndPos": 26,
#     "tagList": "s3://dp-lab-data/collaborators/sunj/AsapseqTest/ASAPseq_test_ATAC_HTO/Hashtag_results/tag-list.csv",
#     "cbCollapsingDistance": 1,
#     "umiStartPos": 17,
#     "fastqR2": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-TrimR2/cacheCopy/R2.fastq.gz",
#     "version": "1.4.2-develop",
#     "dockerRegistry": "hisplan",
#     "dockerImage": "hisplan/cromwell-cite-seq-count:1.4.2-develop",
#     "maxTagError": 2,
#     "fastqR1": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-TrimR1/cacheCopy/R1.fastq.gz",
#     "umiCollapsingDistance": 1,
#     "resourceSpec": {
#       "memory": 64,
#       "cpu": 4
#     },
#     "cbEndPos": 16,
#     "cbWhiteList": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-WhitelistFrom10x/cacheCopy/results/barcodes.acgt.txt",
#     "inputSize": 1.1121320994570851,
#     "cbStartPos": 1,
#     "trimPos": 0
#   },
#   "returnCode": 0,
#   "jobId": "1406be20-e3d2-4bf4-9e0c-d97b7e2e968d",
#   "backend": "AWSBATCH",
#   "end": "2021-07-26T03:40:17.685Z",
#   "dockerImageUsed": "hisplan/cromwell-cite-seq-count@sha256:b3ef27a844fd455ec03696d8f9f5343e01f9b01e9bdeeb0179af316d63bd9c0d",
#   "stderr": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/CiteSeqCount-stderr.log",
#   "callRoot": "s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount",
#   "attempt": 1,
#   "executionEvents": [
#     {
#       "startTime": "2021-07-26T03:27:18.896Z",
#       "description": "RequestingExecutionToken",
#       "endTime": "2021-07-26T03:27:20.875Z"
#     },
#     {
#       "startTime": "2021-07-26T03:27:22.236Z",
#       "description": "RunningJob",
#       "endTime": "2021-07-26T03:40:14.480Z"
#     },
#     {
#       "startTime": "2021-07-26T03:27:18.896Z",
#       "description": "Pending",
#       "endTime": "2021-07-26T03:27:18.896Z"
#     },
#     {
#       "startTime": "2021-07-26T03:27:20.875Z",
#       "description": "WaitingForValueStore",
#       "endTime": "2021-07-26T03:27:20.875Z"
#     },
#     {
#       "startTime": "2021-07-26T03:40:16.706Z",
#       "description": "UpdatingJobStore",
#       "endTime": "2021-07-26T03:40:17.685Z"
#     },
#     {
#       "startTime": "2021-07-26T03:27:20.875Z",
#       "description": "PreparingJob",
#       "endTime": "2021-07-26T03:27:21.612Z"
#     },
#     {
#       "startTime": "2021-07-26T03:40:14.480Z",
#       "description": "UpdatingCallCache",
#       "endTime": "2021-07-26T03:40:16.706Z"
#     },
#     {
#       "startTime": "2021-07-26T03:27:21.612Z",
#       "description": "CallCacheReading",
#       "endTime": "2021-07-26T03:27:22.236Z"
#     }
#   ],
#   "start": "2021-07-26T03:27:18.895Z"
# }

# %% [markdown]
# ### Download Read Count

# %%
download(
    sample_name, workflow_id,
    "reads",
    meta_cite_seq_count["outputs"]["outReadCount"]
)
# Out:
# aws s3 cp s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/barcodes.tsv.gz ./asapseq/asapseq-test/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/reads
# aws s3 cp s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/features.tsv.gz ./asapseq/asapseq-test/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/reads
# aws s3 cp s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-8e7f6a2dd9fb1323e5ebc5c1c063f6df/matrix.mtx.gz ./asapseq/asapseq-test/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/reads

# %% [markdown]
# ### Download UMI Count

# %%
download(
    sample_name, workflow_id,
    "umis",
    meta_cite_seq_count["outputs"]["outUmiCount"]
)
# Out:
# aws s3 cp s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/barcodes.tsv.gz ./asapseq/asapseq-test/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/umis
# aws s3 cp s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/features.tsv.gz ./asapseq/asapseq-test/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/umis
# aws s3 cp s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/glob-5b2373ebac80816456a7726e786fc4d4/matrix.mtx.gz ./asapseq/asapseq-test/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/umis

# %% [markdown]
# ## Download Report

# %%
download(
    sample_name, workflow_id,
    "report",
    meta_cite_seq_count["outputs"]["outReport"]
)
# Out:
# aws s3 cp s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-Preprocess/Preprocess/ce493bee-ed3a-4a8c-8753-d0acfe03f553/call-CiteSeqCount/results/run_report.yaml ./asapseq/asapseq-test/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/report

# %% [markdown]
# ## Get Demux Classification

# %%
# skip if CITE-seq because it does not require demultiplexing
if workflow_name != "CiteSeq":
    meta_demux = metadata["calls"][f"{workflow_name}.HtoDemuxKMeans"][0]
    download(
        sample_name, workflow_id,
        "",
        meta_demux["outputs"]["outClass"]
    )
# Out:
# aws s3 cp s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-HtoDemuxKMeans/classification.tsv.gz ./asapseq/asapseq-test/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/

# %% [markdown]
# ## Download AnnData

# %%
if workflow_name != "CiteSeq":
    attr_adata = f"{workflow_name}.adataFinal"
else:
    # because CITE-seq does not require demultiplexing,
    # final output is a bit different
    attr_adata = f"{workflow_name}.adata"    

download(
    sample_name=sample_name, workflow_id=workflow_id, subfolder="", items=metadata["outputs"][attr_adata]
)
# Out:
# aws s3 cp s3://dp-lab-gwf-core/cromwell-execution/AsapSeq/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/call-UpdateAnnData/ASAPseq_test_HTO_IGO_11671_3.h5ad ./asapseq/asapseq-test/dbc6304d-26bf-42a1-b3bb-4fa65ffaf7a6/

# %% [markdown]
# ## Output Sample Name

# %%
# 1. DO NOT DELETE
# 2. MUST BE THE FINAL LINE
print(sample_name)
# Out:
# asapseq-test
